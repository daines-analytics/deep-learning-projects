# %% [markdown]
# # Multi-Class Deep Learning Model for CIFAR-10 Object Recognition Using Keras Take 7
# ### David Lowe
# ### January 13, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The CIFAR-10 dataset is a multi-class classification situation where we are trying to predict one of several (more than two) possible outcomes.
#
# INTRODUCTION: The CIFAR-10 is a labeled subset of the 80 million tiny images dataset. They were collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton. The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes, with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10,000 images. The test batch contains exactly 1,000 randomly selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5,000 images from each class.
#
# In iteration Take1, we constructed a simple VGG convolutional model with 1 VGG block to classify the images. This model serves as the baseline for the future iterations of modeling.
#
# In iteration Take2, we constructed a few more VGG convolutional models with 2 and 3 VGG blocks to classify the images. The additional models enabled us to choose a final baseline model before applying other performance-enhancing techniques.
#
# In iteration Take3, we tuned the VGG-3 model with various hyperparameters and selected the best model.
#
# In iteration Take4, we added some dropout layers as a regularization technique to reduce over-fitting.
#
# In iteration Take5, we applied data augmentation to the dataset as a regularization technique to reduce over-fitting.
#
# In iteration Take6, we applied both dropout layers and data augmentation to the dataset for reducing over-fitting.
#
# In this iteration, we will apply dropout layers, data augmentation, and batch normalization to the dataset for reducing over-fitting.
#
# ANALYSIS: In iteration Take1, the performance of the Take1 model with the default parameters achieved an accuracy score of 66.39% on the validation dataset after training for 50 epochs. After tuning the hyperparameters, the Take1 model with the best hyperparameters processed the training dataset with an accuracy of 100.00%. The same model, however, processed the test dataset with an accuracy of only 67.01%. We will need to explore other modeling approaches to make a better model that reduces over-fitting.
#
# In iteration Take2, the performance of the VGG-1 model with the default parameters achieved an accuracy score of 66.69% on the validation dataset after training for 50 epochs. The VGG-2 model achieved an accuracy score of 71.35% on the validation dataset after training for 50 epochs. The VGG-3 model achieved an accuracy score of 73.81% on the validation dataset after training for 50 epochs. The additional VGG blocks helped the model, but we still need to explore other modeling approaches to make a better model that reduces over-fitting.
#
# In iteration Take3, the performance of the VGG-3 Take3 model with the default parameters achieved a maximum accuracy score of 73.43% on the validation dataset after training for 50 epochs. After tuning the hyperparameters, the Take1 model with the best hyperparameters processed the training dataset with an accuracy of 98.09%. The same model, however, processed the test dataset with an accuracy of only 73.44%. Even with VGG-3 and hyperparameter tuning, we still have an over-fitting problem with the model.
#
# In iteration Take4, the performance of the Take4 model with the default parameters achieved a maximum accuracy score of 76.96% on the validation dataset after training for 50 epochs. We can see from the graph that the accuracy and loss curves for the training and validation sets were moving in the same direction and converged well. After increasing the number of epochs, the Take4 model processed the training dataset with an accuracy of 82.22% after 100 epochs. The same model processed the test dataset with an accuracy of 82.35%. This iteration indicated to us that having dropout layers can be a good tactic to improve the model's predictive performance.
#
# In iteration Take5, the performance of the Take5 model with the default parameters achieved a maximum accuracy score of 81.41% on the validation dataset after training for 50 epochs. We can see from the graph that the accuracy and loss curves for the training and validation sets were moving in the same direction and converged well. After increasing the number of epochs, the Take5 model processed the training dataset with an accuracy of 91.60% after 100 epochs. The same model processed the test dataset with an accuracy of 84.43%. This iteration indicated to us that applying data augmentation can be a good tactic to improve the model's predictive performance.
#
# In iteration Take6, the performance of the Take6 model with the default parameters achieved a maximum accuracy score of 84.12% on the validation dataset after training for 100 epochs. We can see from the graph that the accuracy and loss curves for the training and validation sets were moving in the same direction and converged well. After increasing the number of epochs, the Take6 model processed the training dataset with an accuracy of 87.21% after 200 epochs. The same model processed the test dataset with an accuracy of 85.79%. This iteration indicated to us that applying dropout layers and data augmentation together can be a good tactic to improve the model's predictive performance.
#
# In this iteration, the performance of the Take7 model with the default parameters achieved a maximum accuracy score of 87.15% on the validation dataset after training for 200 epochs. We can see from the graph that the accuracy and loss curves for the training and validation sets were moving in the same direction and converged well. After increasing the number of epochs, the Take7 model processed the training dataset with an accuracy of 90.15% after 400 epochs. The same model processed the test dataset with an accuracy of 89.02%. This iteration indicated to us that applying dropout layers, data augmentation, and batch normalization together can be a good tactic to improve the model's predictive performance.
#
# CONCLUSION: For this dataset, the model built using Keras and TensorFlow achieved a satisfactory result and should be considered for future modeling activities.
#
# Dataset Used: The CIFAR-10 Dataset
#
# Dataset ML Model: Multi-class classification with numerical attributes
#
# Dataset Reference: https://www.cs.toronto.edu/~kriz/cifar.html
#
# One potential source of performance benchmarks: https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
#
# Any deep-learning modeling project genrally can be broken down into about six major tasks:
#
# 0. Prepare Environment
# 1. Load Data
# 2. Define Model
# 3. Fit and Evaluate Model
# 4. Optimize Model
# 5. Finalize Model

# %% [markdown]
# # Section 0. Prepare Environment

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
# Load libraries and packages
import random
random.seed(seedNum)
import numpy as np
np.random.seed(seedNum)
import tensorflow as tf
tf.random.set_seed(seedNum)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# import keras as K
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasClassifier
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import matplotlib.pyplot as plt
from datetime import datetime
from email.message import EmailMessage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose flag to print detailed messages for debugging (setting to True will activate)
# verbose = True
# tf.debugging.set_log_device_placement(verbose)

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the number of folds for cross validation
n_folds = 5

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.25

# Set various default Keras modeling parameters
default_loss = 'categorical_crossentropy'
default_metrics = ['accuracy']
default_kernel_init = tf.initializers.he_uniform(seed=seedNum)
default_optimizer = tf.optimizers.SGD(learning_rate=0.001, momentum=0.9)
default_epoch = 400
default_batch = 64
# Out:
# Num GPUs Available:  1

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Keras Multi-Class Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
# Reset the random number generators
def reset_random(seedNum):
    random.seed(seedNum)
    np.random.seed(seedNum)
    tf.random.set_seed(seedNum)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 1. Load Data

# %%
if (notifyStatus): email_notify("Phase 1 Load Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## 1.a) Load Dataset

# %%
cifar10 = tf.keras.datasets.cifar10
(X_train, y_train),(X_test, y_test) = cifar10.load_data()

# Summarize loaded datasets
print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 1)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
# Plot first few images
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# ## 1.b) Data Cleaning

# %%
# Not required for this iteration of the project

# %% [markdown]
# ## 1.c) Feature Scaling and Pre-processing

# %%
# Reshape the input data as [samples][width][height][channels]
# X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
# X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# Apply feature scaling and transformation
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## 1.d) Splitting Data into Training and Test Sets

# %%
# Encode class values as integers and perform one-hot-encoding
encoder = preprocessing.LabelEncoder()
encoder.fit(y_train)
train_transformed = encoder.transform(y_train)
test_transformed = encoder.transform(y_test)
y_train = tf.keras.utils.to_categorical(train_transformed)
y_test = tf.keras.utils.to_categorical(test_transformed)

print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))

num_pixels = X_train.shape[1] * X_train.shape[2]
print('Number of pixels:', num_pixels)
num_classes = y_train.shape[1]
print('Number of classes:', num_classes)
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 10)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 10)
# Number of pixels: 1024
# Number of classes: 10
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
if (notifyStatus): email_notify("Phase 1 Load Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 2. Define Model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the Keras model for baseline measurement
def create_default_model():
    default_model = Sequential()
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same', input_shape=(32, 32, 3)))
    default_model.add(BatchNormalization())
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(BatchNormalization())
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Dropout(0.2))
    default_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(BatchNormalization())
    default_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(BatchNormalization())
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Dropout(0.3))
    default_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(BatchNormalization())
    default_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(BatchNormalization())
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Dropout(0.4))
    default_model.add(Flatten())
    default_model.add(Dense(128, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(BatchNormalization())
    default_model.add(Dropout(0.5))
    default_model.add(Dense(num_classes, activation='softmax', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 3. Fit and Evaluate Model

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Initialize the baseline model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model = create_default_model()
# Create data generator for augmentation
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
X_train_aug = datagen.flow(X_train, y_train, batch_size=64)
steps = int(X_train.shape[0] / 64)
baseline_hist = baseline_model.fit(X_train_aug, steps_per_epoch=steps, epochs=default_epoch, validation_data=(X_test, y_test), verbose=1)
print('Total time for creating the baseline model:', (datetime.now() - startTimeModule))
# Out:
# Train for 781 steps, validate on 10000 samples
# Epoch 1/400
# 781/781 [==============================] - 43s 55ms/step - loss: 2.1458 - accuracy: 0.2959 - val_loss: 1.5305 - val_accuracy: 0.4433
# Epoch 2/400
# 781/781 [==============================] - 40s 51ms/step - loss: 1.6308 - accuracy: 0.4061 - val_loss: 1.4740 - val_accuracy: 0.4584
# Epoch 3/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.4964 - accuracy: 0.4515 - val_loss: 1.5477 - val_accuracy: 0.4291
# Epoch 4/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.4115 - accuracy: 0.4852 - val_loss: 1.4528 - val_accuracy: 0.4714
# Epoch 5/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.3346 - accuracy: 0.5147 - val_loss: 1.4268 - val_accuracy: 0.4842
# Epoch 6/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.2870 - accuracy: 0.5336 - val_loss: 1.5348 - val_accuracy: 0.4510
# Epoch 7/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.2379 - accuracy: 0.5505 - val_loss: 1.3590 - val_accuracy: 0.5157
# Epoch 8/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.2011 - accuracy: 0.5637 - val_loss: 1.2877 - val_accuracy: 0.5342
# Epoch 9/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.1718 - accuracy: 0.5801 - val_loss: 1.1699 - val_accuracy: 0.5735
# Epoch 10/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.1335 - accuracy: 0.5927 - val_loss: 1.0991 - val_accuracy: 0.6011
# Epoch 11/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.1074 - accuracy: 0.6025 - val_loss: 1.1573 - val_accuracy: 0.5884
# Epoch 12/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.0804 - accuracy: 0.6153 - val_loss: 1.1508 - val_accuracy: 0.5889
# Epoch 13/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.0570 - accuracy: 0.6216 - val_loss: 1.0938 - val_accuracy: 0.6064
# Epoch 14/400
# 781/781 [==============================] - 40s 51ms/step - loss: 1.0400 - accuracy: 0.6305 - val_loss: 1.1602 - val_accuracy: 0.5893
# Epoch 15/400
# 781/781 [==============================] - 39s 50ms/step - loss: 1.0160 - accuracy: 0.6374 - val_loss: 1.0604 - val_accuracy: 0.6191
# Epoch 16/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9941 - accuracy: 0.6464 - val_loss: 1.0374 - val_accuracy: 0.6337
# Epoch 17/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9820 - accuracy: 0.6504 - val_loss: 0.9304 - val_accuracy: 0.6677
# Epoch 18/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9614 - accuracy: 0.6605 - val_loss: 0.9678 - val_accuracy: 0.6576
# Epoch 19/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9476 - accuracy: 0.6632 - val_loss: 0.9861 - val_accuracy: 0.6507
# Epoch 20/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9327 - accuracy: 0.6712 - val_loss: 0.8512 - val_accuracy: 0.6981
# Epoch 21/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9160 - accuracy: 0.6769 - val_loss: 0.8837 - val_accuracy: 0.6884
# Epoch 22/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.9111 - accuracy: 0.6793 - val_loss: 0.9541 - val_accuracy: 0.6649
# Epoch 23/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.8924 - accuracy: 0.6870 - val_loss: 0.8311 - val_accuracy: 0.7008
# Epoch 24/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.8833 - accuracy: 0.6889 - val_loss: 0.7849 - val_accuracy: 0.7242
# Epoch 25/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.8751 - accuracy: 0.6913 - val_loss: 0.8063 - val_accuracy: 0.7141
# Epoch 26/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.8588 - accuracy: 0.6986 - val_loss: 0.8024 - val_accuracy: 0.7163
# Epoch 27/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.8522 - accuracy: 0.7006 - val_loss: 0.9584 - val_accuracy: 0.6651
# Epoch 28/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8420 - accuracy: 0.7026 - val_loss: 0.7958 - val_accuracy: 0.7203
# Epoch 29/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8386 - accuracy: 0.7063 - val_loss: 0.7862 - val_accuracy: 0.7214
# Epoch 30/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8286 - accuracy: 0.7096 - val_loss: 0.8525 - val_accuracy: 0.6982
# Epoch 31/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.8205 - accuracy: 0.7144 - val_loss: 0.8132 - val_accuracy: 0.7121
# Epoch 32/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8148 - accuracy: 0.7153 - val_loss: 0.7730 - val_accuracy: 0.7252
# Epoch 33/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.7998 - accuracy: 0.7182 - val_loss: 0.7841 - val_accuracy: 0.7245
# Epoch 34/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.8031 - accuracy: 0.7196 - val_loss: 0.8697 - val_accuracy: 0.7005
# Epoch 35/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.7876 - accuracy: 0.7264 - val_loss: 0.7798 - val_accuracy: 0.7262
# Epoch 36/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7853 - accuracy: 0.7251 - val_loss: 0.8830 - val_accuracy: 0.6916
# Epoch 37/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7726 - accuracy: 0.7304 - val_loss: 0.7228 - val_accuracy: 0.7482
# Epoch 38/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.7699 - accuracy: 0.7303 - val_loss: 0.6949 - val_accuracy: 0.7578
# Epoch 39/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7635 - accuracy: 0.7353 - val_loss: 0.8723 - val_accuracy: 0.6989
# Epoch 40/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7576 - accuracy: 0.7366 - val_loss: 0.7486 - val_accuracy: 0.7397
# Epoch 41/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7563 - accuracy: 0.7371 - val_loss: 0.7210 - val_accuracy: 0.7479
# Epoch 42/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.7425 - accuracy: 0.7411 - val_loss: 0.7191 - val_accuracy: 0.7467
# Epoch 43/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7371 - accuracy: 0.7432 - val_loss: 0.6906 - val_accuracy: 0.7543
# Epoch 44/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7341 - accuracy: 0.7439 - val_loss: 0.6822 - val_accuracy: 0.7613
# Epoch 45/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.7275 - accuracy: 0.7472 - val_loss: 0.6588 - val_accuracy: 0.7705
# Epoch 46/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7292 - accuracy: 0.7468 - val_loss: 0.7785 - val_accuracy: 0.7311
# Epoch 47/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7218 - accuracy: 0.7489 - val_loss: 0.6544 - val_accuracy: 0.7699
# Epoch 48/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7155 - accuracy: 0.7511 - val_loss: 0.6727 - val_accuracy: 0.7647
# Epoch 49/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7059 - accuracy: 0.7547 - val_loss: 0.7613 - val_accuracy: 0.7366
# Epoch 50/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.7027 - accuracy: 0.7537 - val_loss: 0.6532 - val_accuracy: 0.7717
# Epoch 51/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6970 - accuracy: 0.7574 - val_loss: 0.6414 - val_accuracy: 0.7754
# Epoch 52/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6964 - accuracy: 0.7563 - val_loss: 0.6313 - val_accuracy: 0.7783
# Epoch 53/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6912 - accuracy: 0.7619 - val_loss: 0.6673 - val_accuracy: 0.7675
# Epoch 54/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6867 - accuracy: 0.7622 - val_loss: 0.7003 - val_accuracy: 0.7547
# Epoch 55/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6805 - accuracy: 0.7633 - val_loss: 0.6250 - val_accuracy: 0.7844
# Epoch 56/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.6773 - accuracy: 0.7665 - val_loss: 0.6298 - val_accuracy: 0.7819
# Epoch 57/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6740 - accuracy: 0.7669 - val_loss: 0.6920 - val_accuracy: 0.7626
# Epoch 58/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6687 - accuracy: 0.7670 - val_loss: 0.6673 - val_accuracy: 0.7669
# Epoch 59/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6683 - accuracy: 0.7695 - val_loss: 0.5935 - val_accuracy: 0.7968
# Epoch 60/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.6585 - accuracy: 0.7717 - val_loss: 0.6082 - val_accuracy: 0.7873
# Epoch 61/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6499 - accuracy: 0.7758 - val_loss: 0.5753 - val_accuracy: 0.8035
# Epoch 62/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6576 - accuracy: 0.7727 - val_loss: 0.6562 - val_accuracy: 0.7747
# Epoch 63/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6470 - accuracy: 0.7761 - val_loss: 0.6221 - val_accuracy: 0.7868
# Epoch 64/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6453 - accuracy: 0.7781 - val_loss: 0.6406 - val_accuracy: 0.7837
# Epoch 65/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6397 - accuracy: 0.7800 - val_loss: 0.6114 - val_accuracy: 0.7926
# Epoch 66/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6321 - accuracy: 0.7823 - val_loss: 0.6731 - val_accuracy: 0.7741
# Epoch 67/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6302 - accuracy: 0.7816 - val_loss: 0.6233 - val_accuracy: 0.7861
# Epoch 68/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.6332 - accuracy: 0.7806 - val_loss: 0.6392 - val_accuracy: 0.7806
# Epoch 69/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6254 - accuracy: 0.7839 - val_loss: 0.5807 - val_accuracy: 0.8020
# Epoch 70/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6266 - accuracy: 0.7839 - val_loss: 0.5841 - val_accuracy: 0.8034
# Epoch 71/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6182 - accuracy: 0.7866 - val_loss: 0.6453 - val_accuracy: 0.7819
# Epoch 72/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.6129 - accuracy: 0.7904 - val_loss: 0.5591 - val_accuracy: 0.8059
# Epoch 73/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6120 - accuracy: 0.7906 - val_loss: 0.5323 - val_accuracy: 0.8179
# Epoch 74/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6135 - accuracy: 0.7887 - val_loss: 0.5762 - val_accuracy: 0.8067
# Epoch 75/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.6045 - accuracy: 0.7914 - val_loss: 0.5426 - val_accuracy: 0.8141
# Epoch 76/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5992 - accuracy: 0.7932 - val_loss: 0.6164 - val_accuracy: 0.7927
# Epoch 77/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5991 - accuracy: 0.7929 - val_loss: 0.5476 - val_accuracy: 0.8136
# Epoch 78/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5944 - accuracy: 0.7938 - val_loss: 0.5327 - val_accuracy: 0.8203
# Epoch 79/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5959 - accuracy: 0.7945 - val_loss: 0.5494 - val_accuracy: 0.8094
# Epoch 80/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5924 - accuracy: 0.7961 - val_loss: 0.5820 - val_accuracy: 0.7999
# Epoch 81/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5857 - accuracy: 0.7992 - val_loss: 0.5294 - val_accuracy: 0.8177
# Epoch 82/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5900 - accuracy: 0.7966 - val_loss: 0.5398 - val_accuracy: 0.8157
# Epoch 83/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.5796 - accuracy: 0.8001 - val_loss: 0.5362 - val_accuracy: 0.8182
# Epoch 84/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5745 - accuracy: 0.8022 - val_loss: 0.5092 - val_accuracy: 0.8266
# Epoch 85/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5700 - accuracy: 0.8035 - val_loss: 0.5330 - val_accuracy: 0.8164
# Epoch 86/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5759 - accuracy: 0.8021 - val_loss: 0.5450 - val_accuracy: 0.8107
# Epoch 87/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5706 - accuracy: 0.8030 - val_loss: 0.5501 - val_accuracy: 0.8111
# Epoch 88/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5667 - accuracy: 0.8058 - val_loss: 0.5363 - val_accuracy: 0.8190
# Epoch 89/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5677 - accuracy: 0.8038 - val_loss: 0.5572 - val_accuracy: 0.8097
# Epoch 90/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5602 - accuracy: 0.8063 - val_loss: 0.5264 - val_accuracy: 0.8244
# Epoch 91/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5578 - accuracy: 0.8068 - val_loss: 0.5614 - val_accuracy: 0.8099
# Epoch 92/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5521 - accuracy: 0.8097 - val_loss: 0.5293 - val_accuracy: 0.8205
# Epoch 93/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5568 - accuracy: 0.8111 - val_loss: 0.5326 - val_accuracy: 0.8184
# Epoch 94/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5562 - accuracy: 0.8088 - val_loss: 0.5568 - val_accuracy: 0.8118
# Epoch 95/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.5572 - accuracy: 0.8081 - val_loss: 0.5099 - val_accuracy: 0.8277
# Epoch 96/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5433 - accuracy: 0.8143 - val_loss: 0.5309 - val_accuracy: 0.8182
# Epoch 97/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5463 - accuracy: 0.8125 - val_loss: 0.5217 - val_accuracy: 0.8227
# Epoch 98/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5422 - accuracy: 0.8129 - val_loss: 0.5482 - val_accuracy: 0.8144
# Epoch 99/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5445 - accuracy: 0.8131 - val_loss: 0.5699 - val_accuracy: 0.8050
# Epoch 100/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.5437 - accuracy: 0.8125 - val_loss: 0.5286 - val_accuracy: 0.8193
# Epoch 101/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5410 - accuracy: 0.8128 - val_loss: 0.5125 - val_accuracy: 0.8282
# Epoch 102/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5370 - accuracy: 0.8163 - val_loss: 0.4845 - val_accuracy: 0.8349
# Epoch 103/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5299 - accuracy: 0.8176 - val_loss: 0.5102 - val_accuracy: 0.8277
# Epoch 104/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5257 - accuracy: 0.8202 - val_loss: 0.4824 - val_accuracy: 0.8369
# Epoch 105/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5306 - accuracy: 0.8176 - val_loss: 0.4999 - val_accuracy: 0.8305
# Epoch 106/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5258 - accuracy: 0.8180 - val_loss: 0.5252 - val_accuracy: 0.8200
# Epoch 107/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5221 - accuracy: 0.8203 - val_loss: 0.4830 - val_accuracy: 0.8354
# Epoch 108/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5263 - accuracy: 0.8196 - val_loss: 0.5053 - val_accuracy: 0.8277
# Epoch 109/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5223 - accuracy: 0.8203 - val_loss: 0.4943 - val_accuracy: 0.8316
# Epoch 110/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5201 - accuracy: 0.8205 - val_loss: 0.4959 - val_accuracy: 0.8331
# Epoch 111/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.5170 - accuracy: 0.8213 - val_loss: 0.4832 - val_accuracy: 0.8375
# Epoch 112/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5169 - accuracy: 0.8217 - val_loss: 0.5074 - val_accuracy: 0.8307
# Epoch 113/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5125 - accuracy: 0.8238 - val_loss: 0.5066 - val_accuracy: 0.8282
# Epoch 114/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5071 - accuracy: 0.8258 - val_loss: 0.4684 - val_accuracy: 0.8389
# Epoch 115/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5079 - accuracy: 0.8270 - val_loss: 0.4880 - val_accuracy: 0.8369
# Epoch 116/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.5070 - accuracy: 0.8258 - val_loss: 0.4945 - val_accuracy: 0.8360
# Epoch 117/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5035 - accuracy: 0.8285 - val_loss: 0.4909 - val_accuracy: 0.8358
# Epoch 118/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5004 - accuracy: 0.8267 - val_loss: 0.5076 - val_accuracy: 0.8287
# Epoch 119/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.5031 - accuracy: 0.8278 - val_loss: 0.4654 - val_accuracy: 0.8424
# Epoch 120/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4995 - accuracy: 0.8300 - val_loss: 0.5039 - val_accuracy: 0.8289
# Epoch 121/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4971 - accuracy: 0.8297 - val_loss: 0.4525 - val_accuracy: 0.8470
# Epoch 122/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4909 - accuracy: 0.8318 - val_loss: 0.4560 - val_accuracy: 0.8443
# Epoch 123/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4946 - accuracy: 0.8302 - val_loss: 0.4925 - val_accuracy: 0.8326
# Epoch 124/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4880 - accuracy: 0.8325 - val_loss: 0.4785 - val_accuracy: 0.8377
# Epoch 125/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4900 - accuracy: 0.8322 - val_loss: 0.4625 - val_accuracy: 0.8428
# Epoch 126/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4881 - accuracy: 0.8316 - val_loss: 0.4898 - val_accuracy: 0.8374
# Epoch 127/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4920 - accuracy: 0.8307 - val_loss: 0.5106 - val_accuracy: 0.8297
# Epoch 128/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4860 - accuracy: 0.8315 - val_loss: 0.4865 - val_accuracy: 0.8365
# Epoch 129/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4817 - accuracy: 0.8334 - val_loss: 0.5037 - val_accuracy: 0.8322
# Epoch 130/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4865 - accuracy: 0.8334 - val_loss: 0.4813 - val_accuracy: 0.8379
# Epoch 131/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4846 - accuracy: 0.8346 - val_loss: 0.5076 - val_accuracy: 0.8299
# Epoch 132/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4810 - accuracy: 0.8348 - val_loss: 0.4695 - val_accuracy: 0.8376
# Epoch 133/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4757 - accuracy: 0.8374 - val_loss: 0.4535 - val_accuracy: 0.8468
# Epoch 134/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4767 - accuracy: 0.8356 - val_loss: 0.5153 - val_accuracy: 0.8288
# Epoch 135/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4773 - accuracy: 0.8381 - val_loss: 0.4597 - val_accuracy: 0.8441
# Epoch 136/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4756 - accuracy: 0.8361 - val_loss: 0.4748 - val_accuracy: 0.8399
# Epoch 137/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4715 - accuracy: 0.8399 - val_loss: 0.4657 - val_accuracy: 0.8423
# Epoch 138/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4702 - accuracy: 0.8400 - val_loss: 0.4275 - val_accuracy: 0.8535
# Epoch 139/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4650 - accuracy: 0.8406 - val_loss: 0.4611 - val_accuracy: 0.8461
# Epoch 140/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4648 - accuracy: 0.8404 - val_loss: 0.4534 - val_accuracy: 0.8488
# Epoch 141/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4693 - accuracy: 0.8404 - val_loss: 0.4423 - val_accuracy: 0.8498
# Epoch 142/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4641 - accuracy: 0.8418 - val_loss: 0.4295 - val_accuracy: 0.8580
# Epoch 143/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4633 - accuracy: 0.8411 - val_loss: 0.4476 - val_accuracy: 0.8490
# Epoch 144/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4600 - accuracy: 0.8424 - val_loss: 0.4306 - val_accuracy: 0.8542
# Epoch 145/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4592 - accuracy: 0.8428 - val_loss: 0.4409 - val_accuracy: 0.8538
# Epoch 146/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4561 - accuracy: 0.8440 - val_loss: 0.4557 - val_accuracy: 0.8481
# Epoch 147/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4588 - accuracy: 0.8409 - val_loss: 0.4670 - val_accuracy: 0.8454
# Epoch 148/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4589 - accuracy: 0.8435 - val_loss: 0.4374 - val_accuracy: 0.8511
# Epoch 149/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4539 - accuracy: 0.8440 - val_loss: 0.4439 - val_accuracy: 0.8503
# Epoch 150/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4489 - accuracy: 0.8455 - val_loss: 0.4747 - val_accuracy: 0.8441
# Epoch 151/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4532 - accuracy: 0.8433 - val_loss: 0.4452 - val_accuracy: 0.8488
# Epoch 152/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4479 - accuracy: 0.8481 - val_loss: 0.4288 - val_accuracy: 0.8548
# Epoch 153/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4562 - accuracy: 0.8434 - val_loss: 0.4469 - val_accuracy: 0.8520
# Epoch 154/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4507 - accuracy: 0.8458 - val_loss: 0.4448 - val_accuracy: 0.8533
# Epoch 155/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4432 - accuracy: 0.8476 - val_loss: 0.4397 - val_accuracy: 0.8531
# Epoch 156/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4494 - accuracy: 0.8448 - val_loss: 0.4493 - val_accuracy: 0.8513
# Epoch 157/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4417 - accuracy: 0.8472 - val_loss: 0.4636 - val_accuracy: 0.8434
# Epoch 158/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4425 - accuracy: 0.8488 - val_loss: 0.4429 - val_accuracy: 0.8533
# Epoch 159/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4423 - accuracy: 0.8462 - val_loss: 0.4371 - val_accuracy: 0.8537
# Epoch 160/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4412 - accuracy: 0.8482 - val_loss: 0.4318 - val_accuracy: 0.8572
# Epoch 161/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4390 - accuracy: 0.8500 - val_loss: 0.4354 - val_accuracy: 0.8529
# Epoch 162/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4381 - accuracy: 0.8497 - val_loss: 0.4284 - val_accuracy: 0.8608
# Epoch 163/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4399 - accuracy: 0.8499 - val_loss: 0.4844 - val_accuracy: 0.8383
# Epoch 164/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4339 - accuracy: 0.8501 - val_loss: 0.4412 - val_accuracy: 0.8538
# Epoch 165/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4321 - accuracy: 0.8518 - val_loss: 0.4317 - val_accuracy: 0.8551
# Epoch 166/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4313 - accuracy: 0.8528 - val_loss: 0.4294 - val_accuracy: 0.8553
# Epoch 167/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4391 - accuracy: 0.8487 - val_loss: 0.4262 - val_accuracy: 0.8606
# Epoch 168/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4332 - accuracy: 0.8531 - val_loss: 0.4398 - val_accuracy: 0.8537
# Epoch 169/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4314 - accuracy: 0.8525 - val_loss: 0.4196 - val_accuracy: 0.8599
# Epoch 170/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4305 - accuracy: 0.8520 - val_loss: 0.4291 - val_accuracy: 0.8584
# Epoch 171/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4227 - accuracy: 0.8563 - val_loss: 0.4085 - val_accuracy: 0.8628
# Epoch 172/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4215 - accuracy: 0.8553 - val_loss: 0.4393 - val_accuracy: 0.8568
# Epoch 173/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4209 - accuracy: 0.8566 - val_loss: 0.4208 - val_accuracy: 0.8609
# Epoch 174/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4199 - accuracy: 0.8553 - val_loss: 0.4095 - val_accuracy: 0.8612
# Epoch 175/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4286 - accuracy: 0.8538 - val_loss: 0.4350 - val_accuracy: 0.8572
# Epoch 176/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4212 - accuracy: 0.8552 - val_loss: 0.4097 - val_accuracy: 0.8623
# Epoch 177/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4221 - accuracy: 0.8558 - val_loss: 0.4545 - val_accuracy: 0.8514
# Epoch 178/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4200 - accuracy: 0.8551 - val_loss: 0.4459 - val_accuracy: 0.8534
# Epoch 179/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4177 - accuracy: 0.8569 - val_loss: 0.4263 - val_accuracy: 0.8571
# Epoch 180/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4140 - accuracy: 0.8569 - val_loss: 0.4547 - val_accuracy: 0.8496
# Epoch 181/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4140 - accuracy: 0.8567 - val_loss: 0.4381 - val_accuracy: 0.8569
# Epoch 182/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4129 - accuracy: 0.8589 - val_loss: 0.3944 - val_accuracy: 0.8669
# Epoch 183/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4124 - accuracy: 0.8589 - val_loss: 0.4167 - val_accuracy: 0.8599
# Epoch 184/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4136 - accuracy: 0.8583 - val_loss: 0.4251 - val_accuracy: 0.8597
# Epoch 185/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4112 - accuracy: 0.8603 - val_loss: 0.4187 - val_accuracy: 0.8617
# Epoch 186/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4093 - accuracy: 0.8600 - val_loss: 0.4259 - val_accuracy: 0.8607
# Epoch 187/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.4111 - accuracy: 0.8585 - val_loss: 0.4220 - val_accuracy: 0.8598
# Epoch 188/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4115 - accuracy: 0.8589 - val_loss: 0.4067 - val_accuracy: 0.8676
# Epoch 189/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4080 - accuracy: 0.8606 - val_loss: 0.4021 - val_accuracy: 0.8667
# Epoch 190/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4081 - accuracy: 0.8604 - val_loss: 0.4481 - val_accuracy: 0.8562
# Epoch 191/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4003 - accuracy: 0.8625 - val_loss: 0.4016 - val_accuracy: 0.8643
# Epoch 192/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4051 - accuracy: 0.8604 - val_loss: 0.4094 - val_accuracy: 0.8642
# Epoch 193/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4064 - accuracy: 0.8611 - val_loss: 0.4071 - val_accuracy: 0.8681
# Epoch 194/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.4024 - accuracy: 0.8624 - val_loss: 0.4279 - val_accuracy: 0.8573
# Epoch 195/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4022 - accuracy: 0.8623 - val_loss: 0.4275 - val_accuracy: 0.8600
# Epoch 196/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3968 - accuracy: 0.8635 - val_loss: 0.4181 - val_accuracy: 0.8641
# Epoch 197/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4042 - accuracy: 0.8618 - val_loss: 0.4103 - val_accuracy: 0.8659
# Epoch 198/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3952 - accuracy: 0.8640 - val_loss: 0.4280 - val_accuracy: 0.8600
# Epoch 199/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3988 - accuracy: 0.8628 - val_loss: 0.4253 - val_accuracy: 0.8600
# Epoch 200/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3932 - accuracy: 0.8656 - val_loss: 0.3965 - val_accuracy: 0.8715
# Epoch 201/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3966 - accuracy: 0.8647 - val_loss: 0.3941 - val_accuracy: 0.8692
# Epoch 202/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3974 - accuracy: 0.8645 - val_loss: 0.3990 - val_accuracy: 0.8694
# Epoch 203/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.4004 - accuracy: 0.8628 - val_loss: 0.4107 - val_accuracy: 0.8661
# Epoch 204/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3977 - accuracy: 0.8632 - val_loss: 0.4102 - val_accuracy: 0.8647
# Epoch 205/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3923 - accuracy: 0.8645 - val_loss: 0.4441 - val_accuracy: 0.8525
# Epoch 206/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3899 - accuracy: 0.8658 - val_loss: 0.4250 - val_accuracy: 0.8598
# Epoch 207/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3893 - accuracy: 0.8648 - val_loss: 0.4061 - val_accuracy: 0.8650
# Epoch 208/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3945 - accuracy: 0.8656 - val_loss: 0.4154 - val_accuracy: 0.8629
# Epoch 209/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3908 - accuracy: 0.8671 - val_loss: 0.4538 - val_accuracy: 0.8506
# Epoch 210/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3893 - accuracy: 0.8657 - val_loss: 0.4165 - val_accuracy: 0.8624
# Epoch 211/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3883 - accuracy: 0.8670 - val_loss: 0.4058 - val_accuracy: 0.8662
# Epoch 212/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3866 - accuracy: 0.8671 - val_loss: 0.4205 - val_accuracy: 0.8612
# Epoch 213/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3878 - accuracy: 0.8675 - val_loss: 0.4201 - val_accuracy: 0.8638
# Epoch 214/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3832 - accuracy: 0.8681 - val_loss: 0.4260 - val_accuracy: 0.8592
# Epoch 215/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3811 - accuracy: 0.8682 - val_loss: 0.3945 - val_accuracy: 0.8680
# Epoch 216/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3823 - accuracy: 0.8680 - val_loss: 0.3938 - val_accuracy: 0.8709
# Epoch 217/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3840 - accuracy: 0.8679 - val_loss: 0.4255 - val_accuracy: 0.8607
# Epoch 218/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3851 - accuracy: 0.8684 - val_loss: 0.4339 - val_accuracy: 0.8579
# Epoch 219/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3791 - accuracy: 0.8674 - val_loss: 0.4343 - val_accuracy: 0.8553
# Epoch 220/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3820 - accuracy: 0.8692 - val_loss: 0.4080 - val_accuracy: 0.8675
# Epoch 221/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3831 - accuracy: 0.8699 - val_loss: 0.4022 - val_accuracy: 0.8668
# Epoch 222/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3762 - accuracy: 0.8697 - val_loss: 0.4074 - val_accuracy: 0.8685
# Epoch 223/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3762 - accuracy: 0.8709 - val_loss: 0.4160 - val_accuracy: 0.8651
# Epoch 224/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3799 - accuracy: 0.8680 - val_loss: 0.4005 - val_accuracy: 0.8715
# Epoch 225/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3806 - accuracy: 0.8706 - val_loss: 0.4062 - val_accuracy: 0.8659
# Epoch 226/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3742 - accuracy: 0.8717 - val_loss: 0.4181 - val_accuracy: 0.8652
# Epoch 227/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3730 - accuracy: 0.8701 - val_loss: 0.4050 - val_accuracy: 0.8663
# Epoch 228/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3758 - accuracy: 0.8712 - val_loss: 0.3994 - val_accuracy: 0.8713
# Epoch 229/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3734 - accuracy: 0.8714 - val_loss: 0.3979 - val_accuracy: 0.8702
# Epoch 230/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3735 - accuracy: 0.8714 - val_loss: 0.4131 - val_accuracy: 0.8675
# Epoch 231/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3698 - accuracy: 0.8722 - val_loss: 0.4143 - val_accuracy: 0.8685
# Epoch 232/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3652 - accuracy: 0.8744 - val_loss: 0.4041 - val_accuracy: 0.8723
# Epoch 233/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3716 - accuracy: 0.8714 - val_loss: 0.3831 - val_accuracy: 0.8759
# Epoch 234/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3739 - accuracy: 0.8700 - val_loss: 0.4122 - val_accuracy: 0.8652
# Epoch 235/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3727 - accuracy: 0.8727 - val_loss: 0.4271 - val_accuracy: 0.8627
# Epoch 236/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3675 - accuracy: 0.8743 - val_loss: 0.3938 - val_accuracy: 0.8693
# Epoch 237/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3704 - accuracy: 0.8716 - val_loss: 0.3831 - val_accuracy: 0.8744
# Epoch 238/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3642 - accuracy: 0.8757 - val_loss: 0.3933 - val_accuracy: 0.8724
# Epoch 239/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3693 - accuracy: 0.8724 - val_loss: 0.4084 - val_accuracy: 0.8693
# Epoch 240/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3633 - accuracy: 0.8742 - val_loss: 0.3926 - val_accuracy: 0.8712
# Epoch 241/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3646 - accuracy: 0.8742 - val_loss: 0.3989 - val_accuracy: 0.8692
# Epoch 242/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3658 - accuracy: 0.8750 - val_loss: 0.3884 - val_accuracy: 0.8735
# Epoch 243/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3630 - accuracy: 0.8742 - val_loss: 0.4050 - val_accuracy: 0.8705
# Epoch 244/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3620 - accuracy: 0.8750 - val_loss: 0.3975 - val_accuracy: 0.8690
# Epoch 245/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3628 - accuracy: 0.8741 - val_loss: 0.3924 - val_accuracy: 0.8715
# Epoch 246/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3602 - accuracy: 0.8750 - val_loss: 0.3822 - val_accuracy: 0.8743
# Epoch 247/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3597 - accuracy: 0.8749 - val_loss: 0.3788 - val_accuracy: 0.8771
# Epoch 248/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3622 - accuracy: 0.8740 - val_loss: 0.4060 - val_accuracy: 0.8701
# Epoch 249/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3558 - accuracy: 0.8754 - val_loss: 0.4106 - val_accuracy: 0.8670
# Epoch 250/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3564 - accuracy: 0.8772 - val_loss: 0.3927 - val_accuracy: 0.8731
# Epoch 251/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3554 - accuracy: 0.8776 - val_loss: 0.4205 - val_accuracy: 0.8643
# Epoch 252/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3565 - accuracy: 0.8778 - val_loss: 0.3951 - val_accuracy: 0.8721
# Epoch 253/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3561 - accuracy: 0.8779 - val_loss: 0.3974 - val_accuracy: 0.8715
# Epoch 254/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3531 - accuracy: 0.8772 - val_loss: 0.3822 - val_accuracy: 0.8762
# Epoch 255/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3540 - accuracy: 0.8779 - val_loss: 0.3746 - val_accuracy: 0.8763
# Epoch 256/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3589 - accuracy: 0.8759 - val_loss: 0.3808 - val_accuracy: 0.8741
# Epoch 257/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3542 - accuracy: 0.8778 - val_loss: 0.3727 - val_accuracy: 0.8786
# Epoch 258/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3543 - accuracy: 0.8774 - val_loss: 0.3886 - val_accuracy: 0.8764
# Epoch 259/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3479 - accuracy: 0.8792 - val_loss: 0.3782 - val_accuracy: 0.8803
# Epoch 260/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3503 - accuracy: 0.8791 - val_loss: 0.4062 - val_accuracy: 0.8708
# Epoch 261/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3518 - accuracy: 0.8775 - val_loss: 0.3749 - val_accuracy: 0.8781
# Epoch 262/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3475 - accuracy: 0.8800 - val_loss: 0.3814 - val_accuracy: 0.8757
# Epoch 263/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3446 - accuracy: 0.8821 - val_loss: 0.3974 - val_accuracy: 0.8743
# Epoch 264/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3430 - accuracy: 0.8815 - val_loss: 0.4012 - val_accuracy: 0.8675
# Epoch 265/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3463 - accuracy: 0.8807 - val_loss: 0.3833 - val_accuracy: 0.8779
# Epoch 266/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3482 - accuracy: 0.8805 - val_loss: 0.4075 - val_accuracy: 0.8674
# Epoch 267/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3476 - accuracy: 0.8789 - val_loss: 0.3892 - val_accuracy: 0.8751
# Epoch 268/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3493 - accuracy: 0.8797 - val_loss: 0.4327 - val_accuracy: 0.8632
# Epoch 269/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3471 - accuracy: 0.8806 - val_loss: 0.3746 - val_accuracy: 0.8767
# Epoch 270/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3417 - accuracy: 0.8820 - val_loss: 0.3814 - val_accuracy: 0.8788
# Epoch 271/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3471 - accuracy: 0.8813 - val_loss: 0.4233 - val_accuracy: 0.8629
# Epoch 272/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3460 - accuracy: 0.8821 - val_loss: 0.3881 - val_accuracy: 0.8762
# Epoch 273/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3426 - accuracy: 0.8831 - val_loss: 0.3984 - val_accuracy: 0.8721
# Epoch 274/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3396 - accuracy: 0.8842 - val_loss: 0.4027 - val_accuracy: 0.8700
# Epoch 275/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3405 - accuracy: 0.8830 - val_loss: 0.3972 - val_accuracy: 0.8712
# Epoch 276/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3465 - accuracy: 0.8799 - val_loss: 0.3838 - val_accuracy: 0.8764
# Epoch 277/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3485 - accuracy: 0.8795 - val_loss: 0.3893 - val_accuracy: 0.8742
# Epoch 278/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3383 - accuracy: 0.8818 - val_loss: 0.3737 - val_accuracy: 0.8788
# Epoch 279/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3399 - accuracy: 0.8817 - val_loss: 0.3991 - val_accuracy: 0.8743
# Epoch 280/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3430 - accuracy: 0.8822 - val_loss: 0.3783 - val_accuracy: 0.8814
# Epoch 281/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3389 - accuracy: 0.8836 - val_loss: 0.4033 - val_accuracy: 0.8701
# Epoch 282/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3343 - accuracy: 0.8834 - val_loss: 0.4092 - val_accuracy: 0.8699
# Epoch 283/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3422 - accuracy: 0.8813 - val_loss: 0.3975 - val_accuracy: 0.8741
# Epoch 284/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3392 - accuracy: 0.8824 - val_loss: 0.3940 - val_accuracy: 0.8757
# Epoch 285/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3386 - accuracy: 0.8836 - val_loss: 0.3874 - val_accuracy: 0.8780
# Epoch 286/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3332 - accuracy: 0.8872 - val_loss: 0.3913 - val_accuracy: 0.8736
# Epoch 287/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3328 - accuracy: 0.8854 - val_loss: 0.3757 - val_accuracy: 0.8814
# Epoch 288/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3364 - accuracy: 0.8838 - val_loss: 0.4074 - val_accuracy: 0.8733
# Epoch 289/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3380 - accuracy: 0.8844 - val_loss: 0.3912 - val_accuracy: 0.8746
# Epoch 290/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3351 - accuracy: 0.8835 - val_loss: 0.3755 - val_accuracy: 0.8798
# Epoch 291/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3337 - accuracy: 0.8844 - val_loss: 0.3553 - val_accuracy: 0.8854
# Epoch 292/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3328 - accuracy: 0.8852 - val_loss: 0.4123 - val_accuracy: 0.8688
# Epoch 293/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3347 - accuracy: 0.8859 - val_loss: 0.3731 - val_accuracy: 0.8836
# Epoch 294/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3311 - accuracy: 0.8851 - val_loss: 0.3885 - val_accuracy: 0.8768
# Epoch 295/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3344 - accuracy: 0.8854 - val_loss: 0.3957 - val_accuracy: 0.8737
# Epoch 296/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3364 - accuracy: 0.8832 - val_loss: 0.3674 - val_accuracy: 0.8816
# Epoch 297/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3306 - accuracy: 0.8869 - val_loss: 0.3924 - val_accuracy: 0.8747
# Epoch 298/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3298 - accuracy: 0.8863 - val_loss: 0.3867 - val_accuracy: 0.8781
# Epoch 299/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3350 - accuracy: 0.8837 - val_loss: 0.3862 - val_accuracy: 0.8750
# Epoch 300/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3296 - accuracy: 0.8859 - val_loss: 0.3870 - val_accuracy: 0.8763
# Epoch 301/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3280 - accuracy: 0.8863 - val_loss: 0.3706 - val_accuracy: 0.8800
# Epoch 302/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3265 - accuracy: 0.8871 - val_loss: 0.3909 - val_accuracy: 0.8748
# Epoch 303/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3250 - accuracy: 0.8872 - val_loss: 0.3826 - val_accuracy: 0.8777
# Epoch 304/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3346 - accuracy: 0.8846 - val_loss: 0.3936 - val_accuracy: 0.8739
# Epoch 305/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3270 - accuracy: 0.8877 - val_loss: 0.3956 - val_accuracy: 0.8744
# Epoch 306/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3215 - accuracy: 0.8883 - val_loss: 0.3990 - val_accuracy: 0.8741
# Epoch 307/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3287 - accuracy: 0.8880 - val_loss: 0.4116 - val_accuracy: 0.8711
# Epoch 308/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3280 - accuracy: 0.8864 - val_loss: 0.3768 - val_accuracy: 0.8777
# Epoch 309/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3249 - accuracy: 0.8880 - val_loss: 0.3870 - val_accuracy: 0.8781
# Epoch 310/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3198 - accuracy: 0.8881 - val_loss: 0.3691 - val_accuracy: 0.8820
# Epoch 311/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3252 - accuracy: 0.8879 - val_loss: 0.4023 - val_accuracy: 0.8720
# Epoch 312/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3240 - accuracy: 0.8871 - val_loss: 0.3777 - val_accuracy: 0.8790
# Epoch 313/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3215 - accuracy: 0.8886 - val_loss: 0.3852 - val_accuracy: 0.8772
# Epoch 314/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3249 - accuracy: 0.8874 - val_loss: 0.3695 - val_accuracy: 0.8826
# Epoch 315/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3216 - accuracy: 0.8880 - val_loss: 0.3861 - val_accuracy: 0.8770
# Epoch 316/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3201 - accuracy: 0.8891 - val_loss: 0.3931 - val_accuracy: 0.8767
# Epoch 317/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3224 - accuracy: 0.8882 - val_loss: 0.3919 - val_accuracy: 0.8767
# Epoch 318/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3206 - accuracy: 0.8863 - val_loss: 0.3817 - val_accuracy: 0.8795
# Epoch 319/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3217 - accuracy: 0.8881 - val_loss: 0.3820 - val_accuracy: 0.8777
# Epoch 320/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3190 - accuracy: 0.8892 - val_loss: 0.3569 - val_accuracy: 0.8841
# Epoch 321/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3217 - accuracy: 0.8889 - val_loss: 0.3782 - val_accuracy: 0.8785
# Epoch 322/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3136 - accuracy: 0.8914 - val_loss: 0.3849 - val_accuracy: 0.8756
# Epoch 323/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3200 - accuracy: 0.8902 - val_loss: 0.3594 - val_accuracy: 0.8841
# Epoch 324/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3183 - accuracy: 0.8889 - val_loss: 0.3970 - val_accuracy: 0.8729
# Epoch 325/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3163 - accuracy: 0.8907 - val_loss: 0.3941 - val_accuracy: 0.8748
# Epoch 326/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3142 - accuracy: 0.8907 - val_loss: 0.3824 - val_accuracy: 0.8772
# Epoch 327/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3202 - accuracy: 0.8883 - val_loss: 0.3897 - val_accuracy: 0.8778
# Epoch 328/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3230 - accuracy: 0.8887 - val_loss: 0.3741 - val_accuracy: 0.8800
# Epoch 329/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3144 - accuracy: 0.8920 - val_loss: 0.3629 - val_accuracy: 0.8847
# Epoch 330/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3120 - accuracy: 0.8927 - val_loss: 0.3698 - val_accuracy: 0.8825
# Epoch 331/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3095 - accuracy: 0.8927 - val_loss: 0.3764 - val_accuracy: 0.8787
# Epoch 332/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3161 - accuracy: 0.8920 - val_loss: 0.3841 - val_accuracy: 0.8768
# Epoch 333/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3182 - accuracy: 0.8878 - val_loss: 0.3759 - val_accuracy: 0.8813
# Epoch 334/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3110 - accuracy: 0.8930 - val_loss: 0.3718 - val_accuracy: 0.8811
# Epoch 335/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3077 - accuracy: 0.8956 - val_loss: 0.3701 - val_accuracy: 0.8821
# Epoch 336/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.3116 - accuracy: 0.8926 - val_loss: 0.3847 - val_accuracy: 0.8790
# Epoch 337/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3115 - accuracy: 0.8924 - val_loss: 0.3898 - val_accuracy: 0.8771
# Epoch 338/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3130 - accuracy: 0.8915 - val_loss: 0.3755 - val_accuracy: 0.8807
# Epoch 339/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3080 - accuracy: 0.8932 - val_loss: 0.3599 - val_accuracy: 0.8845
# Epoch 340/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3130 - accuracy: 0.8900 - val_loss: 0.3731 - val_accuracy: 0.8824
# Epoch 341/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3086 - accuracy: 0.8933 - val_loss: 0.3585 - val_accuracy: 0.8860
# Epoch 342/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3112 - accuracy: 0.8939 - val_loss: 0.3635 - val_accuracy: 0.8840
# Epoch 343/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3079 - accuracy: 0.8928 - val_loss: 0.3825 - val_accuracy: 0.8785
# Epoch 344/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3065 - accuracy: 0.8951 - val_loss: 0.3697 - val_accuracy: 0.8825
# Epoch 345/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3085 - accuracy: 0.8940 - val_loss: 0.3649 - val_accuracy: 0.8809
# Epoch 346/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3086 - accuracy: 0.8933 - val_loss: 0.3656 - val_accuracy: 0.8838
# Epoch 347/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3085 - accuracy: 0.8931 - val_loss: 0.3963 - val_accuracy: 0.8755
# Epoch 348/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.3083 - accuracy: 0.8924 - val_loss: 0.3685 - val_accuracy: 0.8825
# Epoch 349/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3062 - accuracy: 0.8933 - val_loss: 0.4018 - val_accuracy: 0.8735
# Epoch 350/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3060 - accuracy: 0.8956 - val_loss: 0.3936 - val_accuracy: 0.8762
# Epoch 351/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3084 - accuracy: 0.8926 - val_loss: 0.3626 - val_accuracy: 0.8861
# Epoch 352/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3052 - accuracy: 0.8944 - val_loss: 0.3942 - val_accuracy: 0.8763
# Epoch 353/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3050 - accuracy: 0.8951 - val_loss: 0.3632 - val_accuracy: 0.8862
# Epoch 354/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3025 - accuracy: 0.8961 - val_loss: 0.3677 - val_accuracy: 0.8857
# Epoch 355/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2999 - accuracy: 0.8966 - val_loss: 0.3600 - val_accuracy: 0.8862
# Epoch 356/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3096 - accuracy: 0.8927 - val_loss: 0.3679 - val_accuracy: 0.8836
# Epoch 357/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3034 - accuracy: 0.8948 - val_loss: 0.3773 - val_accuracy: 0.8821
# Epoch 358/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3035 - accuracy: 0.8952 - val_loss: 0.3737 - val_accuracy: 0.8816
# Epoch 359/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3040 - accuracy: 0.8936 - val_loss: 0.3611 - val_accuracy: 0.8860
# Epoch 360/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2990 - accuracy: 0.8956 - val_loss: 0.3767 - val_accuracy: 0.8810
# Epoch 361/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3093 - accuracy: 0.8932 - val_loss: 0.3553 - val_accuracy: 0.8854
# Epoch 362/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3006 - accuracy: 0.8944 - val_loss: 0.3594 - val_accuracy: 0.8869
# Epoch 363/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2963 - accuracy: 0.8966 - val_loss: 0.3715 - val_accuracy: 0.8838
# Epoch 364/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3037 - accuracy: 0.8942 - val_loss: 0.3543 - val_accuracy: 0.8856
# Epoch 365/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3025 - accuracy: 0.8941 - val_loss: 0.3717 - val_accuracy: 0.8833
# Epoch 366/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3023 - accuracy: 0.8955 - val_loss: 0.3896 - val_accuracy: 0.8782
# Epoch 367/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.3016 - accuracy: 0.8956 - val_loss: 0.3643 - val_accuracy: 0.8844
# Epoch 368/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2983 - accuracy: 0.8974 - val_loss: 0.3680 - val_accuracy: 0.8844
# Epoch 369/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2985 - accuracy: 0.8958 - val_loss: 0.3640 - val_accuracy: 0.8826
# Epoch 370/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2942 - accuracy: 0.8987 - val_loss: 0.4213 - val_accuracy: 0.8683
# Epoch 371/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2977 - accuracy: 0.8973 - val_loss: 0.3731 - val_accuracy: 0.8815
# Epoch 372/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2971 - accuracy: 0.8963 - val_loss: 0.3740 - val_accuracy: 0.8823
# Epoch 373/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2948 - accuracy: 0.8979 - val_loss: 0.3780 - val_accuracy: 0.8805
# Epoch 374/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2946 - accuracy: 0.8982 - val_loss: 0.3705 - val_accuracy: 0.8864
# Epoch 375/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2907 - accuracy: 0.8998 - val_loss: 0.3704 - val_accuracy: 0.8862
# Epoch 376/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2958 - accuracy: 0.8976 - val_loss: 0.3574 - val_accuracy: 0.8855
# Epoch 377/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2898 - accuracy: 0.8984 - val_loss: 0.3640 - val_accuracy: 0.8848
# Epoch 378/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2922 - accuracy: 0.8996 - val_loss: 0.3664 - val_accuracy: 0.8877
# Epoch 379/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2971 - accuracy: 0.8967 - val_loss: 0.3742 - val_accuracy: 0.8839
# Epoch 380/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2941 - accuracy: 0.8982 - val_loss: 0.3658 - val_accuracy: 0.8871
# Epoch 381/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2936 - accuracy: 0.8984 - val_loss: 0.3570 - val_accuracy: 0.8887
# Epoch 382/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2938 - accuracy: 0.8973 - val_loss: 0.3895 - val_accuracy: 0.8810
# Epoch 383/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2971 - accuracy: 0.8968 - val_loss: 0.3585 - val_accuracy: 0.8874
# Epoch 384/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2968 - accuracy: 0.8960 - val_loss: 0.3662 - val_accuracy: 0.8847
# Epoch 385/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2951 - accuracy: 0.8969 - val_loss: 0.3860 - val_accuracy: 0.8824
# Epoch 386/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2957 - accuracy: 0.8975 - val_loss: 0.3793 - val_accuracy: 0.8818
# Epoch 387/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2907 - accuracy: 0.8998 - val_loss: 0.3750 - val_accuracy: 0.8831
# Epoch 388/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2941 - accuracy: 0.8974 - val_loss: 0.3816 - val_accuracy: 0.8797
# Epoch 389/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2914 - accuracy: 0.8997 - val_loss: 0.3605 - val_accuracy: 0.8838
# Epoch 390/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2898 - accuracy: 0.8997 - val_loss: 0.3779 - val_accuracy: 0.8820
# Epoch 391/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2960 - accuracy: 0.8978 - val_loss: 0.3523 - val_accuracy: 0.8889
# Epoch 392/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2877 - accuracy: 0.9008 - val_loss: 0.3697 - val_accuracy: 0.8820
# Epoch 393/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2932 - accuracy: 0.8982 - val_loss: 0.3501 - val_accuracy: 0.8901
# Epoch 394/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2933 - accuracy: 0.8992 - val_loss: 0.4250 - val_accuracy: 0.8681
# Epoch 395/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2866 - accuracy: 0.9004 - val_loss: 0.3742 - val_accuracy: 0.8819
# Epoch 396/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2909 - accuracy: 0.8982 - val_loss: 0.3759 - val_accuracy: 0.8836
# Epoch 397/400
# 781/781 [==============================] - 40s 51ms/step - loss: 0.2895 - accuracy: 0.8986 - val_loss: 0.3666 - val_accuracy: 0.8842
# Epoch 398/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2889 - accuracy: 0.8997 - val_loss: 0.3645 - val_accuracy: 0.8868
# Epoch 399/400
# 781/781 [==============================] - 39s 51ms/step - loss: 0.2931 - accuracy: 0.8981 - val_loss: 0.3679 - val_accuracy: 0.8852
# Epoch 400/400
# 781/781 [==============================] - 39s 50ms/step - loss: 0.2847 - accuracy: 0.9015 - val_loss: 0.3534 - val_accuracy: 0.8902
# Total time for creating the baseline model: 4:21:59.743356

# %%
# Display a summary of the baseline model
print(baseline_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 552,874
# Trainable params: 551,722
# Non-trainable params: 1,152
# _________________________________________________________________
# None

# %%
# Display the configuration of the baseline model
print(baseline_model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'batch_input_shape': (None, 32, 32, 3), 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization', 'trainable': True, 'dtype': 'float32', 'axis': ListWrapper([3]), 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_1', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization_1', 'trainable': True, 'dtype': 'float32', 'axis': ListWrapper([3]), 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Dropout', 'config': {'name': 'dropout', 'trainable': True, 'dtype': 'float32', 'rate': 0.2, 'noise_shape': None, 'seed': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_2', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization_2', 'trainable': True, 'dtype': 'float32', 'axis': ListWrapper([3]), 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'class_name': 'Zeros', 'config': {}}, 'gamma_initializer': {'class_name': 'Ones', 'config': {}}, 'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}}, 'moving_variance_initializer': {'class_name': 'Ones', 'config': {}}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d ...

# %%
# List all data points in the baseline model training history
print(baseline_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Summarize model training hisotry for accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['accuracy'], color='blue', label='train')
plt.plot(baseline_hist.history['val_accuracy'], color='red', label='test')
plt.title('Baseline Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 4:22:03.292197
