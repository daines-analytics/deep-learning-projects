# %% [markdown]
# # Binary Classification Model for Springleaf Marketing Response Using TensorFlow Take 5
# ### David Lowe
# ### March 23, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The Springleaf Marketing Response dataset is a binary classification situation where we are trying to predict one of the two possible outcomes.
#
# INTRODUCTION: Springleaf leverages the direct mail method for connecting with customers who may need a loan. To improve their targeting efforts, Springleaf must be sure they are focusing on the customers who are likely to respond and be good candidates for their services. Using a dataset with a broad set of anonymized features, Springleaf is looking to predict which customers will respond to a direct mail offer.
#
# In iteration Take1, we constructed several traditional machine learning models using the linear, non-linear, and ensemble techniques. We also observed the best ROC-AUC result that we could obtain with each of these models.
#
# In iteration Take2, we constructed and tuned an XGBoost machine learning model for this dataset. We also observed the best ROC-AUC result that we could obtain with the XGBoost model.
#
# In iteration Take3, we constructed several Multilayer Perceptron (MLP) models with one hidden layer of 64, 128, 256, 512, 1024, and 2048 nodes. These single-layer MLP models serve as the baseline models as we build more complex MLP models in future iterations.
#
# In iteration Take4, we constructed several Multilayer Perceptron (MLP) models with two hidden layers. We also observed whether these two-layer MLP models could improve the AUC-ROC performance of the single-layer models.
#
# In this Take5 iteration, we will construct several Multilayer Perceptron (MLP) models with three hidden layers. We will observe whether these three-layer MLP models can improve the AUC-ROC performance of the single-layer models.
#
# ANALYSIS: In iteration Take1, the baseline performance of the machine learning algorithms achieved an average ROC-AUC of 70.42%. The Random Forest and Gradient Boosting Machine algorithms made the top ROC-AUC metrics after the first round of modeling. After a series of tuning trials, GBM turned in an overall ROC-AUC result of 77.96%. When we apply the tuned GBM algorithm to the test dataset, we obtained a ROC-AUC score of only 62.58%, which was much lower than the score from model training.
#
# In iteration Take2, the XGBoost algorithm achieved a baseline ROC-AUC performance of 77.08%. After a series of tuning trials, XGBoost turned in an overall best ROC-AUC result of 78.23%. When we apply the tuned XGBoost algorithm to the test dataset, we obtained a ROC-AUC score of only 62.86%, which was much lower than the score from model training.
#
# In iteration Take3, all one-layer models achieved a ROC-AUC performance of around 50%.
#
# In iteration Take4, all two-layer models again achieved a ROC-AUC performance of around 50%.
#
# In this Take5 iteration, all three-layer models once again achieved a ROC-AUC performance of around 50%.
#
# CONCLUSION: For this iteration, all three-layer models scored poorly on the ROC-AUC performance. For this dataset, we should consider doing MLP modeling with more neural network layers or with more complex architecture.
#
# Dataset Used: Springleaf Marketing Response Data Set
#
# Dataset ML Model: Binary classification with numerical and categorical attributes
#
# Dataset Reference: https://www.kaggle.com/c/springleaf-marketing-response/data
#
# One potential source of performance benchmark: https://www.kaggle.com/c/springleaf-marketing-response/leaderboard
#
# Any deep-learning modeling project genrally can be broken down into about six major tasks:
#
# 0. Prepare Environment
# 1. Load Data
# 2. Define Model
# 3. Fit and Evaluate Model
# 4. Optimize Model
# 5. Finalize Model

# %% [markdown]
# # Section 0. Prepare Environment

# %%
# Retrieve GPU configuration information from Colab
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Tue Mar 17 17:07:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Retrieve memory configuration information from Colab
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
# Load libraries and packages
import random
random.seed(seedNum)
import numpy as np
np.random.seed(seedNum)
import tensorflow as tf
tf.random.set_seed(seedNum)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import matplotlib.pyplot as plt
from datetime import datetime
from email.message import EmailMessage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose flag to print detailed messages for debugging (setting to True will activate)
# verbose = True
# tf.debugging.set_log_device_placement(verbose)

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the number of folds for cross validation
n_folds = 5

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.15

# Set various default Keras modeling parameters
default_loss = 'binary_crossentropy'
default_metrics = [tf.keras.metrics.AUC()]
default_optimizer = tf.optimizers.Adam(learning_rate=0.001)
default_kernel_init = tf.initializers.RandomNormal(seed=seedNum)
default_epoch = 20
default_batch = 32
# Out:
# Num GPUs Available:  1

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Keras Binary Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
# Reset the random number generators
def reset_random(x):
    random.seed(x)
    np.random.seed(x)
    tf.random.set_seed(x)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 1. Load Data

# %%
if (notifyStatus): email_notify("Phase 1 Load Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## 1.a) Load Dataset

# %%
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-springleaf-marketing-response/train.csv'
Xy_original = pd.read_csv(dataset_path, sep=',', na_values=["NA"," [] ",""], true_values=["true"], false_values=["false"])

# Take a peek at the dataframe after the import
Xy_original.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,9,10,11,12,43,157,196,214,225,228,229,231,235,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID VAR_0001  VAR_0002  VAR_0003  ...  VAR_1932 VAR_1933  VAR_1934  target
# 0   2        H       224         0  ...      9998     9998      IAPS       0
# 1   4        H         7        53  ...      9998     9998      IAPS       0
# 2   5        H       116         3  ...      9998     9998      IAPS       0
# 3   7        H       240       300  ...      9998     9998       RCC       0
# 4   8        R        72       261  ...      9998     9998    BRANCH       1
# 5  14        R         4         4  ...      9998     9998      IAPS       0
# 6  16        H        60       132  ...      9996       76      IAPS       1
# 7  20        R        13        75  ...      9998     9998      IAPS       0
# 8  21        R        17        16  ...      9996       90    MOBILE       1
# 9  22        R        24        72  ...      9998     9998    BRANCH       0
#
# [10 rows x 1934 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145231 entries, 0 to 145230
# Data columns (total 1934 columns):
# ID          int64
# VAR_0001    object
# VAR_0002    int64
# VAR_0003    int64
# VAR_0004    int64
# VAR_0005    object
# VAR_0006    float64
# VAR_0007    float64
# VAR_0008    object
# VAR_0009    object
# VAR_0010    object
# VAR_0011    object
# VAR_0012    object
# VAR_0013    float64
# VAR_0014    float64
# VAR_0015    float64
# VAR_0016    float64
# VAR_0017    float64
# VAR_0018    float64
# VAR_0019    float64
# VAR_0020    float64
# VAR_0021    float64
# VAR_0022    float64
# VAR_0023    float64
# VAR_0024    float64
# VAR_0025    float64
# VAR_0026    float64
# VAR_0027    float64
# VAR_0028    float64
# VAR_0029    float64
# VAR_0030    float64
# VAR_0031    float64
# VAR_0032    float64
# VAR_0033    float64
# VAR_0034    float64
# VAR_0035    float64
# VAR_0036    float64
# VAR_0037    float64
# VAR_0038    float64
# VAR_0039    float64
# VAR_0040    float64
# VAR_0041    float64
# VAR_0042    float64
# VAR_0043    object
# VAR_0044    object
# VAR_0045    float64
# VAR_0046    float64
# VAR_0047    float64
# VAR_0048    float64
# VAR_0049    float64
# VAR_0050    float64
# VAR_0051    float64
# VAR_0052    float64
# VAR_0053    float64
# VAR_0054    float64
# VAR_0055    float64
# VAR_0056    float64
# VAR_0057    float64
# VAR_0058    float64
# VAR_0059    float64
# VAR_0060    float64
# VAR_0061    float64
# VAR_0062    float64
# VAR_0063    float64
# VAR_0064    float64
# VAR_0065    float64
# VAR_0066    float64
# VAR_0067    float64
# VAR_0068    float64
# VAR_0069    float64
# VAR_0070    float64
# VAR_0071    float64
# VAR_0072    float64
# VAR_0073    object
# VAR_0074    float64
# VAR_0075    object
# VAR_0076    float64
# VAR_0077    float64
# VAR_0078    float64
# VAR_0079    float64
# VAR_0080    float64
# VAR_0081    float64
# VAR_0082    float64
# VAR_0083    float64
# VAR_0084    float64
# VAR_0085    float64
# VAR_0086    float64
# VAR_0087    float64
# VAR_0088    float64
# VAR_0089    float64
# VAR_0090    float64
# VAR_0091    float64
# VAR_0092    float64
# VAR_0093    float64
# VAR_0094    float64
# VAR_0095    float64
# VAR_0096    float64
# VAR_0097    float64
# VAR_0098    float64
# VAR_0099    float64
# VAR_0100    float64
# VAR_0101    float64
# VAR_0102    float64
# VAR_0103    float64
# VAR_0104    float64
# VAR_0105    float64
# VAR_0106    float64
# VAR_0107    float64
# VAR_0108    float64
# VAR_0109    float64
# VAR_0110    float64
# VAR_0111    float64
# VAR_0112    float64
# VAR_0113    float64
# VAR_0114    float64
# VAR_0115    float64
# VAR_0116    float64
# VAR_0117    float64
# VAR_0118    float64
# VAR_0119    float64
# VAR_0120    float64
# VAR_0121    float64
# VAR_0122    float64
# VAR_0123    float64
# VAR_0124    float64
# VAR_0125    float64
# VAR_0126    float64
# VAR_0127    float64
# VAR_0128    float64
# VAR_0129    float64
# VAR_0130    float64
# VAR_0131    float64
# VAR_0132    float64
# VAR_0133    float64
# VAR_0134    float64
# VAR_0135    float64
# VAR_0136    float64
# VAR_0137    float64
# VAR_0138    float64
# VAR_0139    float64
# VAR_0140    float64
# VAR_0141    float64
# VAR_0142    float64
# VAR_0143    float64
# VAR_0144    float64
# VAR_0145    float64
# VAR_0146    float64
# VAR_0147    float64
# VAR_0148    float64
# VAR_0149    float64
# VAR_0150    float64
# VAR_0151    float64
# VAR_0152    float64
# VAR_0153    float64
# VAR_0154    float64
# VAR_0155    float64
# VAR_0156    object
# VAR_0157    object
# VAR_0158    object
# VAR_0159    object
# VAR_0160    float64
# VAR_0161    float64
# VAR_0162    float64
# VAR_0163    float64
# VAR_0164    float64
# VAR_0165    float64
# VAR_0166    object
# VAR_0167    object
# VAR_0168    object
# VAR_0169    object
# VAR_0170    float64
# VAR_0171    float64
# VAR_0172    float64
# VAR_0173    float64
# VAR_0174    float64
# VAR_0175    float64
# VAR_0176    object
# VAR_0177    object
# VAR_0178    object
# VAR_0179    object
# VAR_0180    float64
# VAR_0181    float64
# VAR_0182    float64
# VAR_0183    float64
# VAR_0184    float64
# VAR_0185    float64
# VAR_0186    float64
# VAR_0187    float64
# VAR_0188    float64
# VAR_0189    float64
# VAR_0190    float64
# VAR_0191    float64
# VAR_0192    float64
# VAR_0193    float64
# VAR_0194    float64
# VAR_0195    float64
# VAR_0196    object
# VAR_0197    float64
# VAR_0198    float64
# VAR_0199    float64
# VAR_0200    object
# VAR_0201    float64
# VAR_0202    object
# VAR_0203    float64
# VAR_0204    object
# VAR_0205    float64
# VAR_0206    float64
# VAR_0207    float64
# VAR_0208    float64
# VAR_0209    float64
# VAR_0210    float64
# VAR_0211    float64
# VAR_0212    float64
# VAR_0213    float64
# VAR_0214    object
# VAR_0215    float64
# VAR_0216    object
# VAR_0217    object
# VAR_0219    float64
# VAR_0220    float64
# VAR_0221    float64
# VAR_0222    object
# VAR_0223    float64
# VAR_0224    float64
# VAR_0225    float64
# VAR_0226    object
# VAR_0227    float64
# VAR_0228    float64
# VAR_0229    object
# VAR_0230    object
# VAR_0231    float64
# VAR_0232    object
# VAR_0233    float64
# VAR_0234    float64
# VAR_0235    float64
# VAR_0236    object
# VAR_0237    object
# VAR_0238    float64
# VAR_0239    object
# VAR_0241    float64
# VAR_0242    float64
# VAR_0243    float64
# VAR_0244    float64
# VAR_0245    float64
# VAR_0246    float64
# VAR_0247    float64
# VAR_0248    float64
# VAR_0249    float64
# VAR_0250    float64
# VAR_0251    float64
# VAR_0252    float64
# VAR_0253    float64
# VAR_0254    float64
# VAR_0255    float64
# VAR_0256    float64
# VAR_0257    float64
# VAR_0258    float64
# VAR_0259    float64
# VAR_0260    float64
# VAR_0261    float64
# VAR_0262    float64
# VAR_0263    float64
# VAR_0264    float64
# VAR_0265    float64
# VAR_0266    float64
# VAR_0267    float64
# VAR_0268    float64
# VAR_0269    float64
# VAR_0270    float64
# VAR_0271    float64
# VAR_0272    float64
# VAR_0273    float64
# VAR_0274    object
# VAR_0275    float64
# VAR_0276    float64
# VAR_0277    float64
# VAR_0278    float64
# VAR_0279    float64
# VAR_0280    float64
# VAR_0281    float64
# VAR_0282    float64
# VAR_0283    object
# VAR_0284    float64
# VAR_0285    float64
# VAR_0286    float64
# VAR_0287    float64
# VAR_0288    float64
# VAR_0289    float64
# VAR_0290    float64
# VAR_0291    float64
# VAR_0292    float64
# VAR_0293    float64
# VAR_0294    float64
# VAR_0295    float64
# VAR_0296    float64
# VAR_0297    float64
# VAR_0298    float64
# VAR_0299    float64
# VAR_0300    float64
# VAR_0301    float64
# VAR_0302    float64
# VAR_0303    float64
# VAR_0304    float64
# VAR_0305    object
# VAR_0306    float64
# VAR_0307    float64
# VAR_0308    float64
# VAR_0309    float64
# VAR_0310    float64
# VAR_0311    float64
# VAR_0312    float64
# VAR_0313    float64
# VAR_0314    float64
# VAR_0315    float64
# VAR_0316    float64
# VAR_0317    float64
# VAR_0318    float64
# VAR_0319    float64
# VAR_0320    float64
# VAR_0321    float64
# VAR_0322    float64
# VAR_0323    float64
# VAR_0324    float64
# VAR_0325    object
# VAR_0326    float64
# VAR_0327    float64
# VAR_0328    float64
# VAR_0329    float64
# VAR_0330    float64
# VAR_0331    float64
# VAR_0332    float64
# VAR_0333    float64
# VAR_0334    float64
# VAR_0335    float64
# VAR_0336    float64
# VAR_0337    float64
# VAR_0338    float64
# VAR_0339    float64
# VAR_0340    float64
# VAR_0341    float64
# VAR_0342    object
# VAR_0343    float64
# VAR_0344    float64
# VAR_0345    float64
# VAR_0346    float64
# VAR_0347    float64
# VAR_0348    float64
# VAR_0349    float64
# VAR_0350    float64
# VAR_0351    float64
# VAR_0352    object
# VAR_0353    object
# VAR_0354    object
# VAR_0355    float64
# VAR_0356    float64
# VAR_0357    float64
# VAR_0358    float64
# VAR_0359    float64
# VAR_0360    float64
# VAR_0361    float64
# VAR_0362    float64
# VAR_0363    float64
# VAR_0364    float64
# VAR_0365    float64
# VAR_0366    float64
# VAR_0367    float64
# VAR_0368    float64
# VAR_0369    float64
# VAR_0370    float64
# VAR_0371    float64
# VAR_0372    float64
# VAR_0373    float64
# VAR_0374    float64
# VAR_0375    float64
# VAR_0376    float64
# VAR_0377    float64
# VAR_0378    float64
# VAR_0379    float64
# VAR_0380    float64
# VAR_0381    float64
# VAR_0382    float64
# VAR_0383    float64
# VAR_0384    float64
# VAR_0385    float64
# VAR_0386    float64
# VAR_0387    float64
# VAR_0388    float64
# VAR_0389    float64
# VAR_0390    float64
# VAR_0391    float64
# VAR_0392    float64
# VAR_0393    float64
# VAR_0394    float64
# VAR_0395    float64
# VAR_0396    float64
# VAR_0397    float64
# VAR_0398    float64
# VAR_0399    float64
# VAR_0400    float64
# VAR_0401    float64
# VAR_0402    float64
# VAR_0403    float64
# VAR_0404    object
# VAR_0405    float64
# VAR_0406    float64
# VAR_0407    float64
# VAR_0408    float64
# VAR_0409    float64
# VAR_0410    float64
# VAR_0411    float64
# VAR_0412    float64
# VAR_0413    float64
# VAR_0414    float64
# VAR_0415    float64
# VAR_0416    float64
# VAR_0417    float64
# VAR_0418    float64
# VAR_0419    float64
# VAR_0420    float64
# VAR_0421    float64
# VAR_0422    float64
# VAR_0423    float64
# VAR_0424    float64
# VAR_0425    float64
# VAR_0426    float64
# VAR_0427    float64
# VAR_0428    float64
# VAR_0429    float64
# VAR_0430    float64
# VAR_0431    float64
# VAR_0432    float64
# VAR_0433    float64
# VAR_0434    float64
# VAR_0435    float64
# VAR_0436    float64
# VAR_0437    float64
# VAR_0438    float64
# VAR_0439    float64
# VAR_0440    float64
# VAR_0441    float64
# VAR_0442    float64
# VAR_0443    float64
# VAR_0444    float64
# VAR_0445    float64
# VAR_0446    float64
# VAR_0447    float64
# VAR_0448    float64
# VAR_0449    float64
# VAR_0450    float64
# VAR_0451    float64
# VAR_0452    float64
# VAR_0453    float64
# VAR_0454    float64
# VAR_0455    float64
# VAR_0456    float64
# VAR_0457    float64
# VAR_0458    float64
# VAR_0459    float64
# VAR_0460    float64
# VAR_0461    float64
# VAR_0462    float64
# VAR_0463    float64
# VAR_0464    float64
# VAR_0465    float64
# VAR_0466    object
# VAR_0467    object
# VAR_0468    float64
# VAR_0469    float64
# VAR_0470    float64
# VAR_0471    float64
# VAR_0472    float64
# VAR_0473    float64
# VAR_0474    float64
# VAR_0475    float64
# VAR_0476    float64
# VAR_0477    float64
# VAR_0478    float64
# VAR_0479    float64
# VAR_0480    float64
# VAR_0481    float64
# VAR_0482    float64
# VAR_0483    float64
# VAR_0484    float64
# VAR_0485    float64
# VAR_0486    float64
# VAR_0487    float64
# VAR_0488    float64
# VAR_0489    float64
# VAR_0490    float64
# VAR_0491    float64
# VAR_0492    float64
# VAR_0493    object
# VAR_0494    float64
# VAR_0495    float64
# VAR_0496    float64
# VAR_0497    float64
# VAR_0498    float64
# VAR_0499    float64
# VAR_0500    float64
# VAR_0501    float64
# VAR_0502    float64
# VAR_0503    float64
# VAR_0504    float64
# VAR_0505    float64
# VAR_0506    float64
# VAR_0507    float64
# VAR_0508    float64
# VAR_0509    float64
# VAR_0510    float64
# VAR_0511    float64
# VAR_0512    float64
# VAR_0513    float64
# VAR_0514    float64
# VAR_0515    float64
# VAR_0516    float64
# VAR_0517    float64
# VAR_0518    float64
# VAR_0519    float64
# VAR_0520    float64
# VAR_0521    float64
# VAR_0522    float64
# VAR_0523    float64
# VAR_0524    float64
# VAR_0525    float64
# VAR_0526    float64
# VAR_0527    float64
# VAR_0528    float64
# VAR_0529    float64
# VAR_0530    float64
# VAR_0531    float64
# VAR_0532    int64
# VAR_0533    int64
# VAR_0534    int64
# VAR_0535    int64
# VAR_0536    int64
# VAR_0537    int64
# VAR_0538    int64
# VAR_0539    int64
# VAR_0540    int64
# VAR_0541    int64
# VAR_0542    int64
# VAR_0543    int64
# VAR_0544    int64
# VAR_0545    int64
# VAR_0546    int64
# VAR_0547    int64
# VAR_0548    int64
# VAR_0549    int64
# VAR_0550    int64
# VAR_0551    int64
# VAR_0552    int64
# VAR_0553    int64
# VAR_0554    int64
# VAR_0555    int64
# VAR_0556    int64
# VAR_0557    int64
# VAR_0558    int64
# VAR_0559    int64
# VAR_0560    int64
# VAR_0561    int64
# VAR_0562    int64
# VAR_0563    int64
# VAR_0564    int64
# VAR_0565    int64
# VAR_0566    int64
# VAR_0567    int64
# VAR_0568    int64
# VAR_0569    int64
# VAR_0570    int64
# VAR_0571    int64
# VAR_0572    int64
# VAR_0573    int64
# VAR_0574    int64
# VAR_0575    int64
# VAR_0576    int64
# VAR_0577    int64
# VAR_0578    int64
# VAR_0579    int64
# VAR_0580    int64
# VAR_0581    int64
# VAR_0582    int64
# VAR_0583    int64
# VAR_0584    int64
# VAR_0585    int64
# VAR_0586    int64
# VAR_0587    int64
# VAR_0588    int64
# VAR_0589    int64
# VAR_0590    int64
# VAR_0591    int64
# VAR_0592    int64
# VAR_0593    int64
# VAR_0594    int64
# VAR_0595    int64
# VAR_0596    int64
# VAR_0597    int64
# VAR_0598    int64
# VAR_0599    int64
# VAR_0600    int64
# VAR_0601    int64
# VAR_0602    int64
# VAR_0603    int64
# VAR_0604    int64
# VAR_0605    int64
# VAR_0606    int64
# VAR_0607    int64
# VAR_0608    int64
# VAR_0609    int64
# VAR_0610    int64
# VAR_0611    int64
# VAR_0612    int64
# VAR_0613    int64
# VAR_0614    int64
# VAR_0615    int64
# VAR_0616    int64
# VAR_0617    int64
# VAR_0618    int64
# VAR_0619    int64
# VAR_0620    int64
# VAR_0621    int64
# VAR_0622    int64
# VAR_0623    int64
# VAR_0624    int64
# VAR_0625    int64
# VAR_0626    int64
# VAR_0627    int64
# VAR_0628    int64
# VAR_0629    int64
# VAR_0630    int64
# VAR_0631    int64
# VAR_0632    int64
# VAR_0633    int64
# VAR_0634    int64
# VAR_0635    int64
# VAR_0636    int64
# VAR_0637    int64
# VAR_0638    int64
# VAR_0639    int64
# VAR_0640    int64
# VAR_0641    int64
# VAR_0642    int64
# VAR_0643    int64
# VAR_0644    int64
# VAR_0645    int64
# VAR_0646    int64
# VAR_0647    int64
# VAR_0648    int64
# VAR_0649    int64
# VAR_0650    int64
# VAR_0651    int64
# VAR_0652    int64
# VAR_0653    int64
# VAR_0654    int64
# VAR_0655    int64
# VAR_0656    int64
# VAR_0657    int64
# VAR_0658    int64
# VAR_0659    int64
# VAR_0660    int64
# VAR_0661    int64
# VAR_0662    int64
# VAR_0663    int64
# VAR_0664    int64
# VAR_0665    int64
# VAR_0666    int64
# VAR_0667    int64
# VAR_0668    int64
# VAR_0669    int64
# VAR_0670    int64
# VAR_0671    int64
# VAR_0672    int64
# VAR_0673    int64
# VAR_0674    int64
# VAR_0675    int64
# VAR_0676    int64
# VAR_0677    int64
# VAR_0678    int64
# VAR_0679    int64
# VAR_0680    int64
# VAR_0681    int64
# VAR_0682    int64
# VAR_0683    int64
# VAR_0684    int64
# VAR_0685    int64
# VAR_0686    int64
# VAR_0687    int64
# VAR_0688    int64
# VAR_0689    int64
# VAR_0690    int64
# VAR_0691    int64
# VAR_0692    int64
# VAR_0693    int64
# VAR_0694    int64
# VAR_0695    int64
# VAR_0696    int64
# VAR_0697    int64
# VAR_0698    int64
# VAR_0699    int64
# VAR_0700    int64
# VAR_0701    int64
# VAR_0702    int64
# VAR_0703    int64
# VAR_0704    int64
# VAR_0705    int64
# VAR_0706    int64
# VAR_0707    int64
# VAR_0708    int64
# VAR_0709    int64
# VAR_0710    int64
# VAR_0711    int64
# VAR_0712    int64
# VAR_0713    int64
# VAR_0714    int64
# VAR_0715    int64
# VAR_0716    int64
# VAR_0717    int64
# VAR_0718    int64
# VAR_0719    int64
# VAR_0720    int64
# VAR_0721    int64
# VAR_0722    int64
# VAR_0723    int64
# VAR_0724    int64
# VAR_0725    int64
# VAR_0726    int64
# VAR_0727    int64
# VAR_0728    int64
# VAR_0729    int64
# VAR_0730    int64
# VAR_0731    int64
# VAR_0732    int64
# VAR_0733    int64
# VAR_0734    int64
# VAR_0735    int64
# VAR_0736    int64
# VAR_0737    int64
# VAR_0738    int64
# VAR_0739    int64
# VAR_0740    int64
# VAR_0741    int64
# VAR_0742    int64
# VAR_0743    int64
# VAR_0744    int64
# VAR_0745    int64
# VAR_0746    int64
# VAR_0747    int64
# VAR_0748    int64
# VAR_0749    int64
# VAR_0750    int64
# VAR_0751    int64
# VAR_0752    int64
# VAR_0753    int64
# VAR_0754    int64
# VAR_0755    int64
# VAR_0756    int64
# VAR_0757    int64
# VAR_0758    int64
# VAR_0759    int64
# VAR_0760    int64
# VAR_0761    int64
# VAR_0762    int64
# VAR_0763    int64
# VAR_0764    int64
# VAR_0765    int64
# VAR_0766    int64
# VAR_0767    int64
# VAR_0768    int64
# VAR_0769    int64
# VAR_0770    int64
# VAR_0771    int64
# VAR_0772    int64
# VAR_0773    int64
# VAR_0774    int64
# VAR_0775    int64
# VAR_0776    int64
# VAR_0777    int64
# VAR_0778    int64
# VAR_0779    int64
# VAR_0780    int64
# VAR_0781    int64
# VAR_0782    int64
# VAR_0783    int64
# VAR_0784    int64
# VAR_0785    int64
# VAR_0786    int64
# VAR_0787    int64
# VAR_0788    int64
# VAR_0789    int64
# VAR_0790    int64
# VAR_0791    int64
# VAR_0792    int64
# VAR_0793    int64
# VAR_0794    int64
# VAR_0795    int64
# VAR_0796    int64
# VAR_0797    int64
# VAR_0798    int64
# VAR_0799    int64
# VAR_0800    int64
# VAR_0801    int64
# VAR_0802    int64
# VAR_0803    int64
# VAR_0804    int64
# VAR_0805    int64
# VAR_0806    int64
# VAR_0807    int64
# VAR_0808    int64
# VAR_0809    int64
# VAR_0810    int64
# VAR_0811    int64
# VAR_0812    int64
# VAR_0813    int64
# VAR_0814    int64
# VAR_0815    int64
# VAR_0816    int64
# VAR_0817    int64
# VAR_0818    int64
# VAR_0819    int64
# VAR_0820    int64
# VAR_0821    int64
# VAR_0822    int64
# VAR_0823    int64
# VAR_0824    int64
# VAR_0825    int64
# VAR_0826    int64
# VAR_0827    int64
# VAR_0828    int64
# VAR_0829    int64
# VAR_0830    int64
# VAR_0831    int64
# VAR_0832    int64
# VAR_0833    int64
# VAR_0834    int64
# VAR_0835    int64
# VAR_0836    int64
# VAR_0837    int64
# VAR_0838    int64
# VAR_0839    int64
# VAR_0840    float64
# VAR_0841    int64
# VAR_0842    int64
# VAR_0843    int64
# VAR_0844    int64
# VAR_0845    int64
# VAR_0846    int64
# VAR_0847    int64
# VAR_0848    int64
# VAR_0849    int64
# VAR_0850    int64
# VAR_0851    int64
# VAR_0852    int64
# VAR_0853    int64
# VAR_0854    int64
# VAR_0855    int64
# VAR_0856    int64
# VAR_0857    int64
# VAR_0858    int64
# VAR_0859    int64
# VAR_0860    int64
# VAR_0861    int64
# VAR_0862    int64
# VAR_0863    int64
# VAR_0864    int64
# VAR_0865    int64
# VAR_0866    int64
# VAR_0867    int64
# VAR_0868    int64
# VAR_0869    int64
# VAR_0870    int64
# VAR_0871    int64
# VAR_0872    int64
# VAR_0873    int64
# VAR_0874    int64
# VAR_0875    int64
# VAR_0876    int64
# VAR_0877    int64
# VAR_0878    int64
# VAR_0879    int64
# VAR_0880    int64
# VAR_0881    int64
# VAR_0882    int64
# VAR_0883    int64
# VAR_0884    int64
# VAR_0885    int64
# VAR_0886    int64
# VAR_0887    int64
# VAR_0888    int64
# VAR_0889    int64
# VAR_0890    int64
# VAR_0891    int64
# VAR_0892    int64
# VAR_0893    int64
# VAR_0894    int64
# VAR_0895    int64
# VAR_0896    int64
# VAR_0897    int64
# VAR_0898    int64
# VAR_0899    int64
# VAR_0900    int64
# VAR_0901    int64
# VAR_0902    int64
# VAR_0903    int64
# VAR_0904    int64
# VAR_0905    int64
# VAR_0906    int64
# VAR_0907    int64
# VAR_0908    int64
# VAR_0909    int64
# VAR_0910    int64
# VAR_0911    int64
# VAR_0912    int64
# VAR_0913    int64
# VAR_0914    int64
# VAR_0915    int64
# VAR_0916    int64
# VAR_0917    int64
# VAR_0918    int64
# VAR_0919    int64
# VAR_0920    int64
# VAR_0921    int64
# VAR_0922    int64
# VAR_0923    int64
# VAR_0924    int64
# VAR_0925    int64
# VAR_0926    int64
# VAR_0927    int64
# VAR_0928    int64
# VAR_0929    int64
# VAR_0930    int64
# VAR_0931    int64
# VAR_0932    int64
# VAR_0933    int64
# VAR_0934    int64
# VAR_0935    int64
# VAR_0936    int64
# VAR_0937    int64
# VAR_0938    int64
# VAR_0939    int64
# VAR_0940    int64
# VAR_0941    int64
# VAR_0942    int64
# VAR_0943    int64
# VAR_0944    int64
# VAR_0945    int64
# VAR_0946    int64
# VAR_0947    int64
# VAR_0948    int64
# VAR_0949    int64
# VAR_0950    int64
# VAR_0951    int64
# VAR_0952    int64
# VAR_0953    int64
# VAR_0954    int64
# VAR_0955    int64
# VAR_0956    int64
# VAR_0957    int64
# VAR_0958    int64
# VAR_0959    int64
# VAR_0960    int64
# VAR_0961    int64
# VAR_0962    int64
# VAR_0963    int64
# VAR_0964    int64
# VAR_0965    int64
# VAR_0966    int64
# VAR_0967    int64
# VAR_0968    int64
# VAR_0969    int64
# VAR_0970    int64
# VAR_0971    int64
# VAR_0972    int64
# VAR_0973    int64
# VAR_0974    int64
# VAR_0975    int64
# VAR_0976    int64
# VAR_0977    int64
# VAR_0978    int64
# VAR_0979    int64
# VAR_0980    int64
# VAR_0981    int64
# VAR_0982    int64
# VAR_0983    int64
# VAR_0984    int64
# VAR_0985    int64
# VAR_0986    int64
# VAR_0987    int64
# VAR_0988    int64
# VAR_0989    int64
# VAR_0990    int64
# VAR_0991    int64
# VAR_0992    int64
# VAR_0993    int64
# VAR_0994    int64
# VAR_0995    int64
# VAR_0996    int64
# VAR_0997    int64
# VAR_0998    int64
# VAR_0999    int64
# VAR_1000    int64
# VAR_1001    int64
# VAR_1002    int64
# VAR_1003    int64
# VAR_1004    int64
# VAR_1005    int64
# VAR_1006    int64
# VAR_1007    int64
# VAR_1008    int64
# VAR_1009    int64
# VAR_1010    int64
# VAR_1011    int64
# VAR_1012    int64
# VAR_1013    int64
# VAR_1014    int64
# VAR_1015    int64
# VAR_1016    int64
# VAR_1017    int64
# VAR_1018    int64
# VAR_1019    int64
# VAR_1020    int64
# VAR_1021    int64
# VAR_1022    int64
# VAR_1023    int64
# VAR_1024    int64
# VAR_1025    int64
# VAR_1026    int64
# VAR_1027    int64
# VAR_1028    int64
# VAR_1029    int64
# VAR_1030    int64
# VAR_1031    int64
# VAR_1032    int64
# VAR_1033    int64
# VAR_1034    int64
# VAR_1035    int64
# VAR_1036    int64
# VAR_1037    int64
# VAR_1038    int64
# VAR_1039    int64
# VAR_1040    int64
# VAR_1041    int64
# VAR_1042    int64
# VAR_1043    int64
# VAR_1044    int64
# VAR_1045    int64
# VAR_1046    int64
# VAR_1047    int64
# VAR_1048    int64
# VAR_1049    int64
# VAR_1050    int64
# VAR_1051    int64
# VAR_1052    int64
# VAR_1053    int64
# VAR_1054    int64
# VAR_1055    int64
# VAR_1056    int64
# VAR_1057    int64
# VAR_1058    int64
# VAR_1059    int64
# VAR_1060    int64
# VAR_1061    int64
# VAR_1062    int64
# VAR_1063    int64
# VAR_1064    int64
# VAR_1065    int64
# VAR_1066    int64
# VAR_1067    int64
# VAR_1068    int64
# VAR_1069    int64
# VAR_1070    int64
# VAR_1071    int64
# VAR_1072    int64
# VAR_1073    int64
# VAR_1074    int64
# VAR_1075    int64
# VAR_1076    int64
# VAR_1077    int64
# VAR_1078    int64
# VAR_1079    int64
# VAR_1080    int64
# VAR_1081    int64
# VAR_1082    int64
# VAR_1083    int64
# VAR_1084    int64
# VAR_1085    int64
# VAR_1086    int64
# VAR_1087    int64
# VAR_1088    int64
# VAR_1089    int64
# VAR_1090    int64
# VAR_1091    int64
# VAR_1092    int64
# VAR_1093    int64
# VAR_1094    int64
# VAR_1095    int64
# VAR_1096    int64
# VAR_1097    int64
# VAR_1098    int64
# VAR_1099    int64
# VAR_1100    int64
# VAR_1101    int64
# VAR_1102    int64
# VAR_1103    int64
# VAR_1104    int64
# VAR_1105    int64
# VAR_1106    int64
# VAR_1107    int64
# VAR_1108    int64
# VAR_1109    int64
# VAR_1110    int64
# VAR_1111    int64
# VAR_1112    int64
# VAR_1113    int64
# VAR_1114    int64
# VAR_1115    int64
# VAR_1116    int64
# VAR_1117    int64
# VAR_1118    int64
# VAR_1119    int64
# VAR_1120    int64
# VAR_1121    int64
# VAR_1122    int64
# VAR_1123    int64
# VAR_1124    int64
# VAR_1125    int64
# VAR_1126    int64
# VAR_1127    int64
# VAR_1128    int64
# VAR_1129    int64
# VAR_1130    int64
# VAR_1131    int64
# VAR_1132    int64
# VAR_1133    int64
# VAR_1134    int64
# VAR_1135    int64
# VAR_1136    int64
# VAR_1137    int64
# VAR_1138    int64
# VAR_1139    int64
# VAR_1140    int64
# VAR_1141    int64
# VAR_1142    int64
# VAR_1143    int64
# VAR_1144    int64
# VAR_1145    int64
# VAR_1146    int64
# VAR_1147    int64
# VAR_1148    int64
# VAR_1149    int64
# VAR_1150    int64
# VAR_1151    int64
# VAR_1152    int64
# VAR_1153    int64
# VAR_1154    int64
# VAR_1155    int64
# VAR_1156    int64
# VAR_1157    int64
# VAR_1158    int64
# VAR_1159    int64
# VAR_1160    int64
# VAR_1161    int64
# VAR_1162    int64
# VAR_1163    int64
# VAR_1164    int64
# VAR_1165    int64
# VAR_1166    int64
# VAR_1167    int64
# VAR_1168    int64
# VAR_1169    int64
# VAR_1170    int64
# VAR_1171    int64
# VAR_1172    int64
# VAR_1173    int64
# VAR_1174    int64
# VAR_1175    int64
# VAR_1176    int64
# VAR_1177    int64
# VAR_1178    int64
# VAR_1179    int64
# VAR_1180    int64
# VAR_1181    int64
# VAR_1182    int64
# VAR_1183    int64
# VAR_1184    int64
# VAR_1185    int64
# VAR_1186    int64
# VAR_1187    int64
# VAR_1188    int64
# VAR_1189    int64
# VAR_1190    int64
# VAR_1191    int64
# VAR_1192    int64
# VAR_1193    int64
# VAR_1194    int64
# VAR_1195    int64
# VAR_1196    int64
# VAR_1197    int64
# VAR_1198    int64
# VAR_1199    int64
# VAR_1200    int64
# VAR_1201    int64
# VAR_1202    int64
# VAR_1203    int64
# VAR_1204    int64
# VAR_1205    int64
# VAR_1206    int64
# VAR_1207    int64
# VAR_1208    int64
# VAR_1209    int64
# VAR_1210    int64
# VAR_1211    int64
# VAR_1212    int64
# VAR_1213    int64
# VAR_1214    int64
# VAR_1215    int64
# VAR_1216    int64
# VAR_1217    int64
# VAR_1218    int64
# VAR_1219    int64
# VAR_1220    int64
# VAR_1221    int64
# VAR_1222    int64
# VAR_1223    int64
# VAR_1224    int64
# VAR_1225    int64
# VAR_1226    int64
# VAR_1227    int64
# VAR_1228    int64
# VAR_1229    int64
# VAR_1230    int64
# VAR_1231    int64
# VAR_1232    int64
# VAR_1233    int64
# VAR_1234    int64
# VAR_1235    int64
# VAR_1236    int64
# VAR_1237    int64
# VAR_1238    int64
# VAR_1239    int64
# VAR_1240    int64
# VAR_1241    int64
# VAR_1242    int64
# VAR_1243    int64
# VAR_1244    int64
# VAR_1245    int64
# VAR_1246    int64
# VAR_1247    int64
# VAR_1248    int64
# VAR_1249    int64
# VAR_1250    int64
# VAR_1251    int64
# VAR_1252    int64
# VAR_1253    int64
# VAR_1254    int64
# VAR_1255    int64
# VAR_1256    int64
# VAR_1257    int64
# VAR_1258    int64
# VAR_1259    int64
# VAR_1260    int64
# VAR_1261    int64
# VAR_1262    int64
# VAR_1263    int64
# VAR_1264    int64
# VAR_1265    int64
# VAR_1266    int64
# VAR_1267    int64
# VAR_1268    int64
# VAR_1269    int64
# VAR_1270    int64
# VAR_1271    int64
# VAR_1272    int64
# VAR_1273    int64
# VAR_1274    int64
# VAR_1275    int64
# VAR_1276    int64
# VAR_1277    int64
# VAR_1278    int64
# VAR_1279    int64
# VAR_1280    int64
# VAR_1281    int64
# VAR_1282    int64
# VAR_1283    int64
# VAR_1284    int64
# VAR_1285    int64
# VAR_1286    int64
# VAR_1287    int64
# VAR_1288    int64
# VAR_1289    int64
# VAR_1290    int64
# VAR_1291    int64
# VAR_1292    int64
# VAR_1293    int64
# VAR_1294    int64
# VAR_1295    int64
# VAR_1296    int64
# VAR_1297    int64
# VAR_1298    int64
# VAR_1299    int64
# VAR_1300    int64
# VAR_1301    int64
# VAR_1302    int64
# VAR_1303    int64
# VAR_1304    int64
# VAR_1305    int64
# VAR_1306    int64
# VAR_1307    int64
# VAR_1308    int64
# VAR_1309    int64
# VAR_1310    int64
# VAR_1311    int64
# VAR_1312    int64
# VAR_1313    int64
# VAR_1314    int64
# VAR_1315    int64
# VAR_1316    int64
# VAR_1317    int64
# VAR_1318    int64
# VAR_1319    int64
# VAR_1320    int64
# VAR_1321    int64
# VAR_1322    int64
# VAR_1323    int64
# VAR_1324    int64
# VAR_1325    int64
# VAR_1326    int64
# VAR_1327    int64
# VAR_1328    int64
# VAR_1329    int64
# VAR_1330    int64
# VAR_1331    int64
# VAR_1332    int64
# VAR_1333    int64
# VAR_1334    int64
# VAR_1335    int64
# VAR_1336    int64
# VAR_1337    int64
# VAR_1338    int64
# VAR_1339    int64
# VAR_1340    int64
# VAR_1341    int64
# VAR_1342    int64
# VAR_1343    int64
# VAR_1344    int64
# VAR_1345    int64
# VAR_1346    int64
# VAR_1347    int64
# VAR_1348    int64
# VAR_1349    int64
# VAR_1350    int64
# VAR_1351    int64
# VAR_1352    int64
# VAR_1353    int64
# VAR_1354    int64
# VAR_1355    int64
# VAR_1356    int64
# VAR_1357    int64
# VAR_1358    int64
# VAR_1359    int64
# VAR_1360    int64
# VAR_1361    int64
# VAR_1362    int64
# VAR_1363    int64
# VAR_1364    int64
# VAR_1365    int64
# VAR_1366    int64
# VAR_1367    int64
# VAR_1368    int64
# VAR_1369    int64
# VAR_1370    int64
# VAR_1371    int64
# VAR_1372    int64
# VAR_1373    int64
# VAR_1374    int64
# VAR_1375    int64
# VAR_1376    int64
# VAR_1377    int64
# VAR_1378    int64
# VAR_1379    int64
# VAR_1380    int64
# VAR_1381    int64
# VAR_1382    int64
# VAR_1383    int64
# VAR_1384    int64
# VAR_1385    int64
# VAR_1386    int64
# VAR_1387    int64
# VAR_1388    int64
# VAR_1389    int64
# VAR_1390    int64
# VAR_1391    int64
# VAR_1392    int64
# VAR_1393    int64
# VAR_1394    int64
# VAR_1395    int64
# VAR_1396    int64
# VAR_1397    int64
# VAR_1398    int64
# VAR_1399    int64
# VAR_1400    int64
# VAR_1401    int64
# VAR_1402    int64
# VAR_1403    int64
# VAR_1404    int64
# VAR_1405    int64
# VAR_1406    int64
# VAR_1407    int64
# VAR_1408    int64
# VAR_1409    int64
# VAR_1410    int64
# VAR_1411    int64
# VAR_1412    int64
# VAR_1413    int64
# VAR_1414    int64
# VAR_1415    int64
# VAR_1416    int64
# VAR_1417    int64
# VAR_1418    int64
# VAR_1419    int64
# VAR_1420    int64
# VAR_1421    int64
# VAR_1422    int64
# VAR_1423    int64
# VAR_1424    int64
# VAR_1425    int64
# VAR_1426    int64
# VAR_1427    int64
# VAR_1428    int64
# VAR_1429    int64
# VAR_1430    int64
# VAR_1431    int64
# VAR_1432    int64
# VAR_1433    int64
# VAR_1434    int64
# VAR_1435    int64
# VAR_1436    int64
# VAR_1437    int64
# VAR_1438    int64
# VAR_1439    int64
# VAR_1440    int64
# VAR_1441    int64
# VAR_1442    int64
# VAR_1443    int64
# VAR_1444    int64
# VAR_1445    int64
# VAR_1446    int64
# VAR_1447    int64
# VAR_1448    int64
# VAR_1449    int64
# VAR_1450    int64
# VAR_1451    int64
# VAR_1452    int64
# VAR_1453    int64
# VAR_1454    int64
# VAR_1455    int64
# VAR_1456    int64
# VAR_1457    int64
# VAR_1458    int64
# VAR_1459    int64
# VAR_1460    int64
# VAR_1461    int64
# VAR_1462    int64
# VAR_1463    int64
# VAR_1464    int64
# VAR_1465    int64
# VAR_1466    int64
# VAR_1467    int64
# VAR_1468    int64
# VAR_1469    int64
# VAR_1470    int64
# VAR_1471    int64
# VAR_1472    int64
# VAR_1473    int64
# VAR_1474    int64
# VAR_1475    int64
# VAR_1476    int64
# VAR_1477    int64
# VAR_1478    int64
# VAR_1479    int64
# VAR_1480    int64
# VAR_1481    int64
# VAR_1482    int64
# VAR_1483    int64
# VAR_1484    int64
# VAR_1485    int64
# VAR_1486    int64
# VAR_1487    int64
# VAR_1488    int64
# VAR_1489    int64
# VAR_1490    int64
# VAR_1491    int64
# VAR_1492    int64
# VAR_1493    int64
# VAR_1494    int64
# VAR_1495    int64
# VAR_1496    int64
# VAR_1497    int64
# VAR_1498    int64
# VAR_1499    int64
# VAR_1500    int64
# VAR_1501    int64
# VAR_1502    int64
# VAR_1503    int64
# VAR_1504    int64
# VAR_1505    int64
# VAR_1506    int64
# VAR_1507    int64
# VAR_1508    int64
# VAR_1509    int64
# VAR_1510    int64
# VAR_1511    int64
# VAR_1512    int64
# VAR_1513    int64
# VAR_1514    int64
# VAR_1515    int64
# VAR_1516    int64
# VAR_1517    int64
# VAR_1518    int64
# VAR_1519    int64
# VAR_1520    int64
# VAR_1521    int64
# VAR_1522    int64
# VAR_1523    int64
# VAR_1524    int64
# VAR_1525    int64
# VAR_1526    int64
# VAR_1527    int64
# VAR_1528    int64
# VAR_1529    int64
# VAR_1530    int64
# VAR_1531    int64
# VAR_1532    int64
# VAR_1533    int64
# VAR_1534    int64
# VAR_1535    int64
# VAR_1536    int64
# VAR_1537    int64
# VAR_1538    int64
# VAR_1539    int64
# VAR_1540    int64
# VAR_1541    int64
# VAR_1542    int64
# VAR_1543    int64
# VAR_1544    int64
# VAR_1545    int64
# VAR_1546    int64
# VAR_1547    int64
# VAR_1548    int64
# VAR_1549    int64
# VAR_1550    int64
# VAR_1551    int64
# VAR_1552    int64
# VAR_1553    int64
# VAR_1554    int64
# VAR_1555    int64
# VAR_1556    int64
# VAR_1557    int64
# VAR_1558    int64
# VAR_1559    int64
# VAR_1560    int64
# VAR_1561    int64
# VAR_1562    int64
# VAR_1563    int64
# VAR_1564    int64
# VAR_1565    int64
# VAR_1566    int64
# VAR_1567    int64
# VAR_1568    int64
# VAR_1569    int64
# VAR_1570    int64
# VAR_1571    int64
# VAR_1572    int64
# VAR_1573    int64
# VAR_1574    int64
# VAR_1575    int64
# VAR_1576    int64
# VAR_1577    int64
# VAR_1578    int64
# VAR_1579    int64
# VAR_1580    int64
# VAR_1581    int64
# VAR_1582    int64
# VAR_1583    int64
# VAR_1584    int64
# VAR_1585    int64
# VAR_1586    int64
# VAR_1587    int64
# VAR_1588    int64
# VAR_1589    int64
# VAR_1590    int64
# VAR_1591    int64
# VAR_1592    int64
# VAR_1593    int64
# VAR_1594    int64
# VAR_1595    int64
# VAR_1596    int64
# VAR_1597    int64
# VAR_1598    int64
# VAR_1599    int64
# VAR_1600    int64
# VAR_1601    int64
# VAR_1602    int64
# VAR_1603    int64
# VAR_1604    int64
# VAR_1605    int64
# VAR_1606    int64
# VAR_1607    int64
# VAR_1608    int64
# VAR_1609    int64
# VAR_1610    int64
# VAR_1611    int64
# VAR_1612    int64
# VAR_1613    int64
# VAR_1614    int64
# VAR_1615    int64
# VAR_1616    int64
# VAR_1617    int64
# VAR_1618    int64
# VAR_1619    int64
# VAR_1620    int64
# VAR_1621    int64
# VAR_1622    int64
# VAR_1623    int64
# VAR_1624    int64
# VAR_1625    int64
# VAR_1626    int64
# VAR_1627    int64
# VAR_1628    int64
# VAR_1629    int64
# VAR_1630    int64
# VAR_1631    int64
# VAR_1632    int64
# VAR_1633    int64
# VAR_1634    int64
# VAR_1635    int64
# VAR_1636    int64
# VAR_1637    int64
# VAR_1638    int64
# VAR_1639    int64
# VAR_1640    int64
# VAR_1641    int64
# VAR_1642    int64
# VAR_1643    int64
# VAR_1644    int64
# VAR_1645    int64
# VAR_1646    int64
# VAR_1647    int64
# VAR_1648    int64
# VAR_1649    int64
# VAR_1650    int64
# VAR_1651    int64
# VAR_1652    int64
# VAR_1653    int64
# VAR_1654    int64
# VAR_1655    int64
# VAR_1656    int64
# VAR_1657    int64
# VAR_1658    int64
# VAR_1659    int64
# VAR_1660    int64
# VAR_1661    int64
# VAR_1662    int64
# VAR_1663    int64
# VAR_1664    int64
# VAR_1665    int64
# VAR_1666    int64
# VAR_1667    int64
# VAR_1668    int64
# VAR_1669    int64
# VAR_1670    int64
# VAR_1671    int64
# VAR_1672    int64
# VAR_1673    int64
# VAR_1674    int64
# VAR_1675    int64
# VAR_1676    int64
# VAR_1677    int64
# VAR_1678    int64
# VAR_1679    int64
# VAR_1680    int64
# VAR_1681    int64
# VAR_1682    int64
# VAR_1683    int64
# VAR_1684    int64
# VAR_1685    int64
# VAR_1686    int64
# VAR_1687    int64
# VAR_1688    int64
# VAR_1689    int64
# VAR_1690    int64
# VAR_1691    int64
# VAR_1692    int64
# VAR_1693    int64
# VAR_1694    int64
# VAR_1695    int64
# VAR_1696    int64
# VAR_1697    int64
# VAR_1698    int64
# VAR_1699    int64
# VAR_1700    int64
# VAR_1701    int64
# VAR_1702    int64
# VAR_1703    int64
# VAR_1704    int64
# VAR_1705    int64
# VAR_1706    int64
# VAR_1707    int64
# VAR_1708    int64
# VAR_1709    int64
# VAR_1710    int64
# VAR_1711    int64
# VAR_1712    int64
# VAR_1713    int64
# VAR_1714    int64
# VAR_1715    int64
# VAR_1716    int64
# VAR_1717    int64
# VAR_1718    int64
# VAR_1719    int64
# VAR_1720    int64
# VAR_1721    int64
# VAR_1722    int64
# VAR_1723    int64
# VAR_1724    int64
# VAR_1725    int64
# VAR_1726    int64
# VAR_1727    int64
# VAR_1728    int64
# VAR_1729    int64
# VAR_1730    int64
# VAR_1731    int64
# VAR_1732    int64
# VAR_1733    int64
# VAR_1734    int64
# VAR_1735    int64
# VAR_1736    int64
# VAR_1737    int64
# VAR_1738    int64
# VAR_1739    int64
# VAR_1740    int64
# VAR_1741    int64
# VAR_1742    int64
# VAR_1743    int64
# VAR_1744    int64
# VAR_1745    int64
# VAR_1746    int64
# VAR_1747    int64
# VAR_1748    int64
# VAR_1749    int64
# VAR_1750    int64
# VAR_1751    int64
# VAR_1752    int64
# VAR_1753    int64
# VAR_1754    int64
# VAR_1755    int64
# VAR_1756    int64
# VAR_1757    int64
# VAR_1758    int64
# VAR_1759    int64
# VAR_1760    int64
# VAR_1761    int64
# VAR_1762    int64
# VAR_1763    int64
# VAR_1764    int64
# VAR_1765    int64
# VAR_1766    int64
# VAR_1767    int64
# VAR_1768    int64
# VAR_1769    int64
# VAR_1770    int64
# VAR_1771    int64
# VAR_1772    int64
# VAR_1773    int64
# VAR_1774    int64
# VAR_1775    int64
# VAR_1776    int64
# VAR_1777    int64
# VAR_1778    int64
# VAR_1779    int64
# VAR_1780    int64
# VAR_1781    int64
# VAR_1782    int64
# VAR_1783    int64
# VAR_1784    int64
# VAR_1785    int64
# VAR_1786    int64
# VAR_1787    int64
# VAR_1788    int64
# VAR_1789    int64
# VAR_1790    int64
# VAR_1791    int64
# VAR_1792    int64
# VAR_1793    int64
# VAR_1794    int64
# VAR_1795    int64
# VAR_1796    int64
# VAR_1797    int64
# VAR_1798    int64
# VAR_1799    int64
# VAR_1800    int64
# VAR_1801    int64
# VAR_1802    int64
# VAR_1803    int64
# VAR_1804    int64
# VAR_1805    int64
# VAR_1806    int64
# VAR_1807    int64
# VAR_1808    int64
# VAR_1809    int64
# VAR_1810    int64
# VAR_1811    int64
# VAR_1812    int64
# VAR_1813    int64
# VAR_1814    int64
# VAR_1815    int64
# VAR_1816    int64
# VAR_1817    int64
# VAR_1818    int64
# VAR_1819    int64
# VAR_1820    int64
# VAR_1821    int64
# VAR_1822    int64
# VAR_1823    int64
# VAR_1824    int64
# VAR_1825    int64
# VAR_1826    int64
# VAR_1827    int64
# VAR_1828    int64
# VAR_1829    int64
# VAR_1830    int64
# VAR_1831    int64
# VAR_1832    int64
# VAR_1833    int64
# VAR_1834    int64
# VAR_1835    int64
# VAR_1836    int64
# VAR_1837    int64
# VAR_1838    int64
# VAR_1839    int64
# VAR_1840    int64
# VAR_1841    int64
# VAR_1842    int64
# VAR_1843    int64
# VAR_1844    int64
# VAR_1845    int64
# VAR_1846    int64
# VAR_1847    int64
# VAR_1848    int64
# VAR_1849    int64
# VAR_1850    int64
# VAR_1851    int64
# VAR_1852    int64
# VAR_1853    int64
# VAR_1854    int64
# VAR_1855    int64
# VAR_1856    int64
# VAR_1857    int64
# VAR_1858    int64
# VAR_1859    int64
# VAR_1860    int64
# VAR_1861    int64
# VAR_1862    int64
# VAR_1863    int64
# VAR_1864    int64
# VAR_1865    int64
# VAR_1866    int64
# VAR_1867    int64
# VAR_1868    int64
# VAR_1869    int64
# VAR_1870    int64
# VAR_1871    int64
# VAR_1872    int64
# VAR_1873    int64
# VAR_1874    int64
# VAR_1875    int64
# VAR_1876    int64
# VAR_1877    int64
# VAR_1878    int64
# VAR_1879    int64
# VAR_1880    int64
# VAR_1881    int64
# VAR_1882    int64
# VAR_1883    int64
# VAR_1884    int64
# VAR_1885    int64
# VAR_1886    int64
# VAR_1887    int64
# VAR_1888    int64
# VAR_1889    int64
# VAR_1890    int64
# VAR_1891    int64
# VAR_1892    int64
# VAR_1893    int64
# VAR_1894    int64
# VAR_1895    int64
# VAR_1896    int64
# VAR_1897    int64
# VAR_1898    int64
# VAR_1899    int64
# VAR_1900    int64
# VAR_1901    int64
# VAR_1902    int64
# VAR_1903    int64
# VAR_1904    int64
# VAR_1905    int64
# VAR_1906    int64
# VAR_1907    int64
# VAR_1908    int64
# VAR_1909    int64
# VAR_1910    int64
# VAR_1911    int64
# VAR_1912    int64
# VAR_1913    int64
# VAR_1914    int64
# VAR_1915    int64
# VAR_1916    int64
# VAR_1917    int64
# VAR_1918    int64
# VAR_1919    int64
# VAR_1920    int64
# VAR_1921    int64
# VAR_1922    int64
# VAR_1923    int64
# VAR_1924    int64
# VAR_1925    int64
# VAR_1926    int64
# VAR_1927    int64
# VAR_1928    int64
# VAR_1929    int64
# VAR_1930    int64
# VAR_1931    int64
# VAR_1932    int64
# VAR_1933    int64
# VAR_1934    object
# target      int64
# dtypes: float64(477), int64(1406), object(51)
# memory usage: 2.1+ GB

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# VAR_0006        56
# VAR_0007        56
# VAR_0008        56
# VAR_0009        56
# VAR_0010        56
#              ...
# VAR_0528       918
# VAR_0529       917
# VAR_0530       918
# VAR_0531       917
# VAR_0840    145231
# Length: 525, dtype: int64

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  3511742

# %% [markdown]
# ## 1.b) Data Cleaning

# %%
# Standardize the class column to the name of targetVar if required
Xy_original = Xy_original.rename(columns={'target': 'targetVar'})

# %%
# Impute missing values
Xy_original.dropna(subset=['VAR_0008', 'VAR_0090', 'VAR_0242', 'VAR_0200', 'VAR_0350'], inplace=True)

# %%
# Dropping features due to too many missing values in the columns
Xy_original.drop(columns=['VAR_0073', 'VAR_0074'], inplace=True)
Xy_original.drop(columns=['VAR_0156', 'VAR_0157', 'VAR_0158', 'VAR_0159'], inplace=True)
Xy_original.drop(columns=['VAR_0166', 'VAR_0167', 'VAR_0168', 'VAR_0169'], inplace=True)
Xy_original.drop(columns=['VAR_0176', 'VAR_0177', 'VAR_0178', 'VAR_0179'], inplace=True)
Xy_original.drop(columns=['VAR_0205', 'VAR_0206', 'VAR_0207', 'VAR_0208', 'VAR_0209'], inplace=True)
Xy_original.drop(columns=['VAR_0210', 'VAR_0211', 'VAR_0212', 'VAR_0213', 'VAR_0214'], inplace=True)
Xy_original.drop(columns=['VAR_0840'], inplace=True)

# %%
# Dropping features due to non-predictive nature of the columns
Xy_original.drop(columns=['ID'], inplace=True)
Xy_original.drop(columns=['VAR_0008', 'VAR_0009', 'VAR_0010', 'VAR_0011', 'VAR_0012'], inplace=True)
Xy_original.drop(columns=['VAR_0018', 'VAR_0019', 'VAR_0020', 'VAR_0021', 'VAR_0022'], inplace=True)
Xy_original.drop(columns=['VAR_0023', 'VAR_0024', 'VAR_0025', 'VAR_0026', 'VAR_0027'], inplace=True)
Xy_original.drop(columns=['VAR_0028', 'VAR_0029', 'VAR_0030', 'VAR_0031', 'VAR_0032'], inplace=True)
Xy_original.drop(columns=['VAR_0038', 'VAR_0039', 'VAR_0040', 'VAR_0041', 'VAR_0042'], inplace=True)
Xy_original.drop(columns=['VAR_0043', 'VAR_0044', 'VAR_0075'], inplace=True)
Xy_original.drop(columns=['VAR_0188', 'VAR_0189', 'VAR_0190'], inplace=True)
Xy_original.drop(columns=['VAR_0196', 'VAR_0197', 'VAR_0199'], inplace=True)
Xy_original.drop(columns=['VAR_0200', 'VAR_0202', 'VAR_0203', 'VAR_0204'], inplace=True)
Xy_original.drop(columns=['VAR_0215', 'VAR_0216', 'VAR_0217'], inplace=True)
Xy_original.drop(columns=['VAR_0221', 'VAR_0222', 'VAR_0223'], inplace=True)
Xy_original.drop(columns=['VAR_0229', 'VAR_0239', 'VAR_0246'], inplace=True)
Xy_original.drop(columns=['VAR_0394', 'VAR_0404', 'VAR_0438'], inplace=True)
Xy_original.drop(columns=['VAR_0493'], inplace=True)
Xy_original.drop(columns=['VAR_0527', 'VAR_0528', 'VAR_0530'], inplace=True)
Xy_original.drop(columns=['VAR_0847'], inplace=True)
Xy_original.drop(columns=['VAR_1428'], inplace=True)

# %%
# Convert columns from one data type to another
Xy_original['VAR_0001'] = Xy_original['VAR_0001'].astype('category')
Xy_original['VAR_0005'] = Xy_original['VAR_0005'].astype('category')
# Xy_original['VAR_0226'] = Xy_original['VAR_0226'].astype('bool')
# Xy_original['VAR_0230'] = Xy_original['VAR_0230'].astype('bool')
# Xy_original['VAR_0232'] = Xy_original['VAR_0232'].astype('bool')
# Xy_original['VAR_0236'] = Xy_original['VAR_0236'].astype('bool')
Xy_original['VAR_0226'] = Xy_original['VAR_0226'].astype('category')
Xy_original['VAR_0230'] = Xy_original['VAR_0230'].astype('category')
Xy_original['VAR_0232'] = Xy_original['VAR_0232'].astype('category')
Xy_original['VAR_0236'] = Xy_original['VAR_0236'].astype('category')
Xy_original['VAR_0237'] = Xy_original['VAR_0237'].astype('category')
Xy_original['VAR_0274'] = Xy_original['VAR_0274'].astype('category')
Xy_original['VAR_0283'] = Xy_original['VAR_0283'].astype('category')
Xy_original['VAR_0305'] = Xy_original['VAR_0305'].astype('category')
Xy_original['VAR_0325'] = Xy_original['VAR_0325'].astype('category')
Xy_original['VAR_0342'] = Xy_original['VAR_0342'].astype('category')
Xy_original['VAR_0352'] = Xy_original['VAR_0352'].astype('category')
Xy_original['VAR_0353'] = Xy_original['VAR_0353'].astype('category')
Xy_original['VAR_0354'] = Xy_original['VAR_0354'].astype('category')
Xy_original['VAR_0466'] = Xy_original['VAR_0466'].astype('category')
Xy_original['VAR_0467'] = Xy_original['VAR_0467'].astype('category')
Xy_original['VAR_1934'] = Xy_original['VAR_0467'].astype('category')

# %%
# Take a peek at the dataframe after cleaning
Xy_original.head(10)
# Out:
#   VAR_0001  VAR_0002  VAR_0003  ...  VAR_1933    VAR_1934  targetVar
# 0        H       224         0  ...      9998          -1          0
# 1        H         7        53  ...      9998  Discharged          0
# 2        H       116         3  ...      9998          -1          0
# 3        H       240       300  ...      9998          -1          0
# 4        R        72       261  ...      9998          -1          1
# 5        R         4         4  ...      9998          -1          0
# 6        H        60       132  ...        76          -1          1
# 7        R        13        75  ...      9998          -1          0
# 8        R        17        16  ...        90          -1          1
# 9        R        24        72  ...      9998          -1          0
#
# [10 rows x 1852 columns]

# %%
Xy_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144262 entries, 0 to 145230
# Data columns (total 1852 columns):
# VAR_0001     category
# VAR_0002     int64
# VAR_0003     int64
# VAR_0004     int64
# VAR_0005     category
# VAR_0006     float64
# VAR_0007     float64
# VAR_0013     float64
# VAR_0014     float64
# VAR_0015     float64
# VAR_0016     float64
# VAR_0017     float64
# VAR_0033     float64
# VAR_0034     float64
# VAR_0035     float64
# VAR_0036     float64
# VAR_0037     float64
# VAR_0045     float64
# VAR_0046     float64
# VAR_0047     float64
# VAR_0048     float64
# VAR_0049     float64
# VAR_0050     float64
# VAR_0051     float64
# VAR_0052     float64
# VAR_0053     float64
# VAR_0054     float64
# VAR_0055     float64
# VAR_0056     float64
# VAR_0057     float64
# VAR_0058     float64
# VAR_0059     float64
# VAR_0060     float64
# VAR_0061     float64
# VAR_0062     float64
# VAR_0063     float64
# VAR_0064     float64
# VAR_0065     float64
# VAR_0066     float64
# VAR_0067     float64
# VAR_0068     float64
# VAR_0069     float64
# VAR_0070     float64
# VAR_0071     float64
# VAR_0072     float64
# VAR_0076     float64
# VAR_0077     float64
# VAR_0078     float64
# VAR_0079     float64
# VAR_0080     float64
# VAR_0081     float64
# VAR_0082     float64
# VAR_0083     float64
# VAR_0084     float64
# VAR_0085     float64
# VAR_0086     float64
# VAR_0087     float64
# VAR_0088     float64
# VAR_0089     float64
# VAR_0090     float64
# VAR_0091     float64
# VAR_0092     float64
# VAR_0093     float64
# VAR_0094     float64
# VAR_0095     float64
# VAR_0096     float64
# VAR_0097     float64
# VAR_0098     float64
# VAR_0099     float64
# VAR_0100     float64
# VAR_0101     float64
# VAR_0102     float64
# VAR_0103     float64
# VAR_0104     float64
# VAR_0105     float64
# VAR_0106     float64
# VAR_0107     float64
# VAR_0108     float64
# VAR_0109     float64
# VAR_0110     float64
# VAR_0111     float64
# VAR_0112     float64
# VAR_0113     float64
# VAR_0114     float64
# VAR_0115     float64
# VAR_0116     float64
# VAR_0117     float64
# VAR_0118     float64
# VAR_0119     float64
# VAR_0120     float64
# VAR_0121     float64
# VAR_0122     float64
# VAR_0123     float64
# VAR_0124     float64
# VAR_0125     float64
# VAR_0126     float64
# VAR_0127     float64
# VAR_0128     float64
# VAR_0129     float64
# VAR_0130     float64
# VAR_0131     float64
# VAR_0132     float64
# VAR_0133     float64
# VAR_0134     float64
# VAR_0135     float64
# VAR_0136     float64
# VAR_0137     float64
# VAR_0138     float64
# VAR_0139     float64
# VAR_0140     float64
# VAR_0141     float64
# VAR_0142     float64
# VAR_0143     float64
# VAR_0144     float64
# VAR_0145     float64
# VAR_0146     float64
# VAR_0147     float64
# VAR_0148     float64
# VAR_0149     float64
# VAR_0150     float64
# VAR_0151     float64
# VAR_0152     float64
# VAR_0153     float64
# VAR_0154     float64
# VAR_0155     float64
# VAR_0160     float64
# VAR_0161     float64
# VAR_0162     float64
# VAR_0163     float64
# VAR_0164     float64
# VAR_0165     float64
# VAR_0170     float64
# VAR_0171     float64
# VAR_0172     float64
# VAR_0173     float64
# VAR_0174     float64
# VAR_0175     float64
# VAR_0180     float64
# VAR_0181     float64
# VAR_0182     float64
# VAR_0183     float64
# VAR_0184     float64
# VAR_0185     float64
# VAR_0186     float64
# VAR_0187     float64
# VAR_0191     float64
# VAR_0192     float64
# VAR_0193     float64
# VAR_0194     float64
# VAR_0195     float64
# VAR_0198     float64
# VAR_0201     float64
# VAR_0219     float64
# VAR_0220     float64
# VAR_0224     float64
# VAR_0225     float64
# VAR_0226     category
# VAR_0227     float64
# VAR_0228     float64
# VAR_0230     category
# VAR_0231     float64
# VAR_0232     category
# VAR_0233     float64
# VAR_0234     float64
# VAR_0235     float64
# VAR_0236     category
# VAR_0237     category
# VAR_0238     float64
# VAR_0241     float64
# VAR_0242     float64
# VAR_0243     float64
# VAR_0244     float64
# VAR_0245     float64
# VAR_0247     float64
# VAR_0248     float64
# VAR_0249     float64
# VAR_0250     float64
# VAR_0251     float64
# VAR_0252     float64
# VAR_0253     float64
# VAR_0254     float64
# VAR_0255     float64
# VAR_0256     float64
# VAR_0257     float64
# VAR_0258     float64
# VAR_0259     float64
# VAR_0260     float64
# VAR_0261     float64
# VAR_0262     float64
# VAR_0263     float64
# VAR_0264     float64
# VAR_0265     float64
# VAR_0266     float64
# VAR_0267     float64
# VAR_0268     float64
# VAR_0269     float64
# VAR_0270     float64
# VAR_0271     float64
# VAR_0272     float64
# VAR_0273     float64
# VAR_0274     category
# VAR_0275     float64
# VAR_0276     float64
# VAR_0277     float64
# VAR_0278     float64
# VAR_0279     float64
# VAR_0280     float64
# VAR_0281     float64
# VAR_0282     float64
# VAR_0283     category
# VAR_0284     float64
# VAR_0285     float64
# VAR_0286     float64
# VAR_0287     float64
# VAR_0288     float64
# VAR_0289     float64
# VAR_0290     float64
# VAR_0291     float64
# VAR_0292     float64
# VAR_0293     float64
# VAR_0294     float64
# VAR_0295     float64
# VAR_0296     float64
# VAR_0297     float64
# VAR_0298     float64
# VAR_0299     float64
# VAR_0300     float64
# VAR_0301     float64
# VAR_0302     float64
# VAR_0303     float64
# VAR_0304     float64
# VAR_0305     category
# VAR_0306     float64
# VAR_0307     float64
# VAR_0308     float64
# VAR_0309     float64
# VAR_0310     float64
# VAR_0311     float64
# VAR_0312     float64
# VAR_0313     float64
# VAR_0314     float64
# VAR_0315     float64
# VAR_0316     float64
# VAR_0317     float64
# VAR_0318     float64
# VAR_0319     float64
# VAR_0320     float64
# VAR_0321     float64
# VAR_0322     float64
# VAR_0323     float64
# VAR_0324     float64
# VAR_0325     category
# VAR_0326     float64
# VAR_0327     float64
# VAR_0328     float64
# VAR_0329     float64
# VAR_0330     float64
# VAR_0331     float64
# VAR_0332     float64
# VAR_0333     float64
# VAR_0334     float64
# VAR_0335     float64
# VAR_0336     float64
# VAR_0337     float64
# VAR_0338     float64
# VAR_0339     float64
# VAR_0340     float64
# VAR_0341     float64
# VAR_0342     category
# VAR_0343     float64
# VAR_0344     float64
# VAR_0345     float64
# VAR_0346     float64
# VAR_0347     float64
# VAR_0348     float64
# VAR_0349     float64
# VAR_0350     float64
# VAR_0351     float64
# VAR_0352     category
# VAR_0353     category
# VAR_0354     category
# VAR_0355     float64
# VAR_0356     float64
# VAR_0357     float64
# VAR_0358     float64
# VAR_0359     float64
# VAR_0360     float64
# VAR_0361     float64
# VAR_0362     float64
# VAR_0363     float64
# VAR_0364     float64
# VAR_0365     float64
# VAR_0366     float64
# VAR_0367     float64
# VAR_0368     float64
# VAR_0369     float64
# VAR_0370     float64
# VAR_0371     float64
# VAR_0372     float64
# VAR_0373     float64
# VAR_0374     float64
# VAR_0375     float64
# VAR_0376     float64
# VAR_0377     float64
# VAR_0378     float64
# VAR_0379     float64
# VAR_0380     float64
# VAR_0381     float64
# VAR_0382     float64
# VAR_0383     float64
# VAR_0384     float64
# VAR_0385     float64
# VAR_0386     float64
# VAR_0387     float64
# VAR_0388     float64
# VAR_0389     float64
# VAR_0390     float64
# VAR_0391     float64
# VAR_0392     float64
# VAR_0393     float64
# VAR_0395     float64
# VAR_0396     float64
# VAR_0397     float64
# VAR_0398     float64
# VAR_0399     float64
# VAR_0400     float64
# VAR_0401     float64
# VAR_0402     float64
# VAR_0403     float64
# VAR_0405     float64
# VAR_0406     float64
# VAR_0407     float64
# VAR_0408     float64
# VAR_0409     float64
# VAR_0410     float64
# VAR_0411     float64
# VAR_0412     float64
# VAR_0413     float64
# VAR_0414     float64
# VAR_0415     float64
# VAR_0416     float64
# VAR_0417     float64
# VAR_0418     float64
# VAR_0419     float64
# VAR_0420     float64
# VAR_0421     float64
# VAR_0422     float64
# VAR_0423     float64
# VAR_0424     float64
# VAR_0425     float64
# VAR_0426     float64
# VAR_0427     float64
# VAR_0428     float64
# VAR_0429     float64
# VAR_0430     float64
# VAR_0431     float64
# VAR_0432     float64
# VAR_0433     float64
# VAR_0434     float64
# VAR_0435     float64
# VAR_0436     float64
# VAR_0437     float64
# VAR_0439     float64
# VAR_0440     float64
# VAR_0441     float64
# VAR_0442     float64
# VAR_0443     float64
# VAR_0444     float64
# VAR_0445     float64
# VAR_0446     float64
# VAR_0447     float64
# VAR_0448     float64
# VAR_0449     float64
# VAR_0450     float64
# VAR_0451     float64
# VAR_0452     float64
# VAR_0453     float64
# VAR_0454     float64
# VAR_0455     float64
# VAR_0456     float64
# VAR_0457     float64
# VAR_0458     float64
# VAR_0459     float64
# VAR_0460     float64
# VAR_0461     float64
# VAR_0462     float64
# VAR_0463     float64
# VAR_0464     float64
# VAR_0465     float64
# VAR_0466     category
# VAR_0467     category
# VAR_0468     float64
# VAR_0469     float64
# VAR_0470     float64
# VAR_0471     float64
# VAR_0472     float64
# VAR_0473     float64
# VAR_0474     float64
# VAR_0475     float64
# VAR_0476     float64
# VAR_0477     float64
# VAR_0478     float64
# VAR_0479     float64
# VAR_0480     float64
# VAR_0481     float64
# VAR_0482     float64
# VAR_0483     float64
# VAR_0484     float64
# VAR_0485     float64
# VAR_0486     float64
# VAR_0487     float64
# VAR_0488     float64
# VAR_0489     float64
# VAR_0490     float64
# VAR_0491     float64
# VAR_0492     float64
# VAR_0494     float64
# VAR_0495     float64
# VAR_0496     float64
# VAR_0497     float64
# VAR_0498     float64
# VAR_0499     float64
# VAR_0500     float64
# VAR_0501     float64
# VAR_0502     float64
# VAR_0503     float64
# VAR_0504     float64
# VAR_0505     float64
# VAR_0506     float64
# VAR_0507     float64
# VAR_0508     float64
# VAR_0509     float64
# VAR_0510     float64
# VAR_0511     float64
# VAR_0512     float64
# VAR_0513     float64
# VAR_0514     float64
# VAR_0515     float64
# VAR_0516     float64
# VAR_0517     float64
# VAR_0518     float64
# VAR_0519     float64
# VAR_0520     float64
# VAR_0521     float64
# VAR_0522     float64
# VAR_0523     float64
# VAR_0524     float64
# VAR_0525     float64
# VAR_0526     float64
# VAR_0529     float64
# VAR_0531     float64
# VAR_0532     int64
# VAR_0533     int64
# VAR_0534     int64
# VAR_0535     int64
# VAR_0536     int64
# VAR_0537     int64
# VAR_0538     int64
# VAR_0539     int64
# VAR_0540     int64
# VAR_0541     int64
# VAR_0542     int64
# VAR_0543     int64
# VAR_0544     int64
# VAR_0545     int64
# VAR_0546     int64
# VAR_0547     int64
# VAR_0548     int64
# VAR_0549     int64
# VAR_0550     int64
# VAR_0551     int64
# VAR_0552     int64
# VAR_0553     int64
# VAR_0554     int64
# VAR_0555     int64
# VAR_0556     int64
# VAR_0557     int64
# VAR_0558     int64
# VAR_0559     int64
# VAR_0560     int64
# VAR_0561     int64
# VAR_0562     int64
# VAR_0563     int64
# VAR_0564     int64
# VAR_0565     int64
# VAR_0566     int64
# VAR_0567     int64
# VAR_0568     int64
# VAR_0569     int64
# VAR_0570     int64
# VAR_0571     int64
# VAR_0572     int64
# VAR_0573     int64
# VAR_0574     int64
# VAR_0575     int64
# VAR_0576     int64
# VAR_0577     int64
# VAR_0578     int64
# VAR_0579     int64
# VAR_0580     int64
# VAR_0581     int64
# VAR_0582     int64
# VAR_0583     int64
# VAR_0584     int64
# VAR_0585     int64
# VAR_0586     int64
# VAR_0587     int64
# VAR_0588     int64
# VAR_0589     int64
# VAR_0590     int64
# VAR_0591     int64
# VAR_0592     int64
# VAR_0593     int64
# VAR_0594     int64
# VAR_0595     int64
# VAR_0596     int64
# VAR_0597     int64
# VAR_0598     int64
# VAR_0599     int64
# VAR_0600     int64
# VAR_0601     int64
# VAR_0602     int64
# VAR_0603     int64
# VAR_0604     int64
# VAR_0605     int64
# VAR_0606     int64
# VAR_0607     int64
# VAR_0608     int64
# VAR_0609     int64
# VAR_0610     int64
# VAR_0611     int64
# VAR_0612     int64
# VAR_0613     int64
# VAR_0614     int64
# VAR_0615     int64
# VAR_0616     int64
# VAR_0617     int64
# VAR_0618     int64
# VAR_0619     int64
# VAR_0620     int64
# VAR_0621     int64
# VAR_0622     int64
# VAR_0623     int64
# VAR_0624     int64
# VAR_0625     int64
# VAR_0626     int64
# VAR_0627     int64
# VAR_0628     int64
# VAR_0629     int64
# VAR_0630     int64
# VAR_0631     int64
# VAR_0632     int64
# VAR_0633     int64
# VAR_0634     int64
# VAR_0635     int64
# VAR_0636     int64
# VAR_0637     int64
# VAR_0638     int64
# VAR_0639     int64
# VAR_0640     int64
# VAR_0641     int64
# VAR_0642     int64
# VAR_0643     int64
# VAR_0644     int64
# VAR_0645     int64
# VAR_0646     int64
# VAR_0647     int64
# VAR_0648     int64
# VAR_0649     int64
# VAR_0650     int64
# VAR_0651     int64
# VAR_0652     int64
# VAR_0653     int64
# VAR_0654     int64
# VAR_0655     int64
# VAR_0656     int64
# VAR_0657     int64
# VAR_0658     int64
# VAR_0659     int64
# VAR_0660     int64
# VAR_0661     int64
# VAR_0662     int64
# VAR_0663     int64
# VAR_0664     int64
# VAR_0665     int64
# VAR_0666     int64
# VAR_0667     int64
# VAR_0668     int64
# VAR_0669     int64
# VAR_0670     int64
# VAR_0671     int64
# VAR_0672     int64
# VAR_0673     int64
# VAR_0674     int64
# VAR_0675     int64
# VAR_0676     int64
# VAR_0677     int64
# VAR_0678     int64
# VAR_0679     int64
# VAR_0680     int64
# VAR_0681     int64
# VAR_0682     int64
# VAR_0683     int64
# VAR_0684     int64
# VAR_0685     int64
# VAR_0686     int64
# VAR_0687     int64
# VAR_0688     int64
# VAR_0689     int64
# VAR_0690     int64
# VAR_0691     int64
# VAR_0692     int64
# VAR_0693     int64
# VAR_0694     int64
# VAR_0695     int64
# VAR_0696     int64
# VAR_0697     int64
# VAR_0698     int64
# VAR_0699     int64
# VAR_0700     int64
# VAR_0701     int64
# VAR_0702     int64
# VAR_0703     int64
# VAR_0704     int64
# VAR_0705     int64
# VAR_0706     int64
# VAR_0707     int64
# VAR_0708     int64
# VAR_0709     int64
# VAR_0710     int64
# VAR_0711     int64
# VAR_0712     int64
# VAR_0713     int64
# VAR_0714     int64
# VAR_0715     int64
# VAR_0716     int64
# VAR_0717     int64
# VAR_0718     int64
# VAR_0719     int64
# VAR_0720     int64
# VAR_0721     int64
# VAR_0722     int64
# VAR_0723     int64
# VAR_0724     int64
# VAR_0725     int64
# VAR_0726     int64
# VAR_0727     int64
# VAR_0728     int64
# VAR_0729     int64
# VAR_0730     int64
# VAR_0731     int64
# VAR_0732     int64
# VAR_0733     int64
# VAR_0734     int64
# VAR_0735     int64
# VAR_0736     int64
# VAR_0737     int64
# VAR_0738     int64
# VAR_0739     int64
# VAR_0740     int64
# VAR_0741     int64
# VAR_0742     int64
# VAR_0743     int64
# VAR_0744     int64
# VAR_0745     int64
# VAR_0746     int64
# VAR_0747     int64
# VAR_0748     int64
# VAR_0749     int64
# VAR_0750     int64
# VAR_0751     int64
# VAR_0752     int64
# VAR_0753     int64
# VAR_0754     int64
# VAR_0755     int64
# VAR_0756     int64
# VAR_0757     int64
# VAR_0758     int64
# VAR_0759     int64
# VAR_0760     int64
# VAR_0761     int64
# VAR_0762     int64
# VAR_0763     int64
# VAR_0764     int64
# VAR_0765     int64
# VAR_0766     int64
# VAR_0767     int64
# VAR_0768     int64
# VAR_0769     int64
# VAR_0770     int64
# VAR_0771     int64
# VAR_0772     int64
# VAR_0773     int64
# VAR_0774     int64
# VAR_0775     int64
# VAR_0776     int64
# VAR_0777     int64
# VAR_0778     int64
# VAR_0779     int64
# VAR_0780     int64
# VAR_0781     int64
# VAR_0782     int64
# VAR_0783     int64
# VAR_0784     int64
# VAR_0785     int64
# VAR_0786     int64
# VAR_0787     int64
# VAR_0788     int64
# VAR_0789     int64
# VAR_0790     int64
# VAR_0791     int64
# VAR_0792     int64
# VAR_0793     int64
# VAR_0794     int64
# VAR_0795     int64
# VAR_0796     int64
# VAR_0797     int64
# VAR_0798     int64
# VAR_0799     int64
# VAR_0800     int64
# VAR_0801     int64
# VAR_0802     int64
# VAR_0803     int64
# VAR_0804     int64
# VAR_0805     int64
# VAR_0806     int64
# VAR_0807     int64
# VAR_0808     int64
# VAR_0809     int64
# VAR_0810     int64
# VAR_0811     int64
# VAR_0812     int64
# VAR_0813     int64
# VAR_0814     int64
# VAR_0815     int64
# VAR_0816     int64
# VAR_0817     int64
# VAR_0818     int64
# VAR_0819     int64
# VAR_0820     int64
# VAR_0821     int64
# VAR_0822     int64
# VAR_0823     int64
# VAR_0824     int64
# VAR_0825     int64
# VAR_0826     int64
# VAR_0827     int64
# VAR_0828     int64
# VAR_0829     int64
# VAR_0830     int64
# VAR_0831     int64
# VAR_0832     int64
# VAR_0833     int64
# VAR_0834     int64
# VAR_0835     int64
# VAR_0836     int64
# VAR_0837     int64
# VAR_0838     int64
# VAR_0839     int64
# VAR_0841     int64
# VAR_0842     int64
# VAR_0843     int64
# VAR_0844     int64
# VAR_0845     int64
# VAR_0846     int64
# VAR_0848     int64
# VAR_0849     int64
# VAR_0850     int64
# VAR_0851     int64
# VAR_0852     int64
# VAR_0853     int64
# VAR_0854     int64
# VAR_0855     int64
# VAR_0856     int64
# VAR_0857     int64
# VAR_0858     int64
# VAR_0859     int64
# VAR_0860     int64
# VAR_0861     int64
# VAR_0862     int64
# VAR_0863     int64
# VAR_0864     int64
# VAR_0865     int64
# VAR_0866     int64
# VAR_0867     int64
# VAR_0868     int64
# VAR_0869     int64
# VAR_0870     int64
# VAR_0871     int64
# VAR_0872     int64
# VAR_0873     int64
# VAR_0874     int64
# VAR_0875     int64
# VAR_0876     int64
# VAR_0877     int64
# VAR_0878     int64
# VAR_0879     int64
# VAR_0880     int64
# VAR_0881     int64
# VAR_0882     int64
# VAR_0883     int64
# VAR_0884     int64
# VAR_0885     int64
# VAR_0886     int64
# VAR_0887     int64
# VAR_0888     int64
# VAR_0889     int64
# VAR_0890     int64
# VAR_0891     int64
# VAR_0892     int64
# VAR_0893     int64
# VAR_0894     int64
# VAR_0895     int64
# VAR_0896     int64
# VAR_0897     int64
# VAR_0898     int64
# VAR_0899     int64
# VAR_0900     int64
# VAR_0901     int64
# VAR_0902     int64
# VAR_0903     int64
# VAR_0904     int64
# VAR_0905     int64
# VAR_0906     int64
# VAR_0907     int64
# VAR_0908     int64
# VAR_0909     int64
# VAR_0910     int64
# VAR_0911     int64
# VAR_0912     int64
# VAR_0913     int64
# VAR_0914     int64
# VAR_0915     int64
# VAR_0916     int64
# VAR_0917     int64
# VAR_0918     int64
# VAR_0919     int64
# VAR_0920     int64
# VAR_0921     int64
# VAR_0922     int64
# VAR_0923     int64
# VAR_0924     int64
# VAR_0925     int64
# VAR_0926     int64
# VAR_0927     int64
# VAR_0928     int64
# VAR_0929     int64
# VAR_0930     int64
# VAR_0931     int64
# VAR_0932     int64
# VAR_0933     int64
# VAR_0934     int64
# VAR_0935     int64
# VAR_0936     int64
# VAR_0937     int64
# VAR_0938     int64
# VAR_0939     int64
# VAR_0940     int64
# VAR_0941     int64
# VAR_0942     int64
# VAR_0943     int64
# VAR_0944     int64
# VAR_0945     int64
# VAR_0946     int64
# VAR_0947     int64
# VAR_0948     int64
# VAR_0949     int64
# VAR_0950     int64
# VAR_0951     int64
# VAR_0952     int64
# VAR_0953     int64
# VAR_0954     int64
# VAR_0955     int64
# VAR_0956     int64
# VAR_0957     int64
# VAR_0958     int64
# VAR_0959     int64
# VAR_0960     int64
# VAR_0961     int64
# VAR_0962     int64
# VAR_0963     int64
# VAR_0964     int64
# VAR_0965     int64
# VAR_0966     int64
# VAR_0967     int64
# VAR_0968     int64
# VAR_0969     int64
# VAR_0970     int64
# VAR_0971     int64
# VAR_0972     int64
# VAR_0973     int64
# VAR_0974     int64
# VAR_0975     int64
# VAR_0976     int64
# VAR_0977     int64
# VAR_0978     int64
# VAR_0979     int64
# VAR_0980     int64
# VAR_0981     int64
# VAR_0982     int64
# VAR_0983     int64
# VAR_0984     int64
# VAR_0985     int64
# VAR_0986     int64
# VAR_0987     int64
# VAR_0988     int64
# VAR_0989     int64
# VAR_0990     int64
# VAR_0991     int64
# VAR_0992     int64
# VAR_0993     int64
# VAR_0994     int64
# VAR_0995     int64
# VAR_0996     int64
# VAR_0997     int64
# VAR_0998     int64
# VAR_0999     int64
# VAR_1000     int64
# VAR_1001     int64
# VAR_1002     int64
# VAR_1003     int64
# VAR_1004     int64
# VAR_1005     int64
# VAR_1006     int64
# VAR_1007     int64
# VAR_1008     int64
# VAR_1009     int64
# VAR_1010     int64
# VAR_1011     int64
# VAR_1012     int64
# VAR_1013     int64
# VAR_1014     int64
# VAR_1015     int64
# VAR_1016     int64
# VAR_1017     int64
# VAR_1018     int64
# VAR_1019     int64
# VAR_1020     int64
# VAR_1021     int64
# VAR_1022     int64
# VAR_1023     int64
# VAR_1024     int64
# VAR_1025     int64
# VAR_1026     int64
# VAR_1027     int64
# VAR_1028     int64
# VAR_1029     int64
# VAR_1030     int64
# VAR_1031     int64
# VAR_1032     int64
# VAR_1033     int64
# VAR_1034     int64
# VAR_1035     int64
# VAR_1036     int64
# VAR_1037     int64
# VAR_1038     int64
# VAR_1039     int64
# VAR_1040     int64
# VAR_1041     int64
# VAR_1042     int64
# VAR_1043     int64
# VAR_1044     int64
# VAR_1045     int64
# VAR_1046     int64
# VAR_1047     int64
# VAR_1048     int64
# VAR_1049     int64
# VAR_1050     int64
# VAR_1051     int64
# VAR_1052     int64
# VAR_1053     int64
# VAR_1054     int64
# VAR_1055     int64
# VAR_1056     int64
# VAR_1057     int64
# VAR_1058     int64
# VAR_1059     int64
# VAR_1060     int64
# VAR_1061     int64
# VAR_1062     int64
# VAR_1063     int64
# VAR_1064     int64
# VAR_1065     int64
# VAR_1066     int64
# VAR_1067     int64
# VAR_1068     int64
# VAR_1069     int64
# VAR_1070     int64
# VAR_1071     int64
# VAR_1072     int64
# VAR_1073     int64
# VAR_1074     int64
# VAR_1075     int64
# VAR_1076     int64
# VAR_1077     int64
# VAR_1078     int64
# VAR_1079     int64
# VAR_1080     int64
# VAR_1081     int64
# VAR_1082     int64
# VAR_1083     int64
# VAR_1084     int64
# VAR_1085     int64
# VAR_1086     int64
# VAR_1087     int64
# VAR_1088     int64
# VAR_1089     int64
# VAR_1090     int64
# VAR_1091     int64
# VAR_1092     int64
# VAR_1093     int64
# VAR_1094     int64
# VAR_1095     int64
# VAR_1096     int64
# VAR_1097     int64
# VAR_1098     int64
# VAR_1099     int64
# VAR_1100     int64
# VAR_1101     int64
# VAR_1102     int64
# VAR_1103     int64
# VAR_1104     int64
# VAR_1105     int64
# VAR_1106     int64
# VAR_1107     int64
# VAR_1108     int64
# VAR_1109     int64
# VAR_1110     int64
# VAR_1111     int64
# VAR_1112     int64
# VAR_1113     int64
# VAR_1114     int64
# VAR_1115     int64
# VAR_1116     int64
# VAR_1117     int64
# VAR_1118     int64
# VAR_1119     int64
# VAR_1120     int64
# VAR_1121     int64
# VAR_1122     int64
# VAR_1123     int64
# VAR_1124     int64
# VAR_1125     int64
# VAR_1126     int64
# VAR_1127     int64
# VAR_1128     int64
# VAR_1129     int64
# VAR_1130     int64
# VAR_1131     int64
# VAR_1132     int64
# VAR_1133     int64
# VAR_1134     int64
# VAR_1135     int64
# VAR_1136     int64
# VAR_1137     int64
# VAR_1138     int64
# VAR_1139     int64
# VAR_1140     int64
# VAR_1141     int64
# VAR_1142     int64
# VAR_1143     int64
# VAR_1144     int64
# VAR_1145     int64
# VAR_1146     int64
# VAR_1147     int64
# VAR_1148     int64
# VAR_1149     int64
# VAR_1150     int64
# VAR_1151     int64
# VAR_1152     int64
# VAR_1153     int64
# VAR_1154     int64
# VAR_1155     int64
# VAR_1156     int64
# VAR_1157     int64
# VAR_1158     int64
# VAR_1159     int64
# VAR_1160     int64
# VAR_1161     int64
# VAR_1162     int64
# VAR_1163     int64
# VAR_1164     int64
# VAR_1165     int64
# VAR_1166     int64
# VAR_1167     int64
# VAR_1168     int64
# VAR_1169     int64
# VAR_1170     int64
# VAR_1171     int64
# VAR_1172     int64
# VAR_1173     int64
# VAR_1174     int64
# VAR_1175     int64
# VAR_1176     int64
# VAR_1177     int64
# VAR_1178     int64
# VAR_1179     int64
# VAR_1180     int64
# VAR_1181     int64
# VAR_1182     int64
# VAR_1183     int64
# VAR_1184     int64
# VAR_1185     int64
# VAR_1186     int64
# VAR_1187     int64
# VAR_1188     int64
# VAR_1189     int64
# VAR_1190     int64
# VAR_1191     int64
# VAR_1192     int64
# VAR_1193     int64
# VAR_1194     int64
# VAR_1195     int64
# VAR_1196     int64
# VAR_1197     int64
# VAR_1198     int64
# VAR_1199     int64
# VAR_1200     int64
# VAR_1201     int64
# VAR_1202     int64
# VAR_1203     int64
# VAR_1204     int64
# VAR_1205     int64
# VAR_1206     int64
# VAR_1207     int64
# VAR_1208     int64
# VAR_1209     int64
# VAR_1210     int64
# VAR_1211     int64
# VAR_1212     int64
# VAR_1213     int64
# VAR_1214     int64
# VAR_1215     int64
# VAR_1216     int64
# VAR_1217     int64
# VAR_1218     int64
# VAR_1219     int64
# VAR_1220     int64
# VAR_1221     int64
# VAR_1222     int64
# VAR_1223     int64
# VAR_1224     int64
# VAR_1225     int64
# VAR_1226     int64
# VAR_1227     int64
# VAR_1228     int64
# VAR_1229     int64
# VAR_1230     int64
# VAR_1231     int64
# VAR_1232     int64
# VAR_1233     int64
# VAR_1234     int64
# VAR_1235     int64
# VAR_1236     int64
# VAR_1237     int64
# VAR_1238     int64
# VAR_1239     int64
# VAR_1240     int64
# VAR_1241     int64
# VAR_1242     int64
# VAR_1243     int64
# VAR_1244     int64
# VAR_1245     int64
# VAR_1246     int64
# VAR_1247     int64
# VAR_1248     int64
# VAR_1249     int64
# VAR_1250     int64
# VAR_1251     int64
# VAR_1252     int64
# VAR_1253     int64
# VAR_1254     int64
# VAR_1255     int64
# VAR_1256     int64
# VAR_1257     int64
# VAR_1258     int64
# VAR_1259     int64
# VAR_1260     int64
# VAR_1261     int64
# VAR_1262     int64
# VAR_1263     int64
# VAR_1264     int64
# VAR_1265     int64
# VAR_1266     int64
# VAR_1267     int64
# VAR_1268     int64
# VAR_1269     int64
# VAR_1270     int64
# VAR_1271     int64
# VAR_1272     int64
# VAR_1273     int64
# VAR_1274     int64
# VAR_1275     int64
# VAR_1276     int64
# VAR_1277     int64
# VAR_1278     int64
# VAR_1279     int64
# VAR_1280     int64
# VAR_1281     int64
# VAR_1282     int64
# VAR_1283     int64
# VAR_1284     int64
# VAR_1285     int64
# VAR_1286     int64
# VAR_1287     int64
# VAR_1288     int64
# VAR_1289     int64
# VAR_1290     int64
# VAR_1291     int64
# VAR_1292     int64
# VAR_1293     int64
# VAR_1294     int64
# VAR_1295     int64
# VAR_1296     int64
# VAR_1297     int64
# VAR_1298     int64
# VAR_1299     int64
# VAR_1300     int64
# VAR_1301     int64
# VAR_1302     int64
# VAR_1303     int64
# VAR_1304     int64
# VAR_1305     int64
# VAR_1306     int64
# VAR_1307     int64
# VAR_1308     int64
# VAR_1309     int64
# VAR_1310     int64
# VAR_1311     int64
# VAR_1312     int64
# VAR_1313     int64
# VAR_1314     int64
# VAR_1315     int64
# VAR_1316     int64
# VAR_1317     int64
# VAR_1318     int64
# VAR_1319     int64
# VAR_1320     int64
# VAR_1321     int64
# VAR_1322     int64
# VAR_1323     int64
# VAR_1324     int64
# VAR_1325     int64
# VAR_1326     int64
# VAR_1327     int64
# VAR_1328     int64
# VAR_1329     int64
# VAR_1330     int64
# VAR_1331     int64
# VAR_1332     int64
# VAR_1333     int64
# VAR_1334     int64
# VAR_1335     int64
# VAR_1336     int64
# VAR_1337     int64
# VAR_1338     int64
# VAR_1339     int64
# VAR_1340     int64
# VAR_1341     int64
# VAR_1342     int64
# VAR_1343     int64
# VAR_1344     int64
# VAR_1345     int64
# VAR_1346     int64
# VAR_1347     int64
# VAR_1348     int64
# VAR_1349     int64
# VAR_1350     int64
# VAR_1351     int64
# VAR_1352     int64
# VAR_1353     int64
# VAR_1354     int64
# VAR_1355     int64
# VAR_1356     int64
# VAR_1357     int64
# VAR_1358     int64
# VAR_1359     int64
# VAR_1360     int64
# VAR_1361     int64
# VAR_1362     int64
# VAR_1363     int64
# VAR_1364     int64
# VAR_1365     int64
# VAR_1366     int64
# VAR_1367     int64
# VAR_1368     int64
# VAR_1369     int64
# VAR_1370     int64
# VAR_1371     int64
# VAR_1372     int64
# VAR_1373     int64
# VAR_1374     int64
# VAR_1375     int64
# VAR_1376     int64
# VAR_1377     int64
# VAR_1378     int64
# VAR_1379     int64
# VAR_1380     int64
# VAR_1381     int64
# VAR_1382     int64
# VAR_1383     int64
# VAR_1384     int64
# VAR_1385     int64
# VAR_1386     int64
# VAR_1387     int64
# VAR_1388     int64
# VAR_1389     int64
# VAR_1390     int64
# VAR_1391     int64
# VAR_1392     int64
# VAR_1393     int64
# VAR_1394     int64
# VAR_1395     int64
# VAR_1396     int64
# VAR_1397     int64
# VAR_1398     int64
# VAR_1399     int64
# VAR_1400     int64
# VAR_1401     int64
# VAR_1402     int64
# VAR_1403     int64
# VAR_1404     int64
# VAR_1405     int64
# VAR_1406     int64
# VAR_1407     int64
# VAR_1408     int64
# VAR_1409     int64
# VAR_1410     int64
# VAR_1411     int64
# VAR_1412     int64
# VAR_1413     int64
# VAR_1414     int64
# VAR_1415     int64
# VAR_1416     int64
# VAR_1417     int64
# VAR_1418     int64
# VAR_1419     int64
# VAR_1420     int64
# VAR_1421     int64
# VAR_1422     int64
# VAR_1423     int64
# VAR_1424     int64
# VAR_1425     int64
# VAR_1426     int64
# VAR_1427     int64
# VAR_1429     int64
# VAR_1430     int64
# VAR_1431     int64
# VAR_1432     int64
# VAR_1433     int64
# VAR_1434     int64
# VAR_1435     int64
# VAR_1436     int64
# VAR_1437     int64
# VAR_1438     int64
# VAR_1439     int64
# VAR_1440     int64
# VAR_1441     int64
# VAR_1442     int64
# VAR_1443     int64
# VAR_1444     int64
# VAR_1445     int64
# VAR_1446     int64
# VAR_1447     int64
# VAR_1448     int64
# VAR_1449     int64
# VAR_1450     int64
# VAR_1451     int64
# VAR_1452     int64
# VAR_1453     int64
# VAR_1454     int64
# VAR_1455     int64
# VAR_1456     int64
# VAR_1457     int64
# VAR_1458     int64
# VAR_1459     int64
# VAR_1460     int64
# VAR_1461     int64
# VAR_1462     int64
# VAR_1463     int64
# VAR_1464     int64
# VAR_1465     int64
# VAR_1466     int64
# VAR_1467     int64
# VAR_1468     int64
# VAR_1469     int64
# VAR_1470     int64
# VAR_1471     int64
# VAR_1472     int64
# VAR_1473     int64
# VAR_1474     int64
# VAR_1475     int64
# VAR_1476     int64
# VAR_1477     int64
# VAR_1478     int64
# VAR_1479     int64
# VAR_1480     int64
# VAR_1481     int64
# VAR_1482     int64
# VAR_1483     int64
# VAR_1484     int64
# VAR_1485     int64
# VAR_1486     int64
# VAR_1487     int64
# VAR_1488     int64
# VAR_1489     int64
# VAR_1490     int64
# VAR_1491     int64
# VAR_1492     int64
# VAR_1493     int64
# VAR_1494     int64
# VAR_1495     int64
# VAR_1496     int64
# VAR_1497     int64
# VAR_1498     int64
# VAR_1499     int64
# VAR_1500     int64
# VAR_1501     int64
# VAR_1502     int64
# VAR_1503     int64
# VAR_1504     int64
# VAR_1505     int64
# VAR_1506     int64
# VAR_1507     int64
# VAR_1508     int64
# VAR_1509     int64
# VAR_1510     int64
# VAR_1511     int64
# VAR_1512     int64
# VAR_1513     int64
# VAR_1514     int64
# VAR_1515     int64
# VAR_1516     int64
# VAR_1517     int64
# VAR_1518     int64
# VAR_1519     int64
# VAR_1520     int64
# VAR_1521     int64
# VAR_1522     int64
# VAR_1523     int64
# VAR_1524     int64
# VAR_1525     int64
# VAR_1526     int64
# VAR_1527     int64
# VAR_1528     int64
# VAR_1529     int64
# VAR_1530     int64
# VAR_1531     int64
# VAR_1532     int64
# VAR_1533     int64
# VAR_1534     int64
# VAR_1535     int64
# VAR_1536     int64
# VAR_1537     int64
# VAR_1538     int64
# VAR_1539     int64
# VAR_1540     int64
# VAR_1541     int64
# VAR_1542     int64
# VAR_1543     int64
# VAR_1544     int64
# VAR_1545     int64
# VAR_1546     int64
# VAR_1547     int64
# VAR_1548     int64
# VAR_1549     int64
# VAR_1550     int64
# VAR_1551     int64
# VAR_1552     int64
# VAR_1553     int64
# VAR_1554     int64
# VAR_1555     int64
# VAR_1556     int64
# VAR_1557     int64
# VAR_1558     int64
# VAR_1559     int64
# VAR_1560     int64
# VAR_1561     int64
# VAR_1562     int64
# VAR_1563     int64
# VAR_1564     int64
# VAR_1565     int64
# VAR_1566     int64
# VAR_1567     int64
# VAR_1568     int64
# VAR_1569     int64
# VAR_1570     int64
# VAR_1571     int64
# VAR_1572     int64
# VAR_1573     int64
# VAR_1574     int64
# VAR_1575     int64
# VAR_1576     int64
# VAR_1577     int64
# VAR_1578     int64
# VAR_1579     int64
# VAR_1580     int64
# VAR_1581     int64
# VAR_1582     int64
# VAR_1583     int64
# VAR_1584     int64
# VAR_1585     int64
# VAR_1586     int64
# VAR_1587     int64
# VAR_1588     int64
# VAR_1589     int64
# VAR_1590     int64
# VAR_1591     int64
# VAR_1592     int64
# VAR_1593     int64
# VAR_1594     int64
# VAR_1595     int64
# VAR_1596     int64
# VAR_1597     int64
# VAR_1598     int64
# VAR_1599     int64
# VAR_1600     int64
# VAR_1601     int64
# VAR_1602     int64
# VAR_1603     int64
# VAR_1604     int64
# VAR_1605     int64
# VAR_1606     int64
# VAR_1607     int64
# VAR_1608     int64
# VAR_1609     int64
# VAR_1610     int64
# VAR_1611     int64
# VAR_1612     int64
# VAR_1613     int64
# VAR_1614     int64
# VAR_1615     int64
# VAR_1616     int64
# VAR_1617     int64
# VAR_1618     int64
# VAR_1619     int64
# VAR_1620     int64
# VAR_1621     int64
# VAR_1622     int64
# VAR_1623     int64
# VAR_1624     int64
# VAR_1625     int64
# VAR_1626     int64
# VAR_1627     int64
# VAR_1628     int64
# VAR_1629     int64
# VAR_1630     int64
# VAR_1631     int64
# VAR_1632     int64
# VAR_1633     int64
# VAR_1634     int64
# VAR_1635     int64
# VAR_1636     int64
# VAR_1637     int64
# VAR_1638     int64
# VAR_1639     int64
# VAR_1640     int64
# VAR_1641     int64
# VAR_1642     int64
# VAR_1643     int64
# VAR_1644     int64
# VAR_1645     int64
# VAR_1646     int64
# VAR_1647     int64
# VAR_1648     int64
# VAR_1649     int64
# VAR_1650     int64
# VAR_1651     int64
# VAR_1652     int64
# VAR_1653     int64
# VAR_1654     int64
# VAR_1655     int64
# VAR_1656     int64
# VAR_1657     int64
# VAR_1658     int64
# VAR_1659     int64
# VAR_1660     int64
# VAR_1661     int64
# VAR_1662     int64
# VAR_1663     int64
# VAR_1664     int64
# VAR_1665     int64
# VAR_1666     int64
# VAR_1667     int64
# VAR_1668     int64
# VAR_1669     int64
# VAR_1670     int64
# VAR_1671     int64
# VAR_1672     int64
# VAR_1673     int64
# VAR_1674     int64
# VAR_1675     int64
# VAR_1676     int64
# VAR_1677     int64
# VAR_1678     int64
# VAR_1679     int64
# VAR_1680     int64
# VAR_1681     int64
# VAR_1682     int64
# VAR_1683     int64
# VAR_1684     int64
# VAR_1685     int64
# VAR_1686     int64
# VAR_1687     int64
# VAR_1688     int64
# VAR_1689     int64
# VAR_1690     int64
# VAR_1691     int64
# VAR_1692     int64
# VAR_1693     int64
# VAR_1694     int64
# VAR_1695     int64
# VAR_1696     int64
# VAR_1697     int64
# VAR_1698     int64
# VAR_1699     int64
# VAR_1700     int64
# VAR_1701     int64
# VAR_1702     int64
# VAR_1703     int64
# VAR_1704     int64
# VAR_1705     int64
# VAR_1706     int64
# VAR_1707     int64
# VAR_1708     int64
# VAR_1709     int64
# VAR_1710     int64
# VAR_1711     int64
# VAR_1712     int64
# VAR_1713     int64
# VAR_1714     int64
# VAR_1715     int64
# VAR_1716     int64
# VAR_1717     int64
# VAR_1718     int64
# VAR_1719     int64
# VAR_1720     int64
# VAR_1721     int64
# VAR_1722     int64
# VAR_1723     int64
# VAR_1724     int64
# VAR_1725     int64
# VAR_1726     int64
# VAR_1727     int64
# VAR_1728     int64
# VAR_1729     int64
# VAR_1730     int64
# VAR_1731     int64
# VAR_1732     int64
# VAR_1733     int64
# VAR_1734     int64
# VAR_1735     int64
# VAR_1736     int64
# VAR_1737     int64
# VAR_1738     int64
# VAR_1739     int64
# VAR_1740     int64
# VAR_1741     int64
# VAR_1742     int64
# VAR_1743     int64
# VAR_1744     int64
# VAR_1745     int64
# VAR_1746     int64
# VAR_1747     int64
# VAR_1748     int64
# VAR_1749     int64
# VAR_1750     int64
# VAR_1751     int64
# VAR_1752     int64
# VAR_1753     int64
# VAR_1754     int64
# VAR_1755     int64
# VAR_1756     int64
# VAR_1757     int64
# VAR_1758     int64
# VAR_1759     int64
# VAR_1760     int64
# VAR_1761     int64
# VAR_1762     int64
# VAR_1763     int64
# VAR_1764     int64
# VAR_1765     int64
# VAR_1766     int64
# VAR_1767     int64
# VAR_1768     int64
# VAR_1769     int64
# VAR_1770     int64
# VAR_1771     int64
# VAR_1772     int64
# VAR_1773     int64
# VAR_1774     int64
# VAR_1775     int64
# VAR_1776     int64
# VAR_1777     int64
# VAR_1778     int64
# VAR_1779     int64
# VAR_1780     int64
# VAR_1781     int64
# VAR_1782     int64
# VAR_1783     int64
# VAR_1784     int64
# VAR_1785     int64
# VAR_1786     int64
# VAR_1787     int64
# VAR_1788     int64
# VAR_1789     int64
# VAR_1790     int64
# VAR_1791     int64
# VAR_1792     int64
# VAR_1793     int64
# VAR_1794     int64
# VAR_1795     int64
# VAR_1796     int64
# VAR_1797     int64
# VAR_1798     int64
# VAR_1799     int64
# VAR_1800     int64
# VAR_1801     int64
# VAR_1802     int64
# VAR_1803     int64
# VAR_1804     int64
# VAR_1805     int64
# VAR_1806     int64
# VAR_1807     int64
# VAR_1808     int64
# VAR_1809     int64
# VAR_1810     int64
# VAR_1811     int64
# VAR_1812     int64
# VAR_1813     int64
# VAR_1814     int64
# VAR_1815     int64
# VAR_1816     int64
# VAR_1817     int64
# VAR_1818     int64
# VAR_1819     int64
# VAR_1820     int64
# VAR_1821     int64
# VAR_1822     int64
# VAR_1823     int64
# VAR_1824     int64
# VAR_1825     int64
# VAR_1826     int64
# VAR_1827     int64
# VAR_1828     int64
# VAR_1829     int64
# VAR_1830     int64
# VAR_1831     int64
# VAR_1832     int64
# VAR_1833     int64
# VAR_1834     int64
# VAR_1835     int64
# VAR_1836     int64
# VAR_1837     int64
# VAR_1838     int64
# VAR_1839     int64
# VAR_1840     int64
# VAR_1841     int64
# VAR_1842     int64
# VAR_1843     int64
# VAR_1844     int64
# VAR_1845     int64
# VAR_1846     int64
# VAR_1847     int64
# VAR_1848     int64
# VAR_1849     int64
# VAR_1850     int64
# VAR_1851     int64
# VAR_1852     int64
# VAR_1853     int64
# VAR_1854     int64
# VAR_1855     int64
# VAR_1856     int64
# VAR_1857     int64
# VAR_1858     int64
# VAR_1859     int64
# VAR_1860     int64
# VAR_1861     int64
# VAR_1862     int64
# VAR_1863     int64
# VAR_1864     int64
# VAR_1865     int64
# VAR_1866     int64
# VAR_1867     int64
# VAR_1868     int64
# VAR_1869     int64
# VAR_1870     int64
# VAR_1871     int64
# VAR_1872     int64
# VAR_1873     int64
# VAR_1874     int64
# VAR_1875     int64
# VAR_1876     int64
# VAR_1877     int64
# VAR_1878     int64
# VAR_1879     int64
# VAR_1880     int64
# VAR_1881     int64
# VAR_1882     int64
# VAR_1883     int64
# VAR_1884     int64
# VAR_1885     int64
# VAR_1886     int64
# VAR_1887     int64
# VAR_1888     int64
# VAR_1889     int64
# VAR_1890     int64
# VAR_1891     int64
# VAR_1892     int64
# VAR_1893     int64
# VAR_1894     int64
# VAR_1895     int64
# VAR_1896     int64
# VAR_1897     int64
# VAR_1898     int64
# VAR_1899     int64
# VAR_1900     int64
# VAR_1901     int64
# VAR_1902     int64
# VAR_1903     int64
# VAR_1904     int64
# VAR_1905     int64
# VAR_1906     int64
# VAR_1907     int64
# VAR_1908     int64
# VAR_1909     int64
# VAR_1910     int64
# VAR_1911     int64
# VAR_1912     int64
# VAR_1913     int64
# VAR_1914     int64
# VAR_1915     int64
# VAR_1916     int64
# VAR_1917     int64
# VAR_1918     int64
# VAR_1919     int64
# VAR_1920     int64
# VAR_1921     int64
# VAR_1922     int64
# VAR_1923     int64
# VAR_1924     int64
# VAR_1925     int64
# VAR_1926     int64
# VAR_1927     int64
# VAR_1928     int64
# VAR_1929     int64
# VAR_1930     int64
# VAR_1931     int64
# VAR_1932     int64
# VAR_1933     int64
# VAR_1934     category
# targetVar    int64
# dtypes: category(18), float64(431), int64(1403)
# memory usage: 2.0 GB

# %%
null_counts = Xy_original.isnull().sum()
null_counts[null_counts > 0]
# Out:
# Series([], dtype: int64)

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  0

# %% [markdown]
# ## 1.c) Feature Scaling and Pre-processing

# %%
# Use variable totCol to hold the number of columns in the dataframe
totCol = len(Xy_original.columns)

# Set up variable totAttr for the total number of attribute columns
totAttr = totCol-1

# targetCol variable indicates the column location of the target/class variable
# If the first column, set targetCol to 1. If the last column, set targetCol to totCol
# If (targetCol <> 1) and (targetCol <> totCol), be aware when slicing up the dataframes for visualization
targetCol = totCol

# %%
# We create attribute-only and target-only datasets (X_original and y_original)
# for various visualization and cleaning/transformation operations

if targetCol == totCol:
    X_original = Xy_original.iloc[:,0:totAttr]
    y_original = Xy_original.iloc[:,totAttr]
else:
    X_original = Xy_original.iloc[:,1:totCol]
    y_original = Xy_original.iloc[:,0]

print("Xy_original.shape: {} X_original.shape: {} y_original.shape: {}".format(Xy_original.shape, X_original.shape, y_original.shape))
# Out:
# Xy_original.shape: (144262, 1852) X_original.shape: (144262, 1851) y_original.shape: (144262,)

# %% [markdown]
# ### 1.d) Set up the parameters for data visualization

# %%
# Set up the number of row and columns for visualization display. dispRow * dispCol should be >= totAttr
dispCol = 4
if totAttr % dispCol == 0 :
    dispRow = totAttr // dispCol
else :
    dispRow = (totAttr // dispCol) + 1
    
# Set figure width to display the data visualization plots
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = dispCol*4
fig_size[1] = dispRow*4
plt.rcParams["figure.figsize"] = fig_size

# %%
# Histograms for each attribute before pre-processing
# X_original.hist(layout=(dispRow,dispCol))
# plt.show()

# %%
# tobe_transformed_cols = X_original.columns.tolist()
# tobe_transformed_cols.remove('some_column_label')
# print(tobe_transformed_cols)

# %%
# Apply feature scaling and transformation
# X_original = X_original.astype(float)
# scaler = preprocessing.StandardScaler()
# X_original[tobe_transformed_cols] = scaler.fit_transform(X_original[tobe_transformed_cols])

# X_original.head(-10)

# %%
# Histograms for each attribute after pre-processing
# X_original.hist(layout=(dispRow,dispCol))
# plt.show()

# %%
Xy_original.groupby('targetVar').size()
# Out:
# targetVar
# 0    110718
# 1     33544
# dtype: int64

# %%
# Perform one-hot-encoding before splitting into trainig and test
X_original = pd.get_dummies(X_original)
X_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144262 entries, 0 to 145230
# Data columns (total 2046 columns):
# VAR_0002                 int64
# VAR_0003                 int64
# VAR_0004                 int64
# VAR_0006                 float64
# VAR_0007                 float64
# VAR_0013                 float64
# VAR_0014                 float64
# VAR_0015                 float64
# VAR_0016                 float64
# VAR_0017                 float64
# VAR_0033                 float64
# VAR_0034                 float64
# VAR_0035                 float64
# VAR_0036                 float64
# VAR_0037                 float64
# VAR_0045                 float64
# VAR_0046                 float64
# VAR_0047                 float64
# VAR_0048                 float64
# VAR_0049                 float64
# VAR_0050                 float64
# VAR_0051                 float64
# VAR_0052                 float64
# VAR_0053                 float64
# VAR_0054                 float64
# VAR_0055                 float64
# VAR_0056                 float64
# VAR_0057                 float64
# VAR_0058                 float64
# VAR_0059                 float64
# VAR_0060                 float64
# VAR_0061                 float64
# VAR_0062                 float64
# VAR_0063                 float64
# VAR_0064                 float64
# VAR_0065                 float64
# VAR_0066                 float64
# VAR_0067                 float64
# VAR_0068                 float64
# VAR_0069                 float64
# VAR_0070                 float64
# VAR_0071                 float64
# VAR_0072                 float64
# VAR_0076                 float64
# VAR_0077                 float64
# VAR_0078                 float64
# VAR_0079                 float64
# VAR_0080                 float64
# VAR_0081                 float64
# VAR_0082                 float64
# VAR_0083                 float64
# VAR_0084                 float64
# VAR_0085                 float64
# VAR_0086                 float64
# VAR_0087                 float64
# VAR_0088                 float64
# VAR_0089                 float64
# VAR_0090                 float64
# VAR_0091                 float64
# VAR_0092                 float64
# VAR_0093                 float64
# VAR_0094                 float64
# VAR_0095                 float64
# VAR_0096                 float64
# VAR_0097                 float64
# VAR_0098                 float64
# VAR_0099                 float64
# VAR_0100                 float64
# VAR_0101                 float64
# VAR_0102                 float64
# VAR_0103                 float64
# VAR_0104                 float64
# VAR_0105                 float64
# VAR_0106                 float64
# VAR_0107                 float64
# VAR_0108                 float64
# VAR_0109                 float64
# VAR_0110                 float64
# VAR_0111                 float64
# VAR_0112                 float64
# VAR_0113                 float64
# VAR_0114                 float64
# VAR_0115                 float64
# VAR_0116                 float64
# VAR_0117                 float64
# VAR_0118                 float64
# VAR_0119                 float64
# VAR_0120                 float64
# VAR_0121                 float64
# VAR_0122                 float64
# VAR_0123                 float64
# VAR_0124                 float64
# VAR_0125                 float64
# VAR_0126                 float64
# VAR_0127                 float64
# VAR_0128                 float64
# VAR_0129                 float64
# VAR_0130                 float64
# VAR_0131                 float64
# VAR_0132                 float64
# VAR_0133                 float64
# VAR_0134                 float64
# VAR_0135                 float64
# VAR_0136                 float64
# VAR_0137                 float64
# VAR_0138                 float64
# VAR_0139                 float64
# VAR_0140                 float64
# VAR_0141                 float64
# VAR_0142                 float64
# VAR_0143                 float64
# VAR_0144                 float64
# VAR_0145                 float64
# VAR_0146                 float64
# VAR_0147                 float64
# VAR_0148                 float64
# VAR_0149                 float64
# VAR_0150                 float64
# VAR_0151                 float64
# VAR_0152                 float64
# VAR_0153                 float64
# VAR_0154                 float64
# VAR_0155                 float64
# VAR_0160                 float64
# VAR_0161                 float64
# VAR_0162                 float64
# VAR_0163                 float64
# VAR_0164                 float64
# VAR_0165                 float64
# VAR_0170                 float64
# VAR_0171                 float64
# VAR_0172                 float64
# VAR_0173                 float64
# VAR_0174                 float64
# VAR_0175                 float64
# VAR_0180                 float64
# VAR_0181                 float64
# VAR_0182                 float64
# VAR_0183                 float64
# VAR_0184                 float64
# VAR_0185                 float64
# VAR_0186                 float64
# VAR_0187                 float64
# VAR_0191                 float64
# VAR_0192                 float64
# VAR_0193                 float64
# VAR_0194                 float64
# VAR_0195                 float64
# VAR_0198                 float64
# VAR_0201                 float64
# VAR_0219                 float64
# VAR_0220                 float64
# VAR_0224                 float64
# VAR_0225                 float64
# VAR_0227                 float64
# VAR_0228                 float64
# VAR_0231                 float64
# VAR_0233                 float64
# VAR_0234                 float64
# VAR_0235                 float64
# VAR_0238                 float64
# VAR_0241                 float64
# VAR_0242                 float64
# VAR_0243                 float64
# VAR_0244                 float64
# VAR_0245                 float64
# VAR_0247                 float64
# VAR_0248                 float64
# VAR_0249                 float64
# VAR_0250                 float64
# VAR_0251                 float64
# VAR_0252                 float64
# VAR_0253                 float64
# VAR_0254                 float64
# VAR_0255                 float64
# VAR_0256                 float64
# VAR_0257                 float64
# VAR_0258                 float64
# VAR_0259                 float64
# VAR_0260                 float64
# VAR_0261                 float64
# VAR_0262                 float64
# VAR_0263                 float64
# VAR_0264                 float64
# VAR_0265                 float64
# VAR_0266                 float64
# VAR_0267                 float64
# VAR_0268                 float64
# VAR_0269                 float64
# VAR_0270                 float64
# VAR_0271                 float64
# VAR_0272                 float64
# VAR_0273                 float64
# VAR_0275                 float64
# VAR_0276                 float64
# VAR_0277                 float64
# VAR_0278                 float64
# VAR_0279                 float64
# VAR_0280                 float64
# VAR_0281                 float64
# VAR_0282                 float64
# VAR_0284                 float64
# VAR_0285                 float64
# VAR_0286                 float64
# VAR_0287                 float64
# VAR_0288                 float64
# VAR_0289                 float64
# VAR_0290                 float64
# VAR_0291                 float64
# VAR_0292                 float64
# VAR_0293                 float64
# VAR_0294                 float64
# VAR_0295                 float64
# VAR_0296                 float64
# VAR_0297                 float64
# VAR_0298                 float64
# VAR_0299                 float64
# VAR_0300                 float64
# VAR_0301                 float64
# VAR_0302                 float64
# VAR_0303                 float64
# VAR_0304                 float64
# VAR_0306                 float64
# VAR_0307                 float64
# VAR_0308                 float64
# VAR_0309                 float64
# VAR_0310                 float64
# VAR_0311                 float64
# VAR_0312                 float64
# VAR_0313                 float64
# VAR_0314                 float64
# VAR_0315                 float64
# VAR_0316                 float64
# VAR_0317                 float64
# VAR_0318                 float64
# VAR_0319                 float64
# VAR_0320                 float64
# VAR_0321                 float64
# VAR_0322                 float64
# VAR_0323                 float64
# VAR_0324                 float64
# VAR_0326                 float64
# VAR_0327                 float64
# VAR_0328                 float64
# VAR_0329                 float64
# VAR_0330                 float64
# VAR_0331                 float64
# VAR_0332                 float64
# VAR_0333                 float64
# VAR_0334                 float64
# VAR_0335                 float64
# VAR_0336                 float64
# VAR_0337                 float64
# VAR_0338                 float64
# VAR_0339                 float64
# VAR_0340                 float64
# VAR_0341                 float64
# VAR_0343                 float64
# VAR_0344                 float64
# VAR_0345                 float64
# VAR_0346                 float64
# VAR_0347                 float64
# VAR_0348                 float64
# VAR_0349                 float64
# VAR_0350                 float64
# VAR_0351                 float64
# VAR_0355                 float64
# VAR_0356                 float64
# VAR_0357                 float64
# VAR_0358                 float64
# VAR_0359                 float64
# VAR_0360                 float64
# VAR_0361                 float64
# VAR_0362                 float64
# VAR_0363                 float64
# VAR_0364                 float64
# VAR_0365                 float64
# VAR_0366                 float64
# VAR_0367                 float64
# VAR_0368                 float64
# VAR_0369                 float64
# VAR_0370                 float64
# VAR_0371                 float64
# VAR_0372                 float64
# VAR_0373                 float64
# VAR_0374                 float64
# VAR_0375                 float64
# VAR_0376                 float64
# VAR_0377                 float64
# VAR_0378                 float64
# VAR_0379                 float64
# VAR_0380                 float64
# VAR_0381                 float64
# VAR_0382                 float64
# VAR_0383                 float64
# VAR_0384                 float64
# VAR_0385                 float64
# VAR_0386                 float64
# VAR_0387                 float64
# VAR_0388                 float64
# VAR_0389                 float64
# VAR_0390                 float64
# VAR_0391                 float64
# VAR_0392                 float64
# VAR_0393                 float64
# VAR_0395                 float64
# VAR_0396                 float64
# VAR_0397                 float64
# VAR_0398                 float64
# VAR_0399                 float64
# VAR_0400                 float64
# VAR_0401                 float64
# VAR_0402                 float64
# VAR_0403                 float64
# VAR_0405                 float64
# VAR_0406                 float64
# VAR_0407                 float64
# VAR_0408                 float64
# VAR_0409                 float64
# VAR_0410                 float64
# VAR_0411                 float64
# VAR_0412                 float64
# VAR_0413                 float64
# VAR_0414                 float64
# VAR_0415                 float64
# VAR_0416                 float64
# VAR_0417                 float64
# VAR_0418                 float64
# VAR_0419                 float64
# VAR_0420                 float64
# VAR_0421                 float64
# VAR_0422                 float64
# VAR_0423                 float64
# VAR_0424                 float64
# VAR_0425                 float64
# VAR_0426                 float64
# VAR_0427                 float64
# VAR_0428                 float64
# VAR_0429                 float64
# VAR_0430                 float64
# VAR_0431                 float64
# VAR_0432                 float64
# VAR_0433                 float64
# VAR_0434                 float64
# VAR_0435                 float64
# VAR_0436                 float64
# VAR_0437                 float64
# VAR_0439                 float64
# VAR_0440                 float64
# VAR_0441                 float64
# VAR_0442                 float64
# VAR_0443                 float64
# VAR_0444                 float64
# VAR_0445                 float64
# VAR_0446                 float64
# VAR_0447                 float64
# VAR_0448                 float64
# VAR_0449                 float64
# VAR_0450                 float64
# VAR_0451                 float64
# VAR_0452                 float64
# VAR_0453                 float64
# VAR_0454                 float64
# VAR_0455                 float64
# VAR_0456                 float64
# VAR_0457                 float64
# VAR_0458                 float64
# VAR_0459                 float64
# VAR_0460                 float64
# VAR_0461                 float64
# VAR_0462                 float64
# VAR_0463                 float64
# VAR_0464                 float64
# VAR_0465                 float64
# VAR_0468                 float64
# VAR_0469                 float64
# VAR_0470                 float64
# VAR_0471                 float64
# VAR_0472                 float64
# VAR_0473                 float64
# VAR_0474                 float64
# VAR_0475                 float64
# VAR_0476                 float64
# VAR_0477                 float64
# VAR_0478                 float64
# VAR_0479                 float64
# VAR_0480                 float64
# VAR_0481                 float64
# VAR_0482                 float64
# VAR_0483                 float64
# VAR_0484                 float64
# VAR_0485                 float64
# VAR_0486                 float64
# VAR_0487                 float64
# VAR_0488                 float64
# VAR_0489                 float64
# VAR_0490                 float64
# VAR_0491                 float64
# VAR_0492                 float64
# VAR_0494                 float64
# VAR_0495                 float64
# VAR_0496                 float64
# VAR_0497                 float64
# VAR_0498                 float64
# VAR_0499                 float64
# VAR_0500                 float64
# VAR_0501                 float64
# VAR_0502                 float64
# VAR_0503                 float64
# VAR_0504                 float64
# VAR_0505                 float64
# VAR_0506                 float64
# VAR_0507                 float64
# VAR_0508                 float64
# VAR_0509                 float64
# VAR_0510                 float64
# VAR_0511                 float64
# VAR_0512                 float64
# VAR_0513                 float64
# VAR_0514                 float64
# VAR_0515                 float64
# VAR_0516                 float64
# VAR_0517                 float64
# VAR_0518                 float64
# VAR_0519                 float64
# VAR_0520                 float64
# VAR_0521                 float64
# VAR_0522                 float64
# VAR_0523                 float64
# VAR_0524                 float64
# VAR_0525                 float64
# VAR_0526                 float64
# VAR_0529                 float64
# VAR_0531                 float64
# VAR_0532                 int64
# VAR_0533                 int64
# VAR_0534                 int64
# VAR_0535                 int64
# VAR_0536                 int64
# VAR_0537                 int64
# VAR_0538                 int64
# VAR_0539                 int64
# VAR_0540                 int64
# VAR_0541                 int64
# VAR_0542                 int64
# VAR_0543                 int64
# VAR_0544                 int64
# VAR_0545                 int64
# VAR_0546                 int64
# VAR_0547                 int64
# VAR_0548                 int64
# VAR_0549                 int64
# VAR_0550                 int64
# VAR_0551                 int64
# VAR_0552                 int64
# VAR_0553                 int64
# VAR_0554                 int64
# VAR_0555                 int64
# VAR_0556                 int64
# VAR_0557                 int64
# VAR_0558                 int64
# VAR_0559                 int64
# VAR_0560                 int64
# VAR_0561                 int64
# VAR_0562                 int64
# VAR_0563                 int64
# VAR_0564                 int64
# VAR_0565                 int64
# VAR_0566                 int64
# VAR_0567                 int64
# VAR_0568                 int64
# VAR_0569                 int64
# VAR_0570                 int64
# VAR_0571                 int64
# VAR_0572                 int64
# VAR_0573                 int64
# VAR_0574                 int64
# VAR_0575                 int64
# VAR_0576                 int64
# VAR_0577                 int64
# VAR_0578                 int64
# VAR_0579                 int64
# VAR_0580                 int64
# VAR_0581                 int64
# VAR_0582                 int64
# VAR_0583                 int64
# VAR_0584                 int64
# VAR_0585                 int64
# VAR_0586                 int64
# VAR_0587                 int64
# VAR_0588                 int64
# VAR_0589                 int64
# VAR_0590                 int64
# VAR_0591                 int64
# VAR_0592                 int64
# VAR_0593                 int64
# VAR_0594                 int64
# VAR_0595                 int64
# VAR_0596                 int64
# VAR_0597                 int64
# VAR_0598                 int64
# VAR_0599                 int64
# VAR_0600                 int64
# VAR_0601                 int64
# VAR_0602                 int64
# VAR_0603                 int64
# VAR_0604                 int64
# VAR_0605                 int64
# VAR_0606                 int64
# VAR_0607                 int64
# VAR_0608                 int64
# VAR_0609                 int64
# VAR_0610                 int64
# VAR_0611                 int64
# VAR_0612                 int64
# VAR_0613                 int64
# VAR_0614                 int64
# VAR_0615                 int64
# VAR_0616                 int64
# VAR_0617                 int64
# VAR_0618                 int64
# VAR_0619                 int64
# VAR_0620                 int64
# VAR_0621                 int64
# VAR_0622                 int64
# VAR_0623                 int64
# VAR_0624                 int64
# VAR_0625                 int64
# VAR_0626                 int64
# VAR_0627                 int64
# VAR_0628                 int64
# VAR_0629                 int64
# VAR_0630                 int64
# VAR_0631                 int64
# VAR_0632                 int64
# VAR_0633                 int64
# VAR_0634                 int64
# VAR_0635                 int64
# VAR_0636                 int64
# VAR_0637                 int64
# VAR_0638                 int64
# VAR_0639                 int64
# VAR_0640                 int64
# VAR_0641                 int64
# VAR_0642                 int64
# VAR_0643                 int64
# VAR_0644                 int64
# VAR_0645                 int64
# VAR_0646                 int64
# VAR_0647                 int64
# VAR_0648                 int64
# VAR_0649                 int64
# VAR_0650                 int64
# VAR_0651                 int64
# VAR_0652                 int64
# VAR_0653                 int64
# VAR_0654                 int64
# VAR_0655                 int64
# VAR_0656                 int64
# VAR_0657                 int64
# VAR_0658                 int64
# VAR_0659                 int64
# VAR_0660                 int64
# VAR_0661                 int64
# VAR_0662                 int64
# VAR_0663                 int64
# VAR_0664                 int64
# VAR_0665                 int64
# VAR_0666                 int64
# VAR_0667                 int64
# VAR_0668                 int64
# VAR_0669                 int64
# VAR_0670                 int64
# VAR_0671                 int64
# VAR_0672                 int64
# VAR_0673                 int64
# VAR_0674                 int64
# VAR_0675                 int64
# VAR_0676                 int64
# VAR_0677                 int64
# VAR_0678                 int64
# VAR_0679                 int64
# VAR_0680                 int64
# VAR_0681                 int64
# VAR_0682                 int64
# VAR_0683                 int64
# VAR_0684                 int64
# VAR_0685                 int64
# VAR_0686                 int64
# VAR_0687                 int64
# VAR_0688                 int64
# VAR_0689                 int64
# VAR_0690                 int64
# VAR_0691                 int64
# VAR_0692                 int64
# VAR_0693                 int64
# VAR_0694                 int64
# VAR_0695                 int64
# VAR_0696                 int64
# VAR_0697                 int64
# VAR_0698                 int64
# VAR_0699                 int64
# VAR_0700                 int64
# VAR_0701                 int64
# VAR_0702                 int64
# VAR_0703                 int64
# VAR_0704                 int64
# VAR_0705                 int64
# VAR_0706                 int64
# VAR_0707                 int64
# VAR_0708                 int64
# VAR_0709                 int64
# VAR_0710                 int64
# VAR_0711                 int64
# VAR_0712                 int64
# VAR_0713                 int64
# VAR_0714                 int64
# VAR_0715                 int64
# VAR_0716                 int64
# VAR_0717                 int64
# VAR_0718                 int64
# VAR_0719                 int64
# VAR_0720                 int64
# VAR_0721                 int64
# VAR_0722                 int64
# VAR_0723                 int64
# VAR_0724                 int64
# VAR_0725                 int64
# VAR_0726                 int64
# VAR_0727                 int64
# VAR_0728                 int64
# VAR_0729                 int64
# VAR_0730                 int64
# VAR_0731                 int64
# VAR_0732                 int64
# VAR_0733                 int64
# VAR_0734                 int64
# VAR_0735                 int64
# VAR_0736                 int64
# VAR_0737                 int64
# VAR_0738                 int64
# VAR_0739                 int64
# VAR_0740                 int64
# VAR_0741                 int64
# VAR_0742                 int64
# VAR_0743                 int64
# VAR_0744                 int64
# VAR_0745                 int64
# VAR_0746                 int64
# VAR_0747                 int64
# VAR_0748                 int64
# VAR_0749                 int64
# VAR_0750                 int64
# VAR_0751                 int64
# VAR_0752                 int64
# VAR_0753                 int64
# VAR_0754                 int64
# VAR_0755                 int64
# VAR_0756                 int64
# VAR_0757                 int64
# VAR_0758                 int64
# VAR_0759                 int64
# VAR_0760                 int64
# VAR_0761                 int64
# VAR_0762                 int64
# VAR_0763                 int64
# VAR_0764                 int64
# VAR_0765                 int64
# VAR_0766                 int64
# VAR_0767                 int64
# VAR_0768                 int64
# VAR_0769                 int64
# VAR_0770                 int64
# VAR_0771                 int64
# VAR_0772                 int64
# VAR_0773                 int64
# VAR_0774                 int64
# VAR_0775                 int64
# VAR_0776                 int64
# VAR_0777                 int64
# VAR_0778                 int64
# VAR_0779                 int64
# VAR_0780                 int64
# VAR_0781                 int64
# VAR_0782                 int64
# VAR_0783                 int64
# VAR_0784                 int64
# VAR_0785                 int64
# VAR_0786                 int64
# VAR_0787                 int64
# VAR_0788                 int64
# VAR_0789                 int64
# VAR_0790                 int64
# VAR_0791                 int64
# VAR_0792                 int64
# VAR_0793                 int64
# VAR_0794                 int64
# VAR_0795                 int64
# VAR_0796                 int64
# VAR_0797                 int64
# VAR_0798                 int64
# VAR_0799                 int64
# VAR_0800                 int64
# VAR_0801                 int64
# VAR_0802                 int64
# VAR_0803                 int64
# VAR_0804                 int64
# VAR_0805                 int64
# VAR_0806                 int64
# VAR_0807                 int64
# VAR_0808                 int64
# VAR_0809                 int64
# VAR_0810                 int64
# VAR_0811                 int64
# VAR_0812                 int64
# VAR_0813                 int64
# VAR_0814                 int64
# VAR_0815                 int64
# VAR_0816                 int64
# VAR_0817                 int64
# VAR_0818                 int64
# VAR_0819                 int64
# VAR_0820                 int64
# VAR_0821                 int64
# VAR_0822                 int64
# VAR_0823                 int64
# VAR_0824                 int64
# VAR_0825                 int64
# VAR_0826                 int64
# VAR_0827                 int64
# VAR_0828                 int64
# VAR_0829                 int64
# VAR_0830                 int64
# VAR_0831                 int64
# VAR_0832                 int64
# VAR_0833                 int64
# VAR_0834                 int64
# VAR_0835                 int64
# VAR_0836                 int64
# VAR_0837                 int64
# VAR_0838                 int64
# VAR_0839                 int64
# VAR_0841                 int64
# VAR_0842                 int64
# VAR_0843                 int64
# VAR_0844                 int64
# VAR_0845                 int64
# VAR_0846                 int64
# VAR_0848                 int64
# VAR_0849                 int64
# VAR_0850                 int64
# VAR_0851                 int64
# VAR_0852                 int64
# VAR_0853                 int64
# VAR_0854                 int64
# VAR_0855                 int64
# VAR_0856                 int64
# VAR_0857                 int64
# VAR_0858                 int64
# VAR_0859                 int64
# VAR_0860                 int64
# VAR_0861                 int64
# VAR_0862                 int64
# VAR_0863                 int64
# VAR_0864                 int64
# VAR_0865                 int64
# VAR_0866                 int64
# VAR_0867                 int64
# VAR_0868                 int64
# VAR_0869                 int64
# VAR_0870                 int64
# VAR_0871                 int64
# VAR_0872                 int64
# VAR_0873                 int64
# VAR_0874                 int64
# VAR_0875                 int64
# VAR_0876                 int64
# VAR_0877                 int64
# VAR_0878                 int64
# VAR_0879                 int64
# VAR_0880                 int64
# VAR_0881                 int64
# VAR_0882                 int64
# VAR_0883                 int64
# VAR_0884                 int64
# VAR_0885                 int64
# VAR_0886                 int64
# VAR_0887                 int64
# VAR_0888                 int64
# VAR_0889                 int64
# VAR_0890                 int64
# VAR_0891                 int64
# VAR_0892                 int64
# VAR_0893                 int64
# VAR_0894                 int64
# VAR_0895                 int64
# VAR_0896                 int64
# VAR_0897                 int64
# VAR_0898                 int64
# VAR_0899                 int64
# VAR_0900                 int64
# VAR_0901                 int64
# VAR_0902                 int64
# VAR_0903                 int64
# VAR_0904                 int64
# VAR_0905                 int64
# VAR_0906                 int64
# VAR_0907                 int64
# VAR_0908                 int64
# VAR_0909                 int64
# VAR_0910                 int64
# VAR_0911                 int64
# VAR_0912                 int64
# VAR_0913                 int64
# VAR_0914                 int64
# VAR_0915                 int64
# VAR_0916                 int64
# VAR_0917                 int64
# VAR_0918                 int64
# VAR_0919                 int64
# VAR_0920                 int64
# VAR_0921                 int64
# VAR_0922                 int64
# VAR_0923                 int64
# VAR_0924                 int64
# VAR_0925                 int64
# VAR_0926                 int64
# VAR_0927                 int64
# VAR_0928                 int64
# VAR_0929                 int64
# VAR_0930                 int64
# VAR_0931                 int64
# VAR_0932                 int64
# VAR_0933                 int64
# VAR_0934                 int64
# VAR_0935                 int64
# VAR_0936                 int64
# VAR_0937                 int64
# VAR_0938                 int64
# VAR_0939                 int64
# VAR_0940                 int64
# VAR_0941                 int64
# VAR_0942                 int64
# VAR_0943                 int64
# VAR_0944                 int64
# VAR_0945                 int64
# VAR_0946                 int64
# VAR_0947                 int64
# VAR_0948                 int64
# VAR_0949                 int64
# VAR_0950                 int64
# VAR_0951                 int64
# VAR_0952                 int64
# VAR_0953                 int64
# VAR_0954                 int64
# VAR_0955                 int64
# VAR_0956                 int64
# VAR_0957                 int64
# VAR_0958                 int64
# VAR_0959                 int64
# VAR_0960                 int64
# VAR_0961                 int64
# VAR_0962                 int64
# VAR_0963                 int64
# VAR_0964                 int64
# VAR_0965                 int64
# VAR_0966                 int64
# VAR_0967                 int64
# VAR_0968                 int64
# VAR_0969                 int64
# VAR_0970                 int64
# VAR_0971                 int64
# VAR_0972                 int64
# VAR_0973                 int64
# VAR_0974                 int64
# VAR_0975                 int64
# VAR_0976                 int64
# VAR_0977                 int64
# VAR_0978                 int64
# VAR_0979                 int64
# VAR_0980                 int64
# VAR_0981                 int64
# VAR_0982                 int64
# VAR_0983                 int64
# VAR_0984                 int64
# VAR_0985                 int64
# VAR_0986                 int64
# VAR_0987                 int64
# VAR_0988                 int64
# VAR_0989                 int64
# VAR_0990                 int64
# VAR_0991                 int64
# VAR_0992                 int64
# VAR_0993                 int64
# VAR_0994                 int64
# VAR_0995                 int64
# VAR_0996                 int64
# VAR_0997                 int64
# VAR_0998                 int64
# VAR_0999                 int64
# VAR_1000                 int64
# VAR_1001                 int64
# VAR_1002                 int64
# VAR_1003                 int64
# VAR_1004                 int64
# VAR_1005                 int64
# VAR_1006                 int64
# VAR_1007                 int64
# VAR_1008                 int64
# VAR_1009                 int64
# VAR_1010                 int64
# VAR_1011                 int64
# VAR_1012                 int64
# VAR_1013                 int64
# VAR_1014                 int64
# VAR_1015                 int64
# VAR_1016                 int64
# VAR_1017                 int64
# VAR_1018                 int64
# VAR_1019                 int64
# VAR_1020                 int64
# VAR_1021                 int64
# VAR_1022                 int64
# VAR_1023                 int64
# VAR_1024                 int64
# VAR_1025                 int64
# VAR_1026                 int64
# VAR_1027                 int64
# VAR_1028                 int64
# VAR_1029                 int64
# VAR_1030                 int64
# VAR_1031                 int64
# VAR_1032                 int64
# VAR_1033                 int64
# VAR_1034                 int64
# VAR_1035                 int64
# VAR_1036                 int64
# VAR_1037                 int64
# VAR_1038                 int64
# VAR_1039                 int64
# VAR_1040                 int64
# VAR_1041                 int64
# VAR_1042                 int64
# VAR_1043                 int64
# VAR_1044                 int64
# VAR_1045                 int64
# VAR_1046                 int64
# VAR_1047                 int64
# VAR_1048                 int64
# VAR_1049                 int64
# VAR_1050                 int64
# VAR_1051                 int64
# VAR_1052                 int64
# VAR_1053                 int64
# VAR_1054                 int64
# VAR_1055                 int64
# VAR_1056                 int64
# VAR_1057                 int64
# VAR_1058                 int64
# VAR_1059                 int64
# VAR_1060                 int64
# VAR_1061                 int64
# VAR_1062                 int64
# VAR_1063                 int64
# VAR_1064                 int64
# VAR_1065                 int64
# VAR_1066                 int64
# VAR_1067                 int64
# VAR_1068                 int64
# VAR_1069                 int64
# VAR_1070                 int64
# VAR_1071                 int64
# VAR_1072                 int64
# VAR_1073                 int64
# VAR_1074                 int64
# VAR_1075                 int64
# VAR_1076                 int64
# VAR_1077                 int64
# VAR_1078                 int64
# VAR_1079                 int64
# VAR_1080                 int64
# VAR_1081                 int64
# VAR_1082                 int64
# VAR_1083                 int64
# VAR_1084                 int64
# VAR_1085                 int64
# VAR_1086                 int64
# VAR_1087                 int64
# VAR_1088                 int64
# VAR_1089                 int64
# VAR_1090                 int64
# VAR_1091                 int64
# VAR_1092                 int64
# VAR_1093                 int64
# VAR_1094                 int64
# VAR_1095                 int64
# VAR_1096                 int64
# VAR_1097                 int64
# VAR_1098                 int64
# VAR_1099                 int64
# VAR_1100                 int64
# VAR_1101                 int64
# VAR_1102                 int64
# VAR_1103                 int64
# VAR_1104                 int64
# VAR_1105                 int64
# VAR_1106                 int64
# VAR_1107                 int64
# VAR_1108                 int64
# VAR_1109                 int64
# VAR_1110                 int64
# VAR_1111                 int64
# VAR_1112                 int64
# VAR_1113                 int64
# VAR_1114                 int64
# VAR_1115                 int64
# VAR_1116                 int64
# VAR_1117                 int64
# VAR_1118                 int64
# VAR_1119                 int64
# VAR_1120                 int64
# VAR_1121                 int64
# VAR_1122                 int64
# VAR_1123                 int64
# VAR_1124                 int64
# VAR_1125                 int64
# VAR_1126                 int64
# VAR_1127                 int64
# VAR_1128                 int64
# VAR_1129                 int64
# VAR_1130                 int64
# VAR_1131                 int64
# VAR_1132                 int64
# VAR_1133                 int64
# VAR_1134                 int64
# VAR_1135                 int64
# VAR_1136                 int64
# VAR_1137                 int64
# VAR_1138                 int64
# VAR_1139                 int64
# VAR_1140                 int64
# VAR_1141                 int64
# VAR_1142                 int64
# VAR_1143                 int64
# VAR_1144                 int64
# VAR_1145                 int64
# VAR_1146                 int64
# VAR_1147                 int64
# VAR_1148                 int64
# VAR_1149                 int64
# VAR_1150                 int64
# VAR_1151                 int64
# VAR_1152                 int64
# VAR_1153                 int64
# VAR_1154                 int64
# VAR_1155                 int64
# VAR_1156                 int64
# VAR_1157                 int64
# VAR_1158                 int64
# VAR_1159                 int64
# VAR_1160                 int64
# VAR_1161                 int64
# VAR_1162                 int64
# VAR_1163                 int64
# VAR_1164                 int64
# VAR_1165                 int64
# VAR_1166                 int64
# VAR_1167                 int64
# VAR_1168                 int64
# VAR_1169                 int64
# VAR_1170                 int64
# VAR_1171                 int64
# VAR_1172                 int64
# VAR_1173                 int64
# VAR_1174                 int64
# VAR_1175                 int64
# VAR_1176                 int64
# VAR_1177                 int64
# VAR_1178                 int64
# VAR_1179                 int64
# VAR_1180                 int64
# VAR_1181                 int64
# VAR_1182                 int64
# VAR_1183                 int64
# VAR_1184                 int64
# VAR_1185                 int64
# VAR_1186                 int64
# VAR_1187                 int64
# VAR_1188                 int64
# VAR_1189                 int64
# VAR_1190                 int64
# VAR_1191                 int64
# VAR_1192                 int64
# VAR_1193                 int64
# VAR_1194                 int64
# VAR_1195                 int64
# VAR_1196                 int64
# VAR_1197                 int64
# VAR_1198                 int64
# VAR_1199                 int64
# VAR_1200                 int64
# VAR_1201                 int64
# VAR_1202                 int64
# VAR_1203                 int64
# VAR_1204                 int64
# VAR_1205                 int64
# VAR_1206                 int64
# VAR_1207                 int64
# VAR_1208                 int64
# VAR_1209                 int64
# VAR_1210                 int64
# VAR_1211                 int64
# VAR_1212                 int64
# VAR_1213                 int64
# VAR_1214                 int64
# VAR_1215                 int64
# VAR_1216                 int64
# VAR_1217                 int64
# VAR_1218                 int64
# VAR_1219                 int64
# VAR_1220                 int64
# VAR_1221                 int64
# VAR_1222                 int64
# VAR_1223                 int64
# VAR_1224                 int64
# VAR_1225                 int64
# VAR_1226                 int64
# VAR_1227                 int64
# VAR_1228                 int64
# VAR_1229                 int64
# VAR_1230                 int64
# VAR_1231                 int64
# VAR_1232                 int64
# VAR_1233                 int64
# VAR_1234                 int64
# VAR_1235                 int64
# VAR_1236                 int64
# VAR_1237                 int64
# VAR_1238                 int64
# VAR_1239                 int64
# VAR_1240                 int64
# VAR_1241                 int64
# VAR_1242                 int64
# VAR_1243                 int64
# VAR_1244                 int64
# VAR_1245                 int64
# VAR_1246                 int64
# VAR_1247                 int64
# VAR_1248                 int64
# VAR_1249                 int64
# VAR_1250                 int64
# VAR_1251                 int64
# VAR_1252                 int64
# VAR_1253                 int64
# VAR_1254                 int64
# VAR_1255                 int64
# VAR_1256                 int64
# VAR_1257                 int64
# VAR_1258                 int64
# VAR_1259                 int64
# VAR_1260                 int64
# VAR_1261                 int64
# VAR_1262                 int64
# VAR_1263                 int64
# VAR_1264                 int64
# VAR_1265                 int64
# VAR_1266                 int64
# VAR_1267                 int64
# VAR_1268                 int64
# VAR_1269                 int64
# VAR_1270                 int64
# VAR_1271                 int64
# VAR_1272                 int64
# VAR_1273                 int64
# VAR_1274                 int64
# VAR_1275                 int64
# VAR_1276                 int64
# VAR_1277                 int64
# VAR_1278                 int64
# VAR_1279                 int64
# VAR_1280                 int64
# VAR_1281                 int64
# VAR_1282                 int64
# VAR_1283                 int64
# VAR_1284                 int64
# VAR_1285                 int64
# VAR_1286                 int64
# VAR_1287                 int64
# VAR_1288                 int64
# VAR_1289                 int64
# VAR_1290                 int64
# VAR_1291                 int64
# VAR_1292                 int64
# VAR_1293                 int64
# VAR_1294                 int64
# VAR_1295                 int64
# VAR_1296                 int64
# VAR_1297                 int64
# VAR_1298                 int64
# VAR_1299                 int64
# VAR_1300                 int64
# VAR_1301                 int64
# VAR_1302                 int64
# VAR_1303                 int64
# VAR_1304                 int64
# VAR_1305                 int64
# VAR_1306                 int64
# VAR_1307                 int64
# VAR_1308                 int64
# VAR_1309                 int64
# VAR_1310                 int64
# VAR_1311                 int64
# VAR_1312                 int64
# VAR_1313                 int64
# VAR_1314                 int64
# VAR_1315                 int64
# VAR_1316                 int64
# VAR_1317                 int64
# VAR_1318                 int64
# VAR_1319                 int64
# VAR_1320                 int64
# VAR_1321                 int64
# VAR_1322                 int64
# VAR_1323                 int64
# VAR_1324                 int64
# VAR_1325                 int64
# VAR_1326                 int64
# VAR_1327                 int64
# VAR_1328                 int64
# VAR_1329                 int64
# VAR_1330                 int64
# VAR_1331                 int64
# VAR_1332                 int64
# VAR_1333                 int64
# VAR_1334                 int64
# VAR_1335                 int64
# VAR_1336                 int64
# VAR_1337                 int64
# VAR_1338                 int64
# VAR_1339                 int64
# VAR_1340                 int64
# VAR_1341                 int64
# VAR_1342                 int64
# VAR_1343                 int64
# VAR_1344                 int64
# VAR_1345                 int64
# VAR_1346                 int64
# VAR_1347                 int64
# VAR_1348                 int64
# VAR_1349                 int64
# VAR_1350                 int64
# VAR_1351                 int64
# VAR_1352                 int64
# VAR_1353                 int64
# VAR_1354                 int64
# VAR_1355                 int64
# VAR_1356                 int64
# VAR_1357                 int64
# VAR_1358                 int64
# VAR_1359                 int64
# VAR_1360                 int64
# VAR_1361                 int64
# VAR_1362                 int64
# VAR_1363                 int64
# VAR_1364                 int64
# VAR_1365                 int64
# VAR_1366                 int64
# VAR_1367                 int64
# VAR_1368                 int64
# VAR_1369                 int64
# VAR_1370                 int64
# VAR_1371                 int64
# VAR_1372                 int64
# VAR_1373                 int64
# VAR_1374                 int64
# VAR_1375                 int64
# VAR_1376                 int64
# VAR_1377                 int64
# VAR_1378                 int64
# VAR_1379                 int64
# VAR_1380                 int64
# VAR_1381                 int64
# VAR_1382                 int64
# VAR_1383                 int64
# VAR_1384                 int64
# VAR_1385                 int64
# VAR_1386                 int64
# VAR_1387                 int64
# VAR_1388                 int64
# VAR_1389                 int64
# VAR_1390                 int64
# VAR_1391                 int64
# VAR_1392                 int64
# VAR_1393                 int64
# VAR_1394                 int64
# VAR_1395                 int64
# VAR_1396                 int64
# VAR_1397                 int64
# VAR_1398                 int64
# VAR_1399                 int64
# VAR_1400                 int64
# VAR_1401                 int64
# VAR_1402                 int64
# VAR_1403                 int64
# VAR_1404                 int64
# VAR_1405                 int64
# VAR_1406                 int64
# VAR_1407                 int64
# VAR_1408                 int64
# VAR_1409                 int64
# VAR_1410                 int64
# VAR_1411                 int64
# VAR_1412                 int64
# VAR_1413                 int64
# VAR_1414                 int64
# VAR_1415                 int64
# VAR_1416                 int64
# VAR_1417                 int64
# VAR_1418                 int64
# VAR_1419                 int64
# VAR_1420                 int64
# VAR_1421                 int64
# VAR_1422                 int64
# VAR_1423                 int64
# VAR_1424                 int64
# VAR_1425                 int64
# VAR_1426                 int64
# VAR_1427                 int64
# VAR_1429                 int64
# VAR_1430                 int64
# VAR_1431                 int64
# VAR_1432                 int64
# VAR_1433                 int64
# VAR_1434                 int64
# VAR_1435                 int64
# VAR_1436                 int64
# VAR_1437                 int64
# VAR_1438                 int64
# VAR_1439                 int64
# VAR_1440                 int64
# VAR_1441                 int64
# VAR_1442                 int64
# VAR_1443                 int64
# VAR_1444                 int64
# VAR_1445                 int64
# VAR_1446                 int64
# VAR_1447                 int64
# VAR_1448                 int64
# VAR_1449                 int64
# VAR_1450                 int64
# VAR_1451                 int64
# VAR_1452                 int64
# VAR_1453                 int64
# VAR_1454                 int64
# VAR_1455                 int64
# VAR_1456                 int64
# VAR_1457                 int64
# VAR_1458                 int64
# VAR_1459                 int64
# VAR_1460                 int64
# VAR_1461                 int64
# VAR_1462                 int64
# VAR_1463                 int64
# VAR_1464                 int64
# VAR_1465                 int64
# VAR_1466                 int64
# VAR_1467                 int64
# VAR_1468                 int64
# VAR_1469                 int64
# VAR_1470                 int64
# VAR_1471                 int64
# VAR_1472                 int64
# VAR_1473                 int64
# VAR_1474                 int64
# VAR_1475                 int64
# VAR_1476                 int64
# VAR_1477                 int64
# VAR_1478                 int64
# VAR_1479                 int64
# VAR_1480                 int64
# VAR_1481                 int64
# VAR_1482                 int64
# VAR_1483                 int64
# VAR_1484                 int64
# VAR_1485                 int64
# VAR_1486                 int64
# VAR_1487                 int64
# VAR_1488                 int64
# VAR_1489                 int64
# VAR_1490                 int64
# VAR_1491                 int64
# VAR_1492                 int64
# VAR_1493                 int64
# VAR_1494                 int64
# VAR_1495                 int64
# VAR_1496                 int64
# VAR_1497                 int64
# VAR_1498                 int64
# VAR_1499                 int64
# VAR_1500                 int64
# VAR_1501                 int64
# VAR_1502                 int64
# VAR_1503                 int64
# VAR_1504                 int64
# VAR_1505                 int64
# VAR_1506                 int64
# VAR_1507                 int64
# VAR_1508                 int64
# VAR_1509                 int64
# VAR_1510                 int64
# VAR_1511                 int64
# VAR_1512                 int64
# VAR_1513                 int64
# VAR_1514                 int64
# VAR_1515                 int64
# VAR_1516                 int64
# VAR_1517                 int64
# VAR_1518                 int64
# VAR_1519                 int64
# VAR_1520                 int64
# VAR_1521                 int64
# VAR_1522                 int64
# VAR_1523                 int64
# VAR_1524                 int64
# VAR_1525                 int64
# VAR_1526                 int64
# VAR_1527                 int64
# VAR_1528                 int64
# VAR_1529                 int64
# VAR_1530                 int64
# VAR_1531                 int64
# VAR_1532                 int64
# VAR_1533                 int64
# VAR_1534                 int64
# VAR_1535                 int64
# VAR_1536                 int64
# VAR_1537                 int64
# VAR_1538                 int64
# VAR_1539                 int64
# VAR_1540                 int64
# VAR_1541                 int64
# VAR_1542                 int64
# VAR_1543                 int64
# VAR_1544                 int64
# VAR_1545                 int64
# VAR_1546                 int64
# VAR_1547                 int64
# VAR_1548                 int64
# VAR_1549                 int64
# VAR_1550                 int64
# VAR_1551                 int64
# VAR_1552                 int64
# VAR_1553                 int64
# VAR_1554                 int64
# VAR_1555                 int64
# VAR_1556                 int64
# VAR_1557                 int64
# VAR_1558                 int64
# VAR_1559                 int64
# VAR_1560                 int64
# VAR_1561                 int64
# VAR_1562                 int64
# VAR_1563                 int64
# VAR_1564                 int64
# VAR_1565                 int64
# VAR_1566                 int64
# VAR_1567                 int64
# VAR_1568                 int64
# VAR_1569                 int64
# VAR_1570                 int64
# VAR_1571                 int64
# VAR_1572                 int64
# VAR_1573                 int64
# VAR_1574                 int64
# VAR_1575                 int64
# VAR_1576                 int64
# VAR_1577                 int64
# VAR_1578                 int64
# VAR_1579                 int64
# VAR_1580                 int64
# VAR_1581                 int64
# VAR_1582                 int64
# VAR_1583                 int64
# VAR_1584                 int64
# VAR_1585                 int64
# VAR_1586                 int64
# VAR_1587                 int64
# VAR_1588                 int64
# VAR_1589                 int64
# VAR_1590                 int64
# VAR_1591                 int64
# VAR_1592                 int64
# VAR_1593                 int64
# VAR_1594                 int64
# VAR_1595                 int64
# VAR_1596                 int64
# VAR_1597                 int64
# VAR_1598                 int64
# VAR_1599                 int64
# VAR_1600                 int64
# VAR_1601                 int64
# VAR_1602                 int64
# VAR_1603                 int64
# VAR_1604                 int64
# VAR_1605                 int64
# VAR_1606                 int64
# VAR_1607                 int64
# VAR_1608                 int64
# VAR_1609                 int64
# VAR_1610                 int64
# VAR_1611                 int64
# VAR_1612                 int64
# VAR_1613                 int64
# VAR_1614                 int64
# VAR_1615                 int64
# VAR_1616                 int64
# ...
# VAR_1634                 int64
# VAR_1635                 int64
# VAR_1636                 int64
# VAR_1637                 int64
# VAR_1638                 int64
# VAR_1639                 int64
# VAR_1640                 int64
# VAR_1641                 int64
# VAR_1642                 int64
# VAR_1643                 int64
# VAR_1644                 int64
# VAR_1645                 int64
# VAR_1646                 int64
# VAR_1647                 int64
# VAR_1648                 int64
# VAR_1649                 int64
# VAR_1650                 int64
# VAR_1651                 int64
# VAR_1652                 int64
# VAR_1653                 int64
# VAR_1654                 int64
# VAR_1655                 int64
# VAR_1656                 int64
# VAR_1657                 int64
# VAR_1658                 int64
# VAR_1659                 int64
# VAR_1660                 int64
# VAR_1661                 int64
# VAR_1662                 int64
# VAR_1663                 int64
# VAR_1664                 int64
# VAR_1665                 int64
# VAR_1666                 int64
# VAR_1667                 int64
# VAR_1668                 int64
# VAR_1669                 int64
# VAR_1670                 int64
# VAR_1671                 int64
# VAR_1672                 int64
# VAR_1673                 int64
# VAR_1674                 int64
# VAR_1675                 int64
# VAR_1676                 int64
# VAR_1677                 int64
# VAR_1678                 int64
# VAR_1679                 int64
# VAR_1680                 int64
# VAR_1681                 int64
# VAR_1682                 int64
# VAR_1683                 int64
# VAR_1684                 int64
# VAR_1685                 int64
# VAR_1686                 int64
# VAR_1687                 int64
# VAR_1688                 int64
# VAR_1689                 int64
# VAR_1690                 int64
# VAR_1691                 int64
# VAR_1692                 int64
# VAR_1693                 int64
# VAR_1694                 int64
# VAR_1695                 int64
# VAR_1696                 int64
# VAR_1697                 int64
# VAR_1698                 int64
# VAR_1699                 int64
# VAR_1700                 int64
# VAR_1701                 int64
# VAR_1702                 int64
# VAR_1703                 int64
# VAR_1704                 int64
# VAR_1705                 int64
# VAR_1706                 int64
# VAR_1707                 int64
# VAR_1708                 int64
# VAR_1709                 int64
# VAR_1710                 int64
# VAR_1711                 int64
# VAR_1712                 int64
# VAR_1713                 int64
# VAR_1714                 int64
# VAR_1715                 int64
# VAR_1716                 int64
# VAR_1717                 int64
# VAR_1718                 int64
# VAR_1719                 int64
# VAR_1720                 int64
# VAR_1721                 int64
# VAR_1722                 int64
# VAR_1723                 int64
# VAR_1724                 int64
# VAR_1725                 int64
# VAR_1726                 int64
# VAR_1727                 int64
# VAR_1728                 int64
# VAR_1729                 int64
# VAR_1730                 int64
# VAR_1731                 int64
# VAR_1732                 int64
# VAR_1733                 int64
# VAR_1734                 int64
# VAR_1735                 int64
# VAR_1736                 int64
# VAR_1737                 int64
# VAR_1738                 int64
# VAR_1739                 int64
# VAR_1740                 int64
# VAR_1741                 int64
# VAR_1742                 int64
# VAR_1743                 int64
# VAR_1744                 int64
# VAR_1745                 int64
# VAR_1746                 int64
# VAR_1747                 int64
# VAR_1748                 int64
# VAR_1749                 int64
# VAR_1750                 int64
# VAR_1751                 int64
# VAR_1752                 int64
# VAR_1753                 int64
# VAR_1754                 int64
# VAR_1755                 int64
# VAR_1756                 int64
# VAR_1757                 int64
# VAR_1758                 int64
# VAR_1759                 int64
# VAR_1760                 int64
# VAR_1761                 int64
# VAR_1762                 int64
# VAR_1763                 int64
# VAR_1764                 int64
# VAR_1765                 int64
# VAR_1766                 int64
# VAR_1767                 int64
# VAR_1768                 int64
# VAR_1769                 int64
# VAR_1770                 int64
# VAR_1771                 int64
# VAR_1772                 int64
# VAR_1773                 int64
# VAR_1774                 int64
# VAR_1775                 int64
# VAR_1776                 int64
# VAR_1777                 int64
# VAR_1778                 int64
# VAR_1779                 int64
# VAR_1780                 int64
# VAR_1781                 int64
# VAR_1782                 int64
# VAR_1783                 int64
# VAR_1784                 int64
# VAR_1785                 int64
# VAR_1786                 int64
# VAR_1787                 int64
# VAR_1788                 int64
# VAR_1789                 int64
# VAR_1790                 int64
# VAR_1791                 int64
# VAR_1792                 int64
# VAR_1793                 int64
# VAR_1794                 int64
# VAR_1795                 int64
# VAR_1796                 int64
# VAR_1797                 int64
# VAR_1798                 int64
# VAR_1799                 int64
# VAR_1800                 int64
# VAR_1801                 int64
# VAR_1802                 int64
# VAR_1803                 int64
# VAR_1804                 int64
# VAR_1805                 int64
# VAR_1806                 int64
# VAR_1807                 int64
# VAR_1808                 int64
# VAR_1809                 int64
# VAR_1810                 int64
# VAR_1811                 int64
# VAR_1812                 int64
# VAR_1813                 int64
# VAR_1814                 int64
# VAR_1815                 int64
# VAR_1816                 int64
# VAR_1817                 int64
# VAR_1818                 int64
# VAR_1819                 int64
# VAR_1820                 int64
# VAR_1821                 int64
# VAR_1822                 int64
# VAR_1823                 int64
# VAR_1824                 int64
# VAR_1825                 int64
# VAR_1826                 int64
# VAR_1827                 int64
# VAR_1828                 int64
# VAR_1829                 int64
# VAR_1830                 int64
# VAR_1831                 int64
# VAR_1832                 int64
# VAR_1833                 int64
# VAR_1834                 int64
# VAR_1835                 int64
# VAR_1836                 int64
# VAR_1837                 int64
# VAR_1838                 int64
# VAR_1839                 int64
# VAR_1840                 int64
# VAR_1841                 int64
# VAR_1842                 int64
# VAR_1843                 int64
# VAR_1844                 int64
# VAR_1845                 int64
# VAR_1846                 int64
# VAR_1847                 int64
# VAR_1848                 int64
# VAR_1849                 int64
# VAR_1850                 int64
# VAR_1851                 int64
# VAR_1852                 int64
# VAR_1853                 int64
# VAR_1854                 int64
# VAR_1855                 int64
# VAR_1856                 int64
# VAR_1857                 int64
# VAR_1858                 int64
# VAR_1859                 int64
# VAR_1860                 int64
# VAR_1861                 int64
# VAR_1862                 int64
# VAR_1863                 int64
# VAR_1864                 int64
# VAR_1865                 int64
# VAR_1866                 int64
# VAR_1867                 int64
# VAR_1868                 int64
# VAR_1869                 int64
# VAR_1870                 int64
# VAR_1871                 int64
# VAR_1872                 int64
# VAR_1873                 int64
# VAR_1874                 int64
# VAR_1875                 int64
# VAR_1876                 int64
# VAR_1877                 int64
# VAR_1878                 int64
# VAR_1879                 int64
# VAR_1880                 int64
# VAR_1881                 int64
# VAR_1882                 int64
# VAR_1883                 int64
# VAR_1884                 int64
# VAR_1885                 int64
# VAR_1886                 int64
# VAR_1887                 int64
# VAR_1888                 int64
# VAR_1889                 int64
# VAR_1890                 int64
# VAR_1891                 int64
# VAR_1892                 int64
# VAR_1893                 int64
# VAR_1894                 int64
# VAR_1895                 int64
# VAR_1896                 int64
# VAR_1897                 int64
# VAR_1898                 int64
# VAR_1899                 int64
# VAR_1900                 int64
# VAR_1901                 int64
# VAR_1902                 int64
# VAR_1903                 int64
# VAR_1904                 int64
# VAR_1905                 int64
# VAR_1906                 int64
# VAR_1907                 int64
# VAR_1908                 int64
# VAR_1909                 int64
# VAR_1910                 int64
# VAR_1911                 int64
# VAR_1912                 int64
# VAR_1913                 int64
# VAR_1914                 int64
# VAR_1915                 int64
# VAR_1916                 int64
# VAR_1917                 int64
# VAR_1918                 int64
# VAR_1919                 int64
# VAR_1920                 int64
# VAR_1921                 int64
# VAR_1922                 int64
# VAR_1923                 int64
# VAR_1924                 int64
# VAR_1925                 int64
# VAR_1926                 int64
# VAR_1927                 int64
# VAR_1928                 int64
# VAR_1929                 int64
# VAR_1930                 int64
# VAR_1931                 int64
# VAR_1932                 int64
# VAR_1933                 int64
# VAR_0001_H               uint8
# VAR_0001_Q               uint8
# VAR_0001_R               uint8
# VAR_0005_B               uint8
# VAR_0005_C               uint8
# VAR_0005_N               uint8
# VAR_0005_S               uint8
# VAR_0226_False           uint8
# VAR_0226_True            uint8
# VAR_0230_False           uint8
# VAR_0230_True            uint8
# VAR_0232_False           uint8
# VAR_0232_True            uint8
# VAR_0236_False           uint8
# VAR_0236_True            uint8
# VAR_0237_AK              uint8
# VAR_0237_AL              uint8
# VAR_0237_AR              uint8
# VAR_0237_AZ              uint8
# VAR_0237_CA              uint8
# VAR_0237_CO              uint8
# VAR_0237_CT              uint8
# VAR_0237_DC              uint8
# VAR_0237_DE              uint8
# VAR_0237_FL              uint8
# VAR_0237_GA              uint8
# VAR_0237_HI              uint8
# VAR_0237_IA              uint8
# VAR_0237_ID              uint8
# VAR_0237_IL              uint8
# VAR_0237_IN              uint8
# VAR_0237_KS              uint8
# VAR_0237_KY              uint8
# VAR_0237_LA              uint8
# VAR_0237_MD              uint8
# VAR_0237_MI              uint8
# VAR_0237_MN              uint8
# VAR_0237_MO              uint8
# VAR_0237_MS              uint8
# VAR_0237_MT              uint8
# VAR_0237_NC              uint8
# VAR_0237_NE              uint8
# VAR_0237_NJ              uint8
# VAR_0237_NM              uint8
# VAR_0237_NV              uint8
# VAR_0237_NY              uint8
# VAR_0237_OH              uint8
# VAR_0237_OK              uint8
# VAR_0237_OR              uint8
# VAR_0237_PA              uint8
# VAR_0237_SC              uint8
# VAR_0237_SD              uint8
# VAR_0237_TN              uint8
# VAR_0237_TX              uint8
# VAR_0237_UT              uint8
# VAR_0237_VA              uint8
# VAR_0237_WA              uint8
# VAR_0237_WI              uint8
# VAR_0237_WV              uint8
# VAR_0237_WY              uint8
# VAR_0274_-1              uint8
# VAR_0274_AK              uint8
# VAR_0274_AL              uint8
# VAR_0274_AR              uint8
# VAR_0274_AZ              uint8
# VAR_0274_CA              uint8
# VAR_0274_CO              uint8
# VAR_0274_CT              uint8
# VAR_0274_DC              uint8
# VAR_0274_DE              uint8
# VAR_0274_EE              uint8
# VAR_0274_FL              uint8
# VAR_0274_GA              uint8
# VAR_0274_GS              uint8
# VAR_0274_HI              uint8
# VAR_0274_IA              uint8
# VAR_0274_ID              uint8
# VAR_0274_IL              uint8
# VAR_0274_IN              uint8
# VAR_0274_KS              uint8
# VAR_0274_KY              uint8
# VAR_0274_LA              uint8
# VAR_0274_MA              uint8
# VAR_0274_MD              uint8
# VAR_0274_ME              uint8
# VAR_0274_MI              uint8
# VAR_0274_MN              uint8
# VAR_0274_MO              uint8
# VAR_0274_MS              uint8
# VAR_0274_MT              uint8
# VAR_0274_NC              uint8
# VAR_0274_ND              uint8
# VAR_0274_NE              uint8
# VAR_0274_NH              uint8
# VAR_0274_NJ              uint8
# VAR_0274_NM              uint8
# VAR_0274_NV              uint8
# VAR_0274_NY              uint8
# VAR_0274_OH              uint8
# VAR_0274_OK              uint8
# VAR_0274_OR              uint8
# VAR_0274_PA              uint8
# VAR_0274_PR              uint8
# VAR_0274_RI              uint8
# VAR_0274_RN              uint8
# VAR_0274_RR              uint8
# VAR_0274_SC              uint8
# VAR_0274_SD              uint8
# VAR_0274_TN              uint8
# VAR_0274_TX              uint8
# VAR_0274_UT              uint8
# VAR_0274_VA              uint8
# VAR_0274_VT              uint8
# VAR_0274_WA              uint8
# VAR_0274_WI              uint8
# VAR_0274_WV              uint8
# VAR_0274_WY              uint8
# VAR_0283_-1              uint8
# VAR_0283_F               uint8
# VAR_0283_H               uint8
# VAR_0283_P               uint8
# VAR_0283_R               uint8
# VAR_0283_S               uint8
# VAR_0283_U               uint8
# VAR_0305_-1              uint8
# VAR_0305_F               uint8
# VAR_0305_H               uint8
# VAR_0305_M               uint8
# VAR_0305_P               uint8
# VAR_0305_R               uint8
# VAR_0305_S               uint8
# VAR_0305_U               uint8
# VAR_0325_-1              uint8
# VAR_0325_F               uint8
# VAR_0325_G               uint8
# VAR_0325_H               uint8
# VAR_0325_M               uint8
# VAR_0325_P               uint8
# VAR_0325_R               uint8
# VAR_0325_S               uint8
# VAR_0325_U               uint8
# VAR_0342_-1              uint8
# VAR_0342_AA              uint8
# VAR_0342_AB              uint8
# VAR_0342_AC              uint8
# VAR_0342_AD              uint8
# VAR_0342_AE              uint8
# VAR_0342_AF              uint8
# VAR_0342_AU              uint8
# VAR_0342_BA              uint8
# VAR_0342_BB              uint8
# VAR_0342_BC              uint8
# VAR_0342_BD              uint8
# VAR_0342_BE              uint8
# VAR_0342_BF              uint8
# VAR_0342_BU              uint8
# VAR_0342_CA              uint8
# VAR_0342_CB              uint8
# VAR_0342_CC              uint8
# VAR_0342_CD              uint8
# VAR_0342_CE              uint8
# VAR_0342_CF              uint8
# VAR_0342_CU              uint8
# VAR_0342_DA              uint8
# VAR_0342_DB              uint8
# VAR_0342_DC              uint8
# VAR_0342_DD              uint8
# VAR_0342_DE              uint8
# VAR_0342_DF              uint8
# VAR_0342_DU              uint8
# VAR_0342_EA              uint8
# VAR_0342_EB              uint8
# VAR_0342_EC              uint8
# VAR_0342_ED              uint8
# VAR_0342_EE              uint8
# VAR_0342_EF              uint8
# VAR_0342_EU              uint8
# VAR_0342_FA              uint8
# VAR_0342_FB              uint8
# VAR_0342_FC              uint8
# VAR_0342_FD              uint8
# VAR_0342_FE              uint8
# VAR_0342_FF              uint8
# VAR_0342_FU              uint8
# VAR_0342_UA              uint8
# VAR_0342_UB              uint8
# VAR_0342_UC              uint8
# VAR_0342_UD              uint8
# VAR_0342_UE              uint8
# VAR_0342_UF              uint8
# VAR_0342_UU              uint8
# VAR_0352_-1              uint8
# VAR_0352_O               uint8
# VAR_0352_R               uint8
# VAR_0352_U               uint8
# VAR_0353_-1              uint8
# VAR_0353_O               uint8
# VAR_0353_R               uint8
# VAR_0353_U               uint8
# VAR_0354_-1              uint8
# VAR_0354_O               uint8
# VAR_0354_R               uint8
# VAR_0354_U               uint8
# VAR_0466_-1              uint8
# VAR_0466_I               uint8
# VAR_0467_-1              uint8
# VAR_0467_Discharge NA    uint8
# VAR_0467_Discharged      uint8
# VAR_0467_Dismissed       uint8
# VAR_1934_-1              uint8
# VAR_1934_Discharge NA    uint8
# VAR_1934_Discharged      uint8
# VAR_1934_Dismissed       uint8
# dtypes: float64(431), int64(1402), uint8(213)
# memory usage: 2.0 GB

# %% [markdown]
# ## 1.d) Splitting Data into Training and Test Sets

# %%
# Encode class values as integers and perform one-hot-encoding
y_encoded = y_original.to_numpy()
# encoder = preprocessing.LabelEncoder()
# encoder.fit(y_original)
# y_encoded = encoder.transform(y_original)
print(y_encoded)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# Split the data further into training and test datasets
X_encoded = X_original.to_numpy()
if (splitDataset):
    X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=splitPercentage, 
                                                        stratify=y_encoded, random_state=seedNum)
else:
    X_train, y_train = X_encoded, y_encoded
    X_test, y_test = X_encoded, y_encoded
print("X_train.shape: {} X_train.type: {}".format(X_train.shape, type(X_train)))
print("y_train.shape: {} y_train.type: {}".format(y_train.shape, type(y_train)))
print("X_test.shape: {} X_test.type: {}".format(X_test.shape, type(X_test)))
print("y_test.shape: {} y_test.type: {}".format(y_test.shape, type(y_test)))
# Out:
# X_train.shape: (122622, 2046) X_train.type: <class 'numpy.ndarray'>
# y_train.shape: (122622,) y_train.type: <class 'numpy.ndarray'>
# X_test.shape: (21640, 2046) X_test.type: <class 'numpy.ndarray'>
# y_test.shape: (21640,) y_test.type: <class 'numpy.ndarray'>

# %%
if (notifyStatus): email_notify("Phase 1 Load Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 2. Define Model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of modeling

# %%
if (notifyStatus): email_notify("Phase 2 Define Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 3. Fit and Evaluate Model

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Not applicable for this iteration of modeling

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 4. Explore Different Two-Layer Models

# %%
if (notifyStatus): email_notify("Phase 4 Explore Different One-Layer Models has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define MLP model #5A
def create_model_5A():
    default_model = Sequential()
    default_model.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(48, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(32, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5A = create_model_5A()
extra_epochs = 0
baseline_hist = baseline_model_5A.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5A processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 23s 186us/sample - loss: 15274.4366 - auc: 0.5089 - val_loss: 12.5146 - val_auc: 0.5015
# Epoch 2/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 7.0182 - auc: 0.5031 - val_loss: 1.0560 - val_auc: 0.5003
# Epoch 3/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.8376 - auc: 0.4967 - val_loss: 0.7091 - val_auc: 0.5000
# Epoch 4/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5616 - auc: 0.4968 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5423 - auc: 0.4991 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5423 - auc: 0.4980 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5423 - auc: 0.5009 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5424 - auc: 0.4999 - val_loss: 0.5426 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5425 - auc: 0.4985 - val_loss: 0.5426 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5425 - auc: 0.4987 - val_loss: 0.5427 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 20s 161us/sample - loss: 0.5425 - auc: 0.5022 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 12/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5424 - auc: 0.5018 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5425 - auc: 0.4978 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5424 - auc: 0.5017 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5424 - auc: 0.5007 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5425 - auc: 0.4984 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5425 - auc: 0.4973 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5424 - auc: 0.5009 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5425 - auc: 0.4975 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5424 - auc: 0.4985 - val_loss: 0.5424 - val_auc: 0.5000
# Total time for model fitting: 0:06:42.222287

# %%
# Summarize model 5A training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Define MLP model #5B
def create_model_5B():
    default_model = Sequential()
    default_model.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(96, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(64, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5B = create_model_5B()
extra_epochs = 0
baseline_hist = baseline_model_5B.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5B processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 21s 169us/sample - loss: 52337.6406 - auc: 0.5088 - val_loss: 0.5515 - val_auc: 0.5018
# Epoch 2/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.9328 - auc: 0.5005 - val_loss: 0.5422 - val_auc: 0.5002
# Epoch 3/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 8.2952 - auc: 0.4994 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 4/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5423 - auc: 0.4972 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5423 - auc: 0.4981 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5423 - auc: 0.4981 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 0.5423 - auc: 0.5007 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5424 - auc: 0.4995 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5424 - auc: 0.5001 - val_loss: 0.5427 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5426 - auc: 0.4983 - val_loss: 0.5426 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 21s 171us/sample - loss: 0.5425 - auc: 0.5031 - val_loss: 0.5429 - val_auc: 0.5000
# Epoch 12/20
# 122622/122622 [==============================] - 21s 168us/sample - loss: 0.5425 - auc: 0.5018 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5426 - auc: 0.4991 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.5018 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.5008 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 0.5425 - auc: 0.5002 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5426 - auc: 0.4977 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.5006 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 0.5426 - auc: 0.4974 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5425 - auc: 0.4974 - val_loss: 0.5423 - val_auc: 0.5000
# Total time for model fitting: 0:06:46.994948

# %%
# Summarize model 5B training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Define MLP model #5C
def create_model_5C():
    default_model = Sequential()
    default_model.add(Dense(256, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(192, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(128, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5C = create_model_5C()
extra_epochs = 0
baseline_hist = baseline_model_5C.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5C processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 209752.2165 - auc: 0.5132 - val_loss: 584.5973 - val_auc: 0.5220
# Epoch 2/20
# 122622/122622 [==============================] - 21s 168us/sample - loss: 364.1542 - auc: 0.5075 - val_loss: 1.5941 - val_auc: 0.5009
# Epoch 3/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 6.7715 - auc: 0.4989 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 4/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 0.5423 - auc: 0.4970 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 21s 169us/sample - loss: 0.5423 - auc: 0.4989 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5423 - auc: 0.4981 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 21s 170us/sample - loss: 0.5423 - auc: 0.5000 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5424 - auc: 0.5003 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 0.5425 - auc: 0.4996 - val_loss: 0.5428 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5426 - auc: 0.4984 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 1.0347 - auc: 0.5036 - val_loss: 0.5427 - val_auc: 0.5002
# Epoch 12/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 3.0543 - auc: 0.5019 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5425 - auc: 0.4980 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.5014 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5425 - auc: 0.5008 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.4999 - val_loss: 0.5426 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5426 - auc: 0.4984 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5426 - auc: 0.5007 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5427 - auc: 0.4970 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5426 - auc: 0.4979 - val_loss: 0.5423 - val_auc: 0.5000
# Total time for model fitting: 0:06:48.537893

# %%
# Summarize model 5C training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Define MLP model #5D
def create_model_5D():
    default_model = Sequential()
    default_model.add(Dense(512, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(384, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(256, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5D = create_model_5D()
extra_epochs = 0
baseline_hist = baseline_model_5D.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5D processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 22s 179us/sample - loss: 671192.5071 - auc: 0.5143 - val_loss: 37.3008 - val_auc: 0.4998
# Epoch 2/20
# 122622/122622 [==============================] - 20s 167us/sample - loss: 12.9513 - auc: 0.5006 - val_loss: 6.5976 - val_auc: 0.4999
# Epoch 3/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 213.2267 - auc: 0.4973 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 4/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5423 - auc: 0.4961 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5423 - auc: 0.4991 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5423 - auc: 0.4984 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5423 - auc: 0.5007 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5423 - auc: 0.4993 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5424 - auc: 0.5004 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5425 - auc: 0.4987 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 20s 165us/sample - loss: 0.5426 - auc: 0.5039 - val_loss: 0.5430 - val_auc: 0.5000
# Epoch 12/20
# 122622/122622 [==============================] - 20s 166us/sample - loss: 0.5426 - auc: 0.5016 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5426 - auc: 0.4983 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5425 - auc: 0.5023 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5425 - auc: 0.5014 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 21s 167us/sample - loss: 0.5426 - auc: 0.5006 - val_loss: 0.5426 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 21s 168us/sample - loss: 0.5426 - auc: 0.4982 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 20s 162us/sample - loss: 0.5425 - auc: 0.5010 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5426 - auc: 0.4969 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5425 - auc: 0.4977 - val_loss: 0.5423 - val_auc: 0.5000
# Total time for model fitting: 0:06:45.453413

# %%
# Summarize model 5D training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Define MLP model #5E
def create_model_5E():
    default_model = Sequential()
    default_model.add(Dense(1024, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(768, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(512, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5E = create_model_5E()
extra_epochs = 0
baseline_hist = baseline_model_5E.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5E processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 21s 168us/sample - loss: 2663199.4559 - auc: 0.5065 - val_loss: 71.3045 - val_auc: 0.5000
# Epoch 2/20
# 122622/122622 [==============================] - 20s 161us/sample - loss: 17.2046 - auc: 0.5019 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 3/20
# 122622/122622 [==============================] - 20s 164us/sample - loss: 0.5423 - auc: 0.4973 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 4/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5423 - auc: 0.4965 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 20s 163us/sample - loss: 0.5423 - auc: 0.4990 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 20s 161us/sample - loss: 0.5423 - auc: 0.4989 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 19s 159us/sample - loss: 0.5423 - auc: 0.5008 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5423 - auc: 0.4999 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 19s 159us/sample - loss: 0.5424 - auc: 0.4998 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5425 - auc: 0.4988 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 20s 161us/sample - loss: 0.5426 - auc: 0.5042 - val_loss: 0.5429 - val_auc: 0.5000
# Epoch 12/20
# 122622/122622 [==============================] - 21s 170us/sample - loss: 0.5427 - auc: 0.5018 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5427 - auc: 0.4982 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5426 - auc: 0.5023 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 19s 159us/sample - loss: 2770.2744 - auc: 0.5005 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 20s 160us/sample - loss: 0.5424 - auc: 0.4988 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 20s 159us/sample - loss: 0.5424 - auc: 0.4972 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 20s 161us/sample - loss: 0.5424 - auc: 0.4997 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 19s 158us/sample - loss: 0.5424 - auc: 0.4981 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 20s 159us/sample - loss: 0.5424 - auc: 0.4986 - val_loss: 0.5423 - val_auc: 0.5000
# Total time for model fitting: 0:06:35.265337

# %%
# Summarize model 5E training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Define MLP model #5F
def create_model_5F():
    default_model = Sequential()
    default_model.add(Dense(2048, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1536, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1024, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_5F = create_model_5F()
extra_epochs = 0
baseline_hist = baseline_model_5F.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 5F processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 122622 samples, validate on 21640 samples
# Epoch 1/20
# 122622/122622 [==============================] - 22s 180us/sample - loss: 25760053.3590 - auc: 0.5202 - val_loss: 12210.5302 - val_auc: 0.5346
# Epoch 2/20
# 122622/122622 [==============================] - 21s 175us/sample - loss: 20766.8374 - auc: 0.5108 - val_loss: 2263.0817 - val_auc: 0.4925
# Epoch 3/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 4791.3720 - auc: 0.5035 - val_loss: 1.4989 - val_auc: 0.4999
# Epoch 4/20
# 122622/122622 [==============================] - 21s 175us/sample - loss: 2.7279 - auc: 0.4964 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 5/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5424 - auc: 0.4989 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 6/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5424 - auc: 0.4983 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 7/20
# 122622/122622 [==============================] - 22s 183us/sample - loss: 0.5423 - auc: 0.5002 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 8/20
# 122622/122622 [==============================] - 22s 176us/sample - loss: 0.5424 - auc: 0.4998 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 9/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5424 - auc: 0.5002 - val_loss: 0.5427 - val_auc: 0.5000
# Epoch 10/20
# 122622/122622 [==============================] - 21s 172us/sample - loss: 0.5426 - auc: 0.4987 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 11/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5427 - auc: 0.5041 - val_loss: 0.5429 - val_auc: 0.5000
# Epoch 12/20
# 122622/122622 [==============================] - 21s 172us/sample - loss: 0.5428 - auc: 0.5013 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 13/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5428 - auc: 0.4984 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 14/20
# 122622/122622 [==============================] - 21s 172us/sample - loss: 0.5427 - auc: 0.5024 - val_loss: 0.5423 - val_auc: 0.5000
# Epoch 15/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5427 - auc: 0.5014 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 16/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5427 - auc: 0.5009 - val_loss: 0.5428 - val_auc: 0.5000
# Epoch 17/20
# 122622/122622 [==============================] - 21s 174us/sample - loss: 0.5427 - auc: 0.4992 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 18/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5426 - auc: 0.5009 - val_loss: 0.5424 - val_auc: 0.5000
# Epoch 19/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5427 - auc: 0.4977 - val_loss: 0.5425 - val_auc: 0.5000
# Epoch 20/20
# 122622/122622 [==============================] - 21s 173us/sample - loss: 0.5426 - auc: 0.4980 - val_loss: 0.5423 - val_auc: 0.5000
# Total time for model fitting: 0:07:07.584098

# %%
# Summarize model 5F training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['auc'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_auc'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (AUC)')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
if (notifyStatus): email_notify("Phase 4 Explore Different One-Layer Models completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 5. Finalize Model

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Display a summary of the final model
final_model = baseline_model_5A
print(final_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                131008
# _________________________________________________________________
# dense_1 (Dense)              (None, 48)                3120
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1568
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 135,729
# Trainable params: 135,729
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the final model
print(final_model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'batch_input_shape': (None, 2046), 'dtype': 'float32', 'units': 64, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 48, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_2', 'trainable': True, 'dtype': 'float32', 'units': 32, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_3', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:42:34.796915
