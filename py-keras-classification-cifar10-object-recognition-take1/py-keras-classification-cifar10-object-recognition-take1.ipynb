# %% [markdown]
# # Multi-Class Deep Learning Model for CIFAR-10 Object Recognition Using Keras Take 1
# ### David Lowe
# ### December 30, 2019
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The CIFAR-10 dataset is a multi-class classification situation where we are trying to predict one of several (more than two) possible outcomes.
#
# INTRODUCTION: The CIFAR-10 is a labeled subset of the 80 million tiny images dataset. They were collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton. The CIFAR-10 dataset consists of 60000 32x32 color images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# For this iteration, we will construct a simple VGG convolutional model with 1 VGG block to classify the images. This model will serve as the baseline for the future iterations of modeling.
#
# ANALYSIS: In this iteration, the performance of the Take1 model with the default parameters achieved an accuracy score of 66.39% on the validation dataset after training for 50 epochs. After tuning the hyperparameters, the Take1 model with the best hyperparameters processed the training dataset with an accuracy of 100.00%. The same model, however, processed the test dataset with an accuracy of only 67.01%. We will need to explore other modeling approaches to make a better model that reduces over-fitting.
#
# CONCLUSION: For this dataset, the model built using Keras and TensorFlow achieved a satisfactory result and should be considered for future modeling activities.
#
# Dataset Used: The CIFAR-10 Dataset
#
# Dataset ML Model: Multi-class classification with numerical attributes
#
# Dataset Reference: https://www.cs.toronto.edu/~kriz/cifar.html
#
# One potential source of performance benchmarks: https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
#
# Any deep-learning modeling project genrally can be broken down into about six major tasks:
#
# 0. Prepare Environment
# 1. Load Data
# 2. Define Model
# 3. Fit and Evaluate Model
# 4. Optimize Model
# 5. Finalize Model

# %% [markdown]
# # Section 0. Prepare Environment

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
# Load libraries and packages
import random
random.seed(seedNum)
import numpy as np
np.random.seed(seedNum)
import tensorflow as tf
tf.random.set_seed(seedNum)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# import keras as K
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasClassifier
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import matplotlib.pyplot as plt
from datetime import datetime
from email.message import EmailMessage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose flag to print detailed messages for debugging (setting to True will activate)
# verbose = True
# tf.debugging.set_log_device_placement(verbose)

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the number of folds for cross validation
n_folds = 5

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.25

# Set various default Keras modeling parameters
default_loss = 'categorical_crossentropy'
default_metrics = ['accuracy']
default_kernel_init = tf.initializers.he_uniform(seed=seedNum)
default_optimizer = tf.optimizers.SGD(learning_rate=0.001, momentum=0.9)
default_epoch = 50
default_batch = 64
# Out:
# Num GPUs Available:  0

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Keras Multi-Class Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
# Reset the random number generators
def reset_random(seedNum):
    random.seed(seedNum)
    np.random.seed(seedNum)
    tf.random.set_seed(seedNum)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 1. Load Data

# %%
if (notifyStatus): email_notify("Phase 1 Load Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## 1.a) Load Dataset

# %%
cifar10 = tf.keras.datasets.cifar10
(X_train, y_train),(X_test, y_test) = cifar10.load_data()

# Summarize loaded datasets
print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 1)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
# Plot first few images
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# ## 1.b) Data Cleaning

# %%
# Not required for this iteration of the project

# %% [markdown]
# ## 1.c) Feature Scaling and Pre-processing

# %%
# Reshape the input data as [samples][width][height][channels]
# X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
# X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# Apply feature scaling and transformation
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## 1.d) Splitting Data into Training and Test Sets

# %%
# Encode class values as integers and perform one-hot-encoding
encoder = preprocessing.LabelEncoder()
encoder.fit(y_train)
train_transformed = encoder.transform(y_train)
test_transformed = encoder.transform(y_test)
y_train = tf.keras.utils.to_categorical(train_transformed)
y_test = tf.keras.utils.to_categorical(test_transformed)

print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))

num_pixels = X_train.shape[1] * X_train.shape[2]
print('Number of pixels:', num_pixels)
num_classes = y_train.shape[1]
print('Number of classes:', num_classes)
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 10)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 10)
# Number of pixels: 1024
# Number of classes: 10
# /usr/local/lib/python3.7/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
if (notifyStatus): email_notify("Phase 1 Load Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 2. Define Model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the Keras model for baseline measurement
def create_default_model():
    default_model = Sequential()
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same', input_shape=(32, 32, 3)))
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Flatten())
    default_model.add(Dense(128, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(num_classes, activation='softmax', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 3. Fit and Evaluate Model

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Initialize the baseline model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model = create_default_model()
baseline_hist = baseline_model.fit(X_train, y_train, epochs=default_epoch, batch_size=default_batch,
                                   validation_data=(X_test, y_test), verbose=1)
print('Total time for creating the baseline model:', (datetime.now() - startTimeModule))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 1.7761 - accuracy: 0.3703 - val_loss: 1.5371 - val_accuracy: 0.4520
# Epoch 2/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 1.4443 - accuracy: 0.4905 - val_loss: 1.3506 - val_accuracy: 0.5275
# Epoch 3/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 1.2781 - accuracy: 0.5501 - val_loss: 1.2286 - val_accuracy: 0.5640
# Epoch 4/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.1632 - accuracy: 0.5915 - val_loss: 1.2135 - val_accuracy: 0.5774
# Epoch 5/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0772 - accuracy: 0.6241 - val_loss: 1.1249 - val_accuracy: 0.5986
# Epoch 6/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0129 - accuracy: 0.6472 - val_loss: 1.0656 - val_accuracy: 0.6259
# Epoch 7/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9525 - accuracy: 0.6690 - val_loss: 1.0233 - val_accuracy: 0.6410
# Epoch 8/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.8976 - accuracy: 0.6866 - val_loss: 1.0083 - val_accuracy: 0.6497
# Epoch 9/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.8541 - accuracy: 0.7040 - val_loss: 0.9903 - val_accuracy: 0.6551
# Epoch 10/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.8096 - accuracy: 0.7201 - val_loss: 0.9792 - val_accuracy: 0.6638
# Epoch 11/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.7699 - accuracy: 0.7324 - val_loss: 0.9758 - val_accuracy: 0.6653
# Epoch 12/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7330 - accuracy: 0.7469 - val_loss: 1.0045 - val_accuracy: 0.6592
# Epoch 13/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.6902 - accuracy: 0.7609 - val_loss: 0.9619 - val_accuracy: 0.6727
# Epoch 14/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.6522 - accuracy: 0.7741 - val_loss: 0.9768 - val_accuracy: 0.6683
# Epoch 15/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.6094 - accuracy: 0.7895 - val_loss: 0.9926 - val_accuracy: 0.6676
# Epoch 16/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.5736 - accuracy: 0.8047 - val_loss: 0.9820 - val_accuracy: 0.6691
# Epoch 17/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5301 - accuracy: 0.8215 - val_loss: 0.9967 - val_accuracy: 0.6745
# Epoch 18/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.4940 - accuracy: 0.8324 - val_loss: 1.0091 - val_accuracy: 0.6736
# Epoch 19/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4523 - accuracy: 0.8474 - val_loss: 1.0775 - val_accuracy: 0.6610
# Epoch 20/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4137 - accuracy: 0.8638 - val_loss: 1.1046 - val_accuracy: 0.6573
# Epoch 21/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.3757 - accuracy: 0.8768 - val_loss: 1.0999 - val_accuracy: 0.6691
# Epoch 22/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.3365 - accuracy: 0.8933 - val_loss: 1.1447 - val_accuracy: 0.6671
# Epoch 23/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.2983 - accuracy: 0.9064 - val_loss: 1.1456 - val_accuracy: 0.6716
# Epoch 24/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.2593 - accuracy: 0.9205 - val_loss: 1.2169 - val_accuracy: 0.6708
# Epoch 25/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.2285 - accuracy: 0.9317 - val_loss: 1.2804 - val_accuracy: 0.6594
# Epoch 26/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1950 - accuracy: 0.9449 - val_loss: 1.3165 - val_accuracy: 0.6620
# Epoch 27/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1656 - accuracy: 0.9556 - val_loss: 1.4375 - val_accuracy: 0.6607
# Epoch 28/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1440 - accuracy: 0.9623 - val_loss: 1.4245 - val_accuracy: 0.6677
# Epoch 29/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1181 - accuracy: 0.9725 - val_loss: 1.4830 - val_accuracy: 0.6684
# Epoch 30/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0954 - accuracy: 0.9799 - val_loss: 1.5367 - val_accuracy: 0.6632
# Epoch 31/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0754 - accuracy: 0.9868 - val_loss: 1.6188 - val_accuracy: 0.6629
# Epoch 32/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0613 - accuracy: 0.9905 - val_loss: 1.6435 - val_accuracy: 0.6668
# Epoch 33/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0484 - accuracy: 0.9940 - val_loss: 1.7113 - val_accuracy: 0.6618
# Epoch 34/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0381 - accuracy: 0.9965 - val_loss: 1.7743 - val_accuracy: 0.6593
# Epoch 35/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0314 - accuracy: 0.9973 - val_loss: 1.8108 - val_accuracy: 0.6629
# Epoch 36/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0263 - accuracy: 0.9979 - val_loss: 1.8822 - val_accuracy: 0.6594
# Epoch 37/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0208 - accuracy: 0.9988 - val_loss: 1.9008 - val_accuracy: 0.6607
# Epoch 38/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0177 - accuracy: 0.9990 - val_loss: 1.9335 - val_accuracy: 0.6630
# Epoch 39/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0161 - accuracy: 0.9990 - val_loss: 1.9674 - val_accuracy: 0.6650
# Epoch 40/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0124 - accuracy: 0.9996 - val_loss: 2.0025 - val_accuracy: 0.6627
# Epoch 41/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0123 - accuracy: 0.9994 - val_loss: 2.0348 - val_accuracy: 0.6626
# Epoch 42/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0101 - accuracy: 0.9996 - val_loss: 2.0637 - val_accuracy: 0.6632
# Epoch 43/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0084 - accuracy: 0.9998 - val_loss: 2.0971 - val_accuracy: 0.6643
# Epoch 44/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0082 - accuracy: 0.9997 - val_loss: 2.1190 - val_accuracy: 0.6623
# Epoch 45/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0074 - accuracy: 0.9998 - val_loss: 2.1459 - val_accuracy: 0.6635
# Epoch 46/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0065 - accuracy: 0.9998 - val_loss: 2.1696 - val_accuracy: 0.6603
# Epoch 47/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0059 - accuracy: 0.9999 - val_loss: 2.1887 - val_accuracy: 0.6633
# Epoch 48/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0055 - accuracy: 0.9999 - val_loss: 2.2122 - val_accuracy: 0.6639
# Epoch 49/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.2304 - val_accuracy: 0.6626
# Epoch 50/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0049 - accuracy: 0.9999 - val_loss: 2.2508 - val_accuracy: 0.6639
# Total time for creating the baseline model: 1:00:34.600700

# %%
# Display a summary of the baseline model
print(baseline_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,060,138
# Trainable params: 1,060,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the baseline model
print(baseline_model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'batch_input_shape': (None, 32, 32, 3), 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_1', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Flatten', 'config': {'name': 'flatten', 'trainable': True, 'dtype': 'float32', 'data_format': 'channels_last'}}, {'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 128, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': 'float32', 'units': 10, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}

# %%
# List all data points in the baseline model training history
print(baseline_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Summarize model training hisotry for accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['accuracy'], color='blue', label='train')
plt.plot(baseline_hist.history['val_accuracy'], color='red', label='test')
plt.title('Baseline Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 4. Optimize Model

# %%
if (notifyStatus): email_notify("Phase 4 Optimize Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the Keras model required for KerasClassifier
def create_customized_model(optimizer, kernel_init):
    customized_model = Sequential()
    customized_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same', input_shape=(32, 32, 3)))
    customized_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(MaxPooling2D((2, 2)))
    customized_model.add(Flatten())
    customized_model.add(Dense(128, activation='relu', kernel_initializer=kernel_init))
    customized_model.add(Dense(num_classes, activation='softmax', kernel_initializer=kernel_init))
    customized_model.compile(loss=default_loss, optimizer=optimizer, metrics=default_metrics)
    return customized_model

# %%
startTimeModule = datetime.now()

# Set up grid search using different epochs, batch sizes, and optimizers
optz_1 = tf.optimizers.Adam(learning_rate=0.001)
optz_2 = tf.optimizers.RMSprop(learning_rate=0.001)
optz_3 = tf.optimizers.SGD(learning_rate=0.001, momentum=0.9)
optimizer_grid = [optz_1, optz_2, optz_3]
print('Optimizer candidate #1 has the object ID of', optz_1)
print('Optimizer candidate #2 has the object ID of', optz_2)
print('Optimizer candidate #3 has the object ID of', optz_3)

init_1 = tf.initializers.RandomNormal(seed=seedNum)
init_2 = tf.initializers.Orthogonal(seed=seedNum)
init_3 = tf.initializers.he_uniform(seed=seedNum)
init_grid = [init_1, init_2, init_3]
print('Initializer candidate #1 has the object ID of', init_1)
print('Initializer candidate #2 has the object ID of', init_2)
print('Initializer candidate #3 has the object ID of', init_3)

epoch_grid = [50]
batch_grid = [64, 128]

best_score = 0
grid_iteration = 0
best_iteration = 0
best_optimizer = default_optimizer
best_kernel_init = default_kernel_init
best_epoch = default_epoch
best_batch = default_batch

for optimizer in optimizer_grid:
    for kernel_init in init_grid:
        for epoch_num in epoch_grid:
            for batch_num in batch_grid:
                print('\nForming the grid-search model #%d using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
                      % (grid_iteration, optimizer, kernel_init, epoch_num, batch_num))
                reset_random(seedNum)
                grid_model = create_customized_model(optimizer, kernel_init)
                grid_hist = grid_model.fit(X_train, y_train, epochs=epoch_num, batch_size=batch_num, 
                                       validation_data=(X_test, y_test), verbose=1)
                if(grid_hist.history['val_accuracy'][-1] > best_score):
                    best_score = grid_hist.history['val_accuracy'][-1]
                    best_iteration = grid_iteration
                    best_optimizer = optimizer
                    best_kernel_init = kernel_init
                    best_epoch = epoch_num
                    best_batch = batch_num
                grid_iteration = grid_iteration + 1

# summarize results
print("\nBest score (highest validation accuracy) found via grid search: accuracy=%f from model iteration #%d"
      % (best_score, best_iteration))
print('The best modeling parameters are: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
print('Total time for performing grid-search of the best parameters:', (datetime.now() - startTimeModule))
# Out:
# Optimizer candidate #1 has the object ID of <tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>
# Optimizer candidate #2 has the object ID of <tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f340832f990>
# Optimizer candidate #3 has the object ID of <tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f340832f950>
# Initializer candidate #1 has the object ID of <tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f340831ca50>
# Initializer candidate #2 has the object ID of <tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7f340843bf50>
# Initializer candidate #3 has the object ID of <tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f340843b050>
#
# Forming the grid-search model #0 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f340831ca50>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.4585 - accuracy: 0.4756 - val_loss: 1.2128 - val_accuracy: 0.5694
# Epoch 2/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.0891 - accuracy: 0.6171 - val_loss: 1.0493 - val_accuracy: 0.6354
# Epoch 3/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.9214 - accuracy: 0.6758 - val_loss: 0.9713 - val_accuracy: 0.6624
# Epoch 4/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7815 - accuracy: 0.7247 - val_loss: 0.9688 - val_accuracy: 0.6626
# Epoch 5/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6570 - accuracy: 0.7698 - val_loss: 0.9732 - val_accuracy: 0.6731
# Epoch 6/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.5478 - accuracy: 0.8072 - val_loss: 1.0108 - val_accuracy: 0.6764
# Epoch 7/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.4329 - accuracy: 0.8500 - val_loss: 1.0499 - val_accuracy: 0.6802
# Epoch 8/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.3250 - accuracy: 0.8865 - val_loss: 1.2465 - val_accuracy: 0.6602
# Epoch 9/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.2364 - accuracy: 0.9184 - val_loss: 1.4268 - val_accuracy: 0.6579
# Epoch 10/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.1723 - accuracy: 0.9408 - val_loss: 1.6592 - val_accuracy: 0.6506
# Epoch 11/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.1198 - accuracy: 0.9591 - val_loss: 1.7911 - val_accuracy: 0.6542
# Epoch 12/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.1061 - accuracy: 0.9644 - val_loss: 1.9523 - val_accuracy: 0.6601
# Epoch 13/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0788 - accuracy: 0.9733 - val_loss: 2.1189 - val_accuracy: 0.6542
# Epoch 14/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0812 - accuracy: 0.9721 - val_loss: 2.1725 - val_accuracy: 0.6628
# Epoch 15/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0634 - accuracy: 0.9790 - val_loss: 2.5311 - val_accuracy: 0.6454
# Epoch 16/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0630 - accuracy: 0.9787 - val_loss: 2.5634 - val_accuracy: 0.6496
# Epoch 17/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0644 - accuracy: 0.9776 - val_loss: 2.5904 - val_accuracy: 0.6502
# Epoch 18/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0517 - accuracy: 0.9828 - val_loss: 2.6671 - val_accuracy: 0.6529
# Epoch 19/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0491 - accuracy: 0.9840 - val_loss: 2.9624 - val_accuracy: 0.6436
# Epoch 20/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0445 - accuracy: 0.9847 - val_loss: 2.8823 - val_accuracy: 0.6551
# Epoch 21/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0516 - accuracy: 0.9820 - val_loss: 2.8807 - val_accuracy: 0.6516
# Epoch 22/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0507 - accuracy: 0.9834 - val_loss: 2.8795 - val_accuracy: 0.6538
# Epoch 23/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0434 - accuracy: 0.9855 - val_loss: 3.0787 - val_accuracy: 0.6482
# Epoch 24/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0491 - accuracy: 0.9837 - val_loss: 3.1344 - val_accuracy: 0.6550
# Epoch 25/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0383 - accuracy: 0.9867 - val_loss: 3.3381 - val_accuracy: 0.6550
# Epoch 26/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0443 - accuracy: 0.9854 - val_loss: 3.1687 - val_accuracy: 0.6601
# Epoch 27/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0399 - accuracy: 0.9871 - val_loss: 3.3717 - val_accuracy: 0.6607
# Epoch 28/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0318 - accuracy: 0.9894 - val_loss: 3.3618 - val_accuracy: 0.6518
# Epoch 29/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0420 - accuracy: 0.9864 - val_loss: 3.4688 - val_accuracy: 0.6524
# Epoch 30/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0386 - accuracy: 0.9874 - val_loss: 3.3652 - val_accuracy: 0.6459
# Epoch 31/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0376 - accuracy: 0.9879 - val_loss: 3.4177 - val_accuracy: 0.6510
# Epoch 32/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0353 - accuracy: 0.9886 - val_loss: 3.5196 - val_accuracy: 0.6516
# Epoch 33/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0278 - accuracy: 0.9910 - val_loss: 3.6856 - val_accuracy: 0.6515
# Epoch 34/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0340 - accuracy: 0.9889 - val_loss: 3.5746 - val_accuracy: 0.6576
# Epoch 35/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0371 - accuracy: 0.9886 - val_loss: 3.7092 - val_accuracy: 0.6471
# Epoch 36/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0288 - accuracy: 0.9901 - val_loss: 3.7124 - val_accuracy: 0.6563
# Epoch 37/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0377 - accuracy: 0.9875 - val_loss: 3.7734 - val_accuracy: 0.6506
# Epoch 38/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0327 - accuracy: 0.9894 - val_loss: 3.7006 - val_accuracy: 0.6548
# Epoch 39/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0223 - accuracy: 0.9928 - val_loss: 3.8374 - val_accuracy: 0.6493
# Epoch 40/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0223 - accuracy: 0.9928 - val_loss: 3.8415 - val_accuracy: 0.6524
# Epoch 41/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0382 - accuracy: 0.9880 - val_loss: 3.8315 - val_accuracy: 0.6471
# Epoch 42/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0312 - accuracy: 0.9901 - val_loss: 3.8343 - val_accuracy: 0.6497
# Epoch 43/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0227 - accuracy: 0.9924 - val_loss: 3.9032 - val_accuracy: 0.6504
# Epoch 44/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0297 - accuracy: 0.9905 - val_loss: 3.9726 - val_accuracy: 0.6455
# Epoch 45/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0288 - accuracy: 0.9911 - val_loss: 4.0913 - val_accuracy: 0.6489
# Epoch 46/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0243 - accuracy: 0.9918 - val_loss: 4.1211 - val_accuracy: 0.6553
# Epoch 47/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0286 - accuracy: 0.9911 - val_loss: 4.1745 - val_accuracy: 0.6467
# Epoch 48/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0250 - accuracy: 0.9919 - val_loss: 4.0980 - val_accuracy: 0.6594
# Epoch 49/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0237 - accuracy: 0.9925 - val_loss: 4.2358 - val_accuracy: 0.6507
# Epoch 50/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0298 - accuracy: 0.9907 - val_loss: 4.2233 - val_accuracy: 0.6570
#
# Forming the grid-search model #1 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f340831ca50>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.5161 - accuracy: 0.4538 - val_loss: 1.2554 - val_accuracy: 0.5463
# Epoch 2/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1741 - accuracy: 0.5832 - val_loss: 1.1445 - val_accuracy: 0.5959
# Epoch 3/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0222 - accuracy: 0.6380 - val_loss: 1.0693 - val_accuracy: 0.6250
# Epoch 4/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9191 - accuracy: 0.6752 - val_loss: 1.0344 - val_accuracy: 0.6368
# Epoch 5/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8384 - accuracy: 0.7054 - val_loss: 1.0190 - val_accuracy: 0.6470
# Epoch 6/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7744 - accuracy: 0.7281 - val_loss: 1.0069 - val_accuracy: 0.6533
# Epoch 7/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7143 - accuracy: 0.7498 - val_loss: 1.0268 - val_accuracy: 0.6515
# Epoch 8/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6597 - accuracy: 0.7698 - val_loss: 1.0367 - val_accuracy: 0.6587
# Epoch 9/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6145 - accuracy: 0.7856 - val_loss: 1.0511 - val_accuracy: 0.6607
# Epoch 10/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5696 - accuracy: 0.8023 - val_loss: 1.0902 - val_accuracy: 0.6550
# Epoch 11/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5252 - accuracy: 0.8174 - val_loss: 1.1477 - val_accuracy: 0.6454
# Epoch 12/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4798 - accuracy: 0.8331 - val_loss: 1.1859 - val_accuracy: 0.6507
# Epoch 13/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4455 - accuracy: 0.8458 - val_loss: 1.2351 - val_accuracy: 0.6513
# Epoch 14/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4010 - accuracy: 0.8609 - val_loss: 1.2896 - val_accuracy: 0.6412
# Epoch 15/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.3630 - accuracy: 0.8760 - val_loss: 1.3691 - val_accuracy: 0.6414
# Epoch 16/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.3300 - accuracy: 0.8886 - val_loss: 1.4408 - val_accuracy: 0.6449
# Epoch 17/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.2932 - accuracy: 0.9026 - val_loss: 1.5566 - val_accuracy: 0.6383
# Epoch 18/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.2647 - accuracy: 0.9105 - val_loss: 1.6396 - val_accuracy: 0.6424
# Epoch 19/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.2325 - accuracy: 0.9232 - val_loss: 1.7690 - val_accuracy: 0.6280
# Epoch 20/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.2088 - accuracy: 0.9311 - val_loss: 1.8186 - val_accuracy: 0.6334
# Epoch 21/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1793 - accuracy: 0.9424 - val_loss: 1.9930 - val_accuracy: 0.6322
# Epoch 22/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1591 - accuracy: 0.9489 - val_loss: 2.1096 - val_accuracy: 0.6274
# Epoch 23/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1406 - accuracy: 0.9547 - val_loss: 2.2214 - val_accuracy: 0.6212
# Epoch 24/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1247 - accuracy: 0.9599 - val_loss: 2.3649 - val_accuracy: 0.6249
# Epoch 25/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0991 - accuracy: 0.9698 - val_loss: 2.5026 - val_accuracy: 0.6254
# Epoch 26/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1011 - accuracy: 0.9675 - val_loss: 2.6287 - val_accuracy: 0.6200
# Epoch 27/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0821 - accuracy: 0.9755 - val_loss: 2.7971 - val_accuracy: 0.6258
# Epoch 28/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0828 - accuracy: 0.9731 - val_loss: 2.8822 - val_accuracy: 0.6189
# Epoch 29/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0746 - accuracy: 0.9763 - val_loss: 2.9574 - val_accuracy: 0.6219
# Epoch 30/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0645 - accuracy: 0.9799 - val_loss: 3.0412 - val_accuracy: 0.6220
# Epoch 31/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0624 - accuracy: 0.9799 - val_loss: 3.2258 - val_accuracy: 0.6199
# Epoch 32/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0603 - accuracy: 0.9805 - val_loss: 3.3610 - val_accuracy: 0.6159
# Epoch 33/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0618 - accuracy: 0.9797 - val_loss: 3.3956 - val_accuracy: 0.6229
# Epoch 34/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0463 - accuracy: 0.9855 - val_loss: 3.5678 - val_accuracy: 0.6158
# Epoch 35/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0440 - accuracy: 0.9859 - val_loss: 3.6105 - val_accuracy: 0.6199
# Epoch 36/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0548 - accuracy: 0.9817 - val_loss: 3.7540 - val_accuracy: 0.6148
# Epoch 37/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0706 - accuracy: 0.9759 - val_loss: 3.7820 - val_accuracy: 0.6187
# Epoch 38/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0384 - accuracy: 0.9879 - val_loss: 3.8252 - val_accuracy: 0.6211
# Epoch 39/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0262 - accuracy: 0.9926 - val_loss: 4.0981 - val_accuracy: 0.6205
# Epoch 40/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0339 - accuracy: 0.9896 - val_loss: 4.0787 - val_accuracy: 0.6140
# Epoch 41/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0531 - accuracy: 0.9821 - val_loss: 4.0605 - val_accuracy: 0.6174
# Epoch 42/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0485 - accuracy: 0.9833 - val_loss: 4.1581 - val_accuracy: 0.6183
# Epoch 43/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0423 - accuracy: 0.9863 - val_loss: 4.1446 - val_accuracy: 0.6149
# Epoch 44/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0353 - accuracy: 0.9886 - val_loss: 4.2992 - val_accuracy: 0.6142
# Epoch 45/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0375 - accuracy: 0.9875 - val_loss: 4.2723 - val_accuracy: 0.6124
# Epoch 46/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0421 - accuracy: 0.9853 - val_loss: 4.3765 - val_accuracy: 0.6185
# Epoch 47/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0489 - accuracy: 0.9825 - val_loss: 4.3404 - val_accuracy: 0.6174
# Epoch 48/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0255 - accuracy: 0.9924 - val_loss: 4.5417 - val_accuracy: 0.6188
# Epoch 49/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0286 - accuracy: 0.9908 - val_loss: 4.4369 - val_accuracy: 0.6165
# Epoch 50/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.0260 - accuracy: 0.9917 - val_loss: 4.6299 - val_accuracy: 0.6149
#
# Forming the grid-search model #2 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7f340843bf50>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.6442 - accuracy: 0.4080 - val_loss: 1.4534 - val_accuracy: 0.4697
# Epoch 2/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.3668 - accuracy: 0.5117 - val_loss: 1.3760 - val_accuracy: 0.5048
# Epoch 3/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.2815 - accuracy: 0.5430 - val_loss: 1.3759 - val_accuracy: 0.5059
# Epoch 4/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.2241 - accuracy: 0.5629 - val_loss: 1.2977 - val_accuracy: 0.5305
# Epoch 5/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.1760 - accuracy: 0.5810 - val_loss: 1.2860 - val_accuracy: 0.5381
# Epoch 6/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.1406 - accuracy: 0.5937 - val_loss: 1.3009 - val_accuracy: 0.5376
# Epoch 7/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.1085 - accuracy: 0.6052 - val_loss: 1.2896 - val_accuracy: 0.5393
# Epoch 8/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0807 - accuracy: 0.6132 - val_loss: 1.2951 - val_accuracy: 0.5389
# Epoch 9/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0544 - accuracy: 0.6241 - val_loss: 1.3047 - val_accuracy: 0.5418
# Epoch 10/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0322 - accuracy: 0.6319 - val_loss: 1.3083 - val_accuracy: 0.5408
# Epoch 11/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0107 - accuracy: 0.6401 - val_loss: 1.3129 - val_accuracy: 0.5443
# Epoch 12/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9922 - accuracy: 0.6460 - val_loss: 1.3263 - val_accuracy: 0.5459
# Epoch 13/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9771 - accuracy: 0.6513 - val_loss: 1.3383 - val_accuracy: 0.5430
# Epoch 14/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9621 - accuracy: 0.6564 - val_loss: 1.3549 - val_accuracy: 0.5354
# Epoch 15/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9438 - accuracy: 0.6624 - val_loss: 1.3819 - val_accuracy: 0.5405
# Epoch 16/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.9286 - accuracy: 0.6696 - val_loss: 1.3509 - val_accuracy: 0.5398
# Epoch 17/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.9182 - accuracy: 0.6732 - val_loss: 1.3851 - val_accuracy: 0.5337
# Epoch 18/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.9031 - accuracy: 0.6764 - val_loss: 1.3885 - val_accuracy: 0.5372
# Epoch 19/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.8903 - accuracy: 0.6828 - val_loss: 1.4035 - val_accuracy: 0.5329
# Epoch 20/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8788 - accuracy: 0.6862 - val_loss: 1.4030 - val_accuracy: 0.5351
# Epoch 21/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8679 - accuracy: 0.6898 - val_loss: 1.4252 - val_accuracy: 0.5321
# Epoch 22/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8564 - accuracy: 0.6966 - val_loss: 1.4240 - val_accuracy: 0.5407
# Epoch 23/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8447 - accuracy: 0.7005 - val_loss: 1.4583 - val_accuracy: 0.5311
# Epoch 24/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8383 - accuracy: 0.7006 - val_loss: 1.4774 - val_accuracy: 0.5322
# Epoch 25/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8260 - accuracy: 0.7052 - val_loss: 1.4945 - val_accuracy: 0.5302
# Epoch 26/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8164 - accuracy: 0.7073 - val_loss: 1.5179 - val_accuracy: 0.5302
# Epoch 27/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8091 - accuracy: 0.7123 - val_loss: 1.5072 - val_accuracy: 0.5295
# Epoch 28/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7998 - accuracy: 0.7148 - val_loss: 1.5201 - val_accuracy: 0.5279
# Epoch 29/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7923 - accuracy: 0.7167 - val_loss: 1.5205 - val_accuracy: 0.5349
# Epoch 30/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7852 - accuracy: 0.7192 - val_loss: 1.5606 - val_accuracy: 0.5237
# Epoch 31/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7743 - accuracy: 0.7241 - val_loss: 1.5717 - val_accuracy: 0.5316
# Epoch 32/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7664 - accuracy: 0.7253 - val_loss: 1.5883 - val_accuracy: 0.5272
# Epoch 33/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7593 - accuracy: 0.7310 - val_loss: 1.5752 - val_accuracy: 0.5287
# Epoch 34/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7531 - accuracy: 0.7313 - val_loss: 1.6226 - val_accuracy: 0.5219
# Epoch 35/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7451 - accuracy: 0.7332 - val_loss: 1.6185 - val_accuracy: 0.5231
# Epoch 36/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7388 - accuracy: 0.7368 - val_loss: 1.6727 - val_accuracy: 0.5151
# Epoch 37/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7294 - accuracy: 0.7417 - val_loss: 1.6734 - val_accuracy: 0.5249
# Epoch 38/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7254 - accuracy: 0.7397 - val_loss: 1.6786 - val_accuracy: 0.5215
# Epoch 39/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7172 - accuracy: 0.7465 - val_loss: 1.7193 - val_accuracy: 0.5181
# Epoch 40/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7157 - accuracy: 0.7428 - val_loss: 1.7094 - val_accuracy: 0.5196
# Epoch 41/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7048 - accuracy: 0.7477 - val_loss: 1.7184 - val_accuracy: 0.5216
# Epoch 42/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.7006 - accuracy: 0.7492 - val_loss: 1.7064 - val_accuracy: 0.5232
# Epoch 43/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.6918 - accuracy: 0.7524 - val_loss: 1.7637 - val_accuracy: 0.5228
# Epoch 44/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6876 - accuracy: 0.7540 - val_loss: 1.7495 - val_accuracy: 0.5227
# Epoch 45/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6791 - accuracy: 0.7577 - val_loss: 1.7956 - val_accuracy: 0.5215
# Epoch 46/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6714 - accuracy: 0.7579 - val_loss: 1.8276 - val_accuracy: 0.5151
# Epoch 47/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6686 - accuracy: 0.7610 - val_loss: 1.8370 - val_accuracy: 0.5148
# Epoch 48/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6619 - accuracy: 0.7626 - val_loss: 1.8413 - val_accuracy: 0.5137
# Epoch 49/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6592 - accuracy: 0.7641 - val_loss: 1.8463 - val_accuracy: 0.5150
# Epoch 50/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6517 - accuracy: 0.7668 - val_loss: 1.9144 - val_accuracy: 0.5101
#
# Forming the grid-search model #3 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7f340843bf50>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.7943 - accuracy: 0.3605 - val_loss: 1.4798 - val_accuracy: 0.4649
# Epoch 2/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.3843 - accuracy: 0.5048 - val_loss: 1.3606 - val_accuracy: 0.5072
# Epoch 3/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2965 - accuracy: 0.5363 - val_loss: 1.3211 - val_accuracy: 0.5256
# Epoch 4/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.2410 - accuracy: 0.5579 - val_loss: 1.2941 - val_accuracy: 0.5367
# Epoch 5/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1988 - accuracy: 0.5718 - val_loss: 1.2923 - val_accuracy: 0.5365
# Epoch 6/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1696 - accuracy: 0.5841 - val_loss: 1.2707 - val_accuracy: 0.5467
# Epoch 7/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1370 - accuracy: 0.5954 - val_loss: 1.2758 - val_accuracy: 0.5443
# Epoch 8/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1145 - accuracy: 0.6049 - val_loss: 1.2549 - val_accuracy: 0.5518
# Epoch 9/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.0924 - accuracy: 0.6111 - val_loss: 1.2627 - val_accuracy: 0.5570
# Epoch 10/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0706 - accuracy: 0.6209 - val_loss: 1.2607 - val_accuracy: 0.5536
# Epoch 11/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0490 - accuracy: 0.6283 - val_loss: 1.2545 - val_accuracy: 0.5599
# Epoch 12/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0311 - accuracy: 0.6358 - val_loss: 1.2808 - val_accuracy: 0.5489
# Epoch 13/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.0133 - accuracy: 0.6418 - val_loss: 1.2670 - val_accuracy: 0.5614
# Epoch 14/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9998 - accuracy: 0.6467 - val_loss: 1.2693 - val_accuracy: 0.5586
# Epoch 15/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9825 - accuracy: 0.6519 - val_loss: 1.2830 - val_accuracy: 0.5576
# Epoch 16/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9662 - accuracy: 0.6600 - val_loss: 1.2720 - val_accuracy: 0.5608
# Epoch 17/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9548 - accuracy: 0.6626 - val_loss: 1.2908 - val_accuracy: 0.5521
# Epoch 18/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9409 - accuracy: 0.6680 - val_loss: 1.2978 - val_accuracy: 0.5574
# Epoch 19/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9274 - accuracy: 0.6736 - val_loss: 1.3046 - val_accuracy: 0.5603
# Epoch 20/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9162 - accuracy: 0.6773 - val_loss: 1.3183 - val_accuracy: 0.5555
# Epoch 21/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9054 - accuracy: 0.6800 - val_loss: 1.3288 - val_accuracy: 0.5541
# Epoch 22/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8921 - accuracy: 0.6860 - val_loss: 1.3307 - val_accuracy: 0.5541
# Epoch 23/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8808 - accuracy: 0.6917 - val_loss: 1.3345 - val_accuracy: 0.5510
# Epoch 24/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8718 - accuracy: 0.6935 - val_loss: 1.3543 - val_accuracy: 0.5503
# Epoch 25/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8636 - accuracy: 0.6950 - val_loss: 1.3602 - val_accuracy: 0.5535
# Epoch 26/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8538 - accuracy: 0.6991 - val_loss: 1.3674 - val_accuracy: 0.5542
# Epoch 27/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8442 - accuracy: 0.7022 - val_loss: 1.3814 - val_accuracy: 0.5484
# Epoch 28/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8344 - accuracy: 0.7056 - val_loss: 1.3918 - val_accuracy: 0.5518
# Epoch 29/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8276 - accuracy: 0.7089 - val_loss: 1.4195 - val_accuracy: 0.5483
# Epoch 30/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8177 - accuracy: 0.7105 - val_loss: 1.4424 - val_accuracy: 0.5478
# Epoch 31/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8092 - accuracy: 0.7133 - val_loss: 1.4297 - val_accuracy: 0.5447
# Epoch 32/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8002 - accuracy: 0.7174 - val_loss: 1.4549 - val_accuracy: 0.5469
# Epoch 33/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7905 - accuracy: 0.7207 - val_loss: 1.4695 - val_accuracy: 0.5440
# Epoch 34/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7882 - accuracy: 0.7209 - val_loss: 1.4816 - val_accuracy: 0.5401
# Epoch 35/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7785 - accuracy: 0.7249 - val_loss: 1.4816 - val_accuracy: 0.5408
# Epoch 36/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7711 - accuracy: 0.7284 - val_loss: 1.5126 - val_accuracy: 0.5391
# Epoch 37/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7678 - accuracy: 0.7290 - val_loss: 1.5192 - val_accuracy: 0.5441
# Epoch 38/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7604 - accuracy: 0.7300 - val_loss: 1.5133 - val_accuracy: 0.5443
# Epoch 39/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7526 - accuracy: 0.7334 - val_loss: 1.5280 - val_accuracy: 0.5407
# Epoch 40/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7459 - accuracy: 0.7351 - val_loss: 1.5435 - val_accuracy: 0.5384
# Epoch 41/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7410 - accuracy: 0.7384 - val_loss: 1.5656 - val_accuracy: 0.5373
# Epoch 42/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7329 - accuracy: 0.7408 - val_loss: 1.5900 - val_accuracy: 0.5406
# Epoch 43/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7306 - accuracy: 0.7429 - val_loss: 1.5725 - val_accuracy: 0.5369
# Epoch 44/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7240 - accuracy: 0.7440 - val_loss: 1.5907 - val_accuracy: 0.5316
# Epoch 45/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7165 - accuracy: 0.7469 - val_loss: 1.5889 - val_accuracy: 0.5355
# Epoch 46/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7114 - accuracy: 0.7489 - val_loss: 1.6220 - val_accuracy: 0.5339
# Epoch 47/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7043 - accuracy: 0.7512 - val_loss: 1.6150 - val_accuracy: 0.5302
# Epoch 48/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6999 - accuracy: 0.7525 - val_loss: 1.6486 - val_accuracy: 0.5337
# Epoch 49/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6968 - accuracy: 0.7534 - val_loss: 1.6653 - val_accuracy: 0.5317
# Epoch 50/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6948 - accuracy: 0.7536 - val_loss: 1.6761 - val_accuracy: 0.5326
#
# Forming the grid-search model #4 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f340843b050>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 1.7017 - accuracy: 0.3824 - val_loss: 1.4194 - val_accuracy: 0.4853
# Epoch 2/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.3111 - accuracy: 0.5287 - val_loss: 1.2977 - val_accuracy: 0.5261
# Epoch 3/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.1948 - accuracy: 0.5742 - val_loss: 1.3017 - val_accuracy: 0.5359
# Epoch 4/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.1193 - accuracy: 0.6020 - val_loss: 1.2323 - val_accuracy: 0.5610
# Epoch 5/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.0414 - accuracy: 0.6306 - val_loss: 1.2194 - val_accuracy: 0.5678
# Epoch 6/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.9530 - accuracy: 0.6621 - val_loss: 1.1976 - val_accuracy: 0.5806
# Epoch 7/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.8739 - accuracy: 0.6918 - val_loss: 1.2044 - val_accuracy: 0.5914
# Epoch 8/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.8073 - accuracy: 0.7167 - val_loss: 1.2579 - val_accuracy: 0.5806
# Epoch 9/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7437 - accuracy: 0.7392 - val_loss: 1.2545 - val_accuracy: 0.5900
# Epoch 10/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6869 - accuracy: 0.7597 - val_loss: 1.3234 - val_accuracy: 0.5842
# Epoch 11/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.6316 - accuracy: 0.7771 - val_loss: 1.3529 - val_accuracy: 0.5791
# Epoch 12/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.5768 - accuracy: 0.7988 - val_loss: 1.4238 - val_accuracy: 0.5775
# Epoch 13/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.5257 - accuracy: 0.8176 - val_loss: 1.5269 - val_accuracy: 0.5744
# Epoch 14/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.4781 - accuracy: 0.8348 - val_loss: 1.6628 - val_accuracy: 0.5678
# Epoch 15/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.4298 - accuracy: 0.8530 - val_loss: 1.6999 - val_accuracy: 0.5740
# Epoch 16/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.3896 - accuracy: 0.8667 - val_loss: 1.8777 - val_accuracy: 0.5617
# Epoch 17/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.3510 - accuracy: 0.8793 - val_loss: 1.9450 - val_accuracy: 0.5665
# Epoch 18/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.3134 - accuracy: 0.8949 - val_loss: 2.0454 - val_accuracy: 0.5620
# Epoch 19/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.2811 - accuracy: 0.9046 - val_loss: 2.2506 - val_accuracy: 0.5540
# Epoch 20/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.2456 - accuracy: 0.9185 - val_loss: 2.3914 - val_accuracy: 0.5578
# Epoch 21/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.2191 - accuracy: 0.9262 - val_loss: 2.5934 - val_accuracy: 0.5544
# Epoch 22/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1878 - accuracy: 0.9379 - val_loss: 2.6803 - val_accuracy: 0.5581
# Epoch 23/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1672 - accuracy: 0.9450 - val_loss: 2.9447 - val_accuracy: 0.5469
# Epoch 24/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1551 - accuracy: 0.9488 - val_loss: 3.0835 - val_accuracy: 0.5495
# Epoch 25/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1373 - accuracy: 0.9554 - val_loss: 3.1556 - val_accuracy: 0.5565
# Epoch 26/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.1268 - accuracy: 0.9589 - val_loss: 3.4462 - val_accuracy: 0.5475
# Epoch 27/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1199 - accuracy: 0.9604 - val_loss: 3.4781 - val_accuracy: 0.5529
# Epoch 28/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1143 - accuracy: 0.9613 - val_loss: 3.7041 - val_accuracy: 0.5479
# Epoch 29/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.1055 - accuracy: 0.9656 - val_loss: 3.7977 - val_accuracy: 0.5523
# Epoch 30/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0946 - accuracy: 0.9686 - val_loss: 3.9457 - val_accuracy: 0.5495
# Epoch 31/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0807 - accuracy: 0.9738 - val_loss: 4.0812 - val_accuracy: 0.5470
# Epoch 32/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0929 - accuracy: 0.9680 - val_loss: 4.3272 - val_accuracy: 0.5464
# Epoch 33/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0885 - accuracy: 0.9698 - val_loss: 4.2682 - val_accuracy: 0.5515
# Epoch 34/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0707 - accuracy: 0.9770 - val_loss: 4.4365 - val_accuracy: 0.5501
# Epoch 35/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0808 - accuracy: 0.9727 - val_loss: 4.5554 - val_accuracy: 0.5461
# Epoch 36/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0735 - accuracy: 0.9754 - val_loss: 4.6826 - val_accuracy: 0.5491
# Epoch 37/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0575 - accuracy: 0.9812 - val_loss: 4.7457 - val_accuracy: 0.5473
# Epoch 38/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0820 - accuracy: 0.9727 - val_loss: 4.9734 - val_accuracy: 0.5426
# Epoch 39/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0622 - accuracy: 0.9785 - val_loss: 5.0386 - val_accuracy: 0.5467
# Epoch 40/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0527 - accuracy: 0.9829 - val_loss: 5.0959 - val_accuracy: 0.5485
# Epoch 41/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0683 - accuracy: 0.9772 - val_loss: 5.0885 - val_accuracy: 0.5512
# Epoch 42/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0646 - accuracy: 0.9788 - val_loss: 5.1899 - val_accuracy: 0.5462
# Epoch 43/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0639 - accuracy: 0.9784 - val_loss: 5.1314 - val_accuracy: 0.5409
# Epoch 44/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0595 - accuracy: 0.9800 - val_loss: 5.3188 - val_accuracy: 0.5411
# Epoch 45/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0533 - accuracy: 0.9828 - val_loss: 5.5076 - val_accuracy: 0.5430
# Epoch 46/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0569 - accuracy: 0.9808 - val_loss: 5.5208 - val_accuracy: 0.5469
# Epoch 47/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0636 - accuracy: 0.9790 - val_loss: 5.7603 - val_accuracy: 0.5400
# Epoch 48/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0492 - accuracy: 0.9836 - val_loss: 5.6723 - val_accuracy: 0.5390
# Epoch 49/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0509 - accuracy: 0.9832 - val_loss: 5.7560 - val_accuracy: 0.5465
# Epoch 50/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0525 - accuracy: 0.9818 - val_loss: 5.8098 - val_accuracy: 0.5414
#
# Forming the grid-search model #5 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f340832fa10>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f340843b050>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.6747 - accuracy: 0.4046 - val_loss: 1.3922 - val_accuracy: 0.4976
# Epoch 2/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.2801 - accuracy: 0.5414 - val_loss: 1.3420 - val_accuracy: 0.5288
# Epoch 3/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.1444 - accuracy: 0.5941 - val_loss: 1.1882 - val_accuracy: 0.5815
# Epoch 4/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0458 - accuracy: 0.6313 - val_loss: 1.1565 - val_accuracy: 0.5970
# Epoch 5/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9710 - accuracy: 0.6572 - val_loss: 1.1483 - val_accuracy: 0.5968
# Epoch 6/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9171 - accuracy: 0.6747 - val_loss: 1.1651 - val_accuracy: 0.5985
# Epoch 7/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8601 - accuracy: 0.6979 - val_loss: 1.1614 - val_accuracy: 0.6043
# Epoch 8/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8167 - accuracy: 0.7135 - val_loss: 1.1708 - val_accuracy: 0.6042
# Epoch 9/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7692 - accuracy: 0.7316 - val_loss: 1.2119 - val_accuracy: 0.5990
# Epoch 10/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7259 - accuracy: 0.7490 - val_loss: 1.2342 - val_accuracy: 0.5978
# Epoch 11/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6877 - accuracy: 0.7616 - val_loss: 1.2594 - val_accuracy: 0.5960
# Epoch 12/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6511 - accuracy: 0.7770 - val_loss: 1.3251 - val_accuracy: 0.5917
# Epoch 13/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6127 - accuracy: 0.7893 - val_loss: 1.3603 - val_accuracy: 0.5928
# Epoch 14/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5805 - accuracy: 0.8000 - val_loss: 1.3700 - val_accuracy: 0.5925
# Epoch 15/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.5485 - accuracy: 0.8116 - val_loss: 1.4406 - val_accuracy: 0.5865
# Epoch 16/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.5174 - accuracy: 0.8216 - val_loss: 1.4822 - val_accuracy: 0.5918
# Epoch 17/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.4839 - accuracy: 0.8347 - val_loss: 1.5584 - val_accuracy: 0.5832
# Epoch 18/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.4558 - accuracy: 0.8457 - val_loss: 1.6288 - val_accuracy: 0.5809
# Epoch 19/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.4315 - accuracy: 0.8538 - val_loss: 1.6920 - val_accuracy: 0.5784
# Epoch 20/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.4010 - accuracy: 0.8652 - val_loss: 1.7684 - val_accuracy: 0.5777
# Epoch 21/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.3765 - accuracy: 0.8735 - val_loss: 1.8427 - val_accuracy: 0.5752
# Epoch 22/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.3550 - accuracy: 0.8807 - val_loss: 1.9236 - val_accuracy: 0.5732
# Epoch 23/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.3233 - accuracy: 0.8930 - val_loss: 2.0329 - val_accuracy: 0.5697
# Epoch 24/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.3031 - accuracy: 0.8998 - val_loss: 2.1071 - val_accuracy: 0.5676
# Epoch 25/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.2839 - accuracy: 0.9051 - val_loss: 2.2393 - val_accuracy: 0.5697
# Epoch 26/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.2590 - accuracy: 0.9159 - val_loss: 2.3535 - val_accuracy: 0.5599
# Epoch 27/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.2450 - accuracy: 0.9196 - val_loss: 2.4229 - val_accuracy: 0.5636
# Epoch 28/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.2284 - accuracy: 0.9261 - val_loss: 2.5646 - val_accuracy: 0.5650
# Epoch 29/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.2101 - accuracy: 0.9319 - val_loss: 2.6778 - val_accuracy: 0.5659
# Epoch 30/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1947 - accuracy: 0.9370 - val_loss: 2.7945 - val_accuracy: 0.5606
# Epoch 31/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1886 - accuracy: 0.9395 - val_loss: 2.9629 - val_accuracy: 0.5571
# Epoch 32/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1652 - accuracy: 0.9475 - val_loss: 3.0527 - val_accuracy: 0.5585
# Epoch 33/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1450 - accuracy: 0.9551 - val_loss: 3.2278 - val_accuracy: 0.5557
# Epoch 34/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1401 - accuracy: 0.9556 - val_loss: 3.3179 - val_accuracy: 0.5561
# Epoch 35/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1272 - accuracy: 0.9611 - val_loss: 3.4611 - val_accuracy: 0.5565
# Epoch 36/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1324 - accuracy: 0.9578 - val_loss: 3.5542 - val_accuracy: 0.5521
# Epoch 37/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1255 - accuracy: 0.9597 - val_loss: 3.6793 - val_accuracy: 0.5551
# Epoch 38/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1085 - accuracy: 0.9658 - val_loss: 3.7884 - val_accuracy: 0.5572
# Epoch 39/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0970 - accuracy: 0.9704 - val_loss: 3.9139 - val_accuracy: 0.5519
# Epoch 40/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0999 - accuracy: 0.9676 - val_loss: 3.9682 - val_accuracy: 0.5547
# Epoch 41/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0987 - accuracy: 0.9687 - val_loss: 4.0993 - val_accuracy: 0.5515
# Epoch 42/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0837 - accuracy: 0.9743 - val_loss: 4.2678 - val_accuracy: 0.5528
# Epoch 43/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0840 - accuracy: 0.9725 - val_loss: 4.3165 - val_accuracy: 0.5473
# Epoch 44/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0911 - accuracy: 0.9698 - val_loss: 4.5323 - val_accuracy: 0.5508
# Epoch 45/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0807 - accuracy: 0.9740 - val_loss: 4.5378 - val_accuracy: 0.5493
# Epoch 46/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0654 - accuracy: 0.9798 - val_loss: 4.6958 - val_accuracy: 0.5506
# Epoch 47/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.0635 - accuracy: 0.9806 - val_loss: 4.8285 - val_accuracy: 0.5503
# Epoch 48/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0641 - accuracy: 0.9799 - val_loss: 4.9209 - val_accuracy: 0.5480
# Epoch 49/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0675 - accuracy: 0.9783 - val_loss: 4.9318 - val_accuracy: 0.5430
# Epoch 50/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.0866 - accuracy: 0.9698 - val_loss: 4.9663 - val_accuracy: 0.5539
#
# Forming the grid-search model #6 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f340832f990>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f340831ca50>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 76s 2ms/sample - loss: 1.4911 - accuracy: 0.4700 - val_loss: 1.3167 - val_accuracy: 0.5235
# Epoch 2/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 1.0593 - accuracy: 0.6283 - val_loss: 1.0247 - val_accuracy: 0.6380
# Epoch 3/50
# ...
#
# Forming the grid-search model #16 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f340832f950>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f340843b050>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 1.7761 - accuracy: 0.3703 - val_loss: 1.5371 - val_accuracy: 0.4520
# Epoch 2/50
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 1.4443 - accuracy: 0.4905 - val_loss: 1.3506 - val_accuracy: 0.5275
# Epoch 3/50
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 1.2781 - accuracy: 0.5501 - val_loss: 1.2286 - val_accuracy: 0.5640
# Epoch 4/50
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 1.1632 - accuracy: 0.5915 - val_loss: 1.2135 - val_accuracy: 0.5774
# Epoch 5/50
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 1.0772 - accuracy: 0.6241 - val_loss: 1.1249 - val_accuracy: 0.5986
# Epoch 6/50
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 1.0129 - accuracy: 0.6472 - val_loss: 1.0656 - val_accuracy: 0.6259
# Epoch 7/50
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.9525 - accuracy: 0.6690 - val_loss: 1.0233 - val_accuracy: 0.6410
# Epoch 8/50
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.8976 - accuracy: 0.6866 - val_loss: 1.0083 - val_accuracy: 0.6497
# Epoch 9/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.8541 - accuracy: 0.7040 - val_loss: 0.9903 - val_accuracy: 0.6551
# Epoch 10/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.8096 - accuracy: 0.7201 - val_loss: 0.9792 - val_accuracy: 0.6638
# Epoch 11/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.7699 - accuracy: 0.7324 - val_loss: 0.9758 - val_accuracy: 0.6653
# Epoch 12/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.7330 - accuracy: 0.7469 - val_loss: 1.0045 - val_accuracy: 0.6592
# Epoch 13/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.6902 - accuracy: 0.7609 - val_loss: 0.9619 - val_accuracy: 0.6727
# Epoch 14/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.6522 - accuracy: 0.7741 - val_loss: 0.9768 - val_accuracy: 0.6683
# Epoch 15/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.6094 - accuracy: 0.7895 - val_loss: 0.9926 - val_accuracy: 0.6676
# Epoch 16/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5736 - accuracy: 0.8047 - val_loss: 0.9820 - val_accuracy: 0.6691
# Epoch 17/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5301 - accuracy: 0.8215 - val_loss: 0.9967 - val_accuracy: 0.6745
# Epoch 18/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4940 - accuracy: 0.8324 - val_loss: 1.0091 - val_accuracy: 0.6736
# Epoch 19/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4523 - accuracy: 0.8474 - val_loss: 1.0775 - val_accuracy: 0.6610
# Epoch 20/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4137 - accuracy: 0.8638 - val_loss: 1.1046 - val_accuracy: 0.6573
# Epoch 21/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.3757 - accuracy: 0.8768 - val_loss: 1.0999 - val_accuracy: 0.6691
# Epoch 22/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.3365 - accuracy: 0.8933 - val_loss: 1.1447 - val_accuracy: 0.6671
# Epoch 23/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.2983 - accuracy: 0.9064 - val_loss: 1.1456 - val_accuracy: 0.6716
# Epoch 24/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.2593 - accuracy: 0.9205 - val_loss: 1.2169 - val_accuracy: 0.6708
# Epoch 25/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.2285 - accuracy: 0.9317 - val_loss: 1.2804 - val_accuracy: 0.6594
# Epoch 26/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1950 - accuracy: 0.9449 - val_loss: 1.3165 - val_accuracy: 0.6620
# Epoch 27/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1656 - accuracy: 0.9556 - val_loss: 1.4375 - val_accuracy: 0.6607
# Epoch 28/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1440 - accuracy: 0.9623 - val_loss: 1.4245 - val_accuracy: 0.6677
# Epoch 29/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1181 - accuracy: 0.9725 - val_loss: 1.4830 - val_accuracy: 0.6684
# Epoch 30/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0954 - accuracy: 0.9799 - val_loss: 1.5367 - val_accuracy: 0.6632
# Epoch 31/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0754 - accuracy: 0.9868 - val_loss: 1.6188 - val_accuracy: 0.6629
# Epoch 32/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0613 - accuracy: 0.9905 - val_loss: 1.6435 - val_accuracy: 0.6668
# Epoch 33/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0484 - accuracy: 0.9940 - val_loss: 1.7113 - val_accuracy: 0.6618
# Epoch 34/50
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.0381 - accuracy: 0.9965 - val_loss: 1.7743 - val_accuracy: 0.6593
# Epoch 35/50
# 50000/50000 [==============================] - 76s 2ms/sample - loss: 0.0314 - accuracy: 0.9973 - val_loss: 1.8108 - val_accuracy: 0.6629
# Epoch 36/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0263 - accuracy: 0.9979 - val_loss: 1.8822 - val_accuracy: 0.6594
# Epoch 37/50
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.0208 - accuracy: 0.9988 - val_loss: 1.9008 - val_accuracy: 0.6607
# Epoch 38/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0177 - accuracy: 0.9990 - val_loss: 1.9335 - val_accuracy: 0.6630
# Epoch 39/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0161 - accuracy: 0.9990 - val_loss: 1.9674 - val_accuracy: 0.6650
# Epoch 40/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0124 - accuracy: 0.9996 - val_loss: 2.0025 - val_accuracy: 0.6627
# Epoch 41/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0123 - accuracy: 0.9994 - val_loss: 2.0348 - val_accuracy: 0.6626
# Epoch 42/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0101 - accuracy: 0.9996 - val_loss: 2.0637 - val_accuracy: 0.6632
# Epoch 43/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0084 - accuracy: 0.9998 - val_loss: 2.0971 - val_accuracy: 0.6643
# Epoch 44/50
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.0082 - accuracy: 0.9997 - val_loss: 2.1190 - val_accuracy: 0.6623
# Epoch 45/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0074 - accuracy: 0.9998 - val_loss: 2.1459 - val_accuracy: 0.6635
# Epoch 46/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0065 - accuracy: 0.9998 - val_loss: 2.1696 - val_accuracy: 0.6603
# Epoch 47/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.0059 - accuracy: 0.9999 - val_loss: 2.1887 - val_accuracy: 0.6633
# Epoch 48/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0055 - accuracy: 0.9999 - val_loss: 2.2122 - val_accuracy: 0.6639
# Epoch 49/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.2304 - val_accuracy: 0.6626
# Epoch 50/50
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.0049 - accuracy: 0.9999 - val_loss: 2.2508 - val_accuracy: 0.6639
#
# Forming the grid-search model #17 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f340832f950>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f340843b050>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 70s 1ms/sample - loss: 1.8973 - accuracy: 0.3300 - val_loss: 1.7071 - val_accuracy: 0.3919
# Epoch 2/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.5979 - accuracy: 0.4393 - val_loss: 1.5267 - val_accuracy: 0.4648
# Epoch 3/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.4504 - accuracy: 0.4893 - val_loss: 1.3966 - val_accuracy: 0.5066
# Epoch 4/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.3413 - accuracy: 0.5287 - val_loss: 1.2954 - val_accuracy: 0.5449
# Epoch 5/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.2601 - accuracy: 0.5572 - val_loss: 1.2467 - val_accuracy: 0.5610
# Epoch 6/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.1931 - accuracy: 0.5837 - val_loss: 1.1938 - val_accuracy: 0.5815
# Epoch 7/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.1318 - accuracy: 0.6049 - val_loss: 1.1443 - val_accuracy: 0.6030
# Epoch 8/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.0873 - accuracy: 0.6204 - val_loss: 1.1182 - val_accuracy: 0.6041
# Epoch 9/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.0418 - accuracy: 0.6378 - val_loss: 1.0894 - val_accuracy: 0.6192
# Epoch 10/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 1.0079 - accuracy: 0.6501 - val_loss: 1.0755 - val_accuracy: 0.6243
# Epoch 11/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9701 - accuracy: 0.6649 - val_loss: 1.0553 - val_accuracy: 0.6294
# Epoch 12/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.9386 - accuracy: 0.6742 - val_loss: 1.0538 - val_accuracy: 0.6367
# Epoch 13/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9089 - accuracy: 0.6862 - val_loss: 1.0516 - val_accuracy: 0.6286
# Epoch 14/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.8773 - accuracy: 0.6973 - val_loss: 1.0219 - val_accuracy: 0.6455
# Epoch 15/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.8509 - accuracy: 0.7055 - val_loss: 1.0782 - val_accuracy: 0.6221
# Epoch 16/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8213 - accuracy: 0.7169 - val_loss: 1.0136 - val_accuracy: 0.6502
# Epoch 17/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7945 - accuracy: 0.7277 - val_loss: 1.0188 - val_accuracy: 0.6501
# Epoch 18/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7701 - accuracy: 0.7342 - val_loss: 0.9926 - val_accuracy: 0.6588
# Epoch 19/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7520 - accuracy: 0.7412 - val_loss: 0.9841 - val_accuracy: 0.6605
# Epoch 20/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.7226 - accuracy: 0.7497 - val_loss: 1.0031 - val_accuracy: 0.6549
# Epoch 21/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.7073 - accuracy: 0.7579 - val_loss: 0.9934 - val_accuracy: 0.6658
# Epoch 22/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.6840 - accuracy: 0.7646 - val_loss: 0.9634 - val_accuracy: 0.6717
# Epoch 23/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.6596 - accuracy: 0.7736 - val_loss: 0.9658 - val_accuracy: 0.6738
# Epoch 24/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.6364 - accuracy: 0.7838 - val_loss: 0.9685 - val_accuracy: 0.6753
# Epoch 25/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.6145 - accuracy: 0.7913 - val_loss: 1.0029 - val_accuracy: 0.6702
# Epoch 26/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.5882 - accuracy: 0.7999 - val_loss: 0.9780 - val_accuracy: 0.6756
# Epoch 27/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.5721 - accuracy: 0.8059 - val_loss: 1.0129 - val_accuracy: 0.6722
# Epoch 28/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.5494 - accuracy: 0.8135 - val_loss: 0.9932 - val_accuracy: 0.6779
# Epoch 29/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.5248 - accuracy: 0.8251 - val_loss: 1.0476 - val_accuracy: 0.6645
# Epoch 30/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.4990 - accuracy: 0.8315 - val_loss: 1.0120 - val_accuracy: 0.6726
# Epoch 31/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.4790 - accuracy: 0.8408 - val_loss: 1.0193 - val_accuracy: 0.6783
# Epoch 32/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.4558 - accuracy: 0.8487 - val_loss: 1.0522 - val_accuracy: 0.6683
# Epoch 33/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.4312 - accuracy: 0.8577 - val_loss: 1.0657 - val_accuracy: 0.6688
# Epoch 34/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.4098 - accuracy: 0.8650 - val_loss: 1.0918 - val_accuracy: 0.6625
# Epoch 35/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.3867 - accuracy: 0.8757 - val_loss: 1.0964 - val_accuracy: 0.6711
# Epoch 36/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.3697 - accuracy: 0.8801 - val_loss: 1.1436 - val_accuracy: 0.6607
# Epoch 37/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.3495 - accuracy: 0.8880 - val_loss: 1.1282 - val_accuracy: 0.6727
# Epoch 38/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.3186 - accuracy: 0.9000 - val_loss: 1.1545 - val_accuracy: 0.6714
# Epoch 39/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.3030 - accuracy: 0.9069 - val_loss: 1.1594 - val_accuracy: 0.6713
# Epoch 40/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.2799 - accuracy: 0.9151 - val_loss: 1.1913 - val_accuracy: 0.6669
# Epoch 41/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.2636 - accuracy: 0.9201 - val_loss: 1.2170 - val_accuracy: 0.6687
# Epoch 42/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.2373 - accuracy: 0.9311 - val_loss: 1.2661 - val_accuracy: 0.6675
# Epoch 43/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.2244 - accuracy: 0.9350 - val_loss: 1.2753 - val_accuracy: 0.6656
# Epoch 44/50
# 50000/50000 [==============================] - 69s 1ms/sample - loss: 0.2023 - accuracy: 0.9451 - val_loss: 1.3010 - val_accuracy: 0.6589
# Epoch 45/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1906 - accuracy: 0.9485 - val_loss: 1.3640 - val_accuracy: 0.6611
# Epoch 46/50
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.1740 - accuracy: 0.9540 - val_loss: 1.3760 - val_accuracy: 0.6651
# Epoch 47/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1535 - accuracy: 0.9621 - val_loss: 1.3805 - val_accuracy: 0.6653
# Epoch 48/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1434 - accuracy: 0.9658 - val_loss: 1.4393 - val_accuracy: 0.6602
# Epoch 49/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1300 - accuracy: 0.9697 - val_loss: 1.4768 - val_accuracy: 0.6536
# Epoch 50/50
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.1164 - accuracy: 0.9741 - val_loss: 1.4841 - val_accuracy: 0.6649
#
# Best score (highest validation accuracy) found via grid search: accuracy=0.670100 from model iteration #14
# The best modeling parameters are: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f340832f950>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7f340843bf50>, epochs=50, batch_size=64
# Total time for performing grid-search of the best parameters: 17:52:21.609618

# %%
if (notifyStatus): email_notify("Phase 4 Optimize Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 5. Finalize Model

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Create the final model for evaluating the test dataset
startTimeModule = datetime.now()
print('Forming the final model using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
reset_random(seedNum)
final_model = create_customized_model(best_optimizer, best_kernel_init)
final_hist = final_model.fit(X_train, y_train, epochs=best_epoch, batch_size=best_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for training the final model:', (datetime.now() - startTimeModule))
# Out:
# Forming the final model using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f340832f950>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7f340843bf50>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 1.8933 - accuracy: 0.3232 - val_loss: 1.6761 - val_accuracy: 0.3993
# Epoch 2/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 1.5619 - accuracy: 0.4433 - val_loss: 1.4530 - val_accuracy: 0.4852
# Epoch 3/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 1.3843 - accuracy: 0.5073 - val_loss: 1.3344 - val_accuracy: 0.5183
# Epoch 4/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 1.2719 - accuracy: 0.5484 - val_loss: 1.2610 - val_accuracy: 0.5572
# Epoch 5/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 1.1924 - accuracy: 0.5817 - val_loss: 1.2037 - val_accuracy: 0.5685
# Epoch 6/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 1.1264 - accuracy: 0.6088 - val_loss: 1.1510 - val_accuracy: 0.5909
# Epoch 7/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 1.0634 - accuracy: 0.6270 - val_loss: 1.0918 - val_accuracy: 0.6180
# Epoch 8/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 1.0035 - accuracy: 0.6500 - val_loss: 1.0506 - val_accuracy: 0.6310
# Epoch 9/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.9470 - accuracy: 0.6704 - val_loss: 1.0270 - val_accuracy: 0.6442
# Epoch 10/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.8962 - accuracy: 0.6899 - val_loss: 1.0081 - val_accuracy: 0.6475
# Epoch 11/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.8463 - accuracy: 0.7076 - val_loss: 0.9852 - val_accuracy: 0.6602
# Epoch 12/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.8050 - accuracy: 0.7221 - val_loss: 1.0142 - val_accuracy: 0.6488
# Epoch 13/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.7618 - accuracy: 0.7375 - val_loss: 0.9600 - val_accuracy: 0.6666
# Epoch 14/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.7210 - accuracy: 0.7491 - val_loss: 0.9830 - val_accuracy: 0.6606
# Epoch 15/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.6788 - accuracy: 0.7642 - val_loss: 0.9859 - val_accuracy: 0.6647
# Epoch 16/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.6396 - accuracy: 0.7798 - val_loss: 0.9500 - val_accuracy: 0.6786
# Epoch 17/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5983 - accuracy: 0.7941 - val_loss: 0.9692 - val_accuracy: 0.6773
# Epoch 18/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5613 - accuracy: 0.8072 - val_loss: 0.9724 - val_accuracy: 0.6781
# Epoch 19/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5222 - accuracy: 0.8212 - val_loss: 1.0230 - val_accuracy: 0.6693
# Epoch 20/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.4834 - accuracy: 0.8345 - val_loss: 1.0611 - val_accuracy: 0.6656
# Epoch 21/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.4431 - accuracy: 0.8517 - val_loss: 1.0361 - val_accuracy: 0.6765
# Epoch 22/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.4014 - accuracy: 0.8667 - val_loss: 1.0554 - val_accuracy: 0.6774
# Epoch 23/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.3619 - accuracy: 0.8807 - val_loss: 1.0616 - val_accuracy: 0.6832
# Epoch 24/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.3248 - accuracy: 0.8942 - val_loss: 1.1248 - val_accuracy: 0.6761
# Epoch 25/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.2889 - accuracy: 0.9071 - val_loss: 1.1759 - val_accuracy: 0.6707
# Epoch 26/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.2510 - accuracy: 0.9240 - val_loss: 1.2162 - val_accuracy: 0.6704
# Epoch 27/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.2222 - accuracy: 0.9320 - val_loss: 1.2779 - val_accuracy: 0.6742
# Epoch 28/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.1876 - accuracy: 0.9452 - val_loss: 1.3674 - val_accuracy: 0.6605
# Epoch 29/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.1651 - accuracy: 0.9527 - val_loss: 1.4208 - val_accuracy: 0.6623
# Epoch 30/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1382 - accuracy: 0.9629 - val_loss: 1.4335 - val_accuracy: 0.6708
# Epoch 31/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.1162 - accuracy: 0.9706 - val_loss: 1.5241 - val_accuracy: 0.6671
# Epoch 32/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0940 - accuracy: 0.9785 - val_loss: 1.5496 - val_accuracy: 0.6634
# Epoch 33/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0744 - accuracy: 0.9845 - val_loss: 1.6100 - val_accuracy: 0.6687
# Epoch 34/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0585 - accuracy: 0.9899 - val_loss: 1.6920 - val_accuracy: 0.6692
# Epoch 35/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0468 - accuracy: 0.9934 - val_loss: 1.6860 - val_accuracy: 0.6698
# Epoch 36/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0356 - accuracy: 0.9959 - val_loss: 1.7734 - val_accuracy: 0.6725
# Epoch 37/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0282 - accuracy: 0.9976 - val_loss: 1.8263 - val_accuracy: 0.6713
# Epoch 38/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0217 - accuracy: 0.9986 - val_loss: 1.8492 - val_accuracy: 0.6739
# Epoch 39/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0176 - accuracy: 0.9990 - val_loss: 1.9047 - val_accuracy: 0.6725
# Epoch 40/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0148 - accuracy: 0.9992 - val_loss: 1.9403 - val_accuracy: 0.6722
# Epoch 41/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0154 - accuracy: 0.9989 - val_loss: 1.9688 - val_accuracy: 0.6701
# Epoch 42/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0115 - accuracy: 0.9994 - val_loss: 2.0088 - val_accuracy: 0.6727
# Epoch 43/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0095 - accuracy: 0.9996 - val_loss: 2.0422 - val_accuracy: 0.6683
# Epoch 44/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0082 - accuracy: 0.9998 - val_loss: 2.0750 - val_accuracy: 0.6715
# Epoch 45/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0069 - accuracy: 0.9999 - val_loss: 2.0884 - val_accuracy: 0.6708
# Epoch 46/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0061 - accuracy: 0.9999 - val_loss: 2.1193 - val_accuracy: 0.6713
# Epoch 47/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0058 - accuracy: 0.9998 - val_loss: 2.1432 - val_accuracy: 0.6728
# Epoch 48/50
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.0053 - accuracy: 0.9999 - val_loss: 2.1700 - val_accuracy: 0.6715
# Epoch 49/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0048 - accuracy: 0.9999 - val_loss: 2.1894 - val_accuracy: 0.6722
# Epoch 50/50
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.2102 - val_accuracy: 0.6701
# Total time for training the final model: 0:59:44.558787

# %%
# Display a summary of the final model
print(final_model.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               1048704
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,060,138
# Trainable params: 1,060,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the final model
print(final_model.get_config())
# Out:
# {'name': 'sequential_19', 'layers': [{'class_name': 'Conv2D', 'config': {'name': 'conv2d_38', 'trainable': True, 'batch_input_shape': (None, 32, 32, 3), 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_39', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_19', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Flatten', 'config': {'name': 'flatten_19', 'trainable': True, 'dtype': 'float32', 'data_format': 'channels_last'}}, {'class_name': 'Dense', 'config': {'name': 'dense_38', 'trainable': True, 'dtype': 'float32', 'units': 128, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_39', 'trainable': True, 'dtype': 'float32', 'units': 10, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}

# %%
# Summarize model training hisotry for accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(final_hist.history['accuracy'], color='blue', label='train')
plt.plot(final_hist.history['val_accuracy'], color='red', label='test')
plt.title('Final Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(final_hist.history['loss'], color='blue', label='train')
plt.plot(final_hist.history['val_loss'], color='red', label='test')
plt.title('Final Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Evaluate the Keras model on previously unseen data
# scores = final_model.evaluate(X_test, y_test, verbose=0)
# print("The model %s: %f%%" % (final_model.metrics_names[1], scores[1]*100))
# print("The model %s: %f" % (final_model.metrics_names[0], scores[0]))
# Out:
# The model accuracy: 67.009997%
# The model loss: 2.210169

# %%
# Make class predictions with the model
predictions = final_model.predict_classes(X_test)

# Summarize the first 20 cases
for i in range(20):
	print('Data item #%d predicted to be %s (expected %s)' % (i, encoder.inverse_transform([predictions[i]]), encoder.inverse_transform([np.argmax(y_test[i])])))
# Out:
# Data item #0 predicted to be [4] (expected [3])
# Data item #1 predicted to be [1] (expected [8])
# Data item #2 predicted to be [0] (expected [8])
# Data item #3 predicted to be [0] (expected [0])
# Data item #4 predicted to be [6] (expected [6])
# Data item #5 predicted to be [6] (expected [6])
# Data item #6 predicted to be [1] (expected [1])
# Data item #7 predicted to be [2] (expected [6])
# Data item #8 predicted to be [3] (expected [3])
# Data item #9 predicted to be [1] (expected [1])
# Data item #10 predicted to be [0] (expected [0])
# Data item #11 predicted to be [9] (expected [9])
# Data item #12 predicted to be [5] (expected [5])
# Data item #13 predicted to be [7] (expected [7])
# Data item #14 predicted to be [9] (expected [9])
# Data item #15 predicted to be [8] (expected [8])
# Data item #16 predicted to be [5] (expected [5])
# Data item #17 predicted to be [5] (expected [7])
# Data item #18 predicted to be [8] (expected [8])
# Data item #19 predicted to be [6] (expected [6])

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 19:52:58.749375
