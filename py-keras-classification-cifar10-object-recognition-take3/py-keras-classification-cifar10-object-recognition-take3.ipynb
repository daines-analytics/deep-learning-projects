# %% [markdown]
# # Multi-Class Deep Learning Model for CIFAR-10 Object Recognition Using Keras Take 3
# ### David Lowe
# ### January 2, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The CIFAR-10 dataset is a multi-class classification situation where we are trying to predict one of several (more than two) possible outcomes.
#
# INTRODUCTION: The CIFAR-10 is a labeled subset of the 80 million tiny images dataset. They were collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton. The CIFAR-10 dataset consists of 60000 32x32 color images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# In iteration Take1, we constructed a simple VGG convolutional model with 1 VGG block to classify the images. This model serves as the baseline for the future iterations of modeling.
#
# In iteration Take2, we constructd a few more VGG convolutional models with 2 and 3 VGG blocks to classify the images. The additional models enabled us to choose a final baseline model before applying other performance-enhancing techniques.
#
# In this iteration, we will tune the VGG-3 model with various hyperparameters and select the best model before applying other regularization techniques.
#
# ANALYSIS: In iteration Take1, the performance of the Take1 model with the default parameters achieved an accuracy score of 66.39% on the validation dataset after training for 50 epochs. After tuning the hyperparameters, the Take1 model with the best hyperparameters processed the training dataset with an accuracy of 100.00%. The same model, however, processed the test dataset with an accuracy of only 67.01%. We will need to explore other modeling approaches to make a better model that reduces over-fitting.
#
# In iteration Take2, the performance of the VGG-1 model with the default parameters achieved an accuracy score of 66.69% on the validation dataset after training for 50 epochs. The VGG-2 model achieved an accuracy score of 71.35% on the validation dataset after training for 50 epochs. The VGG-3 model achieved an accuracy score of 73.81% on the validation dataset after training for 50 epochs. The additional VGG blocks helped the model, but we still need to explore other modeling approaches to make a better model that reduces over-fitting.
#
# In this iteration, the performance of the VGG-3 Take3 model with the default parameters achieved a maximum accuracy score of 73.43% on the validation dataset after training for 50 epochs. After tuning the hyperparameters, the Take1 model with the best hyperparameters processed the training dataset with an accuracy of 98.09%. The same model, however, processed the test dataset with an accuracy of only 73.44%. Even with VGG-3 and hyperparameter tuning, we still have an over-fitting problem with the model.
#
# CONCLUSION: For this dataset, the model built using Keras and TensorFlow achieved a satisfactory result and should be considered for future modeling activities.
#
# Dataset Used: The CIFAR-10 Dataset
#
# Dataset ML Model: Multi-class classification with numerical attributes
#
# Dataset Reference: https://www.cs.toronto.edu/~kriz/cifar.html
#
# One potential source of performance benchmarks: https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
#
# Any deep-learning modeling project genrally can be broken down into about six major tasks:
#
# 0. Prepare Environment
# 1. Load Data
# 2. Define Model
# 3. Fit and Evaluate Model
# 4. Optimize Model
# 5. Finalize Model

# %% [markdown]
# # Section 0. Prepare Environment

# %%
# Set the warning message filter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
# Load libraries and packages
import random
random.seed(seedNum)
import numpy as np
np.random.seed(seedNum)
import tensorflow as tf
tf.random.set_seed(seedNum)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# import keras as K
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.wrappers.scikit_learn import KerasClassifier
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import matplotlib.pyplot as plt
from datetime import datetime
from email.message import EmailMessage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the verbose flag to print detailed messages for debugging (setting to True will activate)
# verbose = True
# tf.debugging.set_log_device_placement(verbose)

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the number of folds for cross validation
n_folds = 5

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.25

# Set various default Keras modeling parameters
default_loss = 'categorical_crossentropy'
default_metrics = ['accuracy']
default_kernel_init = tf.initializers.he_uniform(seed=seedNum)
default_optimizer = tf.optimizers.SGD(learning_rate=0.001, momentum=0.9)
default_epoch = 50
default_batch = 64
# Out:
# Num GPUs Available:  1

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Keras Multi-Class Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
# Reset the random number generators
def reset_random(seedNum):
    random.seed(seedNum)
    np.random.seed(seedNum)
    tf.random.set_seed(seedNum)

# %%
if (notifyStatus): email_notify("Phase 0 Prepare Environment completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 1. Load Data

# %%
if (notifyStatus): email_notify("Phase 1 Load Data has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## 1.a) Load Dataset

# %%
cifar10 = tf.keras.datasets.cifar10
(X_train, y_train),(X_test, y_test) = cifar10.load_data()

# Summarize loaded datasets
print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 1)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
# Plot first few images
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# ## 1.b) Data Cleaning

# %%
# Not required for this iteration of the project

# %% [markdown]
# ## 1.c) Feature Scaling and Pre-processing

# %%
# Reshape the input data as [samples][width][height][channels]
# X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
# X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# Apply feature scaling and transformation
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## 1.d) Splitting Data into Training and Test Sets

# %%
# Encode class values as integers and perform one-hot-encoding
encoder = preprocessing.LabelEncoder()
encoder.fit(y_train)
train_transformed = encoder.transform(y_train)
test_transformed = encoder.transform(y_test)
y_train = tf.keras.utils.to_categorical(train_transformed)
y_test = tf.keras.utils.to_categorical(test_transformed)

print('Train Shape: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test Shape: X=%s, y=%s' % (X_test.shape, y_test.shape))

num_pixels = X_train.shape[1] * X_train.shape[2]
print('Number of pixels:', num_pixels)
num_classes = y_train.shape[1]
print('Number of classes:', num_classes)
# Out:
# Train Shape: X=(50000, 32, 32, 3), y=(50000, 10)
# Test Shape: X=(10000, 32, 32, 3), y=(10000, 10)
# Number of pixels: 1024
# Number of classes: 10
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
if (notifyStatus): email_notify("Phase 1 Load Data completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 2. Define Model

# %%
if (notifyStatus): email_notify("Phase 2 Define Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the Keras model for baseline measurement
def create_default_model():
    default_model = Sequential()
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same', input_shape=(32, 32, 3)))
    default_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=default_kernel_init, padding='same'))
    default_model.add(MaxPooling2D((2, 2)))
    default_model.add(Flatten())
    default_model.add(Dense(128, activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(num_classes, activation='softmax', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# %%
# Not applicable for this iteration of the project
# Define the Callback class and early-stopping function
# class myCallback(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#         if(logs.get('accuracy') > 0.9):
#             print("\nReached 90% accuracy so cancelling training!")
#             self.model.stop_training = True

# callbacks = myCallback()

# %%
if (notifyStatus): email_notify("Phase 2 Define Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 3. Fit and Evaluate Model

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Initialize the baseline model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model = create_default_model()
baseline_hist = baseline_model.fit(X_train, y_train, epochs=default_epoch, batch_size=default_batch,
                                   validation_data=(X_test, y_test), verbose=1)
print('Total time for creating the baseline model:', (datetime.now() - startTimeModule))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 17s 334us/sample - loss: 1.7597 - accuracy: 0.3664 - val_loss: 1.5105 - val_accuracy: 0.4489
# Epoch 2/50
# 50000/50000 [==============================] - 14s 288us/sample - loss:
50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0544 - accuracy: 0.9814 - val_loss: 1.7851 - val_accuracy: 0.7103
# Epoch 32/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0546 - accuracy: 0.9811 - val_loss: 1.8304 - val_accuracy: 0.7191
# Epoch 33/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0375 - accuracy: 0.9881 - val_loss: 1.8784 - val_accuracy: 0.7149
# Epoch 34/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0341 - accuracy: 0.9886 - val_loss: 1.9465 - val_accuracy: 0.7186
# Epoch 35/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0429 - accuracy: 0.9856 - val_loss: 1.9019 - val_accuracy: 0.7211
# Epoch 36/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0371 - accuracy: 0.9874 - val_loss: 2.0593 - val_accuracy: 0.7176
# Epoch 37/50
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.0427 - accuracy: 0.9854 - val_loss: 2.0105 - val_accuracy: 0.7271
# Epoch 38/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0370 - accuracy: 0.9879 - val_loss: 2.0400 - val_accuracy: 0.7219
# Epoch 39/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0273 - accuracy: 0.9910 - val_loss: 2.0419 - val_accuracy: 0.7163
# Epoch 40/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0311 - accuracy: 0.9899 - val_loss: 2.1070 - val_accuracy: 0.7128
# Epoch 41/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0320 - accuracy: 0.9891 - val_loss: 2.1247 - val_accuracy: 0.7215
# Epoch 42/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0260 - accuracy: 0.9913 - val_loss: 2.0376 - val_accuracy: 0.7183
# Epoch 43/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 0.0178 - accuracy: 0.9942 - val_loss: 2.1957 - val_accuracy: 0.7265
# Epoch 44/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0048 - accuracy: 0.9989 - val_loss: 2.2467 - val_accuracy: 0.7325
# Epoch 45/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 9.9545e-04 - accuracy: 0.9999 - val_loss: 2.3323 - val_accuracy: 0.7296
# Epoch 46/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 4.7702e-04 - accuracy: 1.0000 - val_loss: 2.3547 - val_accuracy: 0.7334
# Epoch 47/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 2.4185e-04 - accuracy: 1.0000 - val_loss: 2.3893 - val_accuracy: 0.7333
# Epoch 48/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 1.9871e-04 - accuracy: 1.0000 - val_loss: 2.4178 - val_accuracy: 0.7321
# Epoch 49/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 1.7322e-04 - accuracy: 1.0000 - val_loss: 2.4415 - val_accuracy: 0.7341
# Epoch 50/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 1.5512e-04 - accuracy: 1.0000 - val_loss: 2.4627 - val_accuracy: 0.7343
# Total time for creating the baseline model: 0:12:00.792984

# %%
# Display a summary of the baseline model
print(baseline_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the baseline model
print(baseline_model.get_config())
# Out:
# {'name': 'sequential', 'layers': [{'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'batch_input_shape': (None, 32, 32, 3), 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_1', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_2', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_3', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_1', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_4', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_5', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 2.0, 'mode': 'fan_in', 'distribution': 'uniform', 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None ...

# %%
# List all data points in the baseline model training history
print(baseline_hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Summarize model training hisotry for accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['accuracy'], color='blue', label='train')
plt.plot(baseline_hist.history['val_accuracy'], color='red', label='test')
plt.title('Baseline Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
if (notifyStatus): email_notify("Phase 3 Fit and Evaluate Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 4. Optimize Model

# %%
if (notifyStatus): email_notify("Phase 4 Optimize Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the Keras model required for KerasClassifier
def create_customized_model(optimizer, kernel_init):
    customized_model = Sequential()
    customized_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same', input_shape=(32, 32, 3)))
    customized_model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(MaxPooling2D((2, 2)))
    customized_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(MaxPooling2D((2, 2)))
    customized_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=kernel_init, padding='same'))
    customized_model.add(MaxPooling2D((2, 2)))
    customized_model.add(Flatten())
    customized_model.add(Dense(128, activation='relu', kernel_initializer=kernel_init))
    customized_model.add(Dense(num_classes, activation='softmax', kernel_initializer=kernel_init))
    customized_model.compile(loss=default_loss, optimizer=optimizer, metrics=default_metrics)
    return customized_model

# %%
startTimeModule = datetime.now()

# Set up grid search using different epochs, batch sizes, and optimizers
optz_1 = tf.optimizers.Adam(learning_rate=0.001)
optz_2 = tf.optimizers.RMSprop(learning_rate=0.001)
optz_3 = tf.optimizers.SGD(learning_rate=0.001, momentum=0.9)
optimizer_grid = [optz_1, optz_2, optz_3]
print('Optimizer candidate #1 has the object ID of', optz_1)
print('Optimizer candidate #2 has the object ID of', optz_2)
print('Optimizer candidate #3 has the object ID of', optz_3)

init_1 = tf.initializers.RandomNormal(seed=seedNum)
init_2 = tf.initializers.he_uniform(seed=seedNum)
init_grid = [init_1, init_2]
print('Initializer candidate #1 has the object ID of', init_1)
print('Initializer candidate #2 has the object ID of', init_2)

epoch_grid = [50]
batch_grid = [64, 128]

best_score = 0
grid_iteration = 0
best_iteration = 0
best_optimizer = default_optimizer
best_kernel_init = default_kernel_init
best_epoch = default_epoch
best_batch = default_batch

for optimizer in optimizer_grid:
    for kernel_init in init_grid:
        for epoch_num in epoch_grid:
            for batch_num in batch_grid:
                print('\nForming the grid-search model #%d using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
                      % (grid_iteration, optimizer, kernel_init, epoch_num, batch_num))
                reset_random(seedNum)
                grid_model = create_customized_model(optimizer, kernel_init)
                grid_hist = grid_model.fit(X_train, y_train, epochs=epoch_num, batch_size=batch_num, 
                                       validation_data=(X_test, y_test), verbose=1)
                if(grid_hist.history['val_accuracy'][-1] > best_score):
                    best_score = grid_hist.history['val_accuracy'][-1]
                    best_iteration = grid_iteration
                    best_optimizer = optimizer
                    best_kernel_init = kernel_init
                    best_epoch = epoch_num
                    best_batch = batch_num
                grid_iteration = grid_iteration + 1

# summarize results
print("\nBest score (highest validation accuracy) found via grid search: accuracy=%f from model iteration #%d"
      % (best_score, best_iteration))
print('The best modeling parameters are: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
print('Total time for performing grid-search of the best parameters:', (datetime.now() - startTimeModule))
# Out:
# Optimizer candidate #1 has the object ID of <tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f9d74068ba8>
# Optimizer candidate #2 has the object ID of <tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f9d74068390>
# Optimizer candidate #3 has the object ID of <tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f9d74068a58>
# Initializer candidate #1 has the object ID of <tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>
# Initializer candidate #2 has the object ID of <tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f9dc091b9b0>
#
# Forming the grid-search model #0 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f9d74068ba8>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 16s 314us/sample - loss: 1.5087 - accuracy: 0.4507 - val_loss: 1.1399 - val_accuracy: 0.5885
# Epoch 2/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 1.0004 - accuracy: 0.6454 - val_loss: 0.8849 - val_accuracy: 0.6854
# Epoch 3/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.7808 - accuracy: 0.7264 - val_loss: 0.7924 - val_accuracy: 0.7201
# Epoch 4/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0
50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0785 - accuracy: 0.9752 - val_loss: 1.7310 - val_accuracy: 0.7477
# Epoch 34/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0714 - accuracy: 0.9776 - val_loss: 1.7476 - val_accuracy: 0.7399
# Epoch 35/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0679 - accuracy: 0.9782 - val_loss: 1.8135 - val_accuracy: 0.7575
# Epoch 36/50
# 50000/50000 [==============================] - 15s 297us/sample - loss: 0.0732 - accuracy: 0.9772 - val_loss: 1.7900 - val_accuracy: 0.7609
# Epoch 37/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0647 - accuracy: 0.9795 - val_loss: 2.0119 - val_accuracy: 0.7380
# Epoch 38/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0678 - accuracy: 0.9779 - val_loss: 2.0433 - val_accuracy: 0.7386
# Epoch 39/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0723 - accuracy: 0.9777 - val_loss: 1.9763 - val_accuracy: 0.7513
# Epoch 40/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0654 - accuracy: 0.9796 - val_loss: 1.8173 - val_accuracy: 0.7518
# Epoch 41/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0633 - accuracy: 0.9802 - val_loss: 1.7893 - val_accuracy: 0.7638
# Epoch 42/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0706 - accuracy: 0.9785 - val_loss: 2.1080 - val_accuracy: 0.7529
# Epoch 43/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0750 - accuracy: 0.9768 - val_loss: 1.8343 - val_accuracy: 0.7555
# Epoch 44/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0614 - accuracy: 0.9807 - val_loss: 1.8922 - val_accuracy: 0.7436
# Epoch 45/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.0590 - accuracy: 0.9817 - val_loss: 1.9742 - val_accuracy: 0.7520
# Epoch 46/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0744 - accuracy: 0.9771 - val_loss: 2.0276 - val_accuracy: 0.7469
# Epoch 47/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0622 - accuracy: 0.9808 - val_loss: 1.9781 - val_accuracy: 0.7534
# Epoch 48/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0598 - accuracy: 0.9822 - val_loss: 2.0643 - val_accuracy: 0.7432
# Epoch 49/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0673 - accuracy: 0.9791 - val_loss: 2.1243 - val_accuracy: 0.7416
# Epoch 50/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0702 - accuracy: 0.9789 - val_loss: 2.0721 - val_accuracy: 0.7505
#
# Forming the grid-search model #1 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f9d74068ba8>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 13s 257us/sample - loss: 1.8574 - accuracy: 0.3099 - val_loss: 1.5588 - val_accuracy: 0.4239
# Epoch 2/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 1.4999 - accuracy: 0.4524 - val_loss: 1.4506 - val_accuracy: 0.4754
# Epoch 3/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 1.3885 - accuracy: 0.4985 - val_loss: 1.3476 - val_accuracy: 0.5135
# Epoch 4/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 1.3056 - accuracy: 0.5307 - val_loss: 1.2972 - val_accuracy: 0.5386
# Epoch 5/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 1.2411 - accuracy: 0.5564 - val_loss: 1.2461 - val_accuracy: 0.5555
# Epoch 6/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 1.1896 - accuracy: 0.5765 - val_loss: 1.2198 - val_accuracy: 0.5652
# Epoch 7/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 1.1338 - accuracy: 0.5968 - val_loss: 1.2016 - val_accuracy: 0.5750
# Epoch 8/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 1.0875 - accuracy: 0.6131 - val_loss: 1.1720 - val_accuracy: 0.5875
# Epoch 9/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 1.0421 - accuracy: 0.6303 - val_loss: 1.1705 - val_accuracy: 0.5907
# Epoch 10/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 1.0022 - accuracy: 0.6433 - val_loss: 1.1734 - val_accuracy: 0.5917
# Epoch 11/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0
50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1430 - accuracy: 0.9497 - val_loss: 1.8575 - val_accuracy: 0.6802
# Epoch 21/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1367 - accuracy: 0.9529 - val_loss: 1.8713 - val_accuracy: 0.6828
# Epoch 22/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.1181 - accuracy: 0.9586 - val_loss: 2.0875 - val_accuracy: 0.6785
# Epoch 23/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1294 - accuracy: 0.9543 - val_loss: 2.0107 - val_accuracy: 0.6825
# Epoch 24/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1233 - accuracy: 0.9575 - val_loss: 1.9692 - val_accuracy: 0.6910
# Epoch 25/50
# 50000/50000 [==============================] - 15s 291us/sample - loss: 0.1149 - accuracy: 0.9601 - val_loss: 2.0563 - val_accuracy: 0.6890
# Epoch 26/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.1131 - accuracy: 0.9618 - val_loss: 2.1672 - val_accuracy: 0.6802
# Epoch 27/50
# 50000/50000 [==============================] - 15s 296us/sample - loss: 0.1162 - accuracy: 0.9606 - val_loss: 2.1672 - val_accuracy: 0.6815
# Epoch 28/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.1109 - accuracy: 0.9619 - val_loss: 2.1516 - val_accuracy: 0.6804
# Epoch 29/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.1084 - accuracy: 0.9629 - val_loss: 2.1764 - val_accuracy: 0.6803
# Epoch 30/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.1015 - accuracy: 0.9651 - val_loss: 2.2464 - val_accuracy: 0.6777
# Epoch 31/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.1053 - accuracy: 0.9639 - val_loss: 2.3564 - val_accuracy: 0.6844
# Epoch 32/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1086 - accuracy: 0.9636 - val_loss: 2.2604 - val_accuracy: 0.6866
# Epoch 33/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0907 - accuracy: 0.9682 - val_loss: 2.3087 - val_accuracy: 0.6854
# Epoch 34/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0980 - accuracy: 0.9667 - val_loss: 2.4361 - val_accuracy: 0.6848
# Epoch 35/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.1063 - accuracy: 0.9648 - val_loss: 2.0883 - val_accuracy: 0.6818
# Epoch 36/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0950 - accuracy: 0.9681 - val_loss: 2.4232 - val_accuracy: 0.6849
# Epoch 37/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.0821 - accuracy: 0.9722 - val_loss: 2.4749 - val_accuracy: 0.6851
# Epoch 38/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0978 - accuracy: 0.9677 - val_loss: 2.3575 - val_accuracy: 0.6785
# Epoch 39/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0992 - accuracy: 0.9671 - val_loss: 2.3557 - val_accuracy: 0.6873
# Epoch 40/50
# 50000/50000 [==============================] - 15s 291us/sample - loss: 0.0799 - accuracy: 0.9726 - val_loss: 2.4931 - val_accuracy: 0.6810
# Epoch 41/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0940 - accuracy: 0.9700 - val_loss: 2.4357 - val_accuracy: 0.6814
# Epoch 42/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0834 - accuracy: 0.9726 - val_loss: 2.5054 - val_accuracy: 0.6863
# Epoch 43/50
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.0769 - accuracy: 0.9750 - val_loss: 2.5889 - val_accuracy: 0.6724
# Epoch 44/50
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.0983 - accuracy: 0.9680 - val_loss: 2.4491 - val_accuracy: 0.6946
# Epoch 45/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0850 - accuracy: 0.9716 - val_loss: 2.4991 - val_accuracy: 0.6857
# Epoch 46/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.0830 - accuracy: 0.9730 - val_loss: 2.5865 - val_accuracy: 0.6873
# Epoch 47/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.0860 - accuracy: 0.9718 - val_loss: 2.4254 - val_accuracy: 0.6902
# Epoch 48/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.0787 - accuracy: 0.9751 - val_loss: 2.6069 - val_accuracy: 0.6819
# Epoch 49/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0857 - accuracy: 0.9715 - val_loss: 2.4887 - val_accuracy: 0.6835
# Epoch 50/50
# 50000/50000 [==============================] - 15s 295us/sample - loss: 0.0749 - accuracy: 0.9754 - val_loss: 2.5706 - val_accuracy: 0.6806
#
# Forming the grid-search model #3 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7f9d74068ba8>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f9dc091b9b0>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 13s 253us/sample - loss: 1.7816 - accuracy: 0.3416 - val_loss: 1.4462 - val_accuracy: 0.4695
# Epoch 2/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 1.3540 - accuracy: 0.5067 - val_loss: 1.2929 - val_accuracy: 0.5333
# Epoch 3/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 1.1622 - accuracy: 0.5828 - val_loss: 1.1278 - val_accuracy: 0.5975
# Epoch 4/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 1.0222 - accuracy: 0.6368 - val_loss: 1.0092 - val_accuracy: 0.6439
# Epoch 5/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.9091 - accuracy: 0.6782 - val_loss: 0.9703 - val_accuracy: 0.6650
# Epoch 6/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.8196 - accuracy: 0.7116 - val_loss: 0.9170 - val_accuracy: 0.6795
# Epoch 7/50
# 50000/50000 [==============================] - 12s 232us/sample - loss: 0.7407 - accuracy: 0.7392 - val_loss: 0.9235 - val_accuracy: 0.6901
# Epoch 8/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.6757 - accuracy: 0.7615 - val_loss: 0.8969 - val_accuracy: 0.6969
# Epoch 9/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.6055 - accuracy: 0.7860 - val_loss: 0.9047 - val_accuracy: 0.7034
# Epoch 10/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.5483 - accuracy: 0.8074 - val_loss: 0.8996 - val_accuracy: 0.7113
# Epoch 11/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.4880 - accuracy: 0.8298 - val_loss: 0.9322 - val_accuracy: 0.7118
# Epoch 12/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.4311 - accuracy: 0.8492 - val_loss: 0.9967 - val_accuracy: 0.6942
# Epoch 13/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.3756 - accuracy: 0.8670 - val_loss: 1.0434 - val_accuracy: 0.7023
# Epoch 14/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.3269 - accuracy: 0.8865 - val_loss: 1.1329 - val_accuracy: 0.6965
# Epoch 15/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.2765 - accuracy: 0.9022 - val_loss: 1.1886 - val_accuracy: 0.6958
# Epoch 16/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.2300 - accuracy: 0.9187 - val_loss: 1.2758 - val_accuracy: 0.7009
# Epoch 17/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.2018 - accuracy: 0.9289 - val_loss: 1.3919 - val_accuracy: 0.6962
# Epoch 18/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.1762 - accuracy: 0.9392 - val_loss: 1.4911 - val_accuracy: 0.6972
# Epoch 19/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.1500 - accuracy: 0.9472 - val_loss: 1.5717 - val_accuracy: 0.6945
# Epoch 20/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.1369 - accuracy: 0.9507 - val_loss: 1.5523 - val_accuracy: 0.6961
# Epoch 21/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.1240 - accuracy: 0.9569 - val_loss: 1.7245 - val_accuracy: 0.6889
# Epoch 22/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.1232 - accuracy: 0.9566 - val_loss: 1.8427 - val_accuracy: 0.6901
# Epoch 23/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.1153 - accuracy: 0.9594 - val_loss: 1.8619 - val_accuracy: 0.6944
# Epoch 24/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.1025 - accuracy: 0.9634 - val_loss: 1.8920 - val_accuracy: 0.6913
# Epoch 25/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.0965 - accuracy: 0.9658 - val_loss: 1.9967 - val_accuracy: 0.6860
# Epoch 26/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.1061 - accuracy: 0.9623 - val_loss: 1.8820 - val_accuracy: 0.6918
# Epoch 27/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0929 - accuracy: 0.9673 - val_loss: 2.0580 - val_accuracy: 0.6872
# Epoch 28/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.0921 - accuracy: 0.9686 - val_loss: 2.1607 - val_accuracy: 0.6907
# Epoch 29/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0766 - accuracy: 0.9730 - val_loss: 2.1400 - val_accuracy: 0.6939
# Epoch 30/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.0950 - accuracy: 0.9672 - val_loss: 2.0826 - val_accuracy: 0.6920
# Epoch 31/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0851 - accuracy: 0.9700 - val_loss: 2.2349 - val_accuracy: 0.6857
# Epoch 32/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0692 - accuracy: 0.9759 - val_loss: 2.2864 - val_accuracy: 0.6885
# Epoch 33/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.0792 - accuracy: 0.9726 - val_loss: 2.3154 - val_accuracy: 0.6956
# Epoch 34/50
# 50000/50000 [==============================] - 12s 232us/sample - loss: 0.0817 - accuracy: 0.9726 - val_loss: 2.3209 - val_accuracy: 0.6893
# Epoch 35/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.0740 - accuracy: 0.9745 - val_loss: 2.3435 - val_accuracy: 0.6897
# Epoch 36/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0702 - accuracy: 0.9755 - val_loss: 2.3421 - val_accuracy: 0.6884
# Epoch 37/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0780 - accuracy: 0.9736 - val_loss: 2.3914 - val_accuracy: 0.6968
# Epoch 38/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.0915 - accuracy: 0.9693 - val_loss: 2.2497 - val_accuracy: 0.6859
# Epoch 39/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.0665 - accuracy: 0.9775 - val_loss: 2.5884 - val_accuracy: 0.6861
# Epoch 40/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.0794 - accuracy: 0.9731 - val_loss: 2.4214 - val_accuracy: 0.6950
# Epoch 41/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0615 - accuracy: 0.9798 - val_loss: 2.3624 - val_accuracy: 0.6992
# Epoch 42/50
# 50000/50000 [==============================] - 12s 231us/sample - loss: 0.0710 - accuracy: 0.9752 - val_loss: 2.4222 - val_accuracy: 0.6935
# Epoch 43/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0680 - accuracy: 0.9774 - val_loss: 2.5651 - val_accuracy: 0.6924
# Epoch 44/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0625 - accuracy: 0.9786 - val_loss: 2.5826 - val_accuracy: 0.6947
# Epoch 45/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.0696 - accuracy: 0.9766 - val_loss: 2.4616 - val_accuracy: 0.6917
# Epoch 46/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0752 - accuracy: 0.9748 - val_loss: 2.5107 - val_accuracy: 0.6852
# Epoch 47/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0536 - accuracy: 0.9813 - val_loss: 2.6004 - val_accuracy: 0.6894
# Epoch 48/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0690 - accuracy: 0.9768 - val_loss: 2.6001 - val_accuracy: 0.6870
# Epoch 49/50
# 50000/50000 [==============================] - 12s 230us/sample - loss: 0.0652 - accuracy: 0.9784 - val_loss: 2.5750 - val_accuracy: 0.6954
# Epoch 50/50
# 50000/50000 [==============================] - 11s 230us/sample - loss: 0.0649 - accuracy: 0.9785 - val_loss: 2.4959 - val_accuracy: 0.6988
#
# Forming the grid-search model #4 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f9d74068390>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=64
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 17s
50
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.2490 - accuracy: 0.9329 - val_loss: 1.4616 - val_accuracy: 0.7427
# Epoch 31/50
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.2577 - accuracy: 0.9326 - val_loss: 1.9075 - val_accuracy: 0.7656
# Epoch 32/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.2638 - accuracy: 0.9298 - val_loss: 2.3953 - val_accuracy: 0.7521
# Epoch 33/50
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.2606 - accuracy: 0.9308 - val_loss: 1.2474 - val_accuracy: 0.7097
# Epoch 34/50
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.2793 - accuracy: 0.9251 - val_loss: 2.2526 - val_accuracy: 0.7670
# Epoch 35/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.2857 - accuracy: 0.9250 - val_loss: 2.5484 - val_accuracy: 0.7374
# Epoch 36/50
# 50000/50000 [==============================] - 16s 314us/sample - loss: 0.2962 - accuracy: 0.9208 - val_loss: 2.8029 - val_accuracy: 0.7578
# Epoch 37/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3079 - accuracy: 0.9182 - val_loss: 1.9618 - val_accuracy: 0.7496
# Epoch 38/50
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.3178 - accuracy: 0.9149 - val_loss: 1.3378 - val_accuracy: 0.7254
# Epoch 39/50
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.3121 - accuracy: 0.9177 - val_loss: 2.4977 - val_accuracy: 0.7085
# Epoch 40/50
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.3092 - accuracy: 0.9160 - val_loss: 1.6259 - val_accuracy: 0.7566
# Epoch 41/50
# 50000/50000 [==============================] - 15s 309us/sample - loss: 0.3121 - accuracy: 0.9150 - val_loss: 2.1793 - val_accuracy: 0.7518
# Epoch 42/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3376 - accuracy: 0.9087 - val_loss: 1.7081 - val_accuracy: 0.7605
# Epoch 43/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3335 - accuracy: 0.9094 - val_loss: 1.9623 - val_accuracy: 0.7485
# Epoch 44/50
# 50000/50000 [==============================] - 16s 312us/sample - loss: 0.3319 - accuracy: 0.9090 - val_loss: 1.8630 - val_accuracy: 0.7481
# Epoch 45/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3302 - accuracy: 0.9098 - val_loss: 2.3985 - val_accuracy: 0.7010
# Epoch 46/50
# 50000/50000 [==============================] - 16s 311us/sample - loss: 0.3395 - accuracy: 0.9082 - val_loss: 1.3080 - val_accuracy: 0.7569
# Epoch 47/50
# 50000/50000 [==============================] - 16s 313us/sample - loss: 0.3446 - accuracy: 0.9046 - val_loss: 1.5267 - val_accuracy: 0.7352
# Epoch 48/50
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.3373 - accuracy: 0.9069 - val_loss: 3.0021 - val_accuracy: 0.7277
# Epoch 49/50
# 50000/50000 [==============================] - 15s 310us/sample - loss: 0.3426 - accuracy: 0.9053 - val_loss: 1.7196 - val_accuracy: 0.7510
# Epoch 50/50
# 50000/50000 [==============================] - 16s 310us/sample - loss: 0.3475 - accuracy: 0.9038 - val_loss: 1.8469 - val_accuracy: 0.7054
#
# Forming the grid-search model #5 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f9d74068390>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 14s 272us/sample - loss: 1.8057 - accuracy: 0.3461 - val_loss: 1.6415 - val_accuracy: 0.4398
# Epoch 2/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 1.2779 - accuracy: 0.5460 - val_loss: 1.2308 - val_accuracy: 0.5603
# Epoch 3/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 1.0085 - accuracy: 0.6465 - val_loss: 0.9470 - val_accuracy: 0.6634
# Epoch 4/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.8209 - accuracy: 0.7150 - val_loss: 0.8524 - val_accuracy: 0.7037
# Epoch 5/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.6832 - accuracy: 0.7628 - val_loss: 0.7642 - val_accuracy: 0.7363
# Epoch 6/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.5665 - accuracy: 0.8027 - val_loss: 0.8631 - val_accuracy: 0.7153
# Epoch 7/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.4727 - accuracy: 0.8352 - val_loss: 0.8035 - val_accuracy: 0.7371
# Epoch 8/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.3794 - accuracy: 0.8673 - val_loss: 0.8788 - val_accuracy: 0.7316
# Epoch 9/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.3057 - accuracy: 0.8938 - val_loss: 0.8691 - val_accuracy: 0.7463
# Epoch 10/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.2423 - accuracy: 0.9153 - val_loss: 0.9067 - val_accuracy: 0.7639
# Epoch 11/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.1970 - accuracy: 0.9296 - val_loss: 1.0764 - val_accuracy: 0.7598
# Epoch 12/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1647 - accuracy: 0.9402 - val_loss: 1.1280 - val_accuracy: 0.7510
# Epoch 13/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1385 - accuracy: 0.9525 - val_loss: 1.1957 - val_accuracy: 0.7634
# Epoch 14/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.1261 - accuracy: 0.9566 - val_loss: 1.2751 - val_accuracy: 0.7598
# Epoch 15/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.1152 - accuracy: 0.9607 - val_loss: 1.4336 - val_accuracy: 0.7542
# Epoch 16/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1101 - accuracy: 0.9628 - val_loss: 1.3769 - val_accuracy: 0.7606
# Epoch 17/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.1035 - accuracy: 0.9646 - val_loss: 1.4942 - val_accuracy: 0.7631
# Epoch 18/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0972 - accuracy: 0.9669 - val_loss: 1.5461 - val_accuracy: 0.7589
# Epoch 19/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0937 - accuracy: 0.9687 - val_loss: 1.6634 - val_accuracy: 0.7604
# Epoch 20/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0899 - accuracy: 0.9709 - val_loss: 1.6291 - val_accuracy: 0.7625
# Epoch 21/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0923 - accuracy: 0.9710 - val_loss: 1.5955 - val_accuracy: 0.7624
# Epoch 22/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0865 - accuracy: 0.9720 - val_loss: 1.7028 - val_accuracy: 0.7661
# Epoch 23/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.0880 - accuracy: 0.9724 - val_loss: 1.7865 - val_accuracy: 0.7514
# Epoch 24/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.0837 - accuracy: 0.9739 - val_loss: 1.8131 - val_accuracy: 0.7624
# Epoch 25/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0800 - accuracy: 0.9757 - val_loss: 2.1413 - val_accuracy: 0.7461
# Epoch 26/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0825 - accuracy: 0.9746 - val_loss: 1.8772 - val_accuracy: 0.7574
# Epoch 27/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0810 - accuracy: 0.9757 - val_loss: 1.9872 - val_accuracy: 0.7612
# Epoch 28/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0802 - accuracy: 0.9763 - val_loss: 2.0473 - val_accuracy: 0.7603
# Epoch 29/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0783 - accuracy: 0.9762 - val_loss: 1.9952 - val_accuracy: 0.7636
# Epoch 30/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.0805 - accuracy: 0.9768 - val_loss: 1.9078 - val_accuracy: 0.7536
# Epoch 31/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0809 - accuracy: 0.9763 - val_loss: 1.9549 - val_accuracy: 0.7567
# Epoch 32/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0787 - accuracy: 0.9773 - val_loss: 2.0160 - val_accuracy: 0.7662
# Epoch 33/50
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.0753 - accuracy: 0.9777 - val_loss: 2.3080 - val_accuracy: 0.7668
# Epoch 34/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0775 - accuracy: 0.9780 - val_loss: 2.2759 - val_accuracy: 0.7611
# Epoch 35/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0790 - accuracy: 0.9772 - val_loss: 2.2150 - val_accuracy: 0.7514
# Epoch 36/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0745 - accuracy: 0.9783 - val_loss: 2.0468 - val_accuracy: 0.7684
# Epoch 37/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0745 - accuracy: 0.9794 - val_loss: 2.4845 - val_accuracy: 0.7449
# Epoch 38/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0827 - accuracy: 0.9778 - val_loss: 2.1511 - val_accuracy: 0.7497
# Epoch 39/50
# 50000/50000 [==============================] - 12s 244us
50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.3158 - accuracy: 0.8902 - val_loss: 1.0028 - val_accuracy: 0.7085
# Epoch 18/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.2743 - accuracy: 0.9031 - val_loss: 1.0788 - val_accuracy: 0.7045
# Epoch 19/50
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.2398 - accuracy: 0.9166 - val_loss: 1.2248 - val_accuracy: 0.6906
# Epoch 20/50
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.2104 - accuracy: 0.9267 - val_loss: 1.1628 - val_accuracy: 0.7171
# Epoch 21/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.1760 - accuracy: 0.9392 - val_loss: 1.2698 - val_accuracy: 0.7063
# Epoch 22/50
# 50000/50000 [==============================] - 15s 290us/sample - loss: 0.1531 - accuracy: 0.9466 - val_loss: 1.2922 - val_accuracy: 0.7175
# Epoch 23/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.1330 - accuracy: 0.9537 - val_loss: 1.3837 - val_accuracy: 0.7139
# Epoch 24/50
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.1170 - accuracy: 0.9600 - val_loss: 1.4553 - val_accuracy: 0.7102
# Epoch 25/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0957 - accuracy: 0.9679 - val_loss: 1.4749 - val_accuracy: 0.7167
# Epoch 26/50
# 50000/50000 [==============================] - 14s 283us/sample - loss: 0.0802 - accuracy: 0.9724 - val_loss: 1.5846 - val_accuracy: 0.7157
# Epoch 27/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0786 - accuracy: 0.9727 - val_loss: 1.6532 - val_accuracy: 0.7118
# Epoch 28/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 0.0667 - accuracy: 0.9773 - val_loss: 1.6881 - val_accuracy: 0.7158
# Epoch 29/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0519 - accuracy: 0.9825 - val_loss: 1.7583 - val_accuracy: 0.7136
# Epoch 30/50
# 50000/50000 [==============================] - 14s 283us/sample - loss: 0.0482 - accuracy: 0.9841 - val_loss: 1.7883 - val_accuracy: 0.7199
# Epoch 31/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0420 - accuracy: 0.9860 - val_loss: 1.9414 - val_accuracy: 0.7063
# Epoch 32/50
# 50000/50000 [==============================] - 14s 289us/sample - loss: 0.0528 - accuracy: 0.9829 - val_loss: 1.9082 - val_accuracy: 0.7147
# Epoch 33/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0623 - accuracy: 0.9780 - val_loss: 1.8439 - val_accuracy: 0.7146
# Epoch 34/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0396 - accuracy: 0.9869 - val_loss: 1.9035 - val_accuracy: 0.7133
# Epoch 35/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0363 - accuracy: 0.9878 - val_loss: 1.9532 - val_accuracy: 0.7139
# Epoch 36/50
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.0354 - accuracy: 0.9886 - val_loss: 2.0184 - val_accuracy: 0.7098
# Epoch 37/50
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.0342 - accuracy: 0.9885 - val_loss: 2.0051 - val_accuracy: 0.7202
# Epoch 38/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0125 - accuracy: 0.9968 - val_loss: 2.2392 - val_accuracy: 0.7165
# Epoch 39/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0495 - accuracy: 0.9824 - val_loss: 2.0276 - val_accuracy: 0.7193
# Epoch 40/50
# 50000/50000 [==============================] - 14s 285us/sample - loss: 0.0254 - accuracy: 0.9916 - val_loss: 2.0727 - val_accuracy: 0.7181
# Epoch 41/50
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.0275 - accuracy: 0.9905 - val_loss: 2.1680 - val_accuracy: 0.7152
# Epoch 42/50
# 50000/50000 [==============================] - 15s 292us/sample - loss: 0.0177 - accuracy: 0.9949 - val_loss: 2.1572 - val_accuracy: 0.7221
# Epoch 43/50
# 50000/50000 [==============================] - 14s 289us/sample - loss: 0.0057 - accuracy: 0.9987 - val_loss: 2.2455 - val_accuracy: 0.7264
# Epoch 44/50
# 50000/50000 [==============================] - 14s 289us/sample - loss: 0.0013 - accuracy: 0.9999 - val_loss: 2.3057 - val_accuracy: 0.7324
# Epoch 45/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 3.4361e-04 - accuracy: 1.0000 - val_loss: 2.3484 - val_accuracy: 0.7332
# Epoch 46/50
# 50000/50000 [==============================] - 14s 290us/sample - loss: 2.5782e-04 - accuracy: 1.0000 - val_loss: 2.3837 - val_accuracy: 0.7332
# Epoch 47/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 2.1708e-04 - accuracy: 1.0000 - val_loss: 2.4130 - val_accuracy: 0.7332
# Epoch 48/50
# 50000/50000 [==============================] - 15s 291us/sample - loss: 1.9081e-04 - accuracy: 1.0000 - val_loss: 2.4383 - val_accuracy: 0.7343
# Epoch 49/50
# 50000/50000 [==============================] - 15s 291us/sample - loss: 1.7094e-04 - accuracy: 1.0000 - val_loss: 2.4603 - val_accuracy: 0.7336
# Epoch 50/50
# 50000/50000 [==============================] - 14s 288us/sample - loss: 1.5568e-04 - accuracy: 1.0000 - val_loss: 2.4805 - val_accuracy: 0.7336
#
# Forming the grid-search model #11 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7f9d74068a58>, kernel=<tensorflow.python.ops.init_ops_v2.VarianceScaling object at 0x7f9dc091b9b0>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 1.8963 - accuracy: 0.3189 - val_loss: 1.5983 - val_accuracy: 0.4207
# Epoch 2/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 1.5166 - accuracy: 0.4558 - val_loss: 1.4463 - val_accuracy: 0.4758
# Epoch 3/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 1.3601 - accuracy: 0.5153 - val_loss: 1.2844 - val_accuracy: 0.5408
# Epoch 4/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 1.2326 - accuracy: 0.5614 - val_loss: 1.2045 - val_accuracy: 0.5695
# Epoch 5/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 1.1365 - accuracy: 0.5996 - val_loss: 1.1408 - val_accuracy: 0.5926
# Epoch 6/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 1.0581 - accuracy: 0.6303 - val_loss: 1.0876 - val_accuracy: 0.6199
# Epoch 7/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.9903 - accuracy: 0.6524 - val_loss: 1.0296 - val_accuracy: 0.6386
# Epoch 8/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.9431 - accuracy: 0.6702 - val_loss: 1.0286 - val_accuracy: 0.6380
# Epoch 9/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.8888 - accuracy: 0.6902 - val_loss: 1.0093 - val_accuracy: 0.6500
# Epoch 10/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.8431 - accuracy: 0.7084 - val_loss: 0.9515 - val_accuracy: 0.6745
# Epoch 11/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.8030 - accuracy: 0.7203 - val_loss: 0.9408 - val_accuracy: 0.6788
# Epoch 12/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.7692 - accuracy: 0.7342 - val_loss: 1.0166 - val_accuracy: 0.6589
# Epoch 13/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.7331 - accuracy: 0.7455 - val_loss: 0.9252 - val_accuracy: 0.6796
# Epoch 14/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.6932 - accuracy: 0.7609 - val_loss: 0.8978 - val_accuracy: 0.6915
# Epoch 15/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.6579 - accuracy: 0.7731 - val_loss: 0.9646 - val_accuracy: 0.6737
# Epoch 16/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.6273 - accuracy: 0.7847 - val_loss: 0.8956 - val_accuracy: 0.6969
# Epoch 17/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.5882 - accuracy: 0.7975 - val_loss: 0.8992 - val_accuracy: 0.6976
# Epoch 18/50
# 50000/50000 [==============================] - 11s 229us/sample - loss: 0.5551 - accuracy: 0.8091 - val_loss: 0.9309 - val_accuracy: 0.6940
# Epoch 19/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.5236 - accuracy: 0.8187 - val_loss: 0.9297 - val_accuracy: 0.6982
# Epoch 20/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.4984 - accuracy: 0.8281 - val_loss: 0.9156 - val_accuracy: 0.7063
# Epoch 21/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.4649 - accuracy: 0.8386 - val_loss: 0.9598 - val_accuracy: 0.7054
# Epoch 22/50
# 50000/50000 [==============================] - 11s 228us/sample - loss: 0.4355 - accuracy: 0.8500 - val_loss: 0.9392 - val_accuracy: 0.7111
# Epoch 23/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.4004 - accuracy: 0.8612 - val_loss: 0.9831 - val_accuracy: 0.7010
# Epoch 24/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.3783 - accuracy: 0.8699 - val_loss: 1.0548 - val_accuracy: 0.6916
# Epoch 25/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.3425 - accuracy: 0.8808 - val_loss: 1.0220 - val_accuracy: 0.7047
# Epoch 26/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.3117 - accuracy: 0.8950 - val_loss: 1.1080 - val_accuracy: 0.6972
# Epoch 27/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.2901 - accuracy: 0.9001 - val_loss: 1.1198 - val_accuracy: 0.6983
# Epoch 28/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.2652 - accuracy: 0.9082 - val_loss: 1.1161 - val_accuracy: 0.7097
# Epoch 29/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.2395 - accuracy: 0.9180 - val_loss: 1.1472 - val_accuracy: 0.7053
# Epoch 30/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.2147 - accuracy: 0.9267 - val_loss: 1.2277 - val_accuracy: 0.6984
# Epoch 31/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.1947 - accuracy: 0.9336 - val_loss: 1.2557 - val_accuracy: 0.7076
# Epoch 32/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.1707 - accuracy: 0.9420 - val_loss: 1.3128 - val_accuracy: 0.7010
# Epoch 33/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.1486 - accuracy: 0.9503 - val_loss: 1.3391 - val_accuracy: 0.7081
# Epoch 34/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.1353 - accuracy: 0.9542 - val_loss: 1.4259 - val_accuracy: 0.7025
# Epoch 35/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.1254 - accuracy: 0.9576 - val_loss: 1.4668 - val_accuracy: 0.7099
# Epoch 36/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0978 - accuracy: 0.9685 - val_loss: 1.5218 - val_accuracy: 0.7053
# Epoch 37/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0831 - accuracy: 0.9737 - val_loss: 1.6340 - val_accuracy: 0.6997
# Epoch 38/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0713 - accuracy: 0.9777 - val_loss: 1.6335 - val_accuracy: 0.7067
# Epoch 39/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0578 - accuracy: 0.9831 - val_loss: 1.7342 - val_accuracy: 0.7092
# Epoch 40/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0806 - accuracy: 0.9722 - val_loss: 1.7376 - val_accuracy: 0.6998
# Epoch 41/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0515 - accuracy: 0.9850 - val_loss: 1.7974 - val_accuracy: 0.7100
# Epoch 42/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0279 - accuracy: 0.9937 - val_loss: 1.8263 - val_accuracy: 0.7097
# Epoch 43/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0251 - accuracy: 0.9944 - val_loss: 1.8807 - val_accuracy: 0.6993
# Epoch 44/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0588 - accuracy: 0.9806 - val_loss: 1.8955 - val_accuracy: 0.7092
# Epoch 45/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0182 - accuracy: 0.9968 - val_loss: 2.0245 - val_accuracy: 0.7094
# Epoch 46/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0078 - accuracy: 0.9993 - val_loss: 2.0535 - val_accuracy: 0.7166
# Epoch 47/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0033 - accuracy: 0.9999 - val_loss: 2.1145 - val_accuracy: 0.7192
# Epoch 48/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.1684 - val_accuracy: 0.7185
# Epoch 49/50
# 50000/50000 [==============================] - 11s 226us/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.2029 - val_accuracy: 0.7191
# Epoch 50/50
# 50000/50000 [==============================] - 11s 227us/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.2307 - val_accuracy: 0.7193
#
# Best score (highest validation accuracy) found via grid search: accuracy=0.763100 from model iteration #5
# The best modeling parameters are: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f9d74068390>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=128
# Total time for performing grid-search of the best parameters: 2:13:10.109892

# %%
if (notifyStatus): email_notify("Phase 4 Optimize Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# # Section 5. Finalize Model

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Create the final model for evaluating the test dataset
startTimeModule = datetime.now()
print('Forming the final model using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
reset_random(seedNum)
final_model = create_customized_model(best_optimizer, best_kernel_init)
final_hist = final_model.fit(X_train, y_train, epochs=best_epoch, batch_size=best_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for training the final model:', (datetime.now() - startTimeModule))
# Out:
# Forming the final model using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7f9d74068390>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7f9d74068f28>, epochs=50, batch_size=128
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 14s 273us/sample - loss: 1.8124 - accuracy: 0.3452 - val_loss: 1.5130 - val_accuracy: 0.4609
# Epoch 2/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 1.3065 - accuracy: 0.5355 - val_loss: 1.3486 - val_accuracy: 0.5218
# Epoch 3/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 1.0343 - accuracy: 0.6362 - val_loss: 0.9654 - val_accuracy: 0.6589
# Epoch 4/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.8456 - accuracy: 0.7038 - val_loss: 0.8968 - val_accuracy: 0.6845
# Epoch 5/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.7042 - accuracy: 0.7581 - val_loss: 0.8029 - val_accuracy: 0.7177
# Epoch 6/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.5865 - accuracy: 0.7962 - val_loss: 0.8864 - val_accuracy: 0.7131
# Epoch 7/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.4878 - accuracy: 0.8301 - val_loss: 0.8073 - val_accuracy: 0.7365
# Epoch 8/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.3932 - accuracy: 0.8635 - val_loss: 0.8527 - val_accuracy: 0.7331
# Epoch 9/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.3165 - accuracy: 0.8889 - val_loss: 1.0926 - val_accuracy: 0.7039
# Epoch 10/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.2535 - accuracy: 0.9112 - val_loss: 0.9523 - val_accuracy: 0.7549
# Epoch 11/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.2026 - accuracy: 0.9291 - val_loss: 1.2137 - val_accuracy: 0.7389
# Epoch 12/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1646 - accuracy: 0.9418 - val_loss: 1.2561 - val_accuracy: 0.7435
# Epoch 13/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1457 - accuracy: 0.9489 - val_loss: 1.3694 - val_accuracy: 0.7437
# Epoch 14/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1330 - accuracy: 0.9543 - val_loss: 1.3992 - val_accuracy: 0.7436
# Epoch 15/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.1192 - accuracy: 0.9589 - val_loss: 1.4580 - val_accuracy: 0.7551
# Epoch 16/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1121 - accuracy: 0.9617 - val_loss: 1.5627 - val_accuracy: 0.7536
# Epoch 17/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.1066 - accuracy: 0.9647 - val_loss: 1.5614 - val_accuracy: 0.7559
# Epoch 18/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0954 - accuracy: 0.9680 - val_loss: 1.5325 - val_accuracy: 0.7550
# Epoch 19/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0961 - accuracy: 0.9679 - val_loss: 1.6902 - val_accuracy: 0.7547
# Epoch 20/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0937 - accuracy: 0.9695 - val_loss: 1.7797 - val_accuracy: 0.7383
# Epoch 21/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0877 - accuracy: 0.9720 - val_loss: 1.7071 - val_accuracy: 0.7563
# Epoch 22/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0866 - accuracy: 0.9726 - val_loss: 1.8328 - val_accuracy: 0.7523
# Epoch 23/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0833 - accuracy: 0.9734 - val_loss: 1.8447 - val_accuracy: 0.7418
# Epoch 24/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0823 - accuracy: 0.9735 - val_loss: 1.7584 - val_accuracy: 0.7586
# Epoch 25/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0794 - accuracy: 0.9754 - val_loss: 2.0262 - val_accuracy: 0.7354
# Epoch 26/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0823 - accuracy: 0.9747 - val_loss: 1.9388 - val_accuracy: 0.7552
# Epoch 27/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0832 - accuracy: 0.9750 - val_loss: 2.3318 - val_accuracy: 0.7481
# Epoch 28/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0784 - accuracy: 0.9759 - val_loss: 1.9145 - val_accuracy: 0.7595
# Epoch 29/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0796 - accuracy: 0.9754 - val_loss: 2.1950 - val_accuracy: 0.7452
# Epoch 30/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0766 - accuracy: 0.9762 - val_loss: 1.7944 - val_accuracy: 0.7522
# Epoch 31/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0758 - accuracy: 0.9779 - val_loss: 1.9752 - val_accuracy: 0.7584
# Epoch 32/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0754 - accuracy: 0.9777 - val_loss: 2.2458 - val_accuracy: 0.7569
# Epoch 33/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0766 - accuracy: 0.9780 - val_loss: 2.3760 - val_accuracy: 0.7567
# Epoch 34/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0762 - accuracy: 0.9779 - val_loss: 2.2171 - val_accuracy: 0.7631
# Epoch 35/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0785 - accuracy: 0.9776 - val_loss: 2.3512 - val_accuracy: 0.7494
# Epoch 36/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0780 - accuracy: 0.9779 - val_loss: 2.2021 - val_accuracy: 0.7610
# Epoch 37/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0700 - accuracy: 0.9796 - val_loss: 2.5094 - val_accuracy: 0.7495
# Epoch 38/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0730 - accuracy: 0.9796 - val_loss: 2.2552 - val_accuracy: 0.7478
# Epoch 39/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0713 - accuracy: 0.9796 - val_loss: 2.6841 - val_accuracy: 0.7597
# Epoch 40/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0703 - accuracy: 0.9792 - val_loss: 2.3853 - val_accuracy: 0.7552
# Epoch 41/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0705 - accuracy: 0.9796 - val_loss: 2.4595 - val_accuracy: 0.7533
# Epoch 42/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0764 - accuracy: 0.9797 - val_loss: 2.2654 - val_accuracy: 0.7577
# Epoch 43/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0765 - accuracy: 0.9801 - val_loss: 2.5590 - val_accuracy: 0.7540
# Epoch 44/50
# 50000/50000 [==============================] - 12s 241us/sample - loss: 0.0737 - accuracy: 0.9803 - val_loss: 2.7297 - val_accuracy: 0.7569
# Epoch 45/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0773 - accuracy: 0.9794 - val_loss: 2.4393 - val_accuracy: 0.7500
# Epoch 46/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0731 - accuracy: 0.9812 - val_loss: 2.7441 - val_accuracy: 0.7439
# Epoch 47/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0767 - accuracy: 0.9798 - val_loss: 3.0713 - val_accuracy: 0.7507
# Epoch 48/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0765 - accuracy: 0.9798 - val_loss: 3.4394 - val_accuracy: 0.7523
# Epoch 49/50
# 50000/50000 [==============================] - 12s 242us/sample - loss: 0.0796 - accuracy: 0.9795 - val_loss: 2.4129 - val_accuracy: 0.7493
# Epoch 50/50
# 50000/50000 [==============================] - 12s 243us/sample - loss: 0.0731 - accuracy: 0.9809 - val_loss: 2.7389 - val_accuracy: 0.7344
# Total time for training the final model: 0:10:08.684147

# %%
# Display a summary of the final model
print(final_model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_78 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the final model
print(final_model.get_config())
# Out:
# {'name': 'sequential_13', 'layers': [{'class_name': 'Conv2D', 'config': {'name': 'conv2d_78', 'trainable': True, 'batch_input_shape': (None, 32, 32, 3), 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_79', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_39', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_80', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_81', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_40', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_82', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Conv2D', 'config': {'name': 'conv2d_83', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'MaxPooling2D', 'config': {'name': 'max_pooling2d_41', ' ...

# %%
# Summarize model training hisotry for accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(final_hist.history['accuracy'], color='blue', label='train')
plt.plot(final_hist.history['val_accuracy'], color='red', label='test')
plt.title('Final Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(final_hist.history['loss'], color='blue', label='train')
plt.plot(final_hist.history['val_loss'], color='red', label='test')
plt.title('Final Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Evaluate the Keras model on previously unseen data
# scores = final_model.evaluate(X_test, y_test, verbose=0)
# print("The model %s: %f%%" % (final_model.metrics_names[1], scores[1]*100))
# print("The model %s: %f" % (final_model.metrics_names[0], scores[0]))

# %%
# Make class predictions with the model
predictions = final_model.predict_classes(X_test)

# Summarize the first 20 cases
for i in range(20):
	print('Data item #%d predicted to be %s (expected %s)' % (i, encoder.inverse_transform([predictions[i]]), encoder.inverse_transform([np.argmax(y_test[i])])))
# Out:
# Data item #0 predicted to be [5] (expected [3])
# Data item #1 predicted to be [8] (expected [8])
# Data item #2 predicted to be [8] (expected [8])
# Data item #3 predicted to be [0] (expected [0])
# Data item #4 predicted to be [4] (expected [6])
# Data item #5 predicted to be [5] (expected [6])
# Data item #6 predicted to be [1] (expected [1])
# Data item #7 predicted to be [6] (expected [6])
# Data item #8 predicted to be [3] (expected [3])
# Data item #9 predicted to be [1] (expected [1])
# Data item #10 predicted to be [4] (expected [0])
# Data item #11 predicted to be [9] (expected [9])
# Data item #12 predicted to be [3] (expected [5])
# Data item #13 predicted to be [7] (expected [7])
# Data item #14 predicted to be [9] (expected [9])
# Data item #15 predicted to be [8] (expected [8])
# Data item #16 predicted to be [5] (expected [5])
# Data item #17 predicted to be [9] (expected [7])
# Data item #18 predicted to be [8] (expected [8])
# Data item #19 predicted to be [6] (expected [6])

# %%
if (notifyStatus): email_notify("Phase 5 Finalize Model completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 2:35:25.355341
