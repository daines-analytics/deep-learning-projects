# %% [markdown]
# # Binary Classification Model for Rain in Australia Using TensorFlow Take 4
# ### David Lowe
# ### March 31, 2020
#
# Template Credit: Adapted from a template made available by Dr. Jason Brownlee of Machine Learning Mastery. [https://machinelearningmastery.com/]
#
# SUMMARY: The purpose of this project is to construct a predictive model using various machine learning algorithms and to document the end-to-end steps using a template. The Rain in Australia dataset is a binary classification situation where we are trying to predict one of the two possible outcomes.
#
# INTRODUCTION: This dataset contains daily weather observations from numerous Australian weather stations. The target variable RainTomorrow represents whether it rained the next day. We also should exclude the variable Risk-MM when training a binary classification model. By not eliminating the Risk-MM feature, we run a risk of leaking the answers into our model and reduce its effectiveness.
#
# In iteration Take1, we constructed several traditional machine learning models using the linear, non-linear, and ensemble techniques. We also observed the best accuracy score that we could obtain with each of these models.
#
# In iteration Take2, we constructed and tuned an XGBoost machine learning model for this dataset. We also observed the best accuracy score that we could obtain with the XGBoost model.
#
# In iteration Take3, we constructed several Multilayer Perceptron (MLP) models with one, two, and three hidden layers. The one-layer MLP model serves as the baseline models as we build more complex MLP models in future iterations.
#
# In this Take4 iteration, we will tune the single-layer MLP model and see whether we can improve our accuracy score.
#
# ANALYSIS: In iteration Take1, the baseline performance of the machine learning algorithms achieved an average accuracy of 83.83%. Two algorithms (Extra Trees and Random Forest) achieved the top accuracy metrics after the first round of modeling. After a series of tuning trials, Random Forest turned in a better overall result than Extra Trees with a lower variance. Random Forest achieved an accuracy metric of 85.44%. When configured with the optimized parameters, the Random Forest algorithm processed the test dataset with an accuracy of 85.52%, which was consistent with the accuracy score from the training phase.
#
# In iteration Take2, the XGBoost algorithm achieved a baseline accuracy of 84.69% by setting n_estimators to the default value of 100. After a series of tuning trials, XGBoost turned in an overall accuracy result of 86.21% with the n_estimators value set to 1000. When we apply the tuned XGBoost model to the test dataset, we obtained an accuracy score of 86.27%, which was consistent with the model performance from the training phase.
#
# In iteration Take3, all one-layer models achieved an accuracy performance of around 86%. The eight-nodes model appears to overfit the least, when compared with models with 12, 16, and 20 nodes. The single-layer eight-nodes model also seems to work better than the two and three-layer models by processing the test dataset with an accuracy score of 86.10% after 20 epochs.
#
# In this Take4 iteration, all models achieved an accuracy performance of around 86%. The model with the RMSprop optimizer appears to have the best accuracy score when predicting with the test dataset. It processed the test dataset with an accuracy score of 86.23% after 20 epochs.
#
# CONCLUSION: For this iteration, the single-layer eight-nodes MLP model produced the accuracy score that is comparable to the XGBoost model. For this dataset, we should consider doing more tuning with the XGBoost and the MLP models.
#
# Dataset Used: Rain in Australia Data Set
#
# Dataset ML Model: Binary classification with numerical and categorical attributes
#
# Dataset Reference: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
# One potential source of performance benchmark: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package/kernels
#
# The project aims to touch on the following areas:
#
# * Document a predictive modeling problem end-to-end.
# * Explore data cleaning and transformation options
# * Explore non-ensemble and ensemble algorithms for baseline model performance
# * Explore algorithm tuning techniques for improving model performance
#
# Any predictive modeling machine learning project genrally can be broken down into about six major tasks:
#
# 1. Prepare Environment
# 2. Summarize Data
# 3. Prepare Data
# 4. Model and Evaluate Algorithms
# 5. Improve Accuracy or Results
# 6. Finalize Model and Present Results

# %% [markdown]
# ## Section 1. Prepare Environment

# %%
# Retrieve GPU configuration information from Colab
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Tue Mar 24 00:08:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Retrieve memory configuration information from Colab
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### 1.a) Load libraries and modules

# %%
# Set the random seed number for reproducible results
seedNum = 888

# %%
# Load libraries and packages
import random
random.seed(seedNum)
import numpy as np
np.random.seed(seedNum)
import tensorflow as tf
tf.random.set_seed(seedNum)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
import matplotlib.pyplot as plt
from datetime import datetime
from email.message import EmailMessage
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions

# %%
# Begin the timer for the script processing
startTimeScript = datetime.now()

# Set up the number of CPU cores available for multi-thread processing
n_jobs = -1
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# Set up the flag to stop sending progress emails (setting to True will send status emails!)
notifyStatus = False

# Set the flag for splitting the dataset
splitDataset = True
splitPercentage = 0.25

# Set the number of folds for cross validation
n_folds = 5

# Set various Pandas options
pd.set_option('display.max_rows', 9999)

# Set up the verbose flag to print detailed messages for debugging (setting to True will activate)
# verbose = True
# tf.debugging.set_log_device_placement(verbose)

# Set various default Keras modeling parameters
default_loss = 'binary_crossentropy'
default_metrics = ['accuracy']
default_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
default_kernel_init = tf.keras.initializers.RandomNormal(seed=seedNum)
default_epoch = 20
default_batch = 32
# Out:
# Num GPUs Available:  1

# %%
# Set up the email notification function
def email_notify(msg_text):
    sender = os.environ.get('MAIL_SENDER')
    receiver = os.environ.get('MAIL_RECEIVER')
    gateway = os.environ.get('SMTP_GATEWAY')
    smtpuser = os.environ.get('SMTP_USERNAME')
    password = os.environ.get('SMTP_PASSWORD')
    if sender==None or receiver==None or gateway==None or smtpuser==None or password==None:
        sys.exit("Incomplete email setup info. Script Processing Aborted!!!")
    msg = EmailMessage()
    msg.set_content(msg_text)
    msg['Subject'] = 'Notification from Python Binary Classification Script'
    msg['From'] = sender
    msg['To'] = receiver
    server = smtplib.SMTP(gateway, 587)
    server.starttls()
    server.login(smtpuser, password)
    server.send_message(msg)
    server.quit()

# %%
# Reset the random number generators
def reset_random(x):
    random.seed(x)
    np.random.seed(x)
    tf.random.set_seed(x)

# %%
if (notifyStatus): email_notify("Library and Data Loading has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 1.c) Load dataset

# %%
dataset_path = 'https://dainesanalytics.com/datasets/kaggle-rain-tomorrow-australia/weatherAUS.csv'

Xy_original = pd.read_csv(dataset_path, sep=',')

# Take a peek at the dataframe after import
Xy_original.head(10)
# Out:
#          Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...         No      0.0            No
# 1  2008-12-02   Albury      7.4  ...         No      0.0            No
# 2  2008-12-03   Albury     12.9  ...         No      0.0            No
# 3  2008-12-04   Albury      9.2  ...         No      1.0            No
# 4  2008-12-05   Albury     17.5  ...         No      0.2            No
# 5  2008-12-06   Albury     14.6  ...         No      0.0            No
# 6  2008-12-07   Albury     14.3  ...         No      0.0            No
# 7  2008-12-08   Albury      7.7  ...         No      0.0            No
# 8  2008-12-09   Albury      9.7  ...         No      1.4           Yes
# 9  2008-12-10   Albury     13.1  ...        Yes      0.0            No
#
# [10 rows x 24 columns]

# %%
Xy_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# Temp3pm          139467 non-null float64
# RainToday        140787 non-null object
# RISK_MM          142193 non-null float64
# RainTomorrow     142193 non-null object
# dtypes: float64(17), object(7)
# memory usage: 26.0+ MB

# %%
Xy_original.describe()
# Out:
#              MinTemp        MaxTemp  ...        Temp3pm        RISK_MM
# count  141556.000000  141871.000000  ...  139467.000000  142193.000000
# mean       12.186400      23.226784  ...      21.687235       2.360682
# std         6.403283       7.117618  ...       6.937594       8.477969
# min        -8.500000      -4.800000  ...      -5.400000       0.000000
# 25%         7.600000      17.900000  ...      16.600000       0.000000
# 50%        12.000000      22.600000  ...      21.100000       0.000000
# 75%        16.800000      28.200000  ...      26.400000       0.800000
# max        33.900000      48.100000  ...      46.700000     371.000000
#
# [8 rows x 17 columns]

# %%
Xy_original.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  316559

# %% [markdown]
# ### 1.d) Data Cleaning

# %%
# Standardize the class column to the name of targetVar if required
# Xy_original = Xy_original.rename(columns={'RainTomorrow': 'targetVar'})

# Dropping features
Xy_original.drop(columns=['Date','RISK_MM'], inplace=True)

# Impute missing values
Xy_original['MinTemp'].fillna(value=Xy_original['MinTemp'].median(), inplace=True)
Xy_original['MaxTemp'].fillna(value=Xy_original['MaxTemp'].median(), inplace=True)
Xy_original['Rainfall'].fillna(0.0, inplace=True)
Xy_original['Evaporation'].fillna(0.0, inplace=True)
Xy_original['Sunshine'].fillna(value=Xy_original['Sunshine'].median(), inplace=True)
Xy_original['WindGustDir'].fillna("UNKNOWN", inplace=True)
Xy_original['WindGustSpeed'].fillna(0, inplace=True)
Xy_original['WindDir9am'].fillna("UNKNOWN", inplace=True)
Xy_original['WindDir3pm'].fillna("UNKNOWN", inplace=True)
Xy_original['WindSpeed9am'].fillna(0, inplace=True)
Xy_original['WindSpeed3pm'].fillna(0, inplace=True)
Xy_original['Humidity9am'].fillna(value=Xy_original['Humidity9am'].median(), inplace=True)
Xy_original['Humidity3pm'].fillna(value=Xy_original['Humidity3pm'].median(), inplace=True)
Xy_original['Pressure9am'].fillna(value=Xy_original['Pressure9am'].median(), inplace=True)
Xy_original['Pressure3pm'].fillna(value=Xy_original['Pressure3pm'].median(), inplace=True)
Xy_original['Cloud9am'].fillna(value=Xy_original['Cloud9am'].median(), inplace=True)
Xy_original['Cloud3pm'].fillna(value=Xy_original['Cloud3pm'].median(), inplace=True)
Xy_original['Temp9am'].fillna(value=Xy_original['Temp9am'].median(), inplace=True)
Xy_original['Temp3pm'].fillna(value=Xy_original['Temp3pm'].median(), inplace=True)
Xy_original['RainToday'].fillna("No", inplace=True)

# Convert columns from one data type to another
# Xy_original.column_name = Xy_original.column_name.astype('int')
Xy_original['Location'] = Xy_original['Location'].astype('category')
Xy_original['WindGustDir'] = Xy_original['WindGustDir'].astype('category')
Xy_original['WindDir9am'] = Xy_original['WindDir9am'].astype('category')
Xy_original['WindDir3pm'] = Xy_original['WindDir3pm'].astype('category')
Xy_original['RainToday'] = Xy_original['RainToday'].astype('category')

# Convert features with Yes/No levels into categorical feature of 1/0
def reClassRainTomorrow(target):
    if (target == 'Yes'): return 1
    else: return 0
Xy_original['targetVar'] = Xy_original['RainTomorrow'].apply(reClassRainTomorrow)
Xy_original.drop(columns=['RainTomorrow'], inplace=True)

# Take a peek at the dataframe after cleaning
Xy_original.head(10)
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  ...  Temp9am  Temp3pm RainToday  targetVar
# 0   Albury     13.4     22.9       0.6  ...     16.9     21.8        No          0
# 1   Albury      7.4     25.1       0.0  ...     17.2     24.3        No          0
# 2   Albury     12.9     25.7       0.0  ...     21.0     23.2        No          0
# 3   Albury      9.2     28.0       0.0  ...     18.1     26.5        No          0
# 4   Albury     17.5     32.3       1.0  ...     17.8     29.7        No          0
# 5   Albury     14.6     29.7       0.2  ...     20.6     28.9        No          0
# 6   Albury     14.3     25.0       0.0  ...     18.1     24.6        No          0
# 7   Albury      7.7     26.7       0.0  ...     16.3     25.5        No          0
# 8   Albury      9.7     31.9       0.0  ...     18.3     30.2        No          1
# 9   Albury     13.1     30.1       1.4  ...     20.1     28.2       Yes          0
#
# [10 rows x 22 columns]

# %%
Xy_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 22 columns):
# Location         142193 non-null category
# MinTemp          142193 non-null float64
# MaxTemp          142193 non-null float64
# Rainfall         142193 non-null float64
# Evaporation      142193 non-null float64
# Sunshine         142193 non-null float64
# WindGustDir      142193 non-null category
# WindGustSpeed    142193 non-null float64
# WindDir9am       142193 non-null category
# WindDir3pm       142193 non-null category
# WindSpeed9am     142193 non-null float64
# WindSpeed3pm     142193 non-null float64
# Humidity9am      142193 non-null float64
# Humidity3pm      142193 non-null float64
# Pressure9am      142193 non-null float64
# Pressure3pm      142193 non-null float64
# Cloud9am         142193 non-null float64
# Cloud3pm         142193 non-null float64
# Temp9am          142193 non-null float64
# Temp3pm          142193 non-null float64
# RainToday        142193 non-null category
# targetVar        142193 non-null int64
# dtypes: category(5), float64(16), int64(1)
# memory usage: 19.1 MB

# %%
Xy_original.describe()
# Out:
#              MinTemp        MaxTemp  ...        Temp3pm      targetVar
# count  142193.000000  142193.000000  ...  142193.000000  142193.000000
# mean       12.185565      23.225365  ...      21.675977       0.224181
# std         6.388936       7.109617  ...       6.871243       0.417043
# min        -8.500000      -4.800000  ...      -5.400000       0.000000
# 25%         7.600000      17.900000  ...      16.700000       0.000000
# 50%        12.000000      22.600000  ...      21.100000       0.000000
# 75%        16.800000      28.200000  ...      26.300000       0.000000
# max        33.900000      48.100000  ...      46.700000       1.000000
#
# [8 rows x 17 columns]

# %%
Xy_original.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# targetVar        0
# dtype: int64

# %%
print('Total number of NaN in the dataframe: ', Xy_original.isnull().sum().sum())
# Out:
# Total number of NaN in the dataframe:  0

# %% [markdown]
# ### 1.e) Splitting Data into Attribute-only and Target-only Sets

# %%
# Use variable totCol to hold the number of columns in the dataframe
totCol = len(Xy_original.columns)

# Set up variable totAttr for the total number of attribute columns
totAttr = totCol-1

# targetCol variable indicates the column location of the target/class variable
# If the first column, set targetCol to 1. If the last column, set targetCol to totCol
# If (targetCol <> 1) and (targetCol <> totCol), be aware when slicing up the dataframes for visualization
targetCol = totCol

# %%
# We create attribute-only and target-only datasets (X_original and y_original)
# for various visualization and cleaning/transformation operations

if targetCol == totCol:
    X_original = Xy_original.iloc[:,0:totAttr]
    y_original = Xy_original.iloc[:,totAttr]
else:
    X_original = Xy_original.iloc[:,1:totCol]
    y_original = Xy_original.iloc[:,0]

print("Xy_original.shape: {} X_original.shape: {} y_original.shape: {}".format(Xy_original.shape, X_original.shape, y_original.shape))
# Out:
# Xy_original.shape: (142193, 22) X_original.shape: (142193, 21) y_original.shape: (142193,)

# %% [markdown]
# ### 1.f) Set up the parameters for data visualization

# %%
# Set up the number of row and columns for visualization display. dispRow * dispCol should be >= totAttr
dispCol = 4
if totAttr % dispCol == 0 :
    dispRow = totAttr // dispCol
else :
    dispRow = (totAttr // dispCol) + 1
    
# Set figure width to display the data visualization plots
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = dispCol*4
fig_size[1] = dispRow*4
plt.rcParams["figure.figsize"] = fig_size

# %%
if (notifyStatus): email_notify("Library and Data Loading completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 2. Summarize Data
# To gain a better understanding of the data that we have on-hand, we will leverage a number of descriptive statistics and data visualization techniques. The plan is to use the results to consider new questions, review assumptions, and validate hypotheses that we can investigate later with specialized models.

# %%
if (notifyStatus): email_notify("Data Summarization and Visualization has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 2.a) Descriptive Statistics

# %% [markdown]
# #### 2.a.i) Peek at the attribute columns

# %%
X_original.head(10)
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  ...  Cloud3pm  Temp9am Temp3pm  RainToday
# 0   Albury     13.4     22.9       0.6  ...       5.0     16.9    21.8         No
# 1   Albury      7.4     25.1       0.0  ...       5.0     17.2    24.3         No
# 2   Albury     12.9     25.7       0.0  ...       2.0     21.0    23.2         No
# 3   Albury      9.2     28.0       0.0  ...       5.0     18.1    26.5         No
# 4   Albury     17.5     32.3       1.0  ...       8.0     17.8    29.7         No
# 5   Albury     14.6     29.7       0.2  ...       5.0     20.6    28.9         No
# 6   Albury     14.3     25.0       0.0  ...       5.0     18.1    24.6         No
# 7   Albury      7.7     26.7       0.0  ...       5.0     16.3    25.5         No
# 8   Albury      9.7     31.9       0.0  ...       5.0     18.3    30.2         No
# 9   Albury     13.1     30.1       1.4  ...       5.0     20.1    28.2        Yes
#
# [10 rows x 21 columns]

# %% [markdown]
# #### 2.a.ii) Dimensions and attribute types

# %%
X_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 21 columns):
# Location         142193 non-null category
# MinTemp          142193 non-null float64
# MaxTemp          142193 non-null float64
# Rainfall         142193 non-null float64
# Evaporation      142193 non-null float64
# Sunshine         142193 non-null float64
# WindGustDir      142193 non-null category
# WindGustSpeed    142193 non-null float64
# WindDir9am       142193 non-null category
# WindDir3pm       142193 non-null category
# WindSpeed9am     142193 non-null float64
# WindSpeed3pm     142193 non-null float64
# Humidity9am      142193 non-null float64
# Humidity3pm      142193 non-null float64
# Pressure9am      142193 non-null float64
# Pressure3pm      142193 non-null float64
# Cloud9am         142193 non-null float64
# Cloud3pm         142193 non-null float64
# Temp9am          142193 non-null float64
# Temp3pm          142193 non-null float64
# RainToday        142193 non-null category
# dtypes: category(5), float64(16)
# memory usage: 18.0 MB

# %% [markdown]
# #### 2.a.iii) Statistical summary of the attributes

# %%
X_original.describe()
# Out:
#              MinTemp        MaxTemp  ...        Temp9am        Temp3pm
# count  142193.000000  142193.000000  ...  142193.000000  142193.000000
# mean       12.185565      23.225365  ...      16.985681      21.675977
# std         6.388936       7.109617  ...       6.472206       6.871243
# min        -8.500000      -4.800000  ...      -7.200000      -5.400000
# 25%         7.600000      17.900000  ...      12.300000      16.700000
# 50%        12.000000      22.600000  ...      16.700000      21.100000
# 75%        16.800000      28.200000  ...      21.500000      26.300000
# max        33.900000      48.100000  ...      40.200000      46.700000
#
# [8 rows x 16 columns]

# %% [markdown]
# #### 2.a.iv) Summarize the levels of the class attribute

# %%
Xy_original.groupby('targetVar').size()
# Out:
# targetVar
# 0    110316
# 1     31877
# dtype: int64

# %% [markdown]
# ### 2.b) Data Visualization

# %%
# Histograms for each attribute
X_original.hist(layout=(dispRow,dispCol))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
# Box and Whisker plot for each attribute
X_original.plot(kind='box', subplots=True, layout=(dispRow,dispCol))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
# Correlation matrix
fig = plt.figure(figsize=(16,12))
ax = fig.add_subplot(111)
correlations = X_original.corr(method='pearson')
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
plt.show()

# %%
if (notifyStatus): email_notify("Data Summarization and Visualization completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 3. Prepare Data
# Some dataset may require additional preparation activities that will best exposes the structure of the problem and the relationships between the input attributes and the output variable. Some data-prep tasks might include:
#
# * Cleaning data by removing duplicates, marking missing values and even imputing missing values.
# * Feature selection where redundant features may be removed.
# * Data transforms where attributes are scaled or redistributed in order to best expose the structure of the problem later to learning algorithms.

# %%
if (notifyStatus): email_notify("Data Cleaning and Transformation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ### 3.a) Feature Scaling and Data Pre-Processing

# %%
# Apply feature scaling techniques
X_original['MinTemp'] = preprocessing.scale(X_original['MinTemp'])
X_original['MaxTemp'] = preprocessing.scale(X_original['MaxTemp'])
X_original['Rainfall'] = preprocessing.scale(X_original['Rainfall'])
X_original['Evaporation'] = preprocessing.scale(X_original['Evaporation'])
X_original['Sunshine'] = preprocessing.scale(X_original['Sunshine'])
X_original['WindGustSpeed'] = preprocessing.scale(X_original['WindGustSpeed'])
X_original['WindSpeed9am'] = preprocessing.scale(X_original['WindSpeed9am'])
X_original['WindSpeed3pm'] = preprocessing.scale(X_original['WindSpeed3pm'])
X_original['Humidity9am'] = preprocessing.scale(X_original['Humidity9am'])
X_original['Humidity3pm'] = preprocessing.scale(X_original['Humidity3pm'])
X_original['Pressure9am'] = preprocessing.scale(X_original['Pressure9am'])
X_original['Pressure3pm'] = preprocessing.scale(X_original['Pressure3pm'])
X_original['Cloud9am'] = preprocessing.scale(X_original['Cloud9am'])
X_original['Cloud3pm'] = preprocessing.scale(X_original['Cloud3pm'])
X_original['Temp9am'] = preprocessing.scale(X_original['Temp9am'])
X_original['Temp3pm'] = preprocessing.scale(X_original['Temp3pm'])
    
print(X_original.head(-10))
# Out:
#        Location   MinTemp   MaxTemp  ...   Temp9am   Temp3pm  RainToday
# 0        Albury  0.190085 -0.045764  ... -0.013238  0.018050         No
# 1        Albury -0.749042  0.263677  ...  0.033114  0.381886         No
# 2        Albury  0.111824  0.348070  ...  0.620242  0.221798         No
# 3        Albury -0.467304  0.671577  ...  0.172171  0.702062         No
# 4        Albury  0.831821  1.276393  ...  0.125818  1.167773         No
# ...         ...       ...       ...  ...       ...       ...        ...
# 142178    Uluru -1.406431 -0.650581  ... -1.357452 -0.622303         No
# 142179    Uluru -1.531648 -0.580253  ... -1.388354 -0.418554         No
# 142180    Uluru -1.109041 -0.495860  ... -1.311100 -0.360340         No
# 142181    Uluru -1.515996 -0.284878  ... -1.032987 -0.200252         No
# 142182    Uluru -1.547300 -0.256747  ... -1.249297 -0.200252         No
#
# [142183 rows x 21 columns]

# %%
# Histograms for each attribute
X_original.hist(layout=(dispRow,dispCol))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ### 3.b) Apply One-Hot-Encoding to Categorical Features

# %%
# Perform one-hot-encoding on the categorical attributes
X_original = pd.get_dummies(X_original)
X_original.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 118 columns):
# MinTemp                      float64
# MaxTemp                      float64
# Rainfall                     float64
# Evaporation                  float64
# Sunshine                     float64
# WindGustSpeed                float64
# WindSpeed9am                 float64
# WindSpeed3pm                 float64
# Humidity9am                  float64
# Humidity3pm                  float64
# Pressure9am                  float64
# Pressure3pm                  float64
# Cloud9am                     float64
# Cloud3pm                     float64
# Temp9am                      float64
# Temp3pm                      float64
# Location_Adelaide            uint8
# Location_Albany              uint8
# Location_Albury              uint8
# Location_AliceSprings        uint8
# Location_BadgerysCreek       uint8
# Location_Ballarat            uint8
# Location_Bendigo             uint8
# Location_Brisbane            uint8
# Location_Cairns              uint8
# Location_Canberra            uint8
# Location_Cobar               uint8
# Location_CoffsHarbour        uint8
# Location_Dartmoor            uint8
# Location_Darwin              uint8
# Location_GoldCoast           uint8
# Location_Hobart              uint8
# Location_Katherine           uint8
# Location_Launceston          uint8
# Location_Melbourne           uint8
# Location_MelbourneAirport    uint8
# Location_Mildura             uint8
# Location_Moree               uint8
# Location_MountGambier        uint8
# Location_MountGinini         uint8
# Location_Newcastle           uint8
# Location_Nhil                uint8
# Location_NorahHead           uint8
# Location_NorfolkIsland       uint8
# Location_Nuriootpa           uint8
# Location_PearceRAAF          uint8
# Location_Penrith             uint8
# Location_Perth               uint8
# Location_PerthAirport        uint8
# Location_Portland            uint8
# Location_Richmond            uint8
# Location_Sale                uint8
# Location_SalmonGums          uint8
# Location_Sydney              uint8
# Location_SydneyAirport       uint8
# Location_Townsville          uint8
# Location_Tuggeranong         uint8
# Location_Uluru               uint8
# Location_WaggaWagga          uint8
# Location_Walpole             uint8
# Location_Watsonia            uint8
# Location_Williamtown         uint8
# Location_Witchcliffe         uint8
# Location_Wollongong          uint8
# Location_Woomera             uint8
# WindGustDir_E                uint8
# WindGustDir_ENE              uint8
# WindGustDir_ESE              uint8
# WindGustDir_N                uint8
# WindGustDir_NE               uint8
# WindGustDir_NNE              uint8
# WindGustDir_NNW              uint8
# WindGustDir_NW               uint8
# WindGustDir_S                uint8
# WindGustDir_SE               uint8
# WindGustDir_SSE              uint8
# WindGustDir_SSW              uint8
# WindGustDir_SW               uint8
# WindGustDir_UNKNOWN          uint8
# WindGustDir_W                uint8
# WindGustDir_WNW              uint8
# WindGustDir_WSW              uint8
# WindDir9am_E                 uint8
# WindDir9am_ENE               uint8
# WindDir9am_ESE               uint8
# WindDir9am_N                 uint8
# WindDir9am_NE                uint8
# WindDir9am_NNE               uint8
# WindDir9am_NNW               uint8
# WindDir9am_NW                uint8
# WindDir9am_S                 uint8
# WindDir9am_SE                uint8
# WindDir9am_SSE               uint8
# WindDir9am_SSW               uint8
# WindDir9am_SW                uint8
# WindDir9am_UNKNOWN           uint8
# WindDir9am_W                 uint8
# WindDir9am_WNW               uint8
# WindDir9am_WSW               uint8
# WindDir3pm_E                 uint8
# WindDir3pm_ENE               uint8
# WindDir3pm_ESE               uint8
# WindDir3pm_N                 uint8
# WindDir3pm_NE                uint8
# WindDir3pm_NNE               uint8
# WindDir3pm_NNW               uint8
# WindDir3pm_NW                uint8
# WindDir3pm_S                 uint8
# WindDir3pm_SE                uint8
# WindDir3pm_SSE               uint8
# WindDir3pm_SSW               uint8
# WindDir3pm_SW                uint8
# WindDir3pm_UNKNOWN           uint8
# WindDir3pm_W                 uint8
# WindDir3pm_WNW               uint8
# WindDir3pm_WSW               uint8
# RainToday_No                 uint8
# RainToday_Yes                uint8
# dtypes: float64(16), uint8(102)
# memory usage: 31.2 MB

# %% [markdown]
# ### 3.c) Training Data Balancing

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.d) Feature Selection

# %%
# Not applicable for this iteration of the project

# %% [markdown]
# ### 3.e) Display the Final Datasets for Model-Building

# %%
# Split the data further into training and test datasets
if (splitDataset):
    X_train_df, X_test_df, y_train_df, y_test_df = train_test_split(X_original, y_original, test_size=splitPercentage, 
                                                                    stratify=y_original, random_state=seedNum)
else:
    X_train_df, y_train_df = X_original, y_original
    X_test_df, y_test_df = X_original, y_original
print("X_train_df.shape: {} y_train_df.shape: {}".format(X_train_df.shape, y_train_df.shape))
print("X_test_df.shape: {} y_test_df.shape: {}".format(X_test_df.shape, y_test_df.shape))
# Out:
# X_train_df.shape: (106644, 118) y_train_df.shape: (106644,)
# X_test_df.shape: (35549, 118) y_test_df.shape: (35549,)

# %%
# Finalize the training and testing datasets for the modeling activities
X_train = X_train_df.to_numpy()
y_train = y_train_df.to_numpy()
X_test = X_test_df.to_numpy()
y_test = y_test_df.to_numpy()
print("X_train.shape: {} y_train.shape: {}".format(X_train.shape, y_train.shape))
print("X_test.shape: {} y_test.shape: {}".format(X_test.shape, y_test.shape))
# Out:
# X_train.shape: (106644, 118) y_train.shape: (106644,)
# X_test.shape: (35549, 118) y_test.shape: (35549,)

# %%
if (notifyStatus): email_notify("Data Cleaning and Transformation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 4. Model and Evaluate Algorithms

# %%
# Define the baseline MLP model
def create_model_4A():
    default_model = Sequential()
    default_model.add(Dense(8, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=default_kernel_init))
    default_model.add(Dense(1, activation='sigmoid', kernel_initializer=default_kernel_init))
    default_model.compile(loss=default_loss, optimizer=default_optimizer, metrics=default_metrics)
    return default_model

# Initialize and fit the model
startTimeModule = datetime.now()
reset_random(seedNum)
baseline_model_4A = create_model_4A()
extra_epochs = 0
baseline_hist = baseline_model_4A.fit(X_train, y_train, epochs=(default_epoch + extra_epochs), batch_size=default_batch, validation_data=(X_test, y_test), verbose=1)
print('Total time for model fitting:', (datetime.now() - startTimeModule), '\n')
if (notifyStatus): email_notify("Model 4A processing completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))
# Out:
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3725 - accuracy: 0.8416 - val_loss: 0.3461 - val_accuracy: 0.8506
# Epoch 2/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3440 - accuracy: 0.8512 - val_loss: 0.3402 - val_accuracy: 0.8530
# Epoch 3/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3379 - accuracy: 0.8538 - val_loss: 0.3363 - val_accuracy: 0.8547
# Epoch 4/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3343 - accuracy: 0.8549 - val_loss: 0.3341 - val_accuracy: 0.8568
# Epoch 5/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3317 - accuracy: 0.8569 - val_loss: 0.3338 - val_accuracy: 0.8559
# Epoch 6/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3298 - accuracy: 0.8579 - val_loss: 0.3305 - val_accuracy: 0.8595
# Epoch 7/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3281 - accuracy: 0.8592 - val_loss: 0.3323 - val_accuracy: 0.8586
# Epoch 8/20
# 106644/106644 [==============================] - 10s 89us/sample - loss: 0.3266 - accuracy: 0.8592 - val_loss: 0.3286 - val_accuracy: 0.8594
# Epoch 9/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3256 - accuracy: 0.8599 - val_loss: 0.3283 - val_accuracy: 0.8599
# Epoch 10/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3248 - accuracy: 0.8602 - val_loss: 0.3277 - val_accuracy: 0.8600
# Epoch 11/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3238 - accuracy: 0.8607 - val_loss: 0.3277 - val_accuracy: 0.8601
# Epoch 12/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3232 - accuracy: 0.8608 - val_loss: 0.3258 - val_accuracy: 0.8601
# Epoch 13/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3227 - accuracy: 0.8611 - val_loss: 0.3260 - val_accuracy: 0.8610
# Epoch 14/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3220 - accuracy: 0.8614 - val_loss: 0.3267 - val_accuracy: 0.8608
# Epoch 15/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3215 - accuracy: 0.8616 - val_loss: 0.3274 - val_accuracy: 0.8591
# Epoch 16/20
# 106644/106644 [==============================] - 10s 89us/sample - loss: 0.3210 - accuracy: 0.8616 - val_loss: 0.3258 - val_accuracy: 0.8604
# Epoch 17/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3204 - accuracy: 0.8619 - val_loss: 0.3265 - val_accuracy: 0.8596
# Epoch 18/20
# 106644/106644 [==============================] - 10s 89us/sample - loss: 0.3201 - accuracy: 0.8622 - val_loss: 0.3249 - val_accuracy: 0.8607
# Epoch 19/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3197 - accuracy: 0.8625 - val_loss: 0.3249 - val_accuracy: 0.8605
# Epoch 20/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3195 - accuracy: 0.8629 - val_loss: 0.3245 - val_accuracy: 0.8610
# Total time for model fitting: 0:03:13.619061

# %%
# Summarize model training hisotry
begin_epoch = 0
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(baseline_hist.history['accuracy'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_accuracy'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(baseline_hist.history['loss'][begin_epoch:], color='blue', label='train')
plt.plot(baseline_hist.history['val_loss'][begin_epoch:], color='red', label='test')
plt.title('Baseline Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Section 5. Model Tuning and Improvement

# %%
if (notifyStatus): email_notify("Model Tuning and Imprvement has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
# Define the customized model for tuning
def create_customized_model(optimizer, kernel_init):
    customized_model = Sequential()
    customized_model.add(Dense(8, input_shape=(X_train.shape[1],), activation='relu', kernel_initializer=kernel_init))
    customized_model.add(Dense(1, activation='sigmoid', kernel_initializer=kernel_init))
    customized_model.compile(loss=default_loss, optimizer=optimizer, metrics=default_metrics)
    return customized_model

# %%
startTimeModule = datetime.now()

# Set up grid search using different epochs, batch sizes, and optimizers
optz_1 = tf.keras.optimizers.Adam(learning_rate=0.001)
optz_2 = tf.keras.optimizers.RMSprop(learning_rate=0.001)
optz_3 = tf.keras.optimizers.SGD(learning_rate=0.01)
optimizer_grid = [optz_1, optz_2, optz_3]
print('Optimizer candidate #1 has the object ID of', optz_1)
print('Optimizer candidate #2 has the object ID of', optz_2)
print('Optimizer candidate #3 has the object ID of', optz_3)

init_1 = tf.initializers.RandomNormal(seed=seedNum)
init_2 = tf.initializers.Orthogonal(seed=seedNum)
init_3 = tf.initializers.GlorotNormal(seed=seedNum)
init_grid = [init_1, init_2, init_3]
print('Initializer candidate #1 has the object ID of', init_1)
print('Initializer candidate #2 has the object ID of', init_2)
print('Initializer candidate #3 has the object ID of', init_3)

epoch_grid = [default_epoch]
batch_grid = [int(default_batch/2), default_batch, int(default_batch*2)]

best_score = 0
grid_iteration = 0
best_iteration = 0
best_optimizer = default_optimizer
best_kernel_init = default_kernel_init
best_epoch = default_epoch
best_batch = default_batch

for optimizer in optimizer_grid:
    for kernel_init in init_grid:
        for epoch_num in epoch_grid:
            for batch_num in batch_grid:
                print('\nForming the grid-search model #%d using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
                      % (grid_iteration, optimizer, kernel_init, epoch_num, batch_num))
                reset_random(seedNum)
                grid_model = create_customized_model(optimizer, kernel_init)
                grid_hist = grid_model.fit(X_train, y_train, epochs=epoch_num, batch_size=batch_num, 
                                       validation_data=(X_test, y_test), verbose=1)
                if(grid_hist.history['val_accuracy'][-1] > best_score):
                    best_score = grid_hist.history['val_accuracy'][-1]
                    best_iteration = grid_iteration
                    best_optimizer = optimizer
                    best_kernel_init = kernel_init
                    best_epoch = epoch_num
                    best_batch = batch_num
                grid_iteration = grid_iteration + 1

# summarize results
print("\nBest score (highest validation accuracy) found via grid search: accuracy=%f from model iteration #%d"
      % (best_score, best_iteration))
print('The best modeling parameters are: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
print('Total time for performing grid-search of the best parameters:', (datetime.now() - startTimeModule))
# Out:
# Optimizer candidate #1 has the object ID of <tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>
# Optimizer candidate #2 has the object ID of <tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>
# Optimizer candidate #3 has the object ID of <tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7fc0442a0550>
# Initializer candidate #1 has the object ID of <tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>
# Initializer candidate #2 has the object ID of <tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>
# Initializer candidate #2 has the object ID of <tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>
#
# Forming the grid-search model #0 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 20s 186us/sample - loss: 0.3640 - accuracy: 0.8435 - val_loss: 0.3431 - val_accuracy: 0.8520
# Epoch 2/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3414 - accuracy: 0.8519 - val_loss: 0.3383 - val_accuracy: 0.8536
# Epoch 3/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3356 - accuracy: 0.8547 - val_loss: 0.3345 - val_accuracy: 0.8561
# Epoch 4/20
# 106644/106644 [==============================] - 19s 183us/sample - loss: 0.3323 - accuracy: 0.8567 - val_loss: 0.3326 - val_accuracy: 0.8578
# Epoch 5/20
# 106644/106644 [==============================] - 19s 179us/sample - loss: 0.3300 - accuracy: 0.8572 - val_loss: 0.3328 - val_accuracy: 0.8567
# Epoch 6/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3285 - accuracy: 0.8573 - val_loss: 0.3297 - val_accuracy: 0.8595
# Epoch 7/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3271 - accuracy: 0.8591 - val_loss: 0.3321 - val_accuracy: 0.8584
# Epoch 8/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3258 - accuracy: 0.8596 - val_loss: 0.3285 - val_accuracy: 0.8589
# Epoch 9/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3248 - accuracy: 0.8599 - val_loss: 0.3272 - val_accuracy: 0.8590
# Epoch 10/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3236 - accuracy: 0.8609 - val_loss: 0.3273 - val_accuracy: 0.8588
# Epoch 11/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3226 - accuracy: 0.8609 - val_loss: 0.3281 - val_accuracy: 0.8593
# Epoch 12/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3218 - accuracy: 0.8611 - val_loss: 0.3255 - val_accuracy: 0.8601
# Epoch 13/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3214 - accuracy: 0.8613 - val_loss: 0.3255 - val_accuracy: 0.8601
# Epoch 14/20
# 106644/106644 [==============================] - 19s 183us/sample - loss: 0.3206 - accuracy: 0.8619 - val_loss: 0.3279 - val_accuracy: 0.8601
# Epoch 15/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3202 - accuracy: 0.8619 - val_loss: 0.3265 - val_accuracy: 0.8592
# Epoch 16/20
# 106644/106644 [==============================] - 20s 192us/sample - loss: 0.3199 - accuracy: 0.8626 - val_loss: 0.3263 - val_accuracy: 0.8586
# Epoch 17/20
# 106644/106644 [==============================] - 20s 187us/sample - loss: 0.3193 - accuracy: 0.8627 - val_loss: 0.3264 - val_accuracy: 0.8608
# Epoch 18/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3191 - accuracy: 0.8625 - val_loss: 0.3250 - val_accuracy: 0.8603
# Epoch 19/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3186 - accuracy: 0.8629 - val_loss: 0.3248 - val_accuracy: 0.8600
# Epoch 20/20
# 106644/106644 [==============================] - 19s 183us/sample - loss: 0.3186 - accuracy: 0.8628 - val_loss: 0.3241 - val_accuracy: 0.8600
#
# Forming the grid-search model #1 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3575 - accuracy: 0.8447 - val_loss: 0.3442 - val_accuracy: 0.8526
# Epoch 2/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3422 - accuracy: 0.8522 - val_loss: 0.3396 - val_accuracy: 0.8534
# Epoch 3/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3368 - accuracy: 0.8547 - val_loss: 0.3360 - val_accuracy: 0.8546
# Epoch 4/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3333 - accuracy: 0.8562 - val_loss: 0.3343 - val_accuracy: 0.8564
# Epoch 5/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3308 - accuracy: 0.8576 - val_loss: 0.3336 - val_accuracy: 0.8566
# Epoch 6/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3290 - accuracy: 0.8586 - val_loss: 0.3309 - val_accuracy: 0.8591
# Epoch 7/20
# 106644/106644 [==============================] - 11s 98us/sample - loss: 0.3275 - accuracy: 0.8596 - val_loss: 0.3329 - val_accuracy: 0.8588
# Epoch 8/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3261 - accuracy: 0.8594 - val_loss: 0.3294 - val_accuracy: 0.8602
# Epoch 9/20
# 106644/106644 [==============================] - 11s 100us/sample - loss: 0.3251 - accuracy: 0.8598 - val_loss: 0.3289 - val_accuracy: 0.8596
# Epoch 10/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3243 - accuracy: 0.8609 - val_loss: 0.3284 - val_accuracy: 0.8597
# Epoch 11/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3232 - accuracy: 0.8606 - val_loss: 0.3284 - val_accuracy: 0.8594
# Epoch 12/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3227 - accuracy: 0.8610 - val_loss: 0.3267 - val_accuracy: 0.8608
# Epoch 13/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3223 - accuracy: 0.8613 - val_loss: 0.3266 - val_accuracy: 0.8602
# Epoch 14/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3216 - accuracy: 0.8617 - val_loss: 0.3274 - val_accuracy: 0.8610
# Epoch 15/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3212 - accuracy: 0.8621 - val_loss: 0.3281 - val_accuracy: 0.8596
# Epoch 16/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3208 - accuracy: 0.8618 - val_loss: 0.3270 - val_accuracy: 0.8601
# Epoch 17/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3202 - accuracy: 0.8627 - val_loss: 0.3281 - val_accuracy: 0.8603
# Epoch 18/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3199 - accuracy: 0.8629 - val_loss: 0.3263 - val_accuracy: 0.8613
# Epoch 19/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3195 - accuracy: 0.8628 - val_loss: 0.3263 - val_accuracy: 0.8615
# Epoch 20/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3194 - accuracy: 0.8629 - val_loss: 0.3256 - val_accuracy: 0.8617
#
# Forming the grid-search model #2 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3608 - accuracy: 0.8442 - val_loss: 0.3451 - val_accuracy: 0.8523
# Epoch 2/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3435 - accuracy: 0.8511 - val_loss: 0.3405 - val_accuracy: 0.8533
# Epoch 3/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3386 - accuracy: 0.8537 - val_loss: 0.3373 - val_accuracy: 0.8547
# Epoch 4/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3352 - accuracy: 0.8545 - val_loss: 0.3355 - val_accuracy: 0.8549
# Epoch 5/20
# 106644/106644 [==============================] - 6s 53us/sample - loss: 0.3327 - accuracy: 0.8558 - val_loss: 0.3349 - val_accuracy: 0.8549
# Epoch 6/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3310 - accuracy: 0.8569 - val_loss: 0.3324 - val_accuracy: 0.8571
# Epoch 7/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3294 - accuracy: 0.8576 - val_loss: 0.3329 - val_accuracy: 0.8577
# Epoch 8/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3279 - accuracy: 0.8581 - val_loss: 0.3304 - val_accuracy: 0.8573
# Epoch 9/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3271 - accuracy: 0.8581 - val_loss: 0.3302 - val_accuracy: 0.8584
# Epoch 10/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3263 - accuracy: 0.8591 - val_loss: 0.3296 - val_accuracy: 0.8572
# Epoch 11/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3254 - accuracy: 0.8587 - val_loss: 0.3294 - val_accuracy: 0.8584
# Epoch 12/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3248 - accuracy: 0.8593 - val_loss: 0.3281 - val_accuracy: 0.8578
# Epoch 13/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3244 - accuracy: 0.8593 - val_loss: 0.3284 - val_accuracy: 0.8577
# Epoch 14/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3237 - accuracy: 0.8596 - val_loss: 0.3280 - val_accuracy: 0.8590
# Epoch 15/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3231 - accuracy: 0.8601 - val_loss: 0.3297 - val_accuracy: 0.8583
# Epoch 16/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3228 - accuracy: 0.8600 - val_loss: 0.3274 - val_accuracy: 0.8591
# Epoch 17/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3221 - accuracy: 0.8602 - val_loss: 0.3287 - val_accuracy: 0.8591
# Epoch 18/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3218 - accuracy: 0.8606 - val_loss: 0.3271 - val_accuracy: 0.8595
# Epoch 19/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3213 - accuracy: 0.8608 - val_loss: 0.3264 - val_accuracy: 0.8598
# Epoch 20/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3211 - accuracy: 0.8616 - val_loss: 0.3261 - val_accuracy: 0.8606
#
# Forming the grid-search model #3 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 20s 186us/sample - loss: 0.3541 - accuracy: 0.8460 - val_loss: 0.3413 - val_accuracy: 0.8534
# Epoch 2/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3390 - accuracy: 0.8538 - val_loss: 0.3381 - val_accuracy: 0.8550
# Epoch 3/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3333 - accuracy: 0.8563 - val_loss: 0.3334 - val_accuracy: 0.8567
# Epoch 4/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3297 - accuracy: 0.8576 - val_loss: 0.3321 - val_accuracy: 0.8581
# Epoch 5/20
# 106644/106644 [==============================] - 20s 185us/sample - loss: 0.3272 - accuracy: 0.8593 - val_loss: 0.3312 - val_accuracy: 0.8574
# Epoch 6/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3256 - accuracy: 0.8597 - val_loss: 0.3283 - val_accuracy: 0.8593
# Epoch 7/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3239 - accuracy: 0.8610 - val_loss: 0.3312 - val_accuracy: 0.8588
# Epoch 8/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3227 - accuracy: 0.8614 - val_loss: 0.3275 - val_accuracy: 0.8596
# Epoch 9/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3218 - accuracy: 0.8619 - val_loss: 0.3273 - val_accuracy: 0.8589
# Epoch 10/20
# 106644/106644 [==============================] - 20s 185us/sample - loss: 0.3213 - accuracy: 0.8622 - val_loss: 0.3271 - val_accuracy: 0.8589
# Epoch 11/20
# 106644/106644 [==============================] - 19s 178us/sample - loss: 0.3203 - accuracy: 0.8624 - val_loss: 0.3286 - val_accuracy: 0.8598
# Epoch 12/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3201 - accuracy: 0.8628 - val_loss: 0.3258 - val_accuracy: 0.8609
# Epoch 13/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3196 - accuracy: 0.8632 - val_loss: 0.3255 - val_accuracy: 0.8602
# Epoch 14/20
# 106644/106644 [==============================] - 20s 187us/sample - loss: 0.3192 - accuracy: 0.8628 - val_loss: 0.3266 - val_accuracy: 0.8608
# Epoch 15/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3188 - accuracy: 0.8635 - val_loss: 0.3261 - val_accuracy: 0.8598
# Epoch 16/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3184 - accuracy: 0.8636 - val_loss: 0.3260 - val_accuracy: 0.8597
# Epoch 17/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3180 - accuracy: 0.8633 - val_loss: 0.3261 - val_accuracy: 0.8604
# Epoch 18/20
# 106644/106644 [==============================] - 20s 185us/sample - loss: 0.3179 - accuracy: 0.8644 - val_loss: 0.3248 - val_accuracy: 0.8606
# Epoch 19/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3175 - accuracy: 0.8637 - val_loss: 0.3259 - val_accuracy: 0.8597
# Epoch 20/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3174 - accuracy: 0.8642 - val_loss: 0.3245 - val_accuracy: 0.8608
#
# Forming the grid-search model #4 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3557 - accuracy: 0.8450 - val_loss: 0.3422 - val_accuracy: 0.8533
# Epoch 2/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3400 - accuracy: 0.8536 - val_loss: 0.3380 - val_accuracy: 0.8541
# Epoch 3/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3344 - accuracy: 0.8554 - val_loss: 0.3342 - val_accuracy: 0.8567
# Epoch 4/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3307 - accuracy: 0.8569 - val_loss: 0.3327 - val_accuracy: 0.8574
# Epoch 5/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3282 - accuracy: 0.8588 - val_loss: 0.3322 - val_accuracy: 0.8562
# Epoch 6/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3265 - accuracy: 0.8588 - val_loss: 0.3296 - val_accuracy: 0.8588
# Epoch 7/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3250 - accuracy: 0.8596 - val_loss: 0.3311 - val_accuracy: 0.8586
# Epoch 8/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3237 - accuracy: 0.8604 - val_loss: 0.3277 - val_accuracy: 0.8588
# Epoch 9/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3227 - accuracy: 0.8609 - val_loss: 0.3279 - val_accuracy: 0.8581
# Epoch 10/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3221 - accuracy: 0.8609 - val_loss: 0.3279 - val_accuracy: 0.8584
# Epoch 11/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3211 - accuracy: 0.8613 - val_loss: 0.3283 - val_accuracy: 0.8593
# Epoch 12/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3207 - accuracy: 0.8618 - val_loss: 0.3264 - val_accuracy: 0.8598
# Epoch 13/20
# 106644/106644 [==============================] - 10s 91us/sample - loss: 0.3203 - accuracy: 0.8621 - val_loss: 0.3260 - val_accuracy: 0.8602
# Epoch 14/20
# 106644/106644 [==============================] - 10s 92us/sample - loss: 0.3199 - accuracy: 0.8624 - val_loss: 0.3267 - val_accuracy: 0.8611
# Epoch 15/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3195 - accuracy: 0.8624 - val_loss: 0.3277 - val_accuracy: 0.8589
# Epoch 16/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3192 - accuracy: 0.8628 - val_loss: 0.3266 - val_accuracy: 0.8586
# Epoch 17/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3187 - accuracy: 0.8635 - val_loss: 0.3278 - val_accuracy: 0.8594
# Epoch 18/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3186 - accuracy: 0.8630 - val_loss: 0.3257 - val_accuracy: 0.8604
# Epoch 19/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3182 - accuracy: 0.8633 - val_loss: 0.3264 - val_accuracy: 0.8591
# Epoch 20/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3182 - accuracy: 0.8635 - val_loss: 0.3256 - val_accuracy: 0.8601
#
# Forming the grid-search model #5 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3589 - accuracy: 0.8439 - val_loss: 0.3436 - val_accuracy: 0.8528
# Epoch 2/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3420 - accuracy: 0.8524 - val_loss: 0.3389 - val_accuracy: 0.8536
# Epoch 3/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3367 - accuracy: 0.8549 - val_loss: 0.3355 - val_accuracy: 0.8559
# Epoch 4/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3331 - accuracy: 0.8563 - val_loss: 0.3336 - val_accuracy: 0.8568
# Epoch 5/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3305 - accuracy: 0.8577 - val_loss: 0.3331 - val_accuracy: 0.8562
# Epoch 6/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3286 - accuracy: 0.8584 - val_loss: 0.3305 - val_accuracy: 0.8578
# Epoch 7/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3268 - accuracy: 0.8594 - val_loss: 0.3309 - val_accuracy: 0.8581
# Epoch 8/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3251 - accuracy: 0.8599 - val_loss: 0.3287 - val_accuracy: 0.8580
# Epoch 9/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3242 - accuracy: 0.8604 - val_loss: 0.3283 - val_accuracy: 0.8583
# Epoch 10/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3233 - accuracy: 0.8607 - val_loss: 0.3279 - val_accuracy: 0.8587
# Epoch 11/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3224 - accuracy: 0.8612 - val_loss: 0.3278 - val_accuracy: 0.8593
# Epoch 12/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3218 - accuracy: 0.8614 - val_loss: 0.3266 - val_accuracy: 0.8601
# Epoch 13/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3216 - accuracy: 0.8615 - val_loss: 0.3266 - val_accuracy: 0.8587
# Epoch 14/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3210 - accuracy: 0.8615 - val_loss: 0.3265 - val_accuracy: 0.8591
# Epoch 15/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3205 - accuracy: 0.8619 - val_loss: 0.3282 - val_accuracy: 0.8582
# Epoch 16/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3201 - accuracy: 0.8623 - val_loss: 0.3262 - val_accuracy: 0.8593
# Epoch 17/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3195 - accuracy: 0.8618 - val_loss: 0.3282 - val_accuracy: 0.8592
# Epoch 18/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3194 - accuracy: 0.8620 - val_loss: 0.3261 - val_accuracy: 0.8599
# Epoch 19/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3189 - accuracy: 0.8625 - val_loss: 0.3261 - val_accuracy: 0.8592
# Epoch 20/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3188 - accuracy: 0.8625 - val_loss: 0.3257 - val_accuracy: 0.8597
#
# Forming the grid-search model #6 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 20s 186us/sample - loss: 0.3529 - accuracy: 0.8462 - val_loss: 0.3402 - val_accuracy: 0.8543
# Epoch 2/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3374 - accuracy: 0.8547 - val_loss: 0.3369 - val_accuracy: 0.8550
# Epoch 3/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3322 - accuracy: 0.8569 - val_loss: 0.3336 - val_accuracy: 0.8564
# Epoch 4/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3290 - accuracy: 0.8577 - val_loss: 0.3317 - val_accuracy: 0.8578
# Epoch 5/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3265 - accuracy: 0.8588 - val_loss: 0.3309 - val_accuracy: 0.8577
# Epoch 6/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3249 - accuracy: 0.8593 - val_loss: 0.3285 - val_accuracy: 0.8593
# Epoch 7/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3234 - accuracy: 0.8603 - val_loss: 0.3305 - val_accuracy: 0.8580
# Epoch 8/20
# 106644/106644 [==============================] - 20s 185us/sample - loss: 0.3221 - accuracy: 0.8606 - val_loss: 0.3269 - val_accuracy: 0.8593
# Epoch 9/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3211 - accuracy: 0.8613 - val_loss: 0.3269 - val_accuracy: 0.8590
# Epoch 10/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3205 - accuracy: 0.8615 - val_loss: 0.3266 - val_accuracy: 0.8602
# Epoch 11/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3197 - accuracy: 0.8617 - val_loss: 0.3285 - val_accuracy: 0.8604
# Epoch 12/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3194 - accuracy: 0.8617 - val_loss: 0.3250 - val_accuracy: 0.8609
# Epoch 13/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3192 - accuracy: 0.8621 - val_loss: 0.3249 - val_accuracy: 0.8604
# Epoch 14/20
# 106644/106644 [==============================] - 19s 181us/sample - loss: 0.3187 - accuracy: 0.8615 - val_loss: 0.3271 - val_accuracy: 0.8608
# Epoch 15/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3184 - accuracy: 0.8622 - val_loss: 0.3261 - val_accuracy: 0.8604
# Epoch 16/20
# 106644/106644 [==============================] - 20s 184us/sample - loss: 0.3180 - accuracy: 0.8628 - val_loss: 0.3263 - val_accuracy: 0.8586
# Epoch 17/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3178 - accuracy: 0.8633 - val_loss: 0.3270 - val_accuracy: 0.8597
# Epoch 18/20
# 106644/106644 [==============================] - 19s 182us/sample - loss: 0.3176 - accuracy: 0.8634 - val_loss: 0.3247 - val_accuracy: 0.8617
# Epoch 19/20
# 106644/106644 [==============================] - 20s 185us/sample - loss: 0.3173 - accuracy: 0.8638 - val_loss: 0.3254 - val_accuracy: 0.8608
# Epoch 20/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3174 - accuracy: 0.8633 - val_loss: 0.3244 - val_accuracy: 0.8605
#
# Forming the grid-search model #7 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3549 - accuracy: 0.8450 - val_loss: 0.3415 - val_accuracy: 0.8536
# Epoch 2/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3387 - accuracy: 0.8535 - val_loss: 0.3380 - val_accuracy: 0.8547
# Epoch 3/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3338 - accuracy: 0.8560 - val_loss: 0.3352 - val_accuracy: 0.8550
# Epoch 4/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3308 - accuracy: 0.8565 - val_loss: 0.3336 - val_accuracy: 0.8568
# Epoch 5/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3286 - accuracy: 0.8575 - val_loss: 0.3335 - val_accuracy: 0.8557
# Epoch 6/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3272 - accuracy: 0.8584 - val_loss: 0.3308 - val_accuracy: 0.8579
# Epoch 7/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3256 - accuracy: 0.8592 - val_loss: 0.3325 - val_accuracy: 0.8576
# Epoch 8/20
# 106644/106644 [==============================] - 11s 100us/sample - loss: 0.3243 - accuracy: 0.8594 - val_loss: 0.3296 - val_accuracy: 0.8587
# Epoch 9/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3232 - accuracy: 0.8602 - val_loss: 0.3289 - val_accuracy: 0.8589
# Epoch 10/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3225 - accuracy: 0.8603 - val_loss: 0.3286 - val_accuracy: 0.8584
# Epoch 11/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3212 - accuracy: 0.8611 - val_loss: 0.3293 - val_accuracy: 0.8604
# Epoch 12/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3208 - accuracy: 0.8612 - val_loss: 0.3266 - val_accuracy: 0.8604
# Epoch 13/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3203 - accuracy: 0.8613 - val_loss: 0.3267 - val_accuracy: 0.8595
# Epoch 14/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3196 - accuracy: 0.8612 - val_loss: 0.3280 - val_accuracy: 0.8596
# Epoch 15/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3191 - accuracy: 0.8617 - val_loss: 0.3281 - val_accuracy: 0.8585
# Epoch 16/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3187 - accuracy: 0.8622 - val_loss: 0.3271 - val_accuracy: 0.8590
# Epoch 17/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3182 - accuracy: 0.8623 - val_loss: 0.3294 - val_accuracy: 0.8588
# Epoch 18/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3181 - accuracy: 0.8621 - val_loss: 0.3259 - val_accuracy: 0.8606
# Epoch 19/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3177 - accuracy: 0.8624 - val_loss: 0.3263 - val_accuracy: 0.8592
# Epoch 20/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3176 - accuracy: 0.8629 - val_loss: 0.3259 - val_accuracy: 0.8590
#
# Forming the grid-search model #8 using: optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fc0442a0978>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3583 - accuracy: 0.8435 - val_loss: 0.3435 - val_accuracy: 0.8531
# Epoch 2/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3405 - accuracy: 0.8525 - val_loss: 0.3391 - val_accuracy: 0.8539
# Epoch 3/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3356 - accuracy: 0.8552 - val_loss: 0.3364 - val_accuracy: 0.8554
# Epoch 4/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3325 - accuracy: 0.8560 - val_loss: 0.3347 - val_accuracy: 0.8564
# Epoch 5/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3304 - accuracy: 0.8569 - val_loss: 0.3347 - val_accuracy: 0.8556
# Epoch 6/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3289 - accuracy: 0.8574 - val_loss: 0.3321 - val_accuracy: 0.8574
# Epoch 7/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3275 - accuracy: 0.8585 - val_loss: 0.3328 - val_accuracy: 0.8580
# Epoch 8/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3261 - accuracy: 0.8590 - val_loss: 0.3309 - val_accuracy: 0.8584
# Epoch 9/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3253 - accuracy: 0.8593 - val_loss: 0.3305 - val_accuracy: 0.8586
# Epoch 10/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3244 - accuracy: 0.8596 - val_loss: 0.3301 - val_accuracy: 0.8588
# Epoch 11/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3233 - accuracy: 0.8602 - val_loss: 0.3302 - val_accuracy: 0.8586
# Epoch 12/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3226 - accuracy: 0.8607 - val_loss: 0.3287 - val_accuracy: 0.8593
# Epoch 13/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3222 - accuracy: 0.8601 - val_loss: 0.3285 - val_accuracy: 0.8585
# Epoch 14/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3214 - accuracy: 0.8608 - val_loss: 0.3286 - val_accuracy: 0.8589
# Epoch 15/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3208 - accuracy: 0.8612 - val_loss: 0.3292 - val_accuracy: 0.8575
# Epoch 16/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3204 - accuracy: 0.8616 - val_loss: 0.3278 - val_accuracy: 0.8592
# Epoch 17/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3197 - accuracy: 0.8615 - val_loss: 0.3299 - val_accuracy: 0.8579
# Epoch 18/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3194 - accuracy: 0.8615 - val_loss: 0.3273 - val_accuracy: 0.8597
# Epoch 19/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3190 - accuracy: 0.8622 - val_loss: 0.3271 - val_accuracy: 0.8593
# Epoch 20/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3187 - accuracy: 0.8620 - val_loss: 0.3266 - val_accuracy: 0.8593
#
# Forming the grid-search model #9 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 21s 200us/sample - loss: 0.3688 - accuracy: 0.8428 - val_loss: 0.3482 - val_accuracy: 0.8494
# Epoch 2/20
# 106644/106644 [==============================] - 21s 197us/sample - loss: 0.3465 - accuracy: 0.8509 - val_loss: 0.3439 - val_accuracy: 0.8525
# Epoch 3/20
# 106644/106644 [==============================] - 21s 196us/sample - loss: 0.3423 - accuracy: 0.8533 - val_loss: 0.3404 - val_accuracy: 0.8546
# Epoch 4/20
# 106644/106644 [==============================] - 22s 209us/sample - loss: 0.3400 - accuracy: 0.8547 - val_loss: 0.3404 - val_accuracy: 0.8552
# Epoch 5/20
# 106644/106644 [==============================] - 21s 201us/sample - loss: 0.3386 - accuracy: 0.8553 - val_loss: 0.3393 - val_accuracy: 0.8559
# Epoch 6/20
# 106644/106644 [==============================] - 21s 195us/sample - loss: 0.3377 - accuracy: 0.8564 - val_loss: 0.3374 - val_accuracy: 0.8579
# Epoch 7/20
# 106644/106644 [==============================] - 21s 195us/sample - loss: 0.3370 - accuracy: 0.8567 - val_loss: 0.3386 - val_accuracy: 0.8575
# Epoch 8/20
# 106644/106644 [==============================] - 22s 202us/sample - loss: 0.3365 - accuracy: 0.8565 - val_loss: 0.3383 - val_accuracy: 0.8582
# Epoch 9/20
# 106644/106644 [==============================] - 22s 204us/sample - loss: 0.3365 - accuracy: 0.8573 - val_loss: 0.3394 - val_accuracy: 0.8569
# Epoch 10/20
# 106644/106644 [==============================] - 21s 200us/sample - loss: 0.3368 - accuracy: 0.8571 - val_loss: 0.3383 - val_accuracy: 0.8566
# Epoch 11/20
# 106644/106644 [==============================] - 21s 196us/sample - loss: 0.3363 - accuracy: 0.8574 - val_loss: 0.3401 - val_accuracy: 0.8568
# Epoch 12/20
# 106644/106644 [==============================] - 21s 193us/sample - loss: 0.3365 - accuracy: 0.8576 - val_loss: 0.3367 - val_accuracy: 0.8582
# Epoch 13/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3360 - accuracy: 0.8580 - val_loss: 0.3390 - val_accuracy: 0.8577
# Epoch 14/20
# 106644/106644 [==============================] - 21s 193us/sample - loss: 0.3358 - accuracy: 0.8582 - val_loss: 0.3440 - val_accuracy: 0.8557
# Epoch 15/20
# 106644/106644 [==============================] - 21s 193us/sample - loss: 0.3359 - accuracy: 0.8578 - val_loss: 0.3383 - val_accuracy: 0.8574
# Epoch 16/20
# 106644/106644 [==============================] - 20s 192us/sample - loss: 0.3363 - accuracy: 0.8581 - val_loss: 0.3404 - val_accuracy: 0.8563
# Epoch 17/20
# 106644/106644 [==============================] - 21s 193us/sample - loss: 0.3357 - accuracy: 0.8580 - val_loss: 0.3433 - val_accuracy: 0.8567
# Epoch 18/20
# 106644/106644 [==============================] - 21s 194us/sample - loss: 0.3361 - accuracy: 0.8578 - val_loss: 0.3416 - val_accuracy: 0.8572
# Epoch 19/20
# 106644/106644 [==============================] - 22s 202us/sample - loss: 0.3357 - accuracy: 0.8579 - val_loss: 0.3372 - val_accuracy: 0.8574
# Epoch 20/20
# 106644/106644 [==============================] - 21s 193us/sample - loss: 0.3358 - accuracy: 0.8581 - val_loss: 0.3374 - val_accuracy: 0.8577
#
# Forming the grid-search model #10 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3766 - accuracy: 0.8413 - val_loss: 0.3496 - val_accuracy: 0.8487
# Epoch 2/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3468 - accuracy: 0.8505 - val_loss: 0.3431 - val_accuracy: 0.8520
# Epoch 3/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3410 - accuracy: 0.8527 - val_loss: 0.3387 - val_accuracy: 0.8543
# Epoch 4/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3377 - accuracy: 0.8547 - val_loss: 0.3375 - val_accuracy: 0.8551
# Epoch 5/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3355 - accuracy: 0.8558 - val_loss: 0.3363 - val_accuracy: 0.8554
# Epoch 6/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3339 - accuracy: 0.8571 - val_loss: 0.3344 - val_accuracy: 0.8565
# Epoch 7/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3325 - accuracy: 0.8577 - val_loss: 0.3342 - val_accuracy: 0.8574
# Epoch 8/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3314 - accuracy: 0.8583 - val_loss: 0.3334 - val_accuracy: 0.8576
# Epoch 9/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3305 - accuracy: 0.8594 - val_loss: 0.3333 - val_accuracy: 0.8582
# Epoch 10/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3299 - accuracy: 0.8595 - val_loss: 0.3322 - val_accuracy: 0.8593
# Epoch 11/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3290 - accuracy: 0.8605 - val_loss: 0.3333 - val_accuracy: 0.8591
# Epoch 12/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3289 - accuracy: 0.8600 - val_loss: 0.3312 - val_accuracy: 0.8606
# Epoch 13/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3284 - accuracy: 0.8603 - val_loss: 0.3318 - val_accuracy: 0.8596
# Epoch 14/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3282 - accuracy: 0.8601 - val_loss: 0.3343 - val_accuracy: 0.8591
# Epoch 15/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3281 - accuracy: 0.8602 - val_loss: 0.3322 - val_accuracy: 0.8595
# Epoch 16/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3280 - accuracy: 0.8599 - val_loss: 0.3313 - val_accuracy: 0.8589
# Epoch 17/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3276 - accuracy: 0.8609 - val_loss: 0.3322 - val_accuracy: 0.8602
# Epoch 18/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3274 - accuracy: 0.8607 - val_loss: 0.3320 - val_accuracy: 0.8607
# Epoch 19/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3273 - accuracy: 0.8610 - val_loss: 0.3316 - val_accuracy: 0.8601
# Epoch 20/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3271 - accuracy: 0.8609 - val_loss: 0.3304 - val_accuracy: 0.8606
#
# Forming the grid-search model #11 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3912 - accuracy: 0.8391 - val_loss: 0.3531 - val_accuracy: 0.8472
# Epoch 2/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3501 - accuracy: 0.8487 - val_loss: 0.3457 - val_accuracy: 0.8513
# Epoch 3/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3436 - accuracy: 0.8512 - val_loss: 0.3405 - val_accuracy: 0.8535
# Epoch 4/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3395 - accuracy: 0.8534 - val_loss: 0.3386 - val_accuracy: 0.8550
# Epoch 5/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.3367 - accuracy: 0.8548 - val_loss: 0.3372 - val_accuracy: 0.8548
# Epoch 6/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3346 - accuracy: 0.8561 - val_loss: 0.3353 - val_accuracy: 0.8560
# Epoch 7/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3329 - accuracy: 0.8569 - val_loss: 0.3339 - val_accuracy: 0.8571
# Epoch 8/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3313 - accuracy: 0.8578 - val_loss: 0.3331 - val_accuracy: 0.8570
# Epoch 9/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3301 - accuracy: 0.8582 - val_loss: 0.3319 - val_accuracy: 0.8576
# Epoch 10/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3286 - accuracy: 0.8591 - val_loss: 0.3306 - val_accuracy: 0.8588
# Epoch 11/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3270 - accuracy: 0.8597 - val_loss: 0.3303 - val_accuracy: 0.8588
# Epoch 12/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3258 - accuracy: 0.8603 - val_loss: 0.3281 - val_accuracy: 0.8605
# Epoch 13/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3246 - accuracy: 0.8604 - val_loss: 0.3277 - val_accuracy: 0.8598
# Epoch 14/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3238 - accuracy: 0.8614 - val_loss: 0.3285 - val_accuracy: 0.8610
# Epoch 15/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3232 - accuracy: 0.8614 - val_loss: 0.3275 - val_accuracy: 0.8611
# Epoch 16/20
# 106644/106644 [==============================] - 6s 54us/sample - loss: 0.3230 - accuracy: 0.8619 - val_loss: 0.3273 - val_accuracy: 0.8611
# Epoch 17/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3224 - accuracy: 0.8621 - val_loss: 0.3278 - val_accuracy: 0.8608
# Epoch 18/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3222 - accuracy: 0.8623 - val_loss: 0.3275 - val_accuracy: 0.8621
# Epoch 19/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3220 - accuracy: 0.8629 - val_loss: 0.3268 - val_accuracy: 0.8611
# Epoch 20/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3218 - accuracy: 0.8623 - val_loss: 0.3261 - val_accuracy: 0.8623
#
# Forming the grid-search model #12 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3655 - accuracy: 0.8422 - val_loss: 0.3466 - val_accuracy: 0.8514
# Epoch 2/20
# 106644/106644 [==============================] - 20s 189us/sample - loss: 0.3457 - accuracy: 0.8508 - val_loss: 0.3440 - val_accuracy: 0.8529
# Epoch 3/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3422 - accuracy: 0.8528 - val_loss: 0.3403 - val_accuracy: 0.8552
# Epoch 4/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3403 - accuracy: 0.8543 - val_loss: 0.3410 - val_accuracy: 0.8546
# Epoch 5/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3390 - accuracy: 0.8553 - val_loss: 0.3398 - val_accuracy: 0.8549
# Epoch 6/20
# 106644/106644 [==============================] - 20s 189us/sample - loss: 0.3384 - accuracy: 0.8552 - val_loss: 0.3388 - val_accuracy: 0.8558
# Epoch 7/20
# 106644/106644 [==============================] - 20s 186us/sample - loss: 0.3377 - accuracy: 0.8565 - val_loss: 0.3395 - val_accuracy: 0.8564
# Epoch 8/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3367 - accuracy: 0.8564 - val_loss: 0.3381 - val_accuracy: 0.8566
# Epoch 9/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3357 - accuracy: 0.8573 - val_loss: 0.3372 - val_accuracy: 0.8578
# Epoch 10/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3351 - accuracy: 0.8574 - val_loss: 0.3355 - val_accuracy: 0.8582
# Epoch 11/20
# 106644/106644 [==============================] - 20s 187us/sample - loss: 0.3343 - accuracy: 0.8581 - val_loss: 0.3371 - val_accuracy: 0.8575
# Epoch 12/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3346 - accuracy: 0.8581 - val_loss: 0.3347 - val_accuracy: 0.8588
# Epoch 13/20
# 106644/106644 [==============================] - 20s 191us/sample - loss: 0.3345 - accuracy: 0.8581 - val_loss: 0.3369 - val_accuracy: 0.8577
# Epoch 14/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3343 - accuracy: 0.8583 - val_loss: 0.3428 - val_accuracy: 0.8561
# Epoch 15/20
# 106644/106644 [==============================] - 21s 198us/sample - loss: 0.3347 - accuracy: 0.8578 - val_loss: 0.3379 - val_accuracy: 0.8576
# Epoch 16/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3352 - accuracy: 0.8581 - val_loss: 0.3389 - val_accuracy: 0.8574
# Epoch 17/20
# 106644/106644 [==============================] - 20s 190us/sample - loss: 0.3349 - accuracy: 0.8587 - val_loss: 0.3421 - val_accuracy: 0.8568
# Epoch 18/20
# 106644/106644 [==============================] - 20s 188us/sample - loss: 0.3355 - accuracy: 0.8580 - val_loss: 0.3416 - val_accuracy: 0.8571
# Epoch 19/20
# 106644/106644 [==============================] - 20s 189us/sample - loss: 0.3351 - accuracy: 0.8586 - val_loss: 0.3369 - val_accuracy: 0.8574
# Epoch 20/20
# 106644/106644 [==============================] - 20s 192us/sample - loss: 0.3353 - accuracy: 0.8585 - val_loss: 0.3369 - val_accuracy: 0.8572
#
# Forming the grid-search model #13 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 98us/sample - loss: 0.3712 - accuracy: 0.8400 - val_loss: 0.3475 - val_accuracy: 0.8504
# Epoch 2/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3455 - accuracy: 0.8510 - val_loss: 0.3427 - val_accuracy: 0.8527
# Epoch 3/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3403 - accuracy: 0.8529 - val_loss: 0.3384 - val_accuracy: 0.8543
# Epoch 4/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3370 - accuracy: 0.8546 - val_loss: 0.3365 - val_accuracy: 0.8552
# Epoch 5/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3342 - accuracy: 0.8564 - val_loss: 0.3346 - val_accuracy: 0.8559
# Epoch 6/20
# 106644/106644 [==============================] - 10s 97us/sample - loss: 0.3317 - accuracy: 0.8581 - val_loss: 0.3321 - val_accuracy: 0.8584
# Epoch 7/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3300 - accuracy: 0.8591 - val_loss: 0.3320 - val_accuracy: 0.8584
# Epoch 8/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3292 - accuracy: 0.8592 - val_loss: 0.3319 - val_accuracy: 0.8586
# Epoch 9/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3288 - accuracy: 0.8599 - val_loss: 0.3320 - val_accuracy: 0.8589
# Epoch 10/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3288 - accuracy: 0.8599 - val_loss: 0.3315 - val_accuracy: 0.8592
# Epoch 11/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3283 - accuracy: 0.8599 - val_loss: 0.3327 - val_accuracy: 0.8592
# Epoch 12/20
# 106644/106644 [==============================] - 10s 93us/sample - loss: 0.3282 - accuracy: 0.8597 - val_loss: 0.3309 - val_accuracy: 0.8601
# Epoch 13/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3280 - accuracy: 0.8608 - val_loss: 0.3312 - val_accuracy: 0.8596
# Epoch 14/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3278 - accuracy: 0.8602 - val_loss: 0.3340 - val_accuracy: 0.8585
# Epoch 15/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3276 - accuracy: 0.8601 - val_loss: 0.3321 - val_accuracy: 0.8589
# Epoch 16/20
# 106644/106644 [==============================] - 10s 95us/sample - loss: 0.3276 - accuracy: 0.8605 - val_loss: 0.3314 - val_accuracy: 0.8583
# Epoch 17/20
# 106644/106644 [==============================] - 10s 96us/sample - loss: 0.3273 - accuracy: 0.8609 - val_loss: 0.3320 - val_accuracy: 0.8581
# Epoch 18/20
# 106644/106644 [==============================] - 10s 94us/sample - loss: 0.3273 - accuracy: 0.8601 - val_loss: 0.3312 - val_accuracy: 0.8608
# Epoch 19/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3271 - accuracy: 0.8606 - val_loss: 0.3304 - val_accuracy: 0.8590
# Epoch 20/20
# 106644/106644 [==============================] - 11s 99us/sample - loss: 0.3271 - accuracy: 0.8610 - val_loss: 0.3292 - val_accuracy: 0.8600
#
# Forming the grid-search model #14 using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 52us/sample - loss: 0.3825 - accuracy: 0.8367 - val_loss: 0.3499 - val_accuracy: 0.8503
# Epoch 2/20
# ...
# Epoch 7/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3469 - accuracy: 0.8498 - val_loss: 0.3460 - val_accuracy: 0.8516
# Epoch 8/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3451 - accuracy: 0.8508 - val_loss: 0.3446 - val_accuracy: 0.8527
# Epoch 9/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3437 - accuracy: 0.8516 - val_loss: 0.3436 - val_accuracy: 0.8529
# Epoch 10/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3425 - accuracy: 0.8522 - val_loss: 0.3425 - val_accuracy: 0.8526
# Epoch 11/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3414 - accuracy: 0.8527 - val_loss: 0.3419 - val_accuracy: 0.8541
# Epoch 12/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3405 - accuracy: 0.8533 - val_loss: 0.3408 - val_accuracy: 0.8542
# Epoch 13/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3396 - accuracy: 0.8533 - val_loss: 0.3402 - val_accuracy: 0.8540
# Epoch 14/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3387 - accuracy: 0.8542 - val_loss: 0.3398 - val_accuracy: 0.8546
# Epoch 15/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3379 - accuracy: 0.8542 - val_loss: 0.3397 - val_accuracy: 0.8534
# Epoch 16/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3372 - accuracy: 0.8542 - val_loss: 0.3390 - val_accuracy: 0.8536
# Epoch 17/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3365 - accuracy: 0.8547 - val_loss: 0.3389 - val_accuracy: 0.8549
# Epoch 18/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3359 - accuracy: 0.8548 - val_loss: 0.3379 - val_accuracy: 0.8552
# Epoch 19/20
# 106644/106644 [==============================] - 10s 90us/sample - loss: 0.3352 - accuracy: 0.8548 - val_loss: 0.3374 - val_accuracy: 0.8552
# Epoch 20/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3347 - accuracy: 0.8553 - val_loss: 0.3368 - val_accuracy: 0.8554
#
# Forming the grid-search model #23 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7fc0442a0550>, kernel=<tensorflow.python.ops.init_ops_v2.Orthogonal object at 0x7fc0442a0b70>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.4277 - accuracy: 0.8202 - val_loss: 0.3779 - val_accuracy: 0.8373
# Epoch 2/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3741 - accuracy: 0.8376 - val_loss: 0.3693 - val_accuracy: 0.8405
# Epoch 3/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3679 - accuracy: 0.8405 - val_loss: 0.3643 - val_accuracy: 0.8431
# Epoch 4/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3637 - accuracy: 0.8425 - val_loss: 0.3607 - val_accuracy: 0.8448
# Epoch 5/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3605 - accuracy: 0.8435 - val_loss: 0.3580 - val_accuracy: 0.8465
# Epoch 6/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3578 - accuracy: 0.8452 - val_loss: 0.3557 - val_accuracy: 0.8466
# Epoch 7/20
# 106644/106644 [==============================] - 5s 47us/sample - loss: 0.3556 - accuracy: 0.8458 - val_loss: 0.3536 - val_accuracy: 0.8479
# Epoch 8/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3536 - accuracy: 0.8467 - val_loss: 0.3521 - val_accuracy: 0.8481
# Epoch 9/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3519 - accuracy: 0.8474 - val_loss: 0.3507 - val_accuracy: 0.8489
# Epoch 10/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3505 - accuracy: 0.8482 - val_loss: 0.3494 - val_accuracy: 0.8498
# Epoch 11/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3491 - accuracy: 0.8489 - val_loss: 0.3484 - val_accuracy: 0.8507
# Epoch 12/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3480 - accuracy: 0.8498 - val_loss: 0.3475 - val_accuracy: 0.8510
# Epoch 13/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3470 - accuracy: 0.8498 - val_loss: 0.3465 - val_accuracy: 0.8520
# Epoch 14/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3460 - accuracy: 0.8506 - val_loss: 0.3458 - val_accuracy: 0.8518
# Epoch 15/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3451 - accuracy: 0.8510 - val_loss: 0.3453 - val_accuracy: 0.8518
# Epoch 16/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3444 - accuracy: 0.8513 - val_loss: 0.3447 - val_accuracy: 0.8526
# Epoch 17/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3437 - accuracy: 0.8517 - val_loss: 0.3441 - val_accuracy: 0.8535
# Epoch 18/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3429 - accuracy: 0.8520 - val_loss: 0.3435 - val_accuracy: 0.8530
# Epoch 19/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3423 - accuracy: 0.8522 - val_loss: 0.3429 - val_accuracy: 0.8534
# Epoch 20/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3417 - accuracy: 0.8527 - val_loss: 0.3424 - val_accuracy: 0.8536
#
# Forming the grid-search model #24 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7fc0442a0550>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=16
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 20s 186us/sample - loss: 0.3856 - accuracy: 0.8327 - val_loss: 0.3614 - val_accuracy: 0.8440
# Epoch 2/20
# 106644/106644 [==============================] - 19s 175us/sample - loss: 0.3576 - accuracy: 0.8446 - val_loss: 0.3530 - val_accuracy: 0.8480
# Epoch 3/20
# 106644/106644 [==============================] - 19s 177us/sample - loss: 0.3507 - accuracy: 0.8478 - val_loss: 0.3475 - val_accuracy: 0.8495
# Epoch 4/20
# 106644/106644 [==============================] - 19s 175us/sample - loss: 0.3467 - accuracy: 0.8497 - val_loss: 0.3453 - val_accuracy: 0.8505
# Epoch 5/20
# 106644/106644 [==============================] - 18s 173us/sample - loss: 0.3441 - accuracy: 0.8508 - val_loss: 0.3440 - val_accuracy: 0.8518
# Epoch 6/20
# 106644/106644 [==============================] - 18s 173us/sample - loss: 0.3423 - accuracy: 0.8521 - val_loss: 0.3418 - val_accuracy: 0.8537
# Epoch 7/20
# 106644/106644 [==============================] - 18s 173us/sample - loss: 0.3408 - accuracy: 0.8531 - val_loss: 0.3414 - val_accuracy: 0.8538
# Epoch 8/20
# 106644/106644 [==============================] - 18s 173us/sample - loss: 0.3393 - accuracy: 0.8532 - val_loss: 0.3405 - val_accuracy: 0.8538
# Epoch 9/20
# 106644/106644 [==============================] - 19s 174us/sample - loss: 0.3382 - accuracy: 0.8542 - val_loss: 0.3396 - val_accuracy: 0.8540
# Epoch 10/20
# 106644/106644 [==============================] - 19s 174us/sample - loss: 0.3372 - accuracy: 0.8550 - val_loss: 0.3385 - val_accuracy: 0.8544
# Epoch 11/20
# 106644/106644 [==============================] - 18s 172us/sample - loss: 0.3362 - accuracy: 0.8547 - val_loss: 0.3384 - val_accuracy: 0.8543
# Epoch 12/20
# 106644/106644 [==============================] - 19s 176us/sample - loss: 0.3353 - accuracy: 0.8556 - val_loss: 0.3365 - val_accuracy: 0.8554
# Epoch 13/20
# 106644/106644 [==============================] - 18s 173us/sample - loss: 0.3344 - accuracy: 0.8559 - val_loss: 0.3363 - val_accuracy: 0.8565
# Epoch 14/20
# 106644/106644 [==============================] - 19s 176us/sample - loss: 0.3335 - accuracy: 0.8562 - val_loss: 0.3372 - val_accuracy: 0.8559
# Epoch 15/20
# 106644/106644 [==============================] - 19s 180us/sample - loss: 0.3328 - accuracy: 0.8562 - val_loss: 0.3366 - val_accuracy: 0.8549
# Epoch 16/20
# 106644/106644 [==============================] - 19s 175us/sample - loss: 0.3321 - accuracy: 0.8570 - val_loss: 0.3357 - val_accuracy: 0.8547
# Epoch 17/20
# 106644/106644 [==============================] - 19s 178us/sample - loss: 0.3312 - accuracy: 0.8572 - val_loss: 0.3353 - val_accuracy: 0.8573
# Epoch 18/20
# 106644/106644 [==============================] - 20s 183us/sample - loss: 0.3306 - accuracy: 0.8571 - val_loss: 0.3354 - val_accuracy: 0.8568
# Epoch 19/20
# 106644/106644 [==============================] - 18s 172us/sample - loss: 0.3301 - accuracy: 0.8573 - val_loss: 0.3336 - val_accuracy: 0.8566
# Epoch 20/20
# 106644/106644 [==============================] - 19s 176us/sample - loss: 0.3296 - accuracy: 0.8580 - val_loss: 0.3330 - val_accuracy: 0.8566
#
# Forming the grid-search model #25 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7fc0442a0550>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=32
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 10s 89us/sample - loss: 0.4033 - accuracy: 0.8246 - val_loss: 0.3710 - val_accuracy: 0.8398
# Epoch 2/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3668 - accuracy: 0.8406 - val_loss: 0.3616 - val_accuracy: 0.8436
# Epoch 3/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3595 - accuracy: 0.8436 - val_loss: 0.3558 - val_accuracy: 0.8468
# Epoch 4/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3548 - accuracy: 0.8462 - val_loss: 0.3524 - val_accuracy: 0.8483
# Epoch 5/20
# 106644/106644 [==============================] - 9s 86us/sample - loss: 0.3516 - accuracy: 0.8474 - val_loss: 0.3498 - val_accuracy: 0.8487
# Epoch 6/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3490 - accuracy: 0.8481 - val_loss: 0.3474 - val_accuracy: 0.8504
# Epoch 7/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3469 - accuracy: 0.8495 - val_loss: 0.3457 - val_accuracy: 0.8518
# Epoch 8/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3451 - accuracy: 0.8509 - val_loss: 0.3445 - val_accuracy: 0.8521
# Epoch 9/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3438 - accuracy: 0.8512 - val_loss: 0.3436 - val_accuracy: 0.8513
# Epoch 10/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3427 - accuracy: 0.8518 - val_loss: 0.3427 - val_accuracy: 0.8530
# Epoch 11/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3418 - accuracy: 0.8523 - val_loss: 0.3423 - val_accuracy: 0.8527
# Epoch 12/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3410 - accuracy: 0.8526 - val_loss: 0.3414 - val_accuracy: 0.8532
# Epoch 13/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3402 - accuracy: 0.8533 - val_loss: 0.3407 - val_accuracy: 0.8539
# Epoch 14/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3395 - accuracy: 0.8535 - val_loss: 0.3407 - val_accuracy: 0.8537
# Epoch 15/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3387 - accuracy: 0.8541 - val_loss: 0.3405 - val_accuracy: 0.8536
# Epoch 16/20
# 106644/106644 [==============================] - 9s 87us/sample - loss: 0.3382 - accuracy: 0.8540 - val_loss: 0.3398 - val_accuracy: 0.8540
# Epoch 17/20
# 106644/106644 [==============================] - 9s 88us/sample - loss: 0.3375 - accuracy: 0.8543 - val_loss: 0.3400 - val_accuracy: 0.8537
# Epoch 18/20
# 106644/106644 [==============================] - 10s 89us/sample - loss: 0.3370 - accuracy: 0.8548 - val_loss: 0.3389 - val_accuracy: 0.8550
# Epoch 19/20
# 106644/106644 [==============================] - 9s 89us/sample - loss: 0.3364 - accuracy: 0.8555 - val_loss: 0.3381 - val_accuracy: 0.8544
# Epoch 20/20
# 106644/106644 [==============================] - 9s 86us/sample - loss: 0.3359 - accuracy: 0.8555 - val_loss: 0.3378 - val_accuracy: 0.8552
#
# Forming the grid-search model #26 using: optimizer=<tensorflow.python.keras.optimizer_v2.gradient_descent.SGD object at 0x7fc0442a0550>, kernel=<tensorflow.python.ops.init_ops_v2.GlorotNormal object at 0x7fc0442a0208>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 46us/sample - loss: 0.4298 - accuracy: 0.8125 - val_loss: 0.3822 - val_accuracy: 0.8341
# Epoch 2/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3766 - accuracy: 0.8358 - val_loss: 0.3710 - val_accuracy: 0.8393
# Epoch 3/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3690 - accuracy: 0.8397 - val_loss: 0.3652 - val_accuracy: 0.8424
# Epoch 4/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3643 - accuracy: 0.8419 - val_loss: 0.3613 - val_accuracy: 0.8437
# Epoch 5/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3607 - accuracy: 0.8432 - val_loss: 0.3583 - val_accuracy: 0.8455
# Epoch 6/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3578 - accuracy: 0.8444 - val_loss: 0.3557 - val_accuracy: 0.8474
# Epoch 7/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3555 - accuracy: 0.8454 - val_loss: 0.3536 - val_accuracy: 0.8484
# Epoch 8/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3535 - accuracy: 0.8465 - val_loss: 0.3521 - val_accuracy: 0.8486
# Epoch 9/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3519 - accuracy: 0.8468 - val_loss: 0.3506 - val_accuracy: 0.8491
# Epoch 10/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3505 - accuracy: 0.8478 - val_loss: 0.3493 - val_accuracy: 0.8494
# Epoch 11/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3492 - accuracy: 0.8482 - val_loss: 0.3482 - val_accuracy: 0.8501
# Epoch 12/20
# 106644/106644 [==============================] - 5s 45us/sample - loss: 0.3480 - accuracy: 0.8488 - val_loss: 0.3472 - val_accuracy: 0.8506
# Epoch 13/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3469 - accuracy: 0.8491 - val_loss: 0.3463 - val_accuracy: 0.8509
# Epoch 14/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3460 - accuracy: 0.8499 - val_loss: 0.3456 - val_accuracy: 0.8512
# Epoch 15/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3450 - accuracy: 0.8502 - val_loss: 0.3450 - val_accuracy: 0.8512
# Epoch 16/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3443 - accuracy: 0.8508 - val_loss: 0.3444 - val_accuracy: 0.8512
# Epoch 17/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3437 - accuracy: 0.8513 - val_loss: 0.3441 - val_accuracy: 0.8519
# Epoch 18/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3430 - accuracy: 0.8515 - val_loss: 0.3434 - val_accuracy: 0.8520
# Epoch 19/20
# 106644/106644 [==============================] - 5s 44us/sample - loss: 0.3425 - accuracy: 0.8518 - val_loss: 0.3429 - val_accuracy: 0.8525
# Epoch 20/20
# 106644/106644 [==============================] - 5s 43us/sample - loss: 0.3420 - accuracy: 0.8522 - val_loss: 0.3426 - val_accuracy: 0.8525
#
# Best score (highest validation accuracy) found via grid search: accuracy=0.862275 from model iteration #11
# The best modeling parameters are: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=64
# Total time for performing grid-search of the best parameters: 1:43:41.406790

# %%
if (notifyStatus): email_notify("Model Tuning and Imprvement completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %% [markdown]
# ## Section 6. Finalize Model

# %%
if (notifyStatus): email_notify("Model Validation and Final Model Creation has begun! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
best_optimizer = optz_2
best_kernel_init = init_1
best_epoch = 20
best_batch = 64

# %%
# Create the final model for evaluating the test dataset
print('Forming the final model using: optimizer=%s, kernel=%s, epochs=%d, batch_size=%d'
      % (best_optimizer, best_kernel_init, best_epoch, best_batch))
reset_random(seedNum)
final_model = create_customized_model(best_optimizer, best_kernel_init)
final_hist = final_model.fit(X_train, y_train, epochs=best_epoch, batch_size=best_batch, validation_data=(X_test, y_test), verbose=1)
# Out:
# Forming the final model using: optimizer=<tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop object at 0x7fc0442a0d30>, kernel=<tensorflow.python.ops.init_ops_v2.RandomNormal object at 0x7fc0442a0c18>, epochs=20, batch_size=64
# Train on 106644 samples, validate on 35549 samples
# Epoch 1/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3912 - accuracy: 0.8391 - val_loss: 0.3531 - val_accuracy: 0.8472
# Epoch 2/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3501 - accuracy: 0.8487 - val_loss: 0.3457 - val_accuracy: 0.8513
# Epoch 3/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3436 - accuracy: 0.8512 - val_loss: 0.3405 - val_accuracy: 0.8535
# Epoch 4/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3395 - accuracy: 0.8534 - val_loss: 0.3386 - val_accuracy: 0.8550
# Epoch 5/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3367 - accuracy: 0.8548 - val_loss: 0.3372 - val_accuracy: 0.8548
# Epoch 6/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3346 - accuracy: 0.8561 - val_loss: 0.3353 - val_accuracy: 0.8560
# Epoch 7/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3329 - accuracy: 0.8569 - val_loss: 0.3339 - val_accuracy: 0.8571
# Epoch 8/20
# 106644/106644 [==============================] - 5s 48us/sample - loss: 0.3313 - accuracy: 0.8578 - val_loss: 0.3331 - val_accuracy: 0.8570
# Epoch 9/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3301 - accuracy: 0.8582 - val_loss: 0.3319 - val_accuracy: 0.8576
# Epoch 10/20
# 106644/106644 [==============================] - 5s 51us/sample - loss: 0.3286 - accuracy: 0.8591 - val_loss: 0.3306 - val_accuracy: 0.8588
# Epoch 11/20
# 106644/106644 [==============================] - 6s 52us/sample - loss: 0.3270 - accuracy: 0.8597 - val_loss: 0.3303 - val_accuracy: 0.8588
# Epoch 12/20
# 106644/106644 [==============================] - 6s 54us/sample - loss: 0.3258 - accuracy: 0.8603 - val_loss: 0.3281 - val_accuracy: 0.8605
# Epoch 13/20
# 106644/106644 [==============================] - 6s 54us/sample - loss: 0.3246 - accuracy: 0.8604 - val_loss: 0.3277 - val_accuracy: 0.8598
# Epoch 14/20
# 106644/106644 [==============================] - 6s 52us/sample - loss: 0.3238 - accuracy: 0.8614 - val_loss: 0.3285 - val_accuracy: 0.8610
# Epoch 15/20
# 106644/106644 [==============================] - 6s 53us/sample - loss: 0.3232 - accuracy: 0.8614 - val_loss: 0.3275 - val_accuracy: 0.8611
# Epoch 16/20
# 106644/106644 [==============================] - 6s 52us/sample - loss: 0.3230 - accuracy: 0.8619 - val_loss: 0.3273 - val_accuracy: 0.8611
# Epoch 17/20
# 106644/106644 [==============================] - 5s 49us/sample - loss: 0.3224 - accuracy: 0.8621 - val_loss: 0.3278 - val_accuracy: 0.8608
# Epoch 18/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3222 - accuracy: 0.8623 - val_loss: 0.3275 - val_accuracy: 0.8621
# Epoch 19/20
# 106644/106644 [==============================] - 6s 53us/sample - loss: 0.3220 - accuracy: 0.8629 - val_loss: 0.3268 - val_accuracy: 0.8611
# Epoch 20/20
# 106644/106644 [==============================] - 5s 50us/sample - loss: 0.3218 - accuracy: 0.8623 - val_loss: 0.3261 - val_accuracy: 0.8623

# %%
# Summarize training hisotry for the final model
fig, axs = plt.subplots(2, 1, figsize=(12,12))
plt.subplot(211)
plt.plot(final_hist.history['accuracy'], color='blue', label='train')
plt.plot(final_hist.history['val_accuracy'], color='red', label='test')
plt.title('Final Model Training Performance (Accuracy)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.subplot(212)
plt.plot(final_hist.history['loss'], color='blue', label='train')
plt.plot(final_hist.history['val_loss'], color='red', label='test')
plt.title('Final Model Training Performance (Loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Display a summary of the final model
print(final_model.summary())
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 8)                 952
# _________________________________________________________________
# dense_57 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 961
# Trainable params: 961
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Display the configuration of the final model
print(final_model.get_config())
# Out:
# {'name': 'sequential_28', 'layers': [{'class_name': 'Dense', 'config': {'name': 'dense_56', 'trainable': True, 'batch_input_shape': (None, 118), 'dtype': 'float32', 'units': 8, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}, {'class_name': 'Dense', 'config': {'name': 'dense_57', 'trainable': True, 'dtype': 'float32', 'units': 1, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.05, 'seed': 888}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}

# %%
if (notifyStatus): email_notify("Model Validation and Final Model Creation completed! "+datetime.now().strftime('%a %B %d, %Y %I:%M:%S %p'))

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 2:14:49.556540
